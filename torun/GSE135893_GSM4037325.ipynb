# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/torun/GSE135893_GSM4037325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE135893_GSM4037325

# %%
# define the values for the analysis

# accession id for the data
id = "GSE135893"
samp_id = ["GSM4037325"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet

  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["None"] * no_samples

condition = ["healthy"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 35.4MB 1.4MB/s
#      |████████████████████████████████| 122kB 47.2MB/s
#      |████████████████████████████████| 51kB 6.3MB/s
#      |████████████████████████████████| 112kB 42.8MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#      |████████████████████████████████| 7.7MB 5.0MB/s
#      |████████████████████████████████| 61kB 6.9MB/s
#      |████████████████████████████████| 51kB 6.2MB/s
#   Building wheel for sinfo (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2020-11-18 17:43:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_1.fastq.gz
#            => ‘SRR9985509_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985509 ... done.
# ==> SIZE SRR9985509_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985509_1.fastq.gz ... done.
#
# SRR9985509_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:43:50 (0.00 B/s) - ‘SRR9985509_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:43:50--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_2.fastq.gz
#            => ‘SRR9985509_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985509 ... done.
# ==> SIZE SRR9985509_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985509_2.fastq.gz ... done.
#
# SRR9985509_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:43:52 (0.00 B/s) - ‘SRR9985509_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:43:52--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_1.fastq.gz
#            => ‘SRR9985505_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985505 ... done.
# ==> SIZE SRR9985505_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985505_1.fastq.gz ... done.
#
# SRR9985505_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:43:53 (0.00 B/s) - ‘SRR9985505_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:43:53--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_2.fastq.gz
#            => ‘SRR9985505_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985505 ... done.
# ==> SIZE SRR9985505_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985505_2.fastq.gz ... done.
#
# SRR9985505_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:43:55 (0.00 B/s) - ‘SRR9985505_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:43:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_1.fastq.gz
#            => ‘SRR9985503_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985503 ... done.
# ==> SIZE SRR9985503_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985503_1.fastq.gz ... done.
#
# SRR9985503_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:43:56 (0.00 B/s) - ‘SRR9985503_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:43:56--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_2.fastq.gz
#            => ‘SRR9985503_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985503 ... done.
# ==> SIZE SRR9985503_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985503_2.fastq.gz ... done.
#
# SRR9985503_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:43:58 (0.00 B/s) - ‘SRR9985503_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:43:58--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_1.fastq.gz
#            => ‘SRR9985506_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985506 ... done.
# ==> SIZE SRR9985506_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985506_1.fastq.gz ... done.
#
# SRR9985506_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:43:59 (0.00 B/s) - ‘SRR9985506_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:43:59--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_2.fastq.gz
#            => ‘SRR9985506_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985506 ... done.
# ==> SIZE SRR9985506_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985506_2.fastq.gz ... done.
#
# SRR9985506_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:01 (0.00 B/s) - ‘SRR9985506_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:01--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_1.fastq.gz
#            => ‘SRR9985507_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985507 ... done.
# ==> SIZE SRR9985507_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985507_1.fastq.gz ... done.
#
# SRR9985507_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:03 (0.00 B/s) - ‘SRR9985507_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:03--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_2.fastq.gz
#            => ‘SRR9985507_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985507 ... done.
# ==> SIZE SRR9985507_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985507_2.fastq.gz ... done.
#
# SRR9985507_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:05 (0.00 B/s) - ‘SRR9985507_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:05--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_1.fastq.gz
#            => ‘SRR9985504_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985504 ... done.
# ==> SIZE SRR9985504_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985504_1.fastq.gz ... done.
#
# SRR9985504_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:06 (0.00 B/s) - ‘SRR9985504_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:06--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_2.fastq.gz
#            => ‘SRR9985504_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985504 ... done.
# ==> SIZE SRR9985504_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985504_2.fastq.gz ... done.
#
# SRR9985504_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:08 (0.00 B/s) - ‘SRR9985504_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:08--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_1.fastq.gz
#            => ‘SRR9985502_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985502 ... done.
# ==> SIZE SRR9985502_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985502_1.fastq.gz ... done.
#
# SRR9985502_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:09 (0.00 B/s) - ‘SRR9985502_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:09--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_2.fastq.gz
#            => ‘SRR9985502_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985502 ... done.
# ==> SIZE SRR9985502_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985502_2.fastq.gz ... done.
#
# SRR9985502_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:11 (0.00 B/s) - ‘SRR9985502_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_1.fastq.gz
#            => ‘SRR9985500_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985500 ... done.
# ==> SIZE SRR9985500_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985500_1.fastq.gz ... done.
#
# SRR9985500_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:12 (0.00 B/s) - ‘SRR9985500_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:12--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_2.fastq.gz
#            => ‘SRR9985500_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985500 ... done.
# ==> SIZE SRR9985500_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985500_2.fastq.gz ... done.
#
# SRR9985500_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:13 (0.00 B/s) - ‘SRR9985500_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:14--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_1.fastq.gz
#            => ‘SRR9985499_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985499 ... done.
# ==> SIZE SRR9985499_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985499_1.fastq.gz ... done.
#
# SRR9985499_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:15 (0.00 B/s) - ‘SRR9985499_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:15--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_2.fastq.gz
#            => ‘SRR9985499_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985499 ... done.
# ==> SIZE SRR9985499_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985499_2.fastq.gz ... done.
#
# SRR9985499_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:16 (0.00 B/s) - ‘SRR9985499_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:17--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_1.fastq.gz
#            => ‘SRR9985501_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985501 ... done.
# ==> SIZE SRR9985501_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985501_1.fastq.gz ... done.
#
# SRR9985501_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:18 (0.00 B/s) - ‘SRR9985501_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:18--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_2.fastq.gz
#            => ‘SRR9985501_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985501 ... done.
# ==> SIZE SRR9985501_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985501_2.fastq.gz ... done.
#
# SRR9985501_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:19 (0.00 B/s) - ‘SRR9985501_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:19--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_1.fastq.gz
#            => ‘SRR9985498_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985498 ... done.
# ==> SIZE SRR9985498_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985498_1.fastq.gz ... done.
#
# SRR9985498_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:21 (0.00 B/s) - ‘SRR9985498_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:21--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_2.fastq.gz
#            => ‘SRR9985498_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985498 ... done.
# ==> SIZE SRR9985498_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985498_2.fastq.gz ... done.
#
# SRR9985498_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:22 (0.00 B/s) - ‘SRR9985498_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:22--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_1.fastq.gz
#            => ‘SRR9985495_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985495 ... done.
# ==> SIZE SRR9985495_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985495_1.fastq.gz ... done.
#
# SRR9985495_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:24 (0.00 B/s) - ‘SRR9985495_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:24--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_2.fastq.gz
#            => ‘SRR9985495_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985495 ... done.
# ==> SIZE SRR9985495_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985495_2.fastq.gz ... done.
#
# SRR9985495_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:25 (0.00 B/s) - ‘SRR9985495_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:25--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_1.fastq.gz
#            => ‘SRR9985497_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985497 ... done.
# ==> SIZE SRR9985497_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985497_1.fastq.gz ... done.
#
# SRR9985497_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:26 (0.00 B/s) - ‘SRR9985497_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:26--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_2.fastq.gz
#            => ‘SRR9985497_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985497 ... done.
# ==> SIZE SRR9985497_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985497_2.fastq.gz ... done.
#
# SRR9985497_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:28 (0.00 B/s) - ‘SRR9985497_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:28--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_1.fastq.gz
#            => ‘SRR9985496_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985496 ... done.
# ==> SIZE SRR9985496_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985496_1.fastq.gz ... done.
#
# SRR9985496_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:29 (0.00 B/s) - ‘SRR9985496_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:29--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_2.fastq.gz
#            => ‘SRR9985496_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985496 ... done.
# ==> SIZE SRR9985496_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985496_2.fastq.gz ... done.
#
# SRR9985496_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:31 (0.00 B/s) - ‘SRR9985496_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:31--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_1.fastq.gz
#            => ‘SRR9985516_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985516 ... done.
# ==> SIZE SRR9985516_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985516_1.fastq.gz ... done.
#
# SRR9985516_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:32 (0.00 B/s) - ‘SRR9985516_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:33--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_2.fastq.gz
#            => ‘SRR9985516_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985516 ... done.
# ==> SIZE SRR9985516_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985516_2.fastq.gz ... done.
#
# SRR9985516_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:34 (0.00 B/s) - ‘SRR9985516_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:34--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_1.fastq.gz
#            => ‘SRR9985517_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985517 ... done.
# ==> SIZE SRR9985517_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985517_1.fastq.gz ... done.
#
# SRR9985517_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:35 (0.00 B/s) - ‘SRR9985517_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:35--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_2.fastq.gz
#            => ‘SRR9985517_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985517 ... done.
# ==> SIZE SRR9985517_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985517_2.fastq.gz ... done.
#
# SRR9985517_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:37 (0.00 B/s) - ‘SRR9985517_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:37--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_1.fastq.gz
#            => ‘SRR9985518_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985518 ... done.
# ==> SIZE SRR9985518_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985518_1.fastq.gz ... done.
#
# SRR9985518_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:38 (0.00 B/s) - ‘SRR9985518_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:38--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_2.fastq.gz
#            => ‘SRR9985518_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985518 ... done.
# ==> SIZE SRR9985518_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985518_2.fastq.gz ... done.
#
# SRR9985518_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:40 (0.00 B/s) - ‘SRR9985518_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:40--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_1.fastq.gz
#            => ‘SRR9985511_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985511 ... done.
# ==> SIZE SRR9985511_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985511_1.fastq.gz ... done.
#
# SRR9985511_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:42 (0.00 B/s) - ‘SRR9985511_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:42--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_2.fastq.gz
#            => ‘SRR9985511_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985511 ... done.
# ==> SIZE SRR9985511_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985511_2.fastq.gz ... done.
#
# SRR9985511_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:44 (0.00 B/s) - ‘SRR9985511_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:44--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_1.fastq.gz
#            => ‘SRR9985515_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985515 ... done.
# ==> SIZE SRR9985515_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985515_1.fastq.gz ... done.
#
# SRR9985515_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:45 (0.00 B/s) - ‘SRR9985515_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:45--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_2.fastq.gz
#            => ‘SRR9985515_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985515 ... done.
# ==> SIZE SRR9985515_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985515_2.fastq.gz ... done.
#
# SRR9985515_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:46 (0.00 B/s) - ‘SRR9985515_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:47--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_1.fastq.gz
#            => ‘SRR9985514_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985514 ... done.
# ==> SIZE SRR9985514_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985514_1.fastq.gz ... done.
#
# SRR9985514_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:48 (0.00 B/s) - ‘SRR9985514_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:48--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_2.fastq.gz
#            => ‘SRR9985514_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985514 ... done.
# ==> SIZE SRR9985514_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985514_2.fastq.gz ... done.
#
# SRR9985514_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:49 (0.00 B/s) - ‘SRR9985514_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_1.fastq.gz
#            => ‘SRR9985512_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985512 ... done.
# ==> SIZE SRR9985512_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985512_1.fastq.gz ... done.
#
# SRR9985512_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:51 (0.00 B/s) - ‘SRR9985512_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:51--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_2.fastq.gz
#            => ‘SRR9985512_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985512 ... done.
# ==> SIZE SRR9985512_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985512_2.fastq.gz ... done.
#
# SRR9985512_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:52 (0.00 B/s) - ‘SRR9985512_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:52--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_1.fastq.gz
#            => ‘SRR9985510_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985510 ... done.
# ==> SIZE SRR9985510_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985510_1.fastq.gz ... done.
#
# SRR9985510_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:53 (0.00 B/s) - ‘SRR9985510_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:53--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_2.fastq.gz
#            => ‘SRR9985510_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985510 ... done.
# ==> SIZE SRR9985510_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985510_2.fastq.gz ... done.
#
# SRR9985510_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:55 (0.00 B/s) - ‘SRR9985510_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_1.fastq.gz
#            => ‘SRR9985508_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985508 ... done.
# ==> SIZE SRR9985508_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985508_1.fastq.gz ... done.
#
# SRR9985508_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:57 (0.00 B/s) - ‘SRR9985508_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:57--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_2.fastq.gz
#            => ‘SRR9985508_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985508 ... done.
# ==> SIZE SRR9985508_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985508_2.fastq.gz ... done.
#
# SRR9985508_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:58 (0.00 B/s) - ‘SRR9985508_2.fastq.gz’ saved [0]
#
# --2020-11-18 17:44:58--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_1.fastq.gz
#            => ‘SRR9985513_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985513 ... done.
# ==> SIZE SRR9985513_1.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985513_1.fastq.gz ... done.
#
# SRR9985513_1.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:44:59 (0.00 B/s) - ‘SRR9985513_1.fastq.gz’ saved [0]
#
# --2020-11-18 17:45:00--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_2.fastq.gz
#            => ‘SRR9985513_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985513 ... done.
# ==> SIZE SRR9985513_2.fastq.gz ... done.
#
# ==> PASV ... done.    ==> RETR SRR9985513_2.fastq.gz ... done.
#
# SRR9985513_2.fastq.     [ <=>                ]       0  --.-KB/s    in 0s
#
# 2020-11-18 17:45:01 (0.00 B/s) - ‘SRR9985513_2.fastq.gz’ saved [0]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2020-11-18 17:45:02,477]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-11-18 17:47:03,182]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['SRR9985495_1.fastq.gz', 'SRR9985495_2.fastq.gz', 'SRR9985496_1.fastq.gz', 'SRR9985496_2.fastq.gz', 'SRR9985497_1.fastq.gz', 'SRR9985497_2.fastq.gz', 'SRR9985498_1.fastq.gz', 'SRR9985498_2.fastq.gz', 'SRR9985499_1.fastq.gz', 'SRR9985499_2.fastq.gz', 'SRR9985500_1.fastq.gz', 'SRR9985500_2.fastq.gz', 'SRR9985501_1.fastq.gz', 'SRR9985501_2.fastq.gz', 'SRR9985502_1.fastq.gz', 'SRR9985502_2.fastq.gz', 'SRR9985503_1.fastq.gz', 'SRR9985503_2.fastq.gz', 'SRR9985504_1.fastq.gz', 'SRR9985504_2.fastq.gz', 'SRR9985505_1.fastq.gz', 'SRR9985505_2.fastq.gz', 'SRR9985506_1.fastq.gz', 'SRR9985506_2.fastq.gz', 'SRR9985507_1.fastq.gz', 'SRR9985507_2.fastq.gz', 'SRR9985508_1.fastq.gz', 'SRR9985508_2.fastq.gz', 'SRR9985509_1.fastq.gz', 'SRR9985509_2.fastq.gz', 'SRR9985510_1.fastq.gz', 'SRR9985510_2.fastq.gz', 'SRR9985511_1.fastq.gz', 'SRR9985511_2.fastq.gz', 'SRR9985512_1.fastq.gz', 'SRR9985512_2.fastq.gz', 'SRR9985513_1.fastq.gz', 'SRR9985513_2.fastq.gz', 'SRR9985514_1.fastq.gz', 'SRR9985514_2.fastq.gz', 'SRR9985515_1.fastq.gz', 'SRR9985515_2.fastq.gz', 'SRR9985516_1.fastq.gz', 'SRR9985516_2.fastq.gz', 'SRR9985517_1.fastq.gz', 'SRR9985517_2.fastq.gz', 'SRR9985518_1.fastq.gz', 'SRR9985518_2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['SRR9985495_1.fastq.gz',
#  'SRR9985495_2.fastq.gz',
#  'SRR9985496_1.fastq.gz',
#  'SRR9985496_2.fastq.gz',
#  'SRR9985497_1.fastq.gz',
#  'SRR9985497_2.fastq.gz',
#  'SRR9985498_1.fastq.gz',
#  'SRR9985498_2.fastq.gz',
#  'SRR9985499_1.fastq.gz',
#  'SRR9985499_2.fastq.gz',
#  'SRR9985500_1.fastq.gz',
#  'SRR9985500_2.fastq.gz',
#  'SRR9985501_1.fastq.gz',
#  'SRR9985501_2.fastq.gz',
#  'SRR9985502_1.fastq.gz',
#  'SRR9985502_2.fastq.gz',
#  'SRR9985503_1.fastq.gz',
#  'SRR9985503_2.fastq.gz',
#  'SRR9985504_1.fastq.gz',
#  'SRR9985504_2.fastq.gz',
#  'SRR9985505_1.fastq.gz',
#  'SRR9985505_2.fastq.gz',
#  'SRR9985506_1.fastq.gz',
#  'SRR9985506_2.fastq.gz',
#  'SRR9985507_1.fastq.gz',
#  'SRR9985507_2.fastq.gz',
#  'SRR9985508_1.fastq.gz',
#  'SRR9985508_2.fastq.gz',
#  'SRR9985509_1.fastq.gz',
#  'SRR9985509_2.fastq.gz',
#  'SRR9985510_1.fastq.gz',
#  'SRR9985510_2.fastq.gz',
#  'SRR9985511_1.fastq.gz',
#  'SRR9985511_2.fastq.gz',
#  'SRR9985512_1.fastq.gz',
#  'SRR9985512_2.fastq.gz',
#  'SRR9985513_1.fastq.gz',
#  'SRR9985513_2.fastq.gz',
#  'SRR9985514_1.fastq.gz',
#  'SRR9985514_2.fastq.gz',
#  'SRR9985515_1.fastq.gz',
#  'SRR9985515_2.fastq.gz',
#  'SRR9985516_1.fastq.gz',
#  'SRR9985516_2.fastq.gz',
#  'SRR9985517_1.fastq.gz',
#  'SRR9985517_2.fastq.gz',
#  'SRR9985518_1.fastq.gz',
#  'SRR9985518_2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-11-18 17:47:42,186]    INFO Generating BUS file from
# [2020-11-18 17:47:42,186]    INFO         SRR9985495_1.fastq.gz
# [2020-11-18 17:47:42,186]    INFO         SRR9985495_2.fastq.gz
# [2020-11-18 17:47:42,186]    INFO         SRR9985496_1.fastq.gz
# [2020-11-18 17:47:42,186]    INFO         SRR9985496_2.fastq.gz
# [2020-11-18 17:47:42,186]    INFO         SRR9985497_1.fastq.gz
# [2020-11-18 17:47:42,186]    INFO         SRR9985497_2.fastq.gz
# [2020-11-18 17:47:42,186]    INFO         SRR9985498_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985498_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985499_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985499_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985500_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985500_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985501_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985501_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985502_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985502_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985503_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985503_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985504_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985504_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985505_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985505_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985506_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985506_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985507_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985507_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985508_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985508_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985509_1.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985509_2.fastq.gz
# [2020-11-18 17:47:42,187]    INFO         SRR9985510_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985510_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985511_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985511_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985512_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985512_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985513_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985513_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985514_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985514_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985515_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985515_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985516_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985516_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985517_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985517_2.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985518_1.fastq.gz
# [2020-11-18 17:47:42,188]    INFO         SRR9985518_2.fastq.gz
# [2020-11-18 17:48:36,145]    INFO Sorting BUS file outputGSM4037325/output.bus to tmp/output.s.bus
# [2020-11-18 17:48:38,729]   ERROR An exception occurred
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/kb_python/main.py", line 483, in main
#     COMMAND_TO_FUNCTION[args.command](args)
#   File "/usr/local/lib/python3.6/dist-packages/kb_python/main.py", line 150, in parse_count
#     h5ad=args.h5ad,
#   File "/usr/local/lib/python3.6/dist-packages/kb_python/count.py", line 521, in count
#     memory=memory
#   File "/usr/local/lib/python3.6/dist-packages/kb_python/count.py", line 97, in bustools_sort
#     run_executable(command)
#   File "/usr/local/lib/python3.6/dist-packages/kb_python/utils.py", line 147, in run_executable
#     raise sp.CalledProcessError(p.returncode, ' '.join(command))
# subprocess.CalledProcessError: Command '/usr/local/lib/python3.6/dist-packages/kb_python/bins/linux/bustools/bustools sort -o tmp/output.s.bus -T tmp -t 2 -m 4G outputGSM4037325/output.bus' died with <Signals.SIGSEGV: 11>.

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-e2553d487dd5> in <module>()
#       1 # load the unfiltered matrix
#       2 for i in range(no_samples):
# ----> 3   results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
#       4   results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values
#       5
#
# /usr/local/lib/python3.6/dist-packages/anndata/_io/h5ad.py in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     411     )
#     412
# --> 413     with h5py.File(filename, "r") as f:
#     414         d = {}
#     415         for k in f.keys():
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'outputGSM4037325/counts_unfiltered/adata.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 8000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 30#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 8000 with at least 218.0 UMIs
# We select 30 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 384,441 cells x 60,623 genes
#     New shape: 7,789 cells x 27,266 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
