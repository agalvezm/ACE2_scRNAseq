# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE134174_GSM4213827.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE134174_GSM4213827

# %%
# !wget -O adata_tcc.h5ad.gz https://caltech.box.com/shared/static/q9b6x6kjhus3fa90ntuvj1fn333ysawa.gz
# !wget -O adata.h5ad.gz https://caltech.box.com/shared/static/j1045nrlsvucjauddqf032i8andbqa5s.gz
# Out:
# --2021-05-06 23:56:41--  https://caltech.box.com/shared/static/q9b6x6kjhus3fa90ntuvj1fn333ysawa.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.26.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/q9b6x6kjhus3fa90ntuvj1fn333ysawa.gz [following]
# --2021-05-06 23:56:41--  https://caltech.box.com/public/static/q9b6x6kjhus3fa90ntuvj1fn333ysawa.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/q9b6x6kjhus3fa90ntuvj1fn333ysawa.gz [following]
# --2021-05-06 23:56:41--  https://caltech.app.box.com/public/static/q9b6x6kjhus3fa90ntuvj1fn333ysawa.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.26.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.26.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!I5qJXkzKSUiQyY3wymuwLpT976qObwiheBdDZK4ygUvSotx8kLbngTeQRlbNy54NS_vK6zn38NFu-HQXjRn7Ba62JV89yKzKMDTs6r0jLHxF2qS8b5mDckvcRoJubiTgUYxl4U9r5eWhnoWTgyiIiWwacLvAZRehYAewF8zEz_jAUfyQHD-Z_jCactfpw41l3soMLZ8ElQOAWCPnuaztwJt_HEg3z1VyxM8How8IESSfef556qvB4wzkVD4f2ivzmFSdgZTORodRmLocZOOWnZNK-_fbRWB12K5ZHtq5ZsbbWvlE3Y_QXBAgml4l2i2XwQB4GCMJr_NnvXdb4owR7PAcRpv8pVYO4h08PBwJ24WLMd3XB_v92zU9x64wWeASYVxqIYIRur75oMdr1aG_okMDM7zYQLQoEGtvJ775q6v4Cn3kP4LC9AVNLvmXQRBM-L8nSUi5_6S8cVc11YT_pcr1QHePegYuZF0ZNUtHftAgK4tjOyDkNzPGt2UKS7XlbzhzrgNgmIV8z77GfcqvhZD73bFIXDqi1to8rrSvj-8OlBbUbhT6st6XU2Aq3-Fzb3Ms8-mtSFTn4pWIg1LpRLsX_bBPT7fGJ20gFNAJeWLctS_xa_yob1KHSvU4SxE3-sLUBYMpi2Cq-W80tyDZOpPFDu0SDtR6l3CHW3urkcsO00amYyXIzq3JNh29uj7_O4iWUKfLCvit1BJfgt-4vj1DMqnYKrm55EIG2NoZ8aABDHUKiqlXTW2clxLJPMbGt6349uxkXGxvLTIG5bJSgH2fYgrwHAAH6jbptU7kYi4-faw3dOXKGPZg9b4fadksXhqF_weSK0-ofAWrj1XzqP13Snz2RRuypfhgUcPg0xva5zF5haugpbMOQjX319Np8smED11xJE99X1KDxBIxbu2gGnE2koRjBZO6kuH7jzJcge-OczY10UAdfyyZARJ_nBRzH2IGCZULKVwGGoeEZIgJf7NtF1duilhyqMeDg4gWK2ppIihMc49C-Zrtzce12JwrSzNl9ph2s7dBlAJl5ozav4JUW7Z7XfXI5-NyqrSQtrdxXRIyfcBGunGQ5cfDhXfJZWRhUOb8g5Nv52ab9z6b97Et-lUV8O4VWOzS_cQhOaf4sMLbR89Vtr06cjEV57zf10Brxrjcj_2lBNp_FfS_ziSXzbnDYCamm-hFC5N-GvqI-CN59oha_37Z0mE1JE1eeEgcMka6VPx8cm_Hr_EEzB1Zf8UXVAXq_YzWDNBWJJMbOP18zV4mOyYiA0A3rd6K6CoeR0lqk1r3vv4FhXVfmSf8_0-P7A0_yZIYiDqFhYGbtAz4V4VF7GslCNd3RXsC4Zee_2YZC2M83MLp-8qsJYsijx8nsy7XCGqI26G88JEcRTDlgVjCNrA24r8TiEjpMO_3cf6O/download [following]
# --2021-05-06 23:56:42--  https://public.boxcloud.com/d/1/b1!I5qJXkzKSUiQyY3wymuwLpT976qObwiheBdDZK4ygUvSotx8kLbngTeQRlbNy54NS_vK6zn38NFu-HQXjRn7Ba62JV89yKzKMDTs6r0jLHxF2qS8b5mDckvcRoJubiTgUYxl4U9r5eWhnoWTgyiIiWwacLvAZRehYAewF8zEz_jAUfyQHD-Z_jCactfpw41l3soMLZ8ElQOAWCPnuaztwJt_HEg3z1VyxM8How8IESSfef556qvB4wzkVD4f2ivzmFSdgZTORodRmLocZOOWnZNK-_fbRWB12K5ZHtq5ZsbbWvlE3Y_QXBAgml4l2i2XwQB4GCMJr_NnvXdb4owR7PAcRpv8pVYO4h08PBwJ24WLMd3XB_v92zU9x64wWeASYVxqIYIRur75oMdr1aG_okMDM7zYQLQoEGtvJ775q6v4Cn3kP4LC9AVNLvmXQRBM-L8nSUi5_6S8cVc11YT_pcr1QHePegYuZF0ZNUtHftAgK4tjOyDkNzPGt2UKS7XlbzhzrgNgmIV8z77GfcqvhZD73bFIXDqi1to8rrSvj-8OlBbUbhT6st6XU2Aq3-Fzb3Ms8-mtSFTn4pWIg1LpRLsX_bBPT7fGJ20gFNAJeWLctS_xa_yob1KHSvU4SxE3-sLUBYMpi2Cq-W80tyDZOpPFDu0SDtR6l3CHW3urkcsO00amYyXIzq3JNh29uj7_O4iWUKfLCvit1BJfgt-4vj1DMqnYKrm55EIG2NoZ8aABDHUKiqlXTW2clxLJPMbGt6349uxkXGxvLTIG5bJSgH2fYgrwHAAH6jbptU7kYi4-faw3dOXKGPZg9b4fadksXhqF_weSK0-ofAWrj1XzqP13Snz2RRuypfhgUcPg0xva5zF5haugpbMOQjX319Np8smED11xJE99X1KDxBIxbu2gGnE2koRjBZO6kuH7jzJcge-OczY10UAdfyyZARJ_nBRzH2IGCZULKVwGGoeEZIgJf7NtF1duilhyqMeDg4gWK2ppIihMc49C-Zrtzce12JwrSzNl9ph2s7dBlAJl5ozav4JUW7Z7XfXI5-NyqrSQtrdxXRIyfcBGunGQ5cfDhXfJZWRhUOb8g5Nv52ab9z6b97Et-lUV8O4VWOzS_cQhOaf4sMLbR89Vtr06cjEV57zf10Brxrjcj_2lBNp_FfS_ziSXzbnDYCamm-hFC5N-GvqI-CN59oha_37Z0mE1JE1eeEgcMka6VPx8cm_Hr_EEzB1Zf8UXVAXq_YzWDNBWJJMbOP18zV4mOyYiA0A3rd6K6CoeR0lqk1r3vv4FhXVfmSf8_0-P7A0_yZIYiDqFhYGbtAz4V4VF7GslCNd3RXsC4Zee_2YZC2M83MLp-8qsJYsijx8nsy7XCGqI26G88JEcRTDlgVjCNrA24r8TiEjpMO_3cf6O/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228399128 (218M) [application/octet-stream]
# Saving to: ‘adata_tcc.h5ad.gz’
#
# adata_tcc.h5ad.gz   100%[===================>] 217.82M  23.1MB/s    in 14s
#
# 2021-05-06 23:56:57 (15.5 MB/s) - ‘adata_tcc.h5ad.gz’ saved [228399128/228399128]
#
# --2021-05-06 23:56:57--  https://caltech.box.com/shared/static/j1045nrlsvucjauddqf032i8andbqa5s.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.26.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/j1045nrlsvucjauddqf032i8andbqa5s.gz [following]
# --2021-05-06 23:56:58--  https://caltech.box.com/public/static/j1045nrlsvucjauddqf032i8andbqa5s.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/j1045nrlsvucjauddqf032i8andbqa5s.gz [following]
# --2021-05-06 23:56:58--  https://caltech.app.box.com/public/static/j1045nrlsvucjauddqf032i8andbqa5s.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.26.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.26.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!FUeaIUGYmj_B3dYE7jisRfdg4mVCmIt88CONGaCRM8QqkztYpkYgCV5nmblWp1WrxCYqeZQBeJGDAyijQHE6gkugfmeyb3Ik9wFqr_WwHjHS1AfHx2CdlaexK-K_CEOgrYL_4xuXhNq89dlNemCrm4eNK61ujwiupfJTisnHRT99Vl4RsJmk95gwQ4WFBa60pE_UndRlZUOCKsTLNK_EyOsSu9CfkCmRtZaQ7oGUfBMluPjLR8H3d9bI3Oj1nVAoKvWy1pKyMJZdiKBEyFvh9ZFj7suIMHN7v5kMOoqNXdI7fF3pTHnVNkTxrho991keH8sDXhu8IUzJJIecr1eX_SgDKJht2vF-naxqaWz_vKVf0uHPoir9nO2p2ks9hiMqbXrcLxSNE3KdeMkFRQ-hyhLAsbQP5wI32ra8u6DooJMTd84o15gxZylJ2iBon59NbO1rDn1r1Lqi1EFai_MjzIBl51IwAQo5J0F-wkJk7Q2otkSGBBRfean7g8bYRFqx6gwzX2B8A8pzgoUECa8rZFG8u_wWKDH83sfhPx0RFNHVf91cLrgtdVGJpmwhzAhGepE7DgLqtXVL2goW-Q-DWfsyFSV74TBX2P1ei_JdLK0QemSaWwu_PEFY-ZB6ydtkR_ao9NZhgvaiLJPBU5Tl4vf5BM_Z4L0eW-hi_hA_VYqu2deNV1iwQVwTg7cQP0Tswahqvqc5m9fkdxEiRb_fUSrVuYe-zJ1kzkQkVvPT3_XACyHAMCQHGuWRb_rasDo4ahrqf6sNs6jRmto28j7nKHAxr6E5L5ZcAaCfbL13W78eedYiuF9oyGl7rkLCc8F70QPCtJYNRFdkfydxwP2yk-7HBfINCxAV3AsLOKN9II6AqqVfN76s1Kg5moj-S5k_9SZex_tKQnvrhXwmcp0xq_etwPy253yGyaQiip_NcQ7CaPo5NECh9SGUxhplYHVmxlRMkGU_GDNavYIRpot3m24_BgLdkB9L9AEGQcp7JyjeVrHATqYmwDAFo7uiDtcd68PR1BCEoUB3huCJTE3QxG9rn1Hf0mF785FCPscljUOmBaGE4HXcqoTT7hz-k_4LQ9opvdv1XR-eUXymhLK64bLAy2oKaX5bOMdDxMoYys9F5_iYGX11wwbTYfM4jgoOV0OxCgsZGe2r4VKvFLKPUWSF7kQ_foi6obQ6ifuownK-ArkePNqB1bIpLeRkTob5P3-mOrlH628acCa5BD0LLsiVtDhUhw-xlSUdYqghVeo9-yVMFXoEAXJ9tIXOCFBsv6Dm1MkL8vv7XneR9pY7m_Eb-6TmfeE4rtV6ze2Nm27vVbmuIXeLFhQz0GpANJm4cgNZUhkaEUhhfVhjXwyX84ca2_jkG-Car4iCWvIJp587b0_SaDiuZI3tyl7bHsVHhHUoclWiCz5IlNlfufRwTpOkKaeLb_5eQeGIotGn/download [following]
# --2021-05-06 23:56:59--  https://public.boxcloud.com/d/1/b1!FUeaIUGYmj_B3dYE7jisRfdg4mVCmIt88CONGaCRM8QqkztYpkYgCV5nmblWp1WrxCYqeZQBeJGDAyijQHE6gkugfmeyb3Ik9wFqr_WwHjHS1AfHx2CdlaexK-K_CEOgrYL_4xuXhNq89dlNemCrm4eNK61ujwiupfJTisnHRT99Vl4RsJmk95gwQ4WFBa60pE_UndRlZUOCKsTLNK_EyOsSu9CfkCmRtZaQ7oGUfBMluPjLR8H3d9bI3Oj1nVAoKvWy1pKyMJZdiKBEyFvh9ZFj7suIMHN7v5kMOoqNXdI7fF3pTHnVNkTxrho991keH8sDXhu8IUzJJIecr1eX_SgDKJht2vF-naxqaWz_vKVf0uHPoir9nO2p2ks9hiMqbXrcLxSNE3KdeMkFRQ-hyhLAsbQP5wI32ra8u6DooJMTd84o15gxZylJ2iBon59NbO1rDn1r1Lqi1EFai_MjzIBl51IwAQo5J0F-wkJk7Q2otkSGBBRfean7g8bYRFqx6gwzX2B8A8pzgoUECa8rZFG8u_wWKDH83sfhPx0RFNHVf91cLrgtdVGJpmwhzAhGepE7DgLqtXVL2goW-Q-DWfsyFSV74TBX2P1ei_JdLK0QemSaWwu_PEFY-ZB6ydtkR_ao9NZhgvaiLJPBU5Tl4vf5BM_Z4L0eW-hi_hA_VYqu2deNV1iwQVwTg7cQP0Tswahqvqc5m9fkdxEiRb_fUSrVuYe-zJ1kzkQkVvPT3_XACyHAMCQHGuWRb_rasDo4ahrqf6sNs6jRmto28j7nKHAxr6E5L5ZcAaCfbL13W78eedYiuF9oyGl7rkLCc8F70QPCtJYNRFdkfydxwP2yk-7HBfINCxAV3AsLOKN9II6AqqVfN76s1Kg5moj-S5k_9SZex_tKQnvrhXwmcp0xq_etwPy253yGyaQiip_NcQ7CaPo5NECh9SGUxhplYHVmxlRMkGU_GDNavYIRpot3m24_BgLdkB9L9AEGQcp7JyjeVrHATqYmwDAFo7uiDtcd68PR1BCEoUB3huCJTE3QxG9rn1Hf0mF785FCPscljUOmBaGE4HXcqoTT7hz-k_4LQ9opvdv1XR-eUXymhLK64bLAy2oKaX5bOMdDxMoYys9F5_iYGX11wwbTYfM4jgoOV0OxCgsZGe2r4VKvFLKPUWSF7kQ_foi6obQ6ifuownK-ArkePNqB1bIpLeRkTob5P3-mOrlH628acCa5BD0LLsiVtDhUhw-xlSUdYqghVeo9-yVMFXoEAXJ9tIXOCFBsv6Dm1MkL8vv7XneR9pY7m_Eb-6TmfeE4rtV6ze2Nm27vVbmuIXeLFhQz0GpANJm4cgNZUhkaEUhhfVhjXwyX84ca2_jkG-Car4iCWvIJp587b0_SaDiuZI3tyl7bHsVHhHUoclWiCz5IlNlfufRwTpOkKaeLb_5eQeGIotGn/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33738614 (32M) [application/octet-stream]
# Saving to: ‘adata.h5ad.gz’
#
# adata.h5ad.gz       100%[===================>]  32.17M  23.5MB/s    in 1.4s
#
# 2021-05-06 23:57:01 (23.5 MB/s) - ‘adata.h5ad.gz’ saved [33738614/33738614]

# %% [markdown]
# This dataset was too large to be processed in google colab. The gene count and TCC were generated using the following commands:
#
# ```
# SRA=SRR10668801
# GSM=GSM4213827
#
# cd /central/scratch/agalvezm/ace2/counts
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/prefetch 2.10.9 ${SRA} --max-size 2000000000
#
# cd ${SRA}
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/fasterq-dump --split-files --outdir fastq --include-technical ${SRA}.sra
#
# ~/anaconda3/bin/kb ref -d human -i index.idx -g t2g.txt -f1 transcriptome.fasta
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/output${GSM} --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/tccoutput${GSM} --tcc --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ```

# %%
no_samples = 1

fastqs_per_sample = [1] 

sample_id = "GSM4213827"

database_id = ["GSE134174"] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["trachea epithelial cells"] * no_samples

species = ["human"] * no_samples

technology = ["10xv3"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 5"] * no_samples

condition = ["heavy smoker"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 76kB/s
#      |████████████████████████████████| 133kB 56.4MB/s
#      |████████████████████████████████| 13.2MB 47.7MB/s
#      |████████████████████████████████| 10.3MB 20.3MB/s
#      |████████████████████████████████| 51kB 5.7MB/s
#      |████████████████████████████████| 81kB 8.1MB/s
#      |████████████████████████████████| 112kB 39.7MB/s
#      |████████████████████████████████| 1.2MB 43.6MB/s
#      |████████████████████████████████| 71kB 6.8MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %%
# Execute kb ref to get t2g.txt file
# !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2021-05-06 23:57:46,906]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:54<00:00, 20.8MB/s]
# [2021-05-06 23:59:43,585]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrices

# %%
# # Gunzip matrices
# !gunzip /content/adata.h5ad.gz
# !gunzip /content/adata_tcc.h5ad.gz

# Load matrices
adata = anndata.read_h5ad("/content/adata.h5ad")
adata_tcc = anndata.read_h5ad("/content/adata_tcc.h5ad")

# %%
adata.var
# Out:
#                      gene_name
# gene_id
# ENSG00000223972.5      DDX11L1
# ENSG00000227232.5       WASH7P
# ENSG00000278267.1    MIR6859-1
# ENSG00000243485.5  MIR1302-2HG
# ENSG00000284332.1    MIR1302-2
# ...                        ...
# ENSG00000271254.6   AC240274.1
# ENSG00000275405.1           U1
# ENSG00000275987.1           U1
# ENSG00000277475.1   AC213203.2
# ENSG00000268674.2   AC213203.1
#
# [60623 rows x 1 columns]

# %%
# Reformat and fill gene count matrix 

adata.var["gene_id"] = adata.var.index.values

t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
t2g.index = t2g.gene_id
t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

adata.var["gene_name"] = adata.var.gene_id.map(t2g["gene_name"])
adata.var.index = adata.var["gene_name"]
print("The unfiltered matrix " + sample_id + " contains {} cells by {} genes".format(len(adata.obs), len(adata.var)))

adata.obs["cell_counts"] = adata.X.sum(axis=1)
adata.var["gene_counts"] = nd(adata.X.sum(axis=0))

adata.obs["n_genes"] = nd((adata.X>0).sum(axis=1))
adata.var["n_cells"] = nd((adata.X>0).sum(axis=0))

mito_genes = adata.var_names.str.startswith("MT-" or "mt-") 
adata.obs["percent_mito"] = adata[:,mito_genes].X.sum(axis=1)/adata.X.sum(axis=1)*100

# Changing the name of the index is necessary to write the file (it won't work with duplicated names)
adata.var.index.name = "index"
# Out:
# The unfiltered matrix GSM4213827 contains 400954 cells by 60623 genes

# %% [markdown]
# ## Assign filters for gene count matrix

# %%
results = {}


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

# %%
expected_num_cells = 2000#@param {type:"integer"}
knee = np.sort(nd(adata.X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 18#@param {type:"integer"}
results["mito_criteria" + sample_id] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(adata.obs["cell_counts"][adata.obs["cell_counts"] > cell_threshold])
y = nd(adata.obs["percent_mito"][adata.obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 2000 with at least 4241.0 UMIs
# We select 18 % as the mitochondrial content threshold

# %% [markdown]
# # Filter gene count matrix

# %%
adata.obs["pass_count_filter"] = adata.obs["cell_counts"] > results["cell_threshold" + sample_id]
adata.obs["pass_mito_filter"] = adata.obs.percent_mito < results["mito_criteria" + sample_id]
adata.var["pass_gene_filter"] = adata.var["n_cells"] > gene_threshold

cell_mask = np.logical_and(adata.obs["pass_count_filter"].values, adata.obs["pass_mito_filter"].values)
gene_mask = adata.var["pass_gene_filter"].values

print("Current Shape: {:,} cells x {:,} genes".format(adata.shape[0], adata.shape[1]))
print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
results["data_" + sample_id] = adata[cell_mask, gene_mask]
# Out:
# Current Shape: 400,954 cells x 60,623 genes
#     New shape: 1,943 cells x 28,018 genes

# %% [markdown]
# # Anotate and write gene count matrix

# %%
adata.uns["database_id"] = database_id

adata.uns["tissue"] = tissue

adata.uns["cell_type"] = cell_type

adata.uns["sample_id"] = sample_id

adata.uns["condition"] = condition

adata.uns["species"] = species

adata.uns["technology"] = technology

adata.uns["paper"] = paper

adata.uns["figure"] = figure

# %cd /content

adata.write("result" + sample_id)
# Out:
# /content
# ... storing 'gene_name' as categorical

# %% [markdown]
# Filter TCC using gene count matrix's filter

# %%
adata_tcc = adata_tcc[adata.obs.index.values]
# transfer obs data
adata_tcc.obs = adata.obs
# transfer metadata
adata_tcc.uns = adata.uns
# write tcc matrix
adata_tcc.write("/content/tcc_" + sample_id)
#gzip tcc matrix
cmd = "gzip /content/tcc_" + sample_id
# !$cmd
