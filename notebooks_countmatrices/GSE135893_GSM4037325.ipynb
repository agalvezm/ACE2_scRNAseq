# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE135893_GSM4037325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE135893_GSM4037325

# %%
# define the values for the analysis

# accession id for the data
id = "GSE135893"
samp_id = ["GSM4037325"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet

  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["None"] * no_samples

condition = ["healthy"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 74kB/s
#      |████████████████████████████████| 51kB 6.7MB/s
#      |████████████████████████████████| 122kB 46.9MB/s
#      |████████████████████████████████| 7.7MB 41.3MB/s
#      |████████████████████████████████| 13.1MB 40.5MB/s
#      |████████████████████████████████| 112kB 24.2MB/s
#      |████████████████████████████████| 51kB 6.5MB/s
#      |████████████████████████████████| 71kB 9.1MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2020-11-19 15:39:23--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_1.fastq.gz
#            => ‘SRR9985509_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985509 ... done.
# ==> SIZE SRR9985509_1.fastq.gz ... 665494275
# ==> PASV ... done.    ==> RETR SRR9985509_1.fastq.gz ... done.
# Length: 665494275 (635M) (unauthoritative)
#
# SRR9985509_1.fastq. 100%[===================>] 634.66M  12.1MB/s    in 57s
#
# 2020-11-19 15:40:23 (11.2 MB/s) - ‘SRR9985509_1.fastq.gz’ saved [665494275]
#
# --2020-11-19 15:40:23--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_2.fastq.gz
#            => ‘SRR9985509_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985509 ... done.
# ==> SIZE SRR9985509_2.fastq.gz ... 674042245
# ==> PASV ... done.    ==> RETR SRR9985509_2.fastq.gz ... done.
# Length: 674042245 (643M) (unauthoritative)
#
# SRR9985509_2.fastq. 100%[===================>] 642.82M  12.1MB/s    in 75s
#
# 2020-11-19 15:41:42 (8.58 MB/s) - ‘SRR9985509_2.fastq.gz’ saved [674042245]
#
# --2020-11-19 15:41:42--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_1.fastq.gz
#            => ‘SRR9985505_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985505 ... done.
# ==> SIZE SRR9985505_1.fastq.gz ... 866824827
# ==> PASV ... done.    ==> RETR SRR9985505_1.fastq.gz ... done.
# Length: 866824827 (827M) (unauthoritative)
#
# SRR9985505_1.fastq. 100%[===================>] 826.67M  12.1MB/s    in 81s
#
# 2020-11-19 15:43:07 (10.2 MB/s) - ‘SRR9985505_1.fastq.gz’ saved [866824827]
#
# --2020-11-19 15:43:07--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_2.fastq.gz
#            => ‘SRR9985505_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985505 ... done.
# ==> SIZE SRR9985505_2.fastq.gz ... 874347943
# ==> PASV ... done.    ==> RETR SRR9985505_2.fastq.gz ... done.
# Length: 874347943 (834M) (unauthoritative)
#
# SRR9985505_2.fastq. 100%[===================>] 833.84M  12.2MB/s    in 75s
#
# 2020-11-19 15:44:25 (11.0 MB/s) - ‘SRR9985505_2.fastq.gz’ saved [874347943]
#
# --2020-11-19 15:44:26--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_1.fastq.gz
#            => ‘SRR9985503_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985503 ... done.
# ==> SIZE SRR9985503_1.fastq.gz ... 618220272
# ==> PASV ... done.    ==> RETR SRR9985503_1.fastq.gz ... done.
# Length: 618220272 (590M) (unauthoritative)
#
# SRR9985503_1.fastq. 100%[===================>] 589.58M  11.9MB/s    in 53s
#
# 2020-11-19 15:45:22 (11.0 MB/s) - ‘SRR9985503_1.fastq.gz’ saved [618220272]
#
# --2020-11-19 15:45:23--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_2.fastq.gz
#            => ‘SRR9985503_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985503 ... done.
# ==> SIZE SRR9985503_2.fastq.gz ... 622433191
# ==> PASV ... done.    ==> RETR SRR9985503_2.fastq.gz ... done.
# Length: 622433191 (594M) (unauthoritative)
#
# SRR9985503_2.fastq. 100%[===================>] 593.60M  12.3MB/s    in 54s
#
# 2020-11-19 15:46:20 (11.0 MB/s) - ‘SRR9985503_2.fastq.gz’ saved [622433191]
#
# --2020-11-19 15:46:20--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_1.fastq.gz
#            => ‘SRR9985506_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985506 ... done.
# ==> SIZE SRR9985506_1.fastq.gz ... 248159151
# ==> PASV ... done.    ==> RETR SRR9985506_1.fastq.gz ... done.
# Length: 248159151 (237M) (unauthoritative)
#
# SRR9985506_1.fastq. 100%[===================>] 236.66M  12.1MB/s    in 25s
#
# 2020-11-19 15:46:49 (9.34 MB/s) - ‘SRR9985506_1.fastq.gz’ saved [248159151]
#
# --2020-11-19 15:46:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_2.fastq.gz
#            => ‘SRR9985506_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985506 ... done.
# ==> SIZE SRR9985506_2.fastq.gz ... 255142545
# ==> PASV ... done.    ==> RETR SRR9985506_2.fastq.gz ... done.
# Length: 255142545 (243M) (unauthoritative)
#
# SRR9985506_2.fastq. 100%[===================>] 243.32M  12.0MB/s    in 29s
#
# 2020-11-19 15:47:22 (8.27 MB/s) - ‘SRR9985506_2.fastq.gz’ saved [255142545]
#
# --2020-11-19 15:47:22--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_1.fastq.gz
#            => ‘SRR9985507_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985507 ... done.
# ==> SIZE SRR9985507_1.fastq.gz ... 861753540
# ==> PASV ... done.    ==> RETR SRR9985507_1.fastq.gz ... done.
# Length: 861753540 (822M) (unauthoritative)
#
# SRR9985507_1.fastq. 100%[===================>] 821.83M  12.0MB/s    in 74s
#
# 2020-11-19 15:48:39 (11.1 MB/s) - ‘SRR9985507_1.fastq.gz’ saved [861753540]
#
# --2020-11-19 15:48:40--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_2.fastq.gz
#            => ‘SRR9985507_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985507 ... done.
# ==> SIZE SRR9985507_2.fastq.gz ... 865817815
# ==> PASV ... done.    ==> RETR SRR9985507_2.fastq.gz ... done.
# Length: 865817815 (826M) (unauthoritative)
#
# SRR9985507_2.fastq. 100%[===================>] 825.71M  12.1MB/s    in 83s
#
# 2020-11-19 15:50:06 (10.0 MB/s) - ‘SRR9985507_2.fastq.gz’ saved [865817815]
#
# --2020-11-19 15:50:06--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_1.fastq.gz
#            => ‘SRR9985504_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985504 ... done.
# ==> SIZE SRR9985504_1.fastq.gz ... 615538795
# ==> PASV ... done.    ==> RETR SRR9985504_1.fastq.gz ... done.
# Length: 615538795 (587M) (unauthoritative)
#
# SRR9985504_1.fastq. 100%[===================>] 587.02M  10.5MB/s    in 67s
#
# 2020-11-19 15:51:16 (8.81 MB/s) - ‘SRR9985504_1.fastq.gz’ saved [615538795]
#
# --2020-11-19 15:51:16--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_2.fastq.gz
#            => ‘SRR9985504_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985504 ... done.
# ==> SIZE SRR9985504_2.fastq.gz ... 617583143
# ==> PASV ... done.    ==> RETR SRR9985504_2.fastq.gz ... done.
# Length: 617583143 (589M) (unauthoritative)
#
# SRR9985504_2.fastq. 100%[===================>] 588.97M  12.1MB/s    in 67s
#
# 2020-11-19 15:52:26 (8.83 MB/s) - ‘SRR9985504_2.fastq.gz’ saved [617583143]
#
# --2020-11-19 15:52:27--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_1.fastq.gz
#            => ‘SRR9985502_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985502 ... done.
# ==> SIZE SRR9985502_1.fastq.gz ... 619148817
# ==> PASV ... done.    ==> RETR SRR9985502_1.fastq.gz ... done.
# Length: 619148817 (590M) (unauthoritative)
#
# SRR9985502_1.fastq. 100%[===================>] 590.47M  11.1MB/s    in 57s
#
# 2020-11-19 15:53:27 (10.4 MB/s) - ‘SRR9985502_1.fastq.gz’ saved [619148817]
#
# --2020-11-19 15:53:27--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_2.fastq.gz
#            => ‘SRR9985502_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985502 ... done.
# ==> SIZE SRR9985502_2.fastq.gz ... 612217436
# ==> PASV ... done.    ==> RETR SRR9985502_2.fastq.gz ... done.
# Length: 612217436 (584M) (unauthoritative)
#
# SRR9985502_2.fastq. 100%[===================>] 583.86M  8.65MB/s    in 96s
#
# 2020-11-19 15:55:06 (6.10 MB/s) - ‘SRR9985502_2.fastq.gz’ saved [612217436]
#
# --2020-11-19 15:55:06--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_1.fastq.gz
#            => ‘SRR9985500_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985500 ... done.
# ==> SIZE SRR9985500_1.fastq.gz ... 588894835
# ==> PASV ... done.    ==> RETR SRR9985500_1.fastq.gz ... done.
# Length: 588894835 (562M) (unauthoritative)
#
# SRR9985500_1.fastq. 100%[===================>] 561.61M  11.9MB/s    in 94s
#
# 2020-11-19 15:56:43 (5.99 MB/s) - ‘SRR9985500_1.fastq.gz’ saved [588894835]
#
# --2020-11-19 15:56:44--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_2.fastq.gz
#            => ‘SRR9985500_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985500 ... done.
# ==> SIZE SRR9985500_2.fastq.gz ... 588149966
# ==> PASV ... done.    ==> RETR SRR9985500_2.fastq.gz ... done.
# Length: 588149966 (561M) (unauthoritative)
#
# SRR9985500_2.fastq. 100%[===================>] 560.90M  12.2MB/s    in 60s
#
# 2020-11-19 15:57:47 (9.38 MB/s) - ‘SRR9985500_2.fastq.gz’ saved [588149966]
#
# --2020-11-19 15:57:47--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_1.fastq.gz
#            => ‘SRR9985499_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985499 ... done.
# ==> SIZE SRR9985499_1.fastq.gz ... 592578996
# ==> PASV ... done.    ==> RETR SRR9985499_1.fastq.gz ... done.
# Length: 592578996 (565M) (unauthoritative)
#
# SRR9985499_1.fastq. 100%[===================>] 565.13M  12.3MB/s    in 70s
#
# 2020-11-19 15:59:00 (8.11 MB/s) - ‘SRR9985499_1.fastq.gz’ saved [592578996]
#
# --2020-11-19 15:59:00--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_2.fastq.gz
#            => ‘SRR9985499_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985499 ... done.
# ==> SIZE SRR9985499_2.fastq.gz ... 593876466
# ==> PASV ... done.    ==> RETR SRR9985499_2.fastq.gz ... done.
# Length: 593876466 (566M) (unauthoritative)
#
# SRR9985499_2.fastq. 100%[===================>] 566.36M  12.0MB/s    in 64s
#
# 2020-11-19 16:00:07 (8.83 MB/s) - ‘SRR9985499_2.fastq.gz’ saved [593876466]
#
# --2020-11-19 16:00:08--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_1.fastq.gz
#            => ‘SRR9985501_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985501 ... done.
# ==> SIZE SRR9985501_1.fastq.gz ... 622446193
# ==> PASV ... done.    ==> RETR SRR9985501_1.fastq.gz ... done.
# Length: 622446193 (594M) (unauthoritative)
#
# SRR9985501_1.fastq. 100%[===================>] 593.61M  10.6MB/s    in 3m 52s
#
# 2020-11-19 16:04:03 (2.56 MB/s) - ‘SRR9985501_1.fastq.gz’ saved [622446193]
#
# --2020-11-19 16:04:03--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_2.fastq.gz
#            => ‘SRR9985501_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985501 ... done.
# ==> SIZE SRR9985501_2.fastq.gz ... 618131589
# ==> PASV ... done.    ==> RETR SRR9985501_2.fastq.gz ... done.
# Length: 618131589 (589M) (unauthoritative)
#
# SRR9985501_2.fastq. 100%[===================>] 589.50M  11.8MB/s    in 2m 34s
#
# 2020-11-19 16:06:41 (3.83 MB/s) - ‘SRR9985501_2.fastq.gz’ saved [618131589]
#
# --2020-11-19 16:06:41--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_1.fastq.gz
#            => ‘SRR9985498_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985498 ... done.
# ==> SIZE SRR9985498_1.fastq.gz ... 848592429
# ==> PASV ... done.    ==> RETR SRR9985498_1.fastq.gz ... done.
# Length: 848592429 (809M) (unauthoritative)
#
# SRR9985498_1.fastq. 100%[===================>] 809.28M  11.8MB/s    in 86s
#
# 2020-11-19 16:08:11 (9.40 MB/s) - ‘SRR9985498_1.fastq.gz’ saved [848592429]
#
# --2020-11-19 16:08:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_2.fastq.gz
#            => ‘SRR9985498_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985498 ... done.
# ==> SIZE SRR9985498_2.fastq.gz ... 854567084
# ==> PASV ... done.    ==> RETR SRR9985498_2.fastq.gz ... done.
# Length: 854567084 (815M) (unauthoritative)
#
# SRR9985498_2.fastq. 100%[===================>] 814.98M  12.4MB/s    in 78s
#
# 2020-11-19 16:09:33 (10.4 MB/s) - ‘SRR9985498_2.fastq.gz’ saved [854567084]
#
# --2020-11-19 16:09:33--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_1.fastq.gz
#            => ‘SRR9985495_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985495 ... done.
# ==> SIZE SRR9985495_1.fastq.gz ... 248764575
# ==> PASV ... done.    ==> RETR SRR9985495_1.fastq.gz ... done.
# Length: 248764575 (237M) (unauthoritative)
#
# SRR9985495_1.fastq. 100%[===================>] 237.24M  12.4MB/s    in 22s
#
# 2020-11-19 16:09:59 (10.8 MB/s) - ‘SRR9985495_1.fastq.gz’ saved [248764575]
#
# --2020-11-19 16:09:59--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_2.fastq.gz
#            => ‘SRR9985495_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985495 ... done.
# ==> SIZE SRR9985495_2.fastq.gz ... 256615763
# ==> PASV ... done.    ==> RETR SRR9985495_2.fastq.gz ... done.
# Length: 256615763 (245M) (unauthoritative)
#
# SRR9985495_2.fastq. 100%[===================>] 244.73M  12.1MB/s    in 31s
#
# 2020-11-19 16:10:34 (7.79 MB/s) - ‘SRR9985495_2.fastq.gz’ saved [256615763]
#
# --2020-11-19 16:10:34--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_1.fastq.gz
#            => ‘SRR9985497_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985497 ... done.
# ==> SIZE SRR9985497_1.fastq.gz ... 851773607
# ==> PASV ... done.    ==> RETR SRR9985497_1.fastq.gz ... done.
# Length: 851773607 (812M) (unauthoritative)
#
# SRR9985497_1.fastq. 100%[===================>] 812.31M  12.2MB/s    in 72s
#
# 2020-11-19 16:11:49 (11.3 MB/s) - ‘SRR9985497_1.fastq.gz’ saved [851773607]
#
# --2020-11-19 16:11:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_2.fastq.gz
#            => ‘SRR9985497_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985497 ... done.
# ==> SIZE SRR9985497_2.fastq.gz ... 860872827
# ==> PASV ... done.    ==> RETR SRR9985497_2.fastq.gz ... done.
# Length: 860872827 (821M) (unauthoritative)
#
# SRR9985497_2.fastq. 100%[===================>] 820.99M  12.2MB/s    in 79s
#
# 2020-11-19 16:13:12 (10.4 MB/s) - ‘SRR9985497_2.fastq.gz’ saved [860872827]
#
# --2020-11-19 16:13:12--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_1.fastq.gz
#            => ‘SRR9985496_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985496 ... done.
# ==> SIZE SRR9985496_1.fastq.gz ... 734938466
# ==> PASV ... done.    ==> RETR SRR9985496_1.fastq.gz ... done.
# Length: 734938466 (701M) (unauthoritative)
#
# SRR9985496_1.fastq. 100%[===================>] 700.89M  12.2MB/s    in 68s
#
# 2020-11-19 16:14:24 (10.3 MB/s) - ‘SRR9985496_1.fastq.gz’ saved [734938466]
#
# --2020-11-19 16:14:24--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_2.fastq.gz
#            => ‘SRR9985496_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985496 ... done.
# ==> SIZE SRR9985496_2.fastq.gz ... 747442361
# ==> PASV ... done.    ==> RETR SRR9985496_2.fastq.gz ... done.
# Length: 747442361 (713M) (unauthoritative)
#
# SRR9985496_2.fastq. 100%[===================>] 712.82M  12.1MB/s    in 64s
#
# 2020-11-19 16:15:31 (11.2 MB/s) - ‘SRR9985496_2.fastq.gz’ saved [747442361]
#
# --2020-11-19 16:15:31--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_1.fastq.gz
#            => ‘SRR9985516_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985516 ... done.
# ==> SIZE SRR9985516_1.fastq.gz ... 301189179
# ==> PASV ... done.    ==> RETR SRR9985516_1.fastq.gz ... done.
# Length: 301189179 (287M) (unauthoritative)
#
# SRR9985516_1.fastq. 100%[===================>] 287.24M  12.1MB/s    in 54s
#
# 2020-11-19 16:16:28 (5.34 MB/s) - ‘SRR9985516_1.fastq.gz’ saved [301189179]
#
# --2020-11-19 16:16:28--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_2.fastq.gz
#            => ‘SRR9985516_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985516 ... done.
# ==> SIZE SRR9985516_2.fastq.gz ... 308733725
# ==> PASV ... done.    ==> RETR SRR9985516_2.fastq.gz ... done.
# Length: 308733725 (294M) (unauthoritative)
#
# SRR9985516_2.fastq. 100%[===================>] 294.43M  7.23MB/s    in 92s
#
# 2020-11-19 16:18:04 (3.19 MB/s) - ‘SRR9985516_2.fastq.gz’ saved [308733725]
#
# --2020-11-19 16:18:04--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_1.fastq.gz
#            => ‘SRR9985517_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985517 ... done.
# ==> SIZE SRR9985517_1.fastq.gz ... 300067368
# ==> PASV ... done.    ==> RETR SRR9985517_1.fastq.gz ... done.
# Length: 300067368 (286M) (unauthoritative)
#
# SRR9985517_1.fastq. 100%[===================>] 286.17M  10.2MB/s    in 93s
#
# 2020-11-19 16:19:40 (3.08 MB/s) - ‘SRR9985517_1.fastq.gz’ saved [300067368]
#
# --2020-11-19 16:19:41--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_2.fastq.gz
#            => ‘SRR9985517_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985517 ... done.
# ==> SIZE SRR9985517_2.fastq.gz ... 306479429
# ==> PASV ... done.    ==> RETR SRR9985517_2.fastq.gz ... done.
# Length: 306479429 (292M) (unauthoritative)
#
# SRR9985517_2.fastq. 100%[===================>] 292.28M  6.78MB/s    in 63s
#
# 2020-11-19 16:20:47 (4.62 MB/s) - ‘SRR9985517_2.fastq.gz’ saved [306479429]
#
# --2020-11-19 16:20:47--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_1.fastq.gz
#            => ‘SRR9985518_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985518 ... done.
# ==> SIZE SRR9985518_1.fastq.gz ... 738541328
# ==> PASV ... done.    ==> RETR SRR9985518_1.fastq.gz ... done.
# Length: 738541328 (704M) (unauthoritative)
#
# SRR9985518_1.fastq. 100%[===================>] 704.33M  12.2MB/s    in 96s
#
# 2020-11-19 16:22:26 (7.36 MB/s) - ‘SRR9985518_1.fastq.gz’ saved [738541328]
#
# --2020-11-19 16:22:26--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_2.fastq.gz
#            => ‘SRR9985518_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985518 ... done.
# ==> SIZE SRR9985518_2.fastq.gz ... 753461882
# ==> PASV ... done.    ==> RETR SRR9985518_2.fastq.gz ... done.
# Length: 753461882 (719M) (unauthoritative)
#
# SRR9985518_2.fastq. 100%[===================>] 718.56M  11.7MB/s    in 1m 54s
#
# 2020-11-19 16:24:24 (6.30 MB/s) - ‘SRR9985518_2.fastq.gz’ saved [753461882]
#
# --2020-11-19 16:24:24--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_1.fastq.gz
#            => ‘SRR9985511_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985511 ... done.
# ==> SIZE SRR9985511_1.fastq.gz ... 734798658
# ==> PASV ... done.    ==> RETR SRR9985511_1.fastq.gz ... done.
# Length: 734798658 (701M) (unauthoritative)
#
# SRR9985511_1.fastq. 100%[===================>] 700.76M  2.81MB/s    in 1m 58s
#
# 2020-11-19 16:26:25 (5.96 MB/s) - ‘SRR9985511_1.fastq.gz’ saved [734798658]
#
# --2020-11-19 16:26:25--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_2.fastq.gz
#            => ‘SRR9985511_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985511 ... done.
# ==> SIZE SRR9985511_2.fastq.gz ... 740300733
# ==> PASV ... done.    ==> RETR SRR9985511_2.fastq.gz ... done.
# Length: 740300733 (706M) (unauthoritative)
#
# SRR9985511_2.fastq. 100%[===================>] 706.00M  1.59MB/s    in 2m 58s
#
# 2020-11-19 16:29:26 (3.97 MB/s) - ‘SRR9985511_2.fastq.gz’ saved [740300733]
#
# --2020-11-19 16:29:26--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_1.fastq.gz
#            => ‘SRR9985515_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985515 ... done.
# ==> SIZE SRR9985515_1.fastq.gz ... 326544779
# ==> PASV ... done.    ==> RETR SRR9985515_1.fastq.gz ... done.
# Length: 326544779 (311M) (unauthoritative)
#
# SRR9985515_1.fastq. 100%[===================>] 311.42M  12.0MB/s    in 93s
#
# 2020-11-19 16:31:04 (3.33 MB/s) - ‘SRR9985515_1.fastq.gz’ saved [326544779]
#
# --2020-11-19 16:31:04--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_2.fastq.gz
#            => ‘SRR9985515_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985515 ... done.
# ==> SIZE SRR9985515_2.fastq.gz ... 325966360
# ==> PASV ... done.    ==> RETR SRR9985515_2.fastq.gz ... done.
# Length: 325966360 (311M) (unauthoritative)
#
# SRR9985515_2.fastq. 100%[===================>] 310.87M  5.29MB/s    in 42s
#
# 2020-11-19 16:31:49 (7.43 MB/s) - ‘SRR9985515_2.fastq.gz’ saved [325966360]
#
# --2020-11-19 16:31:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_1.fastq.gz
#            => ‘SRR9985514_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985514 ... done.
# ==> SIZE SRR9985514_1.fastq.gz ... 327004580
# ==> PASV ... done.    ==> RETR SRR9985514_1.fastq.gz ... done.
# Length: 327004580 (312M) (unauthoritative)
#
# SRR9985514_1.fastq. 100%[===================>] 311.86M  3.50MB/s    in 2m 7s
#
# 2020-11-19 16:33:59 (2.45 MB/s) - ‘SRR9985514_1.fastq.gz’ saved [327004580]
#
# --2020-11-19 16:34:00--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_2.fastq.gz
#            => ‘SRR9985514_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985514 ... done.
# ==> SIZE SRR9985514_2.fastq.gz ... 327681334
# ==> PASV ... done.    ==> RETR SRR9985514_2.fastq.gz ... done.
# Length: 327681334 (313M) (unauthoritative)
#
# SRR9985514_2.fastq. 100%[===================>] 312.50M  10.2MB/s    in 36s
#
# 2020-11-19 16:34:40 (8.58 MB/s) - ‘SRR9985514_2.fastq.gz’ saved [327681334]
#
# --2020-11-19 16:34:40--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_1.fastq.gz
#            => ‘SRR9985512_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985512 ... done.
# ==> SIZE SRR9985512_1.fastq.gz ... 310550951
# ==> PASV ... done.    ==> RETR SRR9985512_1.fastq.gz ... done.
# Length: 310550951 (296M) (unauthoritative)
#
# SRR9985512_1.fastq. 100%[===================>] 296.16M  1.16MB/s    in 1m 43s
#
# 2020-11-19 16:36:26 (2.88 MB/s) - ‘SRR9985512_1.fastq.gz’ saved [310550951]
#
# --2020-11-19 16:36:26--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_2.fastq.gz
#            => ‘SRR9985512_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985512 ... done.
# ==> SIZE SRR9985512_2.fastq.gz ... 317079656
# ==> PASV ... done.    ==> RETR SRR9985512_2.fastq.gz ... done.
# Length: 317079656 (302M) (unauthoritative)
#
# SRR9985512_2.fastq. 100%[===================>] 302.39M  1.01MB/s    in 3m 59s
#
# 2020-11-19 16:40:29 (1.27 MB/s) - ‘SRR9985512_2.fastq.gz’ saved [317079656]
#
# --2020-11-19 16:40:29--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_1.fastq.gz
#            => ‘SRR9985510_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985510 ... done.
# ==> SIZE SRR9985510_1.fastq.gz ... 735054841
# ==> PASV ... done.    ==> RETR SRR9985510_1.fastq.gz ... done.
# Length: 735054841 (701M) (unauthoritative)
#
# SRR9985510_1.fastq. 100%[===================>] 701.00M  11.9MB/s    in 1m 51s
#
# 2020-11-19 16:42:24 (6.31 MB/s) - ‘SRR9985510_1.fastq.gz’ saved [735054841]
#
# --2020-11-19 16:42:24--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_2.fastq.gz
#            => ‘SRR9985510_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985510 ... done.
# ==> SIZE SRR9985510_2.fastq.gz ... 743516384
# ==> PASV ... done.    ==> RETR SRR9985510_2.fastq.gz ... done.
# Length: 743516384 (709M) (unauthoritative)
#
# SRR9985510_2.fastq. 100%[===================>] 709.07M  11.2MB/s    in 71s
#
# 2020-11-19 16:43:39 (10.1 MB/s) - ‘SRR9985510_2.fastq.gz’ saved [743516384]
#
# --2020-11-19 16:43:39--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_1.fastq.gz
#            => ‘SRR9985508_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985508 ... done.
# ==> SIZE SRR9985508_1.fastq.gz ... 668694771
# ==> PASV ... done.    ==> RETR SRR9985508_1.fastq.gz ... done.
# Length: 668694771 (638M) (unauthoritative)
#
# SRR9985508_1.fastq. 100%[===================>] 637.72M   994KB/s    in 6m 0s
#
# 2020-11-19 16:49:42 (1.77 MB/s) - ‘SRR9985508_1.fastq.gz’ saved [668694771]
#
# --2020-11-19 16:49:42--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_2.fastq.gz
#            => ‘SRR9985508_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985508 ... done.
# ==> SIZE SRR9985508_2.fastq.gz ... 679453991
# ==> PASV ... done.    ==> RETR SRR9985508_2.fastq.gz ... done.
# Length: 679453991 (648M) (unauthoritative)
#
# SRR9985508_2.fastq. 100%[===================>] 647.98M  12.2MB/s    in 1m 45s
#
# 2020-11-19 16:51:30 (6.20 MB/s) - ‘SRR9985508_2.fastq.gz’ saved [679453991]
#
# --2020-11-19 16:51:30--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_1.fastq.gz
#            => ‘SRR9985513_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985513 ... done.
# ==> SIZE SRR9985513_1.fastq.gz ... 309178433
# ==> PASV ... done.    ==> RETR SRR9985513_1.fastq.gz ... done.
# Length: 309178433 (295M) (unauthoritative)
#
# SRR9985513_1.fastq. 100%[===================>] 294.86M  11.7MB/s    in 35s
#
# 2020-11-19 16:52:09 (8.48 MB/s) - ‘SRR9985513_1.fastq.gz’ saved [309178433]
#
# --2020-11-19 16:52:09--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_2.fastq.gz
#            => ‘SRR9985513_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985513 ... done.
# ==> SIZE SRR9985513_2.fastq.gz ... 314534778
# ==> PASV ... done.    ==> RETR SRR9985513_2.fastq.gz ... done.
# Length: 314534778 (300M) (unauthoritative)
#
# SRR9985513_2.fastq. 100%[===================>] 299.96M  11.9MB/s    in 27s
#
# 2020-11-19 16:52:40 (10.9 MB/s) - ‘SRR9985513_2.fastq.gz’ saved [314534778]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2020-11-19 16:52:47,378]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [02:38<00:00, 15.0MB/s]
# [2020-11-19 16:55:28,302]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['SRR9985495_1.fastq.gz', 'SRR9985495_2.fastq.gz', 'SRR9985496_1.fastq.gz', 'SRR9985496_2.fastq.gz', 'SRR9985497_1.fastq.gz', 'SRR9985497_2.fastq.gz', 'SRR9985498_1.fastq.gz', 'SRR9985498_2.fastq.gz', 'SRR9985499_1.fastq.gz', 'SRR9985499_2.fastq.gz', 'SRR9985500_1.fastq.gz', 'SRR9985500_2.fastq.gz', 'SRR9985501_1.fastq.gz', 'SRR9985501_2.fastq.gz', 'SRR9985502_1.fastq.gz', 'SRR9985502_2.fastq.gz', 'SRR9985503_1.fastq.gz', 'SRR9985503_2.fastq.gz', 'SRR9985504_1.fastq.gz', 'SRR9985504_2.fastq.gz', 'SRR9985505_1.fastq.gz', 'SRR9985505_2.fastq.gz', 'SRR9985506_1.fastq.gz', 'SRR9985506_2.fastq.gz', 'SRR9985507_1.fastq.gz', 'SRR9985507_2.fastq.gz', 'SRR9985508_1.fastq.gz', 'SRR9985508_2.fastq.gz', 'SRR9985509_1.fastq.gz', 'SRR9985509_2.fastq.gz', 'SRR9985510_1.fastq.gz', 'SRR9985510_2.fastq.gz', 'SRR9985511_1.fastq.gz', 'SRR9985511_2.fastq.gz', 'SRR9985512_1.fastq.gz', 'SRR9985512_2.fastq.gz', 'SRR9985513_1.fastq.gz', 'SRR9985513_2.fastq.gz', 'SRR9985514_1.fastq.gz', 'SRR9985514_2.fastq.gz', 'SRR9985515_1.fastq.gz', 'SRR9985515_2.fastq.gz', 'SRR9985516_1.fastq.gz', 'SRR9985516_2.fastq.gz', 'SRR9985517_1.fastq.gz', 'SRR9985517_2.fastq.gz', 'SRR9985518_1.fastq.gz', 'SRR9985518_2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['SRR9985495_1.fastq.gz',
#  'SRR9985495_2.fastq.gz',
#  'SRR9985496_1.fastq.gz',
#  'SRR9985496_2.fastq.gz',
#  'SRR9985497_1.fastq.gz',
#  'SRR9985497_2.fastq.gz',
#  'SRR9985498_1.fastq.gz',
#  'SRR9985498_2.fastq.gz',
#  'SRR9985499_1.fastq.gz',
#  'SRR9985499_2.fastq.gz',
#  'SRR9985500_1.fastq.gz',
#  'SRR9985500_2.fastq.gz',
#  'SRR9985501_1.fastq.gz',
#  'SRR9985501_2.fastq.gz',
#  'SRR9985502_1.fastq.gz',
#  'SRR9985502_2.fastq.gz',
#  'SRR9985503_1.fastq.gz',
#  'SRR9985503_2.fastq.gz',
#  'SRR9985504_1.fastq.gz',
#  'SRR9985504_2.fastq.gz',
#  'SRR9985505_1.fastq.gz',
#  'SRR9985505_2.fastq.gz',
#  'SRR9985506_1.fastq.gz',
#  'SRR9985506_2.fastq.gz',
#  'SRR9985507_1.fastq.gz',
#  'SRR9985507_2.fastq.gz',
#  'SRR9985508_1.fastq.gz',
#  'SRR9985508_2.fastq.gz',
#  'SRR9985509_1.fastq.gz',
#  'SRR9985509_2.fastq.gz',
#  'SRR9985510_1.fastq.gz',
#  'SRR9985510_2.fastq.gz',
#  'SRR9985511_1.fastq.gz',
#  'SRR9985511_2.fastq.gz',
#  'SRR9985512_1.fastq.gz',
#  'SRR9985512_2.fastq.gz',
#  'SRR9985513_1.fastq.gz',
#  'SRR9985513_2.fastq.gz',
#  'SRR9985514_1.fastq.gz',
#  'SRR9985514_2.fastq.gz',
#  'SRR9985515_1.fastq.gz',
#  'SRR9985515_2.fastq.gz',
#  'SRR9985516_1.fastq.gz',
#  'SRR9985516_2.fastq.gz',
#  'SRR9985517_1.fastq.gz',
#  'SRR9985517_2.fastq.gz',
#  'SRR9985518_1.fastq.gz',
#  'SRR9985518_2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-11-19 16:56:10,740]    INFO Using index index.idx to generate BUS file to outputGSM4037325 from
# [2020-11-19 16:56:10,740]    INFO         SRR9985495_1.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985495_2.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985496_1.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985496_2.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985497_1.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985497_2.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985498_1.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985498_2.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985499_1.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985499_2.fastq.gz
# [2020-11-19 16:56:10,740]    INFO         SRR9985500_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985500_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985501_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985501_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985502_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985502_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985503_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985503_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985504_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985504_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985505_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985505_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985506_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985506_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985507_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985507_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985508_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985508_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985509_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985509_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985510_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985510_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985511_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985511_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985512_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985512_2.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985513_1.fastq.gz
# [2020-11-19 16:56:10,741]    INFO         SRR9985513_2.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985514_1.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985514_2.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985515_1.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985515_2.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985516_1.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985516_2.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985517_1.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985517_2.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985518_1.fastq.gz
# [2020-11-19 16:56:10,742]    INFO         SRR9985518_2.fastq.gz
# [2020-11-19 17:38:53,222]    INFO Sorting BUS file outputGSM4037325/output.bus to outputGSM4037325/tmp/output.s.bus
# [2020-11-19 17:42:55,220]    INFO Whitelist not provided
# [2020-11-19 17:42:55,220]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM4037325
# [2020-11-19 17:42:55,353]    INFO Inspecting BUS file outputGSM4037325/tmp/output.s.bus
# [2020-11-19 17:43:25,219]    INFO Correcting BUS records in outputGSM4037325/tmp/output.s.bus to outputGSM4037325/tmp/output.s.c.bus with whitelist outputGSM4037325/10xv2_whitelist.txt
# [2020-11-19 17:44:14,472]    INFO Sorting BUS file outputGSM4037325/tmp/output.s.c.bus to outputGSM4037325/output.unfiltered.bus
# [2020-11-19 17:46:31,904]    INFO Generating count matrix outputGSM4037325/counts_unfiltered/cells_x_genes from BUS file outputGSM4037325/output.unfiltered.bus
# [2020-11-19 17:47:47,738]    INFO Reading matrix outputGSM4037325/counts_unfiltered/cells_x_genes.mtx
# [2020-11-19 17:48:34,201]    INFO Writing matrix to h5ad outputGSM4037325/counts_unfiltered/adata.h5ad
# ... storing 'gene_name' as categorical
# [2020-11-19 17:48:35,648]    INFO Filtering with bustools
# [2020-11-19 17:48:35,648]    INFO Generating whitelist outputGSM4037325/filter_barcodes.txt from BUS file outputGSM4037325/output.unfiltered.bus
# [2020-11-19 17:48:36,435]    INFO Correcting BUS records in outputGSM4037325/output.unfiltered.bus to outputGSM4037325/tmp/output.unfiltered.c.bus with whitelist outputGSM4037325/filter_barcodes.txt
# [2020-11-19 17:49:02,518]    INFO Sorting BUS file outputGSM4037325/tmp/output.unfiltered.c.bus to outputGSM4037325/output.filtered.bus
# [2020-11-19 17:50:04,924]    INFO Generating count matrix outputGSM4037325/counts_filtered/cells_x_genes from BUS file outputGSM4037325/output.filtered.bus
# [2020-11-19 17:50:32,918]    INFO Reading matrix outputGSM4037325/counts_filtered/cells_x_genes.mtx
# [2020-11-19 17:50:47,702]    INFO Writing matrix to h5ad outputGSM4037325/counts_filtered/adata.h5ad
# ... storing 'gene_name' as categorical

# %% [markdown]
# # Waiting

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM4037325 contains 467082 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 5700#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 33#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 5700 with at least 515.0 UMIs
# We select 33 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 467,082 cells x 60,623 genes
#     New shape: 5,551 cells x 31,372 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
