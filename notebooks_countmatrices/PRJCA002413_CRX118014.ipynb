# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/PRJCA002413_CRX118014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRJCA002413_CRX118014

# %%
# define the values for the analysis

# accession id for the data
id = "PRJCA002413"
samp_id = ["CRX118014"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet
  links_raw = "ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_r2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

#sample specific metadata

no_samples = 1

condition = ["healthy control"] * no_samples

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["blood"] * no_samples

cell_type = ["PBMCs"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Wen et al 2020"] * no_samples

figure = ["Fig: all"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 1.2MB/s
#      |████████████████████████████████| 10.3MB 50.8MB/s
#      |████████████████████████████████| 51kB 3.8MB/s
#      |████████████████████████████████| 13.2MB 65.9MB/s
#      |████████████████████████████████| 133kB 86.1MB/s
#      |████████████████████████████████| 81kB 6.5MB/s
#      |████████████████████████████████| 112kB 78.0MB/s
#      |████████████████████████████████| 1.2MB 66.4MB/s
#      |████████████████████████████████| 71kB 6.9MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  while len(os.listdir()) != len(fastqs):
    for link in fastqs:
      # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2021-04-28 01:25:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_f1.fastq.gz
#            => ‘CRR143977_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143977 ...
# No such directory ‘gsa3/CRA002497/CRR143977’.
#
# --2021-04-28 01:25:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_r2.fastq.gz
#            => ‘CRR143977_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143977 ...
# No such directory ‘gsa3/CRA002497/CRR143977’.
#
# --2021-04-28 01:25:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_f1.fastq.gz
#            => ‘CRR143978_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143978 ... done.
# ==> SIZE CRR143978_f1.fastq.gz ... 1039839804
# ==> PASV ... done.    ==> RETR CRR143978_f1.fastq.gz ... done.
# Length: 1039839804 (992M) (unauthoritative)
#
# CRR143978_f1.fastq. 100%[===================>] 991.67M  9.22MB/s    in 1m 51s
#
# 2021-04-28 01:27:36 (8.92 MB/s) - ‘CRR143978_f1.fastq.gz’ saved [1039839804]
#
# --2021-04-28 01:27:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_r2.fastq.gz
#            => ‘CRR143978_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143978 ...
# No such directory ‘gsa3/CRA002497/CRR143978’.
#
# --2021-04-28 01:27:50--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_f1.fastq.gz
#            => ‘CRR143979_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ... done.
# ==> SIZE CRR143979_f1.fastq.gz ... 853486762
# ==> PASV ... done.    ==> RETR CRR143979_f1.fastq.gz ... done.
# Length: 853486762 (814M) (unauthoritative)
#
# CRR143979_f1.fastq. 100%[===================>] 813.95M  4.70MB/s    in 2m 55s
#
# 2021-04-28 01:30:49 (4.65 MB/s) - ‘CRR143979_f1.fastq.gz’ saved [853486762]
#
# --2021-04-28 01:30:49--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_r2.fastq.gz
#            => ‘CRR143979_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ...
# No such directory ‘gsa3/CRA002497/CRR143979’.
#
# --2021-04-28 01:31:02--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_f1.fastq.gz
#            => ‘CRR143980_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ... done.
# ==> SIZE CRR143980_f1.fastq.gz ... 1808523116
# ==> PASV ... done.    ==> RETR CRR143980_f1.fastq.gz ... done.
# Length: 1808523116 (1.7G) (unauthoritative)
#
# CRR143980_f1.fastq. 100%[===================>]   1.68G  6.92MB/s    in 6m 15s
#
# 2021-04-28 01:37:21 (4.60 MB/s) - ‘CRR143980_f1.fastq.gz’ saved [1808523116]
#
# --2021-04-28 01:37:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_r2.fastq.gz
#            => ‘CRR143980_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ... done.
# ==> SIZE CRR143980_r2.fastq.gz ... 1813862669
# ==> PASV ... done.    ==> RETR CRR143980_r2.fastq.gz ... done.
# Length: 1813862669 (1.7G) (unauthoritative)
#
# CRR143980_r2.fastq. 100%[===================>]   1.69G  8.62MB/s    in 3m 33s
#
# 2021-04-28 01:40:59 (8.12 MB/s) - ‘CRR143980_r2.fastq.gz’ saved [1813862669]
#
# --2021-04-28 01:40:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_f1.fastq.gz
#            => ‘CRR143981_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ...
# No such directory ‘gsa3/CRA002497/CRR143981’.
#
# --2021-04-28 01:41:12--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_r2.fastq.gz
#            => ‘CRR143981_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ... done.
# ==> SIZE CRR143981_r2.fastq.gz ... 1084767493
# ==> PASV ... done.    ==> RETR CRR143981_r2.fastq.gz ... done.
# Length: 1084767493 (1.0G) (unauthoritative)
#
# CRR143981_r2.fastq. 100%[===================>]   1.01G  8.87MB/s    in 2m 21s
#
# 2021-04-28 01:43:37 (7.34 MB/s) - ‘CRR143981_r2.fastq.gz’ saved [1084767493]
#
# --2021-04-28 01:43:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_f1.fastq.gz
#            => ‘CRR143982_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ... done.
# ==> SIZE CRR143982_f1.fastq.gz ... 1758518551
# ==> PASV ... done.    ==> RETR CRR143982_f1.fastq.gz ... done.
# Length: 1758518551 (1.6G) (unauthoritative)
#
# CRR143982_f1.fastq. 100%[===================>]   1.64G  7.63MB/s    in 4m 45s
#
# 2021-04-28 01:48:26 (5.89 MB/s) - ‘CRR143982_f1.fastq.gz’ saved [1758518551]
#
# --2021-04-28 01:48:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_r2.fastq.gz
#            => ‘CRR143982_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ... done.
# ==> SIZE CRR143982_r2.fastq.gz ... 1736130668
# ==> PASV ... done.    ==> RETR CRR143982_r2.fastq.gz ... done.
# Length: 1736130668 (1.6G) (unauthoritative)
#
# CRR143982_r2.fastq. 100%[===================>]   1.62G  8.36MB/s    in 3m 59s
#
# 2021-04-28 01:52:31 (6.91 MB/s) - ‘CRR143982_r2.fastq.gz’ saved [1736130668]
#
# --2021-04-28 01:52:31--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_f1.fastq.gz
#            => ‘CRR143983_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ...
# No such directory ‘gsa3/CRA002497/CRR143983’.
#
# --2021-04-28 01:52:45--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_r2.fastq.gz
#            => ‘CRR143983_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ...
# No such directory ‘gsa3/CRA002497/CRR143983’.
#
# --2021-04-28 01:52:58--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_f1.fastq.gz
#            => ‘CRR143984_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143984 ... done.
# ==> SIZE CRR143984_f1.fastq.gz ... 837973043
# ==> PASV ... done.    ==> RETR CRR143984_f1.fastq.gz ... done.
# Length: 837973043 (799M) (unauthoritative)
#
# CRR143984_f1.fastq. 100%[===================>] 799.15M  9.24MB/s    in 91s
#
# 2021-04-28 01:54:33 (8.78 MB/s) - ‘CRR143984_f1.fastq.gz’ saved [837973043]
#
# --2021-04-28 01:54:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_r2.fastq.gz
#            => ‘CRR143984_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143984 ... done.
# ==> SIZE CRR143984_r2.fastq.gz ... 825257042
# ==> PASV ... done.    ==> RETR CRR143984_r2.fastq.gz ... done.
# Length: 825257042 (787M) (unauthoritative)
#
# CRR143984_r2.fastq. 100%[===================>] 787.03M  9.20MB/s    in 89s
#
# 2021-04-28 01:56:07 (8.84 MB/s) - ‘CRR143984_r2.fastq.gz’ saved [825257042]
#
# --2021-04-28 01:56:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_f1.fastq.gz
#            => ‘CRR143985_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143985 ... done.
# ==> SIZE CRR143985_f1.fastq.gz ... 2758316588
# ==> PASV ... done.    ==> RETR CRR143985_f1.fastq.gz ... done.
# Length: 2758316588 (2.6G) (unauthoritative)
#
# CRR143985_f1.fastq. 100%[===================>]   2.57G  8.82MB/s    in 4m 50s
#
# 2021-04-28 02:01:01 (9.09 MB/s) - ‘CRR143985_f1.fastq.gz’ saved [2758316588]
#
# --2021-04-28 02:01:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_r2.fastq.gz
#            => ‘CRR143985_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143985 ...
# No such directory ‘gsa3/CRA002497/CRR143985’.
#
# --2021-04-28 02:01:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_f1.fastq.gz
#            => ‘CRR143986_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143986 ... done.
# ==> SIZE CRR143986_f1.fastq.gz ... 1681580856
# ==> PASV ... done.    ==> RETR CRR143986_f1.fastq.gz ... done.
# Length: 1681580856 (1.6G) (unauthoritative)
#
# CRR143986_f1.fastq. 100%[===================>]   1.57G  8.68MB/s    in 3m 0s
#
# 2021-04-28 02:04:18 (8.93 MB/s) - ‘CRR143986_f1.fastq.gz’ saved [1681580856]
#
# --2021-04-28 02:04:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_r2.fastq.gz
#            => ‘CRR143986_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143986 ... done.
# ==> SIZE CRR143986_r2.fastq.gz ... 6431553408
# ==> PASV ... done.    ==> RETR CRR143986_r2.fastq.gz ... done.
# Length: 6431553408 (6.0G) (unauthoritative)
#
# CRR143986_r2.fastq. 100%[===================>]   5.99G  9.43MB/s    in 16m 34s
#
# 2021-04-28 02:20:56 (6.17 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 02:35:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_r2.fastq.gz
#   (try: 2) => ‘CRR143986_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143986 ... done.
# ==> SIZE CRR143986_r2.fastq.gz ... 6431553408
# File has already been retrieved.
# 2021-04-28 02:36:00 (0.00 B/s) - ‘CRR143986_r2.fastq.gz’ saved [6431553408]
#
# --2021-04-28 02:36:00--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_f1.fastq.gz
#            => ‘CRR143987_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143987 ...
# No such directory ‘gsa3/CRA002497/CRR143987’.
#
# --2021-04-28 02:36:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_r2.fastq.gz
#            => ‘CRR143987_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143987 ... done.
# ==> SIZE CRR143987_r2.fastq.gz ... 5674427750
# ==> PASV ... done.    ==> RETR CRR143987_r2.fastq.gz ... done.
# Length: 5674427750 (5.3G) (unauthoritative)
#
# CRR143987_r2.fastq. 100%[===================>]   5.28G  2.75MB/s    in 13m 41s
#
# 2021-04-28 02:50:00 (6.59 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 03:05:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_r2.fastq.gz
#   (try: 2) => ‘CRR143987_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143987 ...
# No such directory ‘gsa3/CRA002497/CRR143987’.
#
# --2021-04-28 03:05:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_f1.fastq.gz
#            => ‘CRR143988_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143988 ...
# No such directory ‘gsa3/CRA002497/CRR143988’.
#
# --2021-04-28 03:05:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_r2.fastq.gz
#            => ‘CRR143988_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143988 ... done.
# ==> SIZE CRR143988_r2.fastq.gz ... 5249829923
# ==> PASV ... done.    ==> RETR CRR143988_r2.fastq.gz ... done.
# Length: 5249829923 (4.9G) (unauthoritative)
#
# CRR143988_r2.fastq. 100%[===================>]   4.89G  8.53MB/s    in 9m 52s
#
# 2021-04-28 03:15:24 (8.46 MB/s) - ‘CRR143988_r2.fastq.gz’ saved [5249829923]
#
# --2021-04-28 03:15:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_f1.fastq.gz
#            => ‘CRR143989_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143989 ...
# No such directory ‘gsa3/CRA002497/CRR143989’.
#
# --2021-04-28 03:15:38--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_r2.fastq.gz
#            => ‘CRR143989_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143989 ... done.
# ==> SIZE CRR143989_r2.fastq.gz ... 772950910
# ==> PASV ... done.    ==> RETR CRR143989_r2.fastq.gz ... done.
# Length: 772950910 (737M) (unauthoritative)
#
# CRR143989_r2.fastq. 100%[===================>] 737.14M  8.98MB/s    in 87s
#
# 2021-04-28 03:17:10 (8.43 MB/s) - ‘CRR143989_r2.fastq.gz’ saved [772950910]
#
# --2021-04-28 03:17:10--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_f1.fastq.gz
#            => ‘CRR143990_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143990 ... done.
# ==> SIZE CRR143990_f1.fastq.gz ... 126902123
# ==> PASV ... done.    ==> RETR CRR143990_f1.fastq.gz ... done.
# Length: 126902123 (121M) (unauthoritative)
#
# CRR143990_f1.fastq. 100%[===================>] 121.02M  8.86MB/s    in 17s
#
# 2021-04-28 03:17:31 (7.30 MB/s) - ‘CRR143990_f1.fastq.gz’ saved [126902123]
#
# --2021-04-28 03:17:31--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_r2.fastq.gz
#            => ‘CRR143990_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143990 ...
# No such directory ‘gsa3/CRA002497/CRR143990’.
#
# --2021-04-28 03:17:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_f1.fastq.gz
#            => ‘CRR143991_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143991 ... done.
# ==> SIZE CRR143991_f1.fastq.gz ... 112747312
# ==> PASV ... done.    ==> RETR CRR143991_f1.fastq.gz ... done.
# Length: 112747312 (108M) (unauthoritative)
#
# CRR143991_f1.fastq. 100%[===================>] 107.52M  8.58MB/s    in 15s
#
# 2021-04-28 03:18:04 (7.19 MB/s) - ‘CRR143991_f1.fastq.gz’ saved [112747312]
#
# --2021-04-28 03:18:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_r2.fastq.gz
#            => ‘CRR143991_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143991 ...
# No such directory ‘gsa3/CRA002497/CRR143991’.
#
# --2021-04-28 03:18:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_f1.fastq.gz
#            => ‘CRR143992_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143992 ... done.
# ==> SIZE CRR143992_f1.fastq.gz ... 104210218
# ==> PASV ... done.    ==> RETR CRR143992_f1.fastq.gz ... done.
# Length: 104210218 (99M) (unauthoritative)
#
# CRR143992_f1.fastq. 100%[===================>]  99.38M  8.81MB/s    in 14s
#
# 2021-04-28 03:18:36 (7.24 MB/s) - ‘CRR143992_f1.fastq.gz’ saved [104210218]
#
# --2021-04-28 03:18:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_r2.fastq.gz
#            => ‘CRR143992_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143992 ... done.
# ==> SIZE CRR143992_r2.fastq.gz ... 382788464
# ==> PASV ... done.    ==> RETR CRR143992_r2.fastq.gz ... done.
# Length: 382788464 (365M) (unauthoritative)
#
# CRR143992_r2.fastq. 100%[===================>] 365.05M  8.81MB/s    in 44s
#
# 2021-04-28 03:19:25 (8.27 MB/s) - ‘CRR143992_r2.fastq.gz’ saved [382788464]
#
# --2021-04-28 03:19:26--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_f1.fastq.gz
#            => ‘CRR143977_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143977 ... done.
# ==> SIZE CRR143977_f1.fastq.gz ... 780495252
# ==> PASV ... done.    ==> RETR CRR143977_f1.fastq.gz ... done.
# Length: 780495252 (744M) (unauthoritative)
#
# CRR143977_f1.fastq. 100%[===================>] 744.34M  8.86MB/s    in 88s
#
# 2021-04-28 03:20:57 (8.48 MB/s) - ‘CRR143977_f1.fastq.gz’ saved [780495252]
#
# --2021-04-28 03:20:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_r2.fastq.gz
#            => ‘CRR143977_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143977 ... done.
# ==> SIZE CRR143977_r2.fastq.gz ... 839689293
# ==> PASV ... done.    ==> RETR CRR143977_r2.fastq.gz ... done.
# Length: 839689293 (801M) (unauthoritative)
#
# CRR143977_r2.fastq. 100%[===================>] 800.79M  8.69MB/s    in 99s
#
# 2021-04-28 03:22:40 (8.09 MB/s) - ‘CRR143977_r2.fastq.gz’ saved [839689293]
#
# --2021-04-28 03:22:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_f1.fastq.gz
#            => ‘CRR143978_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143978 ... done.
# ==> SIZE CRR143978_f1.fastq.gz ... 1039839804
# File has already been retrieved.
# 2021-04-28 03:22:43 (0.00 B/s) - ‘CRR143978_f1.fastq.gz’ saved [1039839804]
#
# --2021-04-28 03:22:43--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_r2.fastq.gz
#            => ‘CRR143978_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143978 ...
# No such directory ‘gsa3/CRA002497/CRR143978’.
#
# --2021-04-28 03:22:56--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_f1.fastq.gz
#            => ‘CRR143979_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ... done.
# ==> SIZE CRR143979_f1.fastq.gz ... 853486762
# File has already been retrieved.
# 2021-04-28 03:22:59 (0.00 B/s) - ‘CRR143979_f1.fastq.gz’ saved [853486762]
#
# --2021-04-28 03:22:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_r2.fastq.gz
#            => ‘CRR143979_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ... done.
# ==> SIZE CRR143979_r2.fastq.gz ... 898432746
# ==> PASV ... done.    ==> RETR CRR143979_r2.fastq.gz ... done.
# Length: 898432746 (857M) (unauthoritative)
#
# CRR143979_r2.fastq. 100%[===================>] 856.81M  7.09MB/s    in 1m 57s
#
# 2021-04-28 03:25:00 (7.32 MB/s) - ‘CRR143979_r2.fastq.gz’ saved [898432746]
#
# --2021-04-28 03:25:00--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_f1.fastq.gz
#            => ‘CRR143980_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ... done.
# ==> SIZE CRR143980_f1.fastq.gz ... 1808523116
# File has already been retrieved.
# 2021-04-28 03:25:03 (0.00 B/s) - ‘CRR143980_f1.fastq.gz’ saved [1808523116]
#
# --2021-04-28 03:25:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_r2.fastq.gz
#            => ‘CRR143980_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ... done.
# ==> SIZE CRR143980_r2.fastq.gz ... 1813862669
# File has already been retrieved.
# 2021-04-28 03:25:07 (0.00 B/s) - ‘CRR143980_r2.fastq.gz’ saved [1813862669]
#
# --2021-04-28 03:25:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_f1.fastq.gz
#            => ‘CRR143981_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ...
# No such directory ‘gsa3/CRA002497/CRR143981’.
#
# --2021-04-28 03:25:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_r2.fastq.gz
#            => ‘CRR143981_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ... done.
# ==> SIZE CRR143981_r2.fastq.gz ... 1084767493
# File has already been retrieved.
# 2021-04-28 03:25:24 (0.00 B/s) - ‘CRR143981_r2.fastq.gz’ saved [1084767493]
#
# --2021-04-28 03:25:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_f1.fastq.gz
#            => ‘CRR143982_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ... done.
# ==> SIZE CRR143982_f1.fastq.gz ... 1758518551
# File has already been retrieved.
# 2021-04-28 03:25:27 (0.00 B/s) - ‘CRR143982_f1.fastq.gz’ saved [1758518551]
#
# --2021-04-28 03:25:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_r2.fastq.gz
#            => ‘CRR143982_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ...
# No such directory ‘gsa3/CRA002497/CRR143982’.
#
# --2021-04-28 03:25:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_f1.fastq.gz
#            => ‘CRR143983_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ...
# No such directory ‘gsa3/CRA002497/CRR143983’.
#
# --2021-04-28 03:25:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_r2.fastq.gz
#            => ‘CRR143983_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ...
# No such directory ‘gsa3/CRA002497/CRR143983’.
#
# --2021-04-28 03:26:05--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_f1.fastq.gz
#            => ‘CRR143984_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143984 ... done.
# ==> SIZE CRR143984_f1.fastq.gz ... 837973043
# File has already been retrieved.
# 2021-04-28 03:26:08 (0.00 B/s) - ‘CRR143984_f1.fastq.gz’ saved [837973043]
#
# --2021-04-28 03:26:08--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_r2.fastq.gz
#            => ‘CRR143984_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143984 ... done.
# ==> SIZE CRR143984_r2.fastq.gz ... 825257042
# File has already been retrieved.
# 2021-04-28 03:26:11 (0.00 B/s) - ‘CRR143984_r2.fastq.gz’ saved [825257042]
#
# --2021-04-28 03:26:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_f1.fastq.gz
#            => ‘CRR143985_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143985 ...
# No such directory ‘gsa3/CRA002497/CRR143985’.
#
# --2021-04-28 03:26:23--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_r2.fastq.gz
#            => ‘CRR143985_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143985 ...
# No such directory ‘gsa3/CRA002497/CRR143985’.
#
# --2021-04-28 03:26:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_f1.fastq.gz
#            => ‘CRR143986_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143986 ... done.
# ==> SIZE CRR143986_f1.fastq.gz ... 1681580856
# File has already been retrieved.
# 2021-04-28 03:26:39 (0.00 B/s) - ‘CRR143986_f1.fastq.gz’ saved [1681580856]
#
# --2021-04-28 03:26:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_r2.fastq.gz
#            => ‘CRR143986_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143986 ...
# No such directory ‘gsa3/CRA002497/CRR143986’.
#
# --2021-04-28 03:26:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_f1.fastq.gz
#            => ‘CRR143987_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143987 ... done.
# ==> SIZE CRR143987_f1.fastq.gz ... 1495794838
# ==> PASV ... done.    ==> RETR CRR143987_f1.fastq.gz ... done.
# Length: 1495794838 (1.4G) (unauthoritative)
#
# CRR143987_f1.fastq. 100%[===================>]   1.39G  8.77MB/s    in 2m 50s
#
# 2021-04-28 03:29:48 (8.38 MB/s) - ‘CRR143987_f1.fastq.gz’ saved [1495794838]
#
# --2021-04-28 03:29:48--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_r2.fastq.gz
#            => ‘CRR143987_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143987 ... done.
# ==> SIZE CRR143987_r2.fastq.gz ... 5674427750
# File has already been retrieved.
# 2021-04-28 03:29:52 (0.00 B/s) - ‘CRR143987_r2.fastq.gz’ saved [5674427750]
#
# --2021-04-28 03:29:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_f1.fastq.gz
#            => ‘CRR143988_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143988 ... done.
# ==> SIZE CRR143988_f1.fastq.gz ... 1383633563
# ==> PASV ... done.    ==> RETR CRR143988_f1.fastq.gz ... done.
# Length: 1383633563 (1.3G) (unauthoritative)
#
# CRR143988_f1.fastq. 100%[===================>]   1.29G  8.76MB/s    in 2m 36s
#
# 2021-04-28 03:32:32 (8.46 MB/s) - ‘CRR143988_f1.fastq.gz’ saved [1383633563]
#
# --2021-04-28 03:32:32--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_r2.fastq.gz
#            => ‘CRR143988_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143988 ... done.
# ==> SIZE CRR143988_r2.fastq.gz ... 5249829923
# File has already been retrieved.
# 2021-04-28 03:32:35 (0.00 B/s) - ‘CRR143988_r2.fastq.gz’ saved [5249829923]
#
# --2021-04-28 03:32:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_f1.fastq.gz
#            => ‘CRR143989_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143989 ...
# No such directory ‘gsa3/CRA002497/CRR143989’.
#
# --2021-04-28 03:32:48--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_r2.fastq.gz
#            => ‘CRR143989_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143989 ...
# No such directory ‘gsa3/CRA002497/CRR143989’.
#
# --2021-04-28 03:33:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_f1.fastq.gz
#            => ‘CRR143990_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143990 ... done.
# ==> SIZE CRR143990_f1.fastq.gz ... 126902123
# File has already been retrieved.
# 2021-04-28 03:33:06 (0.00 B/s) - ‘CRR143990_f1.fastq.gz’ saved [126902123]
#
# --2021-04-28 03:33:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_r2.fastq.gz
#            => ‘CRR143990_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143990 ...
# No such directory ‘gsa3/CRA002497/CRR143990’.
#
# --2021-04-28 03:33:19--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_f1.fastq.gz
#            => ‘CRR143991_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143991 ... done.
# ==> SIZE CRR143991_f1.fastq.gz ... 112747312
# File has already been retrieved.
# 2021-04-28 03:33:22 (0.00 B/s) - ‘CRR143991_f1.fastq.gz’ saved [112747312]
#
# --2021-04-28 03:33:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_r2.fastq.gz
#            => ‘CRR143991_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143991 ...
# No such directory ‘gsa3/CRA002497/CRR143991’.
#
# --2021-04-28 03:33:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_f1.fastq.gz
#            => ‘CRR143992_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143992 ...
# No such directory ‘gsa3/CRA002497/CRR143992’.
#
# --2021-04-28 03:33:48--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_r2.fastq.gz
#            => ‘CRR143992_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143992 ... done.
# ==> SIZE CRR143992_r2.fastq.gz ... 382788464
# File has already been retrieved.
# 2021-04-28 03:33:51 (0.00 B/s) - ‘CRR143992_r2.fastq.gz’ saved [382788464]
#
# --2021-04-28 03:33:51--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_f1.fastq.gz
#            => ‘CRR143977_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143977 ...
# No such directory ‘gsa3/CRA002497/CRR143977’.
#
# --2021-04-28 03:34:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143977/CRR143977_r2.fastq.gz
#            => ‘CRR143977_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143977 ... done.
# ==> SIZE CRR143977_r2.fastq.gz ... 839689293
# File has already been retrieved.
# 2021-04-28 03:34:07 (0.00 B/s) - ‘CRR143977_r2.fastq.gz’ saved [839689293]
#
# --2021-04-28 03:34:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_f1.fastq.gz
#            => ‘CRR143978_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143978 ...
# No such directory ‘gsa3/CRA002497/CRR143978’.
#
# --2021-04-28 03:34:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143978/CRR143978_r2.fastq.gz
#            => ‘CRR143978_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143978 ... done.
# ==> SIZE CRR143978_r2.fastq.gz ... 1008366420
# ==> PASV ... done.    ==> RETR CRR143978_r2.fastq.gz ... done.
# Length: 1008366420 (962M) (unauthoritative)
#
# CRR143978_r2.fastq. 100%[===================>] 961.65M  9.04MB/s    in 1m 55s
#
# 2021-04-28 03:36:19 (8.34 MB/s) - ‘CRR143978_r2.fastq.gz’ saved [1008366420]
#
# --2021-04-28 03:36:19--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_f1.fastq.gz
#            => ‘CRR143979_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ...
# No such directory ‘gsa3/CRA002497/CRR143979’.
#
# --2021-04-28 03:36:31--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_r2.fastq.gz
#            => ‘CRR143979_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ...
# No such directory ‘gsa3/CRA002497/CRR143979’.
#
# --2021-04-28 03:36:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_f1.fastq.gz
#            => ‘CRR143980_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ...
# No such directory ‘gsa3/CRA002497/CRR143980’.
#
# --2021-04-28 03:36:58--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_r2.fastq.gz
#            => ‘CRR143980_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ... done.
# ==> SIZE CRR143980_r2.fastq.gz ... 1813862669
# File has already been retrieved.
# 2021-04-28 03:37:01 (0.00 B/s) - ‘CRR143980_r2.fastq.gz’ saved [1813862669]
#
# --2021-04-28 03:37:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_f1.fastq.gz
#            => ‘CRR143981_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ... done.
# ==> SIZE CRR143981_f1.fastq.gz ... 1011297082
# ==> PASV ... done.    ==> RETR CRR143981_f1.fastq.gz ... done.
# Length: 1011297082 (964M) (unauthoritative)
#
# CRR143981_f1.fastq. 100%[===================>] 964.45M  8.95MB/s    in 1m 55s
#
# 2021-04-28 03:39:00 (8.40 MB/s) - ‘CRR143981_f1.fastq.gz’ saved [1011297082]
#
# --2021-04-28 03:39:00--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_r2.fastq.gz
#            => ‘CRR143981_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ...
# No such directory ‘gsa3/CRA002497/CRR143981’.
#
# --2021-04-28 03:39:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_f1.fastq.gz
#            => ‘CRR143982_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ... done.
# ==> SIZE CRR143982_f1.fastq.gz ... 1758518551
# File has already been retrieved.
# 2021-04-28 03:39:17 (0.00 B/s) - ‘CRR143982_f1.fastq.gz’ saved [1758518551]
#
# --2021-04-28 03:39:17--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_r2.fastq.gz
#            => ‘CRR143982_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ... done.
# ==> SIZE CRR143982_r2.fastq.gz ... 1736130668
# File has already been retrieved.
# 2021-04-28 03:39:20 (0.00 B/s) - ‘CRR143982_r2.fastq.gz’ saved [1736130668]
#
# --2021-04-28 03:39:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_f1.fastq.gz
#            => ‘CRR143983_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ...
# No such directory ‘gsa3/CRA002497/CRR143983’.
#
# --2021-04-28 03:39:32--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_r2.fastq.gz
#            => ‘CRR143983_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ... done.
# ==> SIZE CRR143983_r2.fastq.gz ... 915368743
# ==> PASV ... done.    ==> RETR CRR143983_r2.fastq.gz ... done.
# Length: 915368743 (873M) (unauthoritative)
#
# CRR143983_r2.fastq. 100%[===================>] 872.96M  8.92MB/s    in 1m 57s
#
# 2021-04-28 03:41:33 (7.49 MB/s) - ‘CRR143983_r2.fastq.gz’ saved [915368743]
#
# --2021-04-28 03:41:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_f1.fastq.gz
#            => ‘CRR143984_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# ...
# File has already been retrieved.
# 2021-04-28 04:42:03 (0.00 B/s) - ‘CRR143978_r2.fastq.gz’ saved [1008366420]
#
# --2021-04-28 04:42:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_f1.fastq.gz
#            => ‘CRR143979_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ... done.
# ==> SIZE CRR143979_f1.fastq.gz ... 853486762
# File has already been retrieved.
# 2021-04-28 04:42:07 (0.00 B/s) - ‘CRR143979_f1.fastq.gz’ saved [853486762]
#
# --2021-04-28 04:42:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143979/CRR143979_r2.fastq.gz
#            => ‘CRR143979_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143979 ... done.
# ==> SIZE CRR143979_r2.fastq.gz ... 898432746
# File has already been retrieved.
# 2021-04-28 04:42:09 (0.00 B/s) - ‘CRR143979_r2.fastq.gz’ saved [898432746]
#
# --2021-04-28 04:42:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_f1.fastq.gz
#            => ‘CRR143980_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ...
# No such directory ‘gsa3/CRA002497/CRR143980’.
#
# --2021-04-28 04:42:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143980/CRR143980_r2.fastq.gz
#            => ‘CRR143980_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143980 ... done.
# ==> SIZE CRR143980_r2.fastq.gz ... 1813862669
# File has already been retrieved.
# 2021-04-28 04:42:25 (0.00 B/s) - ‘CRR143980_r2.fastq.gz’ saved [1813862669]
#
# --2021-04-28 04:42:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_f1.fastq.gz
#            => ‘CRR143981_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ... done.
# ==> SIZE CRR143981_f1.fastq.gz ... 1011297082
# File has already been retrieved.
# 2021-04-28 04:42:28 (0.00 B/s) - ‘CRR143981_f1.fastq.gz’ saved [1011297082]
#
# --2021-04-28 04:42:28--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143981/CRR143981_r2.fastq.gz
#            => ‘CRR143981_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143981 ...
# No such directory ‘gsa3/CRA002497/CRR143981’.
#
# --2021-04-28 04:42:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_f1.fastq.gz
#            => ‘CRR143982_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ... done.
# ==> SIZE CRR143982_f1.fastq.gz ... 1758518551
# File has already been retrieved.
# 2021-04-28 04:42:43 (0.00 B/s) - ‘CRR143982_f1.fastq.gz’ saved [1758518551]
#
# --2021-04-28 04:42:43--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143982/CRR143982_r2.fastq.gz
#            => ‘CRR143982_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143982 ...
# No such directory ‘gsa3/CRA002497/CRR143982’.
#
# --2021-04-28 04:42:56--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_f1.fastq.gz
#            => ‘CRR143983_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ... done.
# ==> SIZE CRR143983_f1.fastq.gz ... 851861973
# File has already been retrieved.
# 2021-04-28 04:42:58 (0.00 B/s) - ‘CRR143983_f1.fastq.gz’ saved [851861973]
#
# --2021-04-28 04:42:58--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143983/CRR143983_r2.fastq.gz
#            => ‘CRR143983_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143983 ... done.
# ==> SIZE CRR143983_r2.fastq.gz ... 915368743
# File has already been retrieved.
# 2021-04-28 04:43:01 (0.00 B/s) - ‘CRR143983_r2.fastq.gz’ saved [915368743]
#
# --2021-04-28 04:43:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_f1.fastq.gz
#            => ‘CRR143984_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143984 ... done.
# ==> SIZE CRR143984_f1.fastq.gz ... 837973043
# File has already been retrieved.
# 2021-04-28 04:43:04 (0.00 B/s) - ‘CRR143984_f1.fastq.gz’ saved [837973043]
#
# --2021-04-28 04:43:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143984/CRR143984_r2.fastq.gz
#            => ‘CRR143984_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143984 ...
# No such directory ‘gsa3/CRA002497/CRR143984’.
#
# --2021-04-28 04:43:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_f1.fastq.gz
#            => ‘CRR143985_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143985 ... done.
# ==> SIZE CRR143985_f1.fastq.gz ... 2758316588
# File has already been retrieved.
# 2021-04-28 04:43:21 (0.00 B/s) - ‘CRR143985_f1.fastq.gz’ saved [2758316588]
#
# --2021-04-28 04:43:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143985/CRR143985_r2.fastq.gz
#            => ‘CRR143985_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143985 ...
# No such directory ‘gsa3/CRA002497/CRR143985’.
#
# --2021-04-28 04:43:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_f1.fastq.gz
#            => ‘CRR143986_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143986 ... done.
# ==> SIZE CRR143986_f1.fastq.gz ... 1681580856
# File has already been retrieved.
# 2021-04-28 04:43:37 (0.00 B/s) - ‘CRR143986_f1.fastq.gz’ saved [1681580856]
#
# --2021-04-28 04:43:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143986/CRR143986_r2.fastq.gz
#            => ‘CRR143986_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143986 ...
# No such directory ‘gsa3/CRA002497/CRR143986’.
#
# --2021-04-28 04:43:49--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_f1.fastq.gz
#            => ‘CRR143987_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143987 ... done.
# ==> SIZE CRR143987_f1.fastq.gz ... 1495794838
# File has already been retrieved.
# 2021-04-28 04:43:52 (0.00 B/s) - ‘CRR143987_f1.fastq.gz’ saved [1495794838]
#
# --2021-04-28 04:43:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143987/CRR143987_r2.fastq.gz
#            => ‘CRR143987_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143987 ...
# No such directory ‘gsa3/CRA002497/CRR143987’.
#
# --2021-04-28 04:44:05--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_f1.fastq.gz
#            => ‘CRR143988_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143988 ... done.
# ==> SIZE CRR143988_f1.fastq.gz ... 1383633563
# File has already been retrieved.
# 2021-04-28 04:44:07 (0.00 B/s) - ‘CRR143988_f1.fastq.gz’ saved [1383633563]
#
# --2021-04-28 04:44:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143988/CRR143988_r2.fastq.gz
#            => ‘CRR143988_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143988 ... done.
# ==> SIZE CRR143988_r2.fastq.gz ... 5249829923
# File has already been retrieved.
# 2021-04-28 04:44:10 (0.00 B/s) - ‘CRR143988_r2.fastq.gz’ saved [5249829923]
#
# --2021-04-28 04:44:10--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_f1.fastq.gz
#            => ‘CRR143989_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143989 ... done.
# ==> SIZE CRR143989_f1.fastq.gz ... 207933846
# ==> PASV ... done.    ==> RETR CRR143989_f1.fastq.gz ... done.
# Length: 207933846 (198M) (unauthoritative)
#
# CRR143989_f1.fastq. 100%[===================>] 198.30M  6.54MB/s    in 30s
#
# 2021-04-28 04:44:44 (6.57 MB/s) - ‘CRR143989_f1.fastq.gz’ saved [207933846]
#
# --2021-04-28 04:44:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143989/CRR143989_r2.fastq.gz
#            => ‘CRR143989_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143989 ... done.
# ==> SIZE CRR143989_r2.fastq.gz ... 772950910
# File has already been retrieved.
# 2021-04-28 04:44:47 (0.00 B/s) - ‘CRR143989_r2.fastq.gz’ saved [772950910]
#
# --2021-04-28 04:44:47--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_f1.fastq.gz
#            => ‘CRR143990_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143990 ... done.
# ==> SIZE CRR143990_f1.fastq.gz ... 126902123
# File has already been retrieved.
# 2021-04-28 04:44:50 (0.00 B/s) - ‘CRR143990_f1.fastq.gz’ saved [126902123]
#
# --2021-04-28 04:44:50--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143990/CRR143990_r2.fastq.gz
#            => ‘CRR143990_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143990 ... done.
# ==> SIZE CRR143990_r2.fastq.gz ... 471322110
# File has already been retrieved.
# 2021-04-28 04:44:53 (0.00 B/s) - ‘CRR143990_r2.fastq.gz’ saved [471322110]
#
# --2021-04-28 04:44:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_f1.fastq.gz
#            => ‘CRR143991_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143991 ...
# No such directory ‘gsa3/CRA002497/CRR143991’.
#
# --2021-04-28 04:45:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143991/CRR143991_r2.fastq.gz
#            => ‘CRR143991_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143991 ... done.
# ==> SIZE CRR143991_r2.fastq.gz ... 414944968
# File has already been retrieved.
# 2021-04-28 04:45:09 (0.00 B/s) - ‘CRR143991_r2.fastq.gz’ saved [414944968]
#
# --2021-04-28 04:45:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_f1.fastq.gz
#            => ‘CRR143992_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143992 ... done.
# ==> SIZE CRR143992_f1.fastq.gz ... 104210218
# File has already been retrieved.
# 2021-04-28 04:45:12 (0.00 B/s) - ‘CRR143992_f1.fastq.gz’ saved [104210218]
#
# --2021-04-28 04:45:12--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143992/CRR143992_r2.fastq.gz
#            => ‘CRR143992_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143992 ... done.
# ==> SIZE CRR143992_r2.fastq.gz ... 382788464
# File has already been retrieved.
# 2021-04-28 04:45:15 (0.00 B/s) - ‘CRR143992_r2.fastq.gz’ saved [382788464]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2021-04-28 04:45:19,213]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [03:31<00:00, 11.3MB/s]
# [2021-04-28 04:48:52,273]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['CRR143977_f1.fastq.gz', 'CRR143977_r2.fastq.gz', 'CRR143978_f1.fastq.gz', 'CRR143978_r2.fastq.gz', 'CRR143979_f1.fastq.gz', 'CRR143979_r2.fastq.gz', 'CRR143980_f1.fastq.gz', 'CRR143980_r2.fastq.gz', 'CRR143981_f1.fastq.gz', 'CRR143981_r2.fastq.gz', 'CRR143982_f1.fastq.gz', 'CRR143982_r2.fastq.gz', 'CRR143983_f1.fastq.gz', 'CRR143983_r2.fastq.gz', 'CRR143984_f1.fastq.gz', 'CRR143984_r2.fastq.gz', 'CRR143985_f1.fastq.gz', 'CRR143985_r2.fastq.gz', 'CRR143986_f1.fastq.gz', 'CRR143986_r2.fastq.gz', 'CRR143987_f1.fastq.gz', 'CRR143987_r2.fastq.gz', 'CRR143988_f1.fastq.gz', 'CRR143988_r2.fastq.gz', 'CRR143989_f1.fastq.gz', 'CRR143989_r2.fastq.gz', 'CRR143990_f1.fastq.gz', 'CRR143990_r2.fastq.gz', 'CRR143991_f1.fastq.gz', 'CRR143991_r2.fastq.gz', 'CRR143992_f1.fastq.gz', 'CRR143992_r2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['CRR143977_f1.fastq.gz',
#  'CRR143977_r2.fastq.gz',
#  'CRR143978_f1.fastq.gz',
#  'CRR143978_r2.fastq.gz',
#  'CRR143979_f1.fastq.gz',
#  'CRR143979_r2.fastq.gz',
#  'CRR143980_f1.fastq.gz',
#  'CRR143980_r2.fastq.gz',
#  'CRR143981_f1.fastq.gz',
#  'CRR143981_r2.fastq.gz',
#  'CRR143982_f1.fastq.gz',
#  'CRR143982_r2.fastq.gz',
#  'CRR143983_f1.fastq.gz',
#  'CRR143983_r2.fastq.gz',
#  'CRR143984_f1.fastq.gz',
#  'CRR143984_r2.fastq.gz',
#  'CRR143985_f1.fastq.gz',
#  'CRR143985_r2.fastq.gz',
#  'CRR143986_f1.fastq.gz',
#  'CRR143986_r2.fastq.gz',
#  'CRR143987_f1.fastq.gz',
#  'CRR143987_r2.fastq.gz',
#  'CRR143988_f1.fastq.gz',
#  'CRR143988_r2.fastq.gz',
#  'CRR143989_f1.fastq.gz',
#  'CRR143989_r2.fastq.gz',
#  'CRR143990_f1.fastq.gz',
#  'CRR143990_r2.fastq.gz',
#  'CRR143991_f1.fastq.gz',
#  'CRR143991_r2.fastq.gz',
#  'CRR143992_f1.fastq.gz',
#  'CRR143992_r2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2021-04-28 04:49:26,632]    INFO Using index index.idx to generate BUS file to outputCRX118014 from
# [2021-04-28 04:49:26,633]    INFO         CRR143977_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143977_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143978_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143978_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143979_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143979_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143980_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143980_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143981_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143981_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143982_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143982_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143983_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143983_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143984_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143984_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143985_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143985_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143986_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143986_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143987_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143987_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143988_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143988_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143989_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143989_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143990_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143990_r2.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143991_f1.fastq.gz
# [2021-04-28 04:49:26,633]    INFO         CRR143991_r2.fastq.gz
# [2021-04-28 04:49:26,634]    INFO         CRR143992_f1.fastq.gz
# [2021-04-28 04:49:26,634]    INFO         CRR143992_r2.fastq.gz
# [2021-04-28 06:32:11,110]    INFO Sorting BUS file outputCRX118014/output.bus to outputCRX118014/tmp/output.s.bus
# [2021-04-28 06:36:16,268]    INFO Whitelist not provided
# [2021-04-28 06:36:16,268]    INFO Copying pre-packaged 10XV2 whitelist to outputCRX118014
# [2021-04-28 06:36:16,371]    INFO Inspecting BUS file outputCRX118014/tmp/output.s.bus
# [2021-04-28 06:37:02,726]    INFO Correcting BUS records in outputCRX118014/tmp/output.s.bus to outputCRX118014/tmp/output.s.c.bus with whitelist outputCRX118014/10xv2_whitelist.txt
# [2021-04-28 06:37:40,746]    INFO Sorting BUS file outputCRX118014/tmp/output.s.c.bus to outputCRX118014/output.unfiltered.bus
# [2021-04-28 06:39:33,071]    INFO Generating count matrix outputCRX118014/counts_unfiltered/cells_x_genes from BUS file outputCRX118014/output.unfiltered.bus
# [2021-04-28 06:40:40,131]    INFO Reading matrix outputCRX118014/counts_unfiltered/cells_x_genes.mtx
# [2021-04-28 06:41:19,834]    INFO Writing matrix to h5ad outputCRX118014/counts_unfiltered/adata.h5ad
# [2021-04-28 06:41:21,114]    INFO Filtering with bustools
# [2021-04-28 06:41:21,114]    INFO Generating whitelist outputCRX118014/filter_barcodes.txt from BUS file outputCRX118014/output.unfiltered.bus
# [2021-04-28 06:41:21,842]    INFO Correcting BUS records in outputCRX118014/output.unfiltered.bus to outputCRX118014/tmp/output.unfiltered.c.bus with whitelist outputCRX118014/filter_barcodes.txt
# [2021-04-28 06:41:46,525]    INFO Sorting BUS file outputCRX118014/tmp/output.unfiltered.c.bus to outputCRX118014/output.filtered.bus
# [2021-04-28 06:43:17,931]    INFO Generating count matrix outputCRX118014/counts_filtered/cells_x_genes from BUS file outputCRX118014/output.filtered.bus
# [2021-04-28 06:44:15,615]    INFO Reading matrix outputCRX118014/counts_filtered/cells_x_genes.mtx
# [2021-04-28 06:44:46,715]    INFO Writing matrix to h5ad outputCRX118014/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix CRX118014 contains 419244 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 10000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 27#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 10000 with at least 2456.0 UMIs
# We select 27 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 419,244 cells x 60,623 genes
#     New shape: 9,943 cells x 26,688 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[i]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[i]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[i]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[i]

  results["data_" + sample_id[i]].uns["condition"] = condition[i]

  results["data_" + sample_id[i]].uns["species"] = species[i]

  results["data_" + sample_id[i]].uns["technology"] = technology[i]

  results["data_" + sample_id[i]].uns["paper"] = paper[i]

  results["data_" + sample_id[i]].uns["figure"] = figure[i]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
