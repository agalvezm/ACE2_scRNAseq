# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/SRA_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE : GSM

# %%
# Accession id for the data
database_id = "GSE114530"
species = "human"
name_SRA_table = "SraRunTable.txt"

# %% [markdown]
# # Clone, import and install software

# %%
# Clone repository for sradownloader
# !git clone https://github.com/s-andrews/sradownloader.git


# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
# Cloning into 'sradownloader'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 134 (delta 66), reused 87 (delta 32), pack-reused 0
# Receiving objects: 100% (134/134), 172.50 KiB | 486.00 KiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %% [markdown]
# # Download data and reference

# %% [markdown]
# SRA table downloaded from:

# %%
# !./sradownloader/sradownloader --outdir fastqs $name_SRA_table
# Out:
# Testing for fasterq-dump at fasterq-dump
# WARNING: Couldn't find fasterq-dump at fasterq-dump. Please ensure that sratoolkit is downloaded and that you've run vdb-config if you want to download from NCBI
# Testing for gzip in the path
# Found gzip
# Reading samples from SraRunTable.txt
# Trying to get name for SRR8313165 from GEO
# Found sample SRR8313165 with basename SRR8313165_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313157 from GEO
# Found sample SRR8313157 with basename SRR8313157_GSM3509837_Week_9_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313160 from GEO
# Found sample SRR8313160 with basename SRR8313160_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313162 from GEO
# Found sample SRR8313162 with basename SRR8313162_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313164 from GEO
# Found sample SRR8313164 with basename SRR8313164_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313168 from GEO
# Found sample SRR8313168 with basename SRR8313168_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313172 from GEO
# Found sample SRR8313172 with basename SRR8313172_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313173 from GEO
# Found sample SRR8313173 with basename SRR8313173_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313181 from GEO
# Found sample SRR8313181 with basename SRR8313181_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313170 from GEO
# Found sample SRR8313170 with basename SRR8313170_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313174 from GEO
# Found sample SRR8313174 with basename SRR8313174_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313177 from GEO
# Found sample SRR8313177 with basename SRR8313177_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313178 from GEO
# Found sample SRR8313178 with basename SRR8313178_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313179 from GEO
# Found sample SRR8313179 with basename SRR8313179_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313180 from GEO
# Found sample SRR8313180 with basename SRR8313180_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313176 from GEO
# Found sample SRR8313176 with basename SRR8313176_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313182 from GEO
# Found sample SRR8313182 with basename SRR8313182_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR7171580 from GEO
# Found sample SRR7171580 with basename SRR7171580_GSM3143601_w16_human_embryonic_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR7171582 from GEO
# Found sample SRR7171582 with basename SRR7171582_GSM3143601_w16_human_embryonic_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR7171583 from GEO
# Found sample SRR7171583 with basename SRR7171583_GSM3143601_w16_human_embryonic_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313159 from GEO
# Found sample SRR8313159 with basename SRR8313159_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313166 from GEO
# Found sample SRR8313166 with basename SRR8313166_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR7171581 from GEO
# Found sample SRR7171581 with basename SRR7171581_GSM3143601_w16_human_embryonic_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313155 from GEO
# Found sample SRR8313155 with basename SRR8313155_GSM3509837_Week_9_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313156 from GEO
# Found sample SRR8313156 with basename SRR8313156_GSM3509837_Week_9_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313158 from GEO
# Found sample SRR8313158 with basename SRR8313158_GSM3509837_Week_9_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313161 from GEO
# Found sample SRR8313161 with basename SRR8313161_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313163 from GEO
# Found sample SRR8313163 with basename SRR8313163_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313167 from GEO
# Found sample SRR8313167 with basename SRR8313167_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313169 from GEO
# Found sample SRR8313169 with basename SRR8313169_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313171 from GEO
# Found sample SRR8313171 with basename SRR8313171_GSM3509839_Week_13_fetal_kidney_Homo_sapiens_RNA-Seq
# Trying to get name for SRR8313175 from GEO
# Found sample SRR8313175 with basename SRR8313175_GSM3509840_Week_18_fetal_kidney_Homo_sapiens_RNA-Seq
# [ENA] Downloading SRR8313165 into SRR8313165_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# run_accession	fastq_ftp
# SRR8313165	ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/005/SRR8313165/SRR8313165_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/005/SRR8313165/SRR8313165_2.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/005/SRR8313165/SRR8313165_1.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/005/SRR8313165 file=SRR8313165_1.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/005/SRR8313165/SRR8313165_1.fastq.gz into fastqs/SRR8313165_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_1.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/005/SRR8313165/SRR8313165_2.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/005/SRR8313165 file=SRR8313165_2.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/005/SRR8313165/SRR8313165_2.fastq.gz into fastqs/SRR8313165_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_2.fastq.gz
# [ENA] Downloading SRR8313157 into SRR8313157_GSM3509837_Week_9_fetal_kidney_Homo_sapiens_RNA-Seq
# run_accession	fastq_ftp
# SRR8313157	ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/007/SRR8313157/SRR8313157_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/007/SRR8313157/SRR8313157_2.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/007/SRR8313157/SRR8313157_1.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/007/SRR8313157 file=SRR8313157_1.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/007/SRR8313157/SRR8313157_1.fastq.gz into fastqs/SRR8313157_GSM3509837_Week_9_fetal_kidney_Homo_sapiens_RNA-Seq_1.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/007/SRR8313157/SRR8313157_2.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/007/SRR8313157 file=SRR8313157_2.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/007/SRR8313157/SRR8313157_2.fastq.gz into fastqs/SRR8313157_GSM3509837_Week_9_fetal_kidney_Homo_sapiens_RNA-Seq_2.fastq.gz
# [ENA] Downloading SRR8313160 into SRR8313160_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# run_accession	fastq_ftp
# SRR8313160	ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/000/SRR8313160/SRR8313160_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/000/SRR8313160/SRR8313160_2.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/000/SRR8313160/SRR8313160_1.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/000/SRR8313160 file=SRR8313160_1.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/000/SRR8313160/SRR8313160_1.fastq.gz into fastqs/SRR8313160_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_1.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/000/SRR8313160/SRR8313160_2.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/000/SRR8313160 file=SRR8313160_2.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/000/SRR8313160/SRR8313160_2.fastq.gz into fastqs/SRR8313160_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_2.fastq.gz
# [ENA] Downloading SRR8313162 into SRR8313162_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# run_accession	fastq_ftp
# SRR8313162	ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/002/SRR8313162/SRR8313162_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/002/SRR8313162/SRR8313162_2.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/002/SRR8313162/SRR8313162_1.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/002/SRR8313162 file=SRR8313162_1.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/002/SRR8313162/SRR8313162_1.fastq.gz into fastqs/SRR8313162_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_1.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/002/SRR8313162/SRR8313162_2.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/002/SRR8313162 file=SRR8313162_2.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/002/SRR8313162/SRR8313162_2.fastq.gz into fastqs/SRR8313162_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_2.fastq.gz
# [ENA] Downloading SRR8313164 into SRR8313164_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq
# run_accession	fastq_ftp
# SRR8313164	ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/004/SRR8313164/SRR8313164_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/004/SRR8313164/SRR8313164_2.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/004/SRR8313164/SRR8313164_1.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/004/SRR8313164 file=SRR8313164_1.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/004/SRR8313164/SRR8313164_1.fastq.gz into fastqs/SRR8313164_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_1.fastq.gz
# URL is ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/004/SRR8313164/SRR8313164_2.fastq.gz server=ftp.sra.ebi.ac.uk folder=vol1/fastq/SRR831/004/SRR8313164 file=SRR8313164_2.fastq.gz
# [ENA Attempt 1] Downloading ftp.sra.ebi.ac.uk/vol1/fastq/SRR831/004/SRR8313164/SRR8313164_2.fastq.gz into fastqs/SRR8313164_GSM3509838_Week_11_fetal_kidney_Homo_sapiens_RNA-Seq_2.fastq.gz

# %%
# Download the corresponding Kallisto index to content folder
# !kb ref -d $species -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2020-10-04 18:48:28,356]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-10-04 18:50:55,490]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %% [markdown]
# # Metadata

# %%
number_of_samples = 5

fastqs_per_sample = [8, 8, 16, 16, 16]

sample_id = ["GSM3143601", "GSM3509837", "GSM3509838", "GSM3509839", "GSM3509840"]

tissue = ["kidney"] * number_of_samples

cell_type = ["embrionic kidney"] * number_of_samples

condition = ["week 6", "week 9", "week 11", "week 13", "week 18"] 

technology = ["10xv2"] * number_of_samples

paper = ["Muus et al 2020"] * number_of_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * number_of_samples

# Filters for analysis

cell_threshold = 100

gene_threshold = 3

# Set string variables for kb functions

species_kb = species

technology_kb = technology[0]

# %%
# Check that you have the right amount of files

files = !ls /content/fastqs | wc -l
int(files[0])  == np.sum(fastqs_per_sample)

# %%
# Store filenames in fastqs variable
fastqs = !ls /content/fastqs

# %%
# Check variable
fastqs

# %% [markdown]
# # Run kb

# %%
# Run kb

if number_of_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd


# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(number_of_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]

# %% [markdown]
# # Load unfiltered matrices

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix

t2g = pd.read_csv("../t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
t2g.index = t2g.gene_id
t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

for i in range(number_of_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM3143601 contains 373711 cells by 60623 genes
# The unfiltered matrix GSM3509837 contains 112570 cells by 60623 genes
# The unfiltered matrix GSM3509838 contains 356735 cells by 60623 genes
# The unfiltered matrix GSM3509839 contains 361098 cells by 60623 genes
# The unfiltered matrix GSM3509840 contains 317694 cells by 60623 genes

# %% [markdown]
# # Assign filter to each sample individually

# %%
# Change sample number manually
samp_n = 4

# %%
expected_num_cells = 4000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 30#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[i]].obs["cell_counts"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[i]].obs["percent_mito"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 4000 with at least 45.0 UMIs
# We select 30 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(number_of_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 373,711 cells x 60,623 genes
#     New shape: 13,808 cells x 32,707 genes
# Current Shape: 112,570 cells x 60,623 genes
#     New shape: 845 cells x 15,775 genes
# Current Shape: 356,735 cells x 60,623 genes
#     New shape: 4,318 cells x 28,116 genes
# Current Shape: 361,098 cells x 60,623 genes
#     New shape: 4,810 cells x 28,567 genes
# Current Shape: 317,694 cells x 60,623 genes
#     New shape: 3,492 cells x 27,383 genes

# %% [markdown]
# # Annotate and write Anndata object

# %%
for i in range(number_of_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]

# Write anndata object

# %cd /content

for i in range(number_of_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# /content
