# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE131391_GSM3773108__GSM3773109__GSM3773111__GSM3773112__GSM3773114__GSM3773116__GSM3773117__GSM3773119__GSM3773121__GSM3773122__GSM3773124__GSM3773125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE131391_GSM3773108_GSM3773109_GSM3773111_GSM3773112_GSM3773114_GSM3773116_GSM3773117_GSM3773119_GSM3773121_GSM3773122_GSM3773124_GSM3773125

# %%
# define the values for the analysis

# accession id for the data
id = "GSE131391"
samp_id = ["GSM3773108", 	"GSM3773109", 	"GSM3773111", 	"GSM3773112", 	"GSM3773114", 	"GSM3773116", 	"GSM3773117", 	"GSM3773119", 	"GSM3773121", 	"GSM3773122", 	"GSM3773124", 	"GSM3773125"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = True


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet
  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_1.fastq.gz ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079177/SRR9079177_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079177/SRR9079177_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/008/SRR9079178/SRR9079178_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/008/SRR9079178/SRR9079178_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/009/SRR9079179/SRR9079179_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/009/SRR9079179/SRR9079179_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/000/SRR9079180/SRR9079180_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/000/SRR9079180/SRR9079180_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/001/SRR9079181/SRR9079181_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/001/SRR9079181/SRR9079181_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/002/SRR9079182/SRR9079182_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/002/SRR9079182/SRR9079182_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/003/SRR9079183/SRR9079183_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/003/SRR9079183/SRR9079183_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/004/SRR9079184/SRR9079184_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/004/SRR9079184/SRR9079184_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/005/SRR9079185/SRR9079185_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/005/SRR9079185/SRR9079185_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079186/SRR9079186_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079186/SRR9079186_2.fastq.gz \
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079187/SRR9079187_1.fastq.gz  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079187/SRR9079187_2.fastq.gz \
"
  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 12

fastqs_per_sample = [2] * no_samples

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["bronchial brush, 84 ALCAM+ cells and 11 CD45+ cells"] * no_samples

condition = ["never smoker, female, 43 years old", 	"never smoker, male, 34 years old", 	"never smoker, female, 26 years old", 	"never smoker, male, 25 years old", 	"never smoker, male, 25  years old", 	"never smoker, female, 24  years old", 	"current smoker, male, 35 years old", 	"current smoker, female, 49 years old", 	"current smoker, male, 51 years old", 	"current smoker, female, 27 years old", 	"current smoker, male, 50 years old", 	"current smoker, female, 44 years old"] 

species = ["human"] * no_samples

technology = ["CELseq2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 3"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 75kB/s
#      |████████████████████████████████| 13.2MB 42.0MB/s
#      |████████████████████████████████| 51kB 5.4MB/s
#      |████████████████████████████████| 133kB 24.9MB/s
#      |████████████████████████████████| 10.3MB 51.6MB/s
#      |████████████████████████████████| 112kB 21.2MB/s
#      |████████████████████████████████| 81kB 8.0MB/s
#      |████████████████████████████████| 51kB 5.0MB/s
#      |████████████████████████████████| 71kB 6.1MB/s
#      |████████████████████████████████| 1.2MB 37.2MB/s
# ...

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content
# [2021-04-15 17:10:20,992]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:36<00:00, 24.8MB/s]
# [2021-04-15 17:11:59,283]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079177/SRR9079177_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079177/SRR9079177_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/008/SRR9079178/SRR9079178_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/008/SRR9079178/SRR9079178_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/009/SRR9079179/SRR9079179_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/009/SRR9079179/SRR9079179_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/000/SRR9079180/SRR9079180_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/000/SRR9079180/SRR9079180_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/001/SRR9079181/SRR9079181_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/001/SRR9079181/SRR9079181_2.fastq.gz', 'ftp://ftp.sr
# ...

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079177/SRR9079177_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/007/SRR9079177/SRR9079177_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/008/SRR9079178/SRR9079178_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/008/SRR9079178/SRR9079178_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/009/SRR9079179/SRR9079179_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/009/SRR9079179/SRR9079179_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/000/SRR9079180/SRR9079180_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/000/SRR9079180/SRR9079180_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/001/SRR9079181/SRR9079181_1.fastq.gz',
# ...

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2021-04-15 17:15:33,282]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_1.fastq.gz to outputGSM3773108/tmp/SRR9079176_1.fastq.gz
# [2021-04-15 17:15:33,284]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR907/006/SRR9079176/SRR9079176_2.fastq.gz to outputGSM3773108/tmp/SRR9079176_2.fastq.gz
# [2021-04-15 17:15:33,286]    INFO Using index index.idx to generate BUS file to outputGSM3773108 from
# [2021-04-15 17:15:33,286]    INFO         outputGSM3773108/tmp/SRR9079176_1.fastq.gz
# [2021-04-15 17:15:33,286]    INFO         outputGSM3773108/tmp/SRR9079176_2.fastq.gz
# [2021-04-15 17:18:09,931]    INFO Sorting BUS file outputGSM3773108/output.bus to outputGSM3773108/tmp/output.s.bus
# [2021-04-15 17:18:15,693]    INFO Whitelist not provided
# [2021-04-15 17:18:15,693]    INFO Generating whitelist outputGSM3773108/whitelist.txt from BUS file outputGSM3773108/tmp/output.s.bus
# ...

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM3773108 contains 87 cells by 60623 genes
# The unfiltered matrix GSM3773109 contains 91 cells by 60623 genes
# The unfiltered matrix GSM3773111 contains 88 cells by 60623 genes
# The unfiltered matrix GSM3773112 contains 90 cells by 60623 genes
# The unfiltered matrix GSM3773114 contains 73 cells by 60623 genes
# The unfiltered matrix GSM3773116 contains 91 cells by 60623 genes
# The unfiltered matrix GSM3773117 contains 76 cells by 60623 genes
# The unfiltered matrix GSM3773119 contains 79 cells by 60623 genes
# The unfiltered matrix GSM3773121 contains 42 cells by 60623 genes
# The unfiltered matrix GSM3773122 contains 91 cells by 60623 genes
# The unfiltered matrix GSM3773124 contains 81 cells by 60623 genes
# The unfiltered matrix GSM3773125 contains 84 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
samp_n = 0
expected_num_cells = 86#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 46#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 86 with at least 86.0 UMIs
# We select 46 % as the mitochondrial content threshold

# %%
samp_n = 1
expected_num_cells = 87#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 45#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 87 with at least 95.0 UMIs
# We select 45 % as the mitochondrial content threshold

# %%
samp_n = 2
expected_num_cells = 87#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 65#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 87 with at least 93.0 UMIs
# We select 65 % as the mitochondrial content threshold

# %%
samp_n = 3
expected_num_cells = 87#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 42#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 87 with at least 78.0 UMIs
# We select 42 % as the mitochondrial content threshold

# %%
samp_n = 4
expected_num_cells = 70#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 40#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 70 with at least 96.0 UMIs
# We select 40 % as the mitochondrial content threshold

# %%
samp_n = 5
expected_num_cells = 87#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 53#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 87 with at least 106.0 UMIs
# We select 53 % as the mitochondrial content threshold

# %%
samp_n = 6
expected_num_cells = 75#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 50#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 75 with at least 71.0 UMIs
# We select 50 % as the mitochondrial content threshold

# %%
samp_n = 7
expected_num_cells = 78#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 53#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 78 with at least 87.0 UMIs
# We select 53 % as the mitochondrial content threshold

# %%
samp_n = 8
expected_num_cells = 41#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 45#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 41 with at least 65.0 UMIs
# We select 45 % as the mitochondrial content threshold

# %%
samp_n = 9
expected_num_cells = 90#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 65#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 90 with at least 77.0 UMIs
# We select 65 % as the mitochondrial content threshold

# %%
samp_n = 10
expected_num_cells = 80#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 52#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 80 with at least 64.0 UMIs
# We select 52 % as the mitochondrial content threshold

# %%
samp_n = 11
expected_num_cells = 83#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 50#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 83 with at least 83.0 UMIs
# We select 50 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 87 cells x 60,623 genes
#     New shape: 86 cells x 594 genes
# Current Shape: 91 cells x 60,623 genes
#     New shape: 82 cells x 534 genes
# Current Shape: 88 cells x 60,623 genes
#     New shape: 86 cells x 538 genes
# Current Shape: 90 cells x 60,623 genes
#     New shape: 82 cells x 485 genes
# Current Shape: 73 cells x 60,623 genes
#     New shape: 57 cells x 449 genes
# Current Shape: 91 cells x 60,623 genes
#     New shape: 85 cells x 502 genes
# Current Shape: 76 cells x 60,623 genes
#     New shape: 62 cells x 438 genes
# Current Shape: 79 cells x 60,623 genes
#     New shape: 77 cells x 439 genes
# Current Shape: 42 cells x 60,623 genes
#     New shape: 41 cells x 405 genes
# Current Shape: 91 cells x 60,623 genes
#     New shape: 89 cells x 561 genes
# Current Shape: 81 cells x 60,623 genes
#     New shape: 78 cells x 576 genes
# Current Shape: 84 cells x 60,623 genes
#     New shape: 82 cells x 615 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[i]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[i]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[i]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[i]

  results["data_" + sample_id[i]].uns["condition"] = condition[i]

  results["data_" + sample_id[i]].uns["species"] = species[i]

  results["data_" + sample_id[i]].uns["technology"] = technology[i]

  results["data_" + sample_id[i]].uns["paper"] = paper[i]

  results["data_" + sample_id[i]].uns["figure"] = figure[i]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# Trying to set attribute `.uns` of view, copying.
# /content
