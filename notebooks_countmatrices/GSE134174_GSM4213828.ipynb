# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE134174_GSM4213828.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE134174_GSM4213828

# %%
# !wget -O adata_tcc.h5ad.gz https://caltech.box.com/shared/static/xfrqd6bzlbzm53lbrifin1xt6dez0pmt.gz
# !wget -O adata.h5ad.gz https://caltech.box.com/shared/static/fvttees53rp5hnjndjz9jt2d5i1lnmj4.gz
# Out:
# --2021-05-06 16:50:28--  https://caltech.box.com/shared/static/xfrqd6bzlbzm53lbrifin1xt6dez0pmt.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.26.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/xfrqd6bzlbzm53lbrifin1xt6dez0pmt.gz [following]
# --2021-05-06 16:50:29--  https://caltech.box.com/public/static/xfrqd6bzlbzm53lbrifin1xt6dez0pmt.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/xfrqd6bzlbzm53lbrifin1xt6dez0pmt.gz [following]
# --2021-05-06 16:50:29--  https://caltech.app.box.com/public/static/xfrqd6bzlbzm53lbrifin1xt6dez0pmt.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.26.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.26.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!cu0T8XR7kAP_YpQwnWH55IJi5qMv1EQ9G0fLtuv0YqvaZibXWkvgSDUiDIkUwhKyPhXLxSB6PNacL9C54BWPWKG4Q2mR8rBcQ0CN7Pj2ZQ5yrHZT5GiqN2gHGV7KU4E95vPsOwd938RmdpbtLcse6_iREknmYdb9GecRXtmDqG30o5b4rbH8lZ_Zeur6yCPGD6bB4yzDJZz1-9_lQyjJNUlCa6MRLQaEzryRO1Sq1Fj_KuLGs91nBRUqgaqFeIZKycOiKcuSA_DuSmUGzgWMfU872PtEfYBCe0Fh6c84yexocpKwOHTJmepoo1Mh8JOPdAPwa2llWPLg00B383ZM6GBJv1zm4Xme7nT95eN4RVx6tjcjPX-IRq59ar2egH2zzDPRnBgj8-1VJIJ2bjU-AlmHSEUMpEbCww4uTVJdLOyk_9txgQHvibrYTrIYP5iKM1hpyAlRip8ZLZ-f4oCcMj5r07ybCOO0KQOv5puE68YMr8EwdhpuWAZBegbTO8-GFNIcKFyx6dOHrl_sTmVIKUnOhjZ7sEyr2Tyw_g7ZAHxn23kseMkOOSA2NsP_t8XRSjCvkDbFgu4NqCZWAsynka_dPQfruwlMciNSikuPSIK5sYmMO898GDxenXxc-83p8jYMebKDHMrH5gAZNSZShVhsLwGGbgQXeb4mcTxnY9hbmV3bz_LoxiVlwxqNoLHtvnpMw8ELF3HcKqq6XyhOepyOMO6_rLA6vJ40Wwesx_LgK9QyyQXHMQJ6qjKVMRkYPsKN5lcyI2pUkAsc4xcq_wR7lyrhz0nvPf0HR5WWTEKSEgAKg3OsZtNDH5mP3IxPn08oqBdiWjL1Td6OqhOpTiFR6zZffcCOJrTtvDFaMK41mv-wX5q1oiJJdXz3hD9F6XpfH03pfK4ucYB0WTluBBkWjZ9aMszQpCXMHY10ZUAgGCLAHvgdb8PRvHJTqtCwERFMIu5f_g54E0pbW0iIclLKa2W-MGDr4UaLTjM2dTnLZ_14csUgJWAvBR8z4nzHIbqyZiMdPxEIJApNX1qhivROtaEwSn_V-q2q4Rxv0ozWWUeo6F6P4THKFmWhR-qKsnopXqF2EqxMpjN4gifcoQMB4LJ6DX47oBIaSwtcxJa6hpUgsGHNecutwVxMtlnDqDRPxNNDe8x9AJ_tT-Er01T54UVQfMql6d_2p8a0w9WFqC6FajcobJBO8w3T64Yf8bq0huiMdTxI_cto1lQiNMeEXbVYurpM6vGVyVgA5NPhnfFzKrPSzRqblFlOAg-HvtA2EanTJOPf7_ZJD1muQoznY_LrIDBzHQlZQ3-HRItSrXdFd4BJgOyV3qEojyiyGLbjG1WtT44lKUPDOCwnQK6J4XSJk1oppGziVN4pQdOkJ1uBzQih0Rvqb9KvTRauQBZWuFRoUw../download [following]
# --2021-05-06 16:50:30--  https://public.boxcloud.com/d/1/b1!cu0T8XR7kAP_YpQwnWH55IJi5qMv1EQ9G0fLtuv0YqvaZibXWkvgSDUiDIkUwhKyPhXLxSB6PNacL9C54BWPWKG4Q2mR8rBcQ0CN7Pj2ZQ5yrHZT5GiqN2gHGV7KU4E95vPsOwd938RmdpbtLcse6_iREknmYdb9GecRXtmDqG30o5b4rbH8lZ_Zeur6yCPGD6bB4yzDJZz1-9_lQyjJNUlCa6MRLQaEzryRO1Sq1Fj_KuLGs91nBRUqgaqFeIZKycOiKcuSA_DuSmUGzgWMfU872PtEfYBCe0Fh6c84yexocpKwOHTJmepoo1Mh8JOPdAPwa2llWPLg00B383ZM6GBJv1zm4Xme7nT95eN4RVx6tjcjPX-IRq59ar2egH2zzDPRnBgj8-1VJIJ2bjU-AlmHSEUMpEbCww4uTVJdLOyk_9txgQHvibrYTrIYP5iKM1hpyAlRip8ZLZ-f4oCcMj5r07ybCOO0KQOv5puE68YMr8EwdhpuWAZBegbTO8-GFNIcKFyx6dOHrl_sTmVIKUnOhjZ7sEyr2Tyw_g7ZAHxn23kseMkOOSA2NsP_t8XRSjCvkDbFgu4NqCZWAsynka_dPQfruwlMciNSikuPSIK5sYmMO898GDxenXxc-83p8jYMebKDHMrH5gAZNSZShVhsLwGGbgQXeb4mcTxnY9hbmV3bz_LoxiVlwxqNoLHtvnpMw8ELF3HcKqq6XyhOepyOMO6_rLA6vJ40Wwesx_LgK9QyyQXHMQJ6qjKVMRkYPsKN5lcyI2pUkAsc4xcq_wR7lyrhz0nvPf0HR5WWTEKSEgAKg3OsZtNDH5mP3IxPn08oqBdiWjL1Td6OqhOpTiFR6zZffcCOJrTtvDFaMK41mv-wX5q1oiJJdXz3hD9F6XpfH03pfK4ucYB0WTluBBkWjZ9aMszQpCXMHY10ZUAgGCLAHvgdb8PRvHJTqtCwERFMIu5f_g54E0pbW0iIclLKa2W-MGDr4UaLTjM2dTnLZ_14csUgJWAvBR8z4nzHIbqyZiMdPxEIJApNX1qhivROtaEwSn_V-q2q4Rxv0ozWWUeo6F6P4THKFmWhR-qKsnopXqF2EqxMpjN4gifcoQMB4LJ6DX47oBIaSwtcxJa6hpUgsGHNecutwVxMtlnDqDRPxNNDe8x9AJ_tT-Er01T54UVQfMql6d_2p8a0w9WFqC6FajcobJBO8w3T64Yf8bq0huiMdTxI_cto1lQiNMeEXbVYurpM6vGVyVgA5NPhnfFzKrPSzRqblFlOAg-HvtA2EanTJOPf7_ZJD1muQoznY_LrIDBzHQlZQ3-HRItSrXdFd4BJgOyV3qEojyiyGLbjG1WtT44lKUPDOCwnQK6J4XSJk1oppGziVN4pQdOkJ1uBzQih0Rvqb9KvTRauQBZWuFRoUw../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229391638 (219M) [application/octet-stream]
# Saving to: ‘adata_tcc.h5ad.gz’
#
# adata_tcc.h5ad.gz   100%[===================>] 218.76M  22.2MB/s    in 9.8s
#
# 2021-05-06 16:50:40 (22.3 MB/s) - ‘adata_tcc.h5ad.gz’ saved [229391638/229391638]
#
# --2021-05-06 16:50:40--  https://caltech.box.com/shared/static/fvttees53rp5hnjndjz9jt2d5i1lnmj4.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.26.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/fvttees53rp5hnjndjz9jt2d5i1lnmj4.gz [following]
# --2021-05-06 16:50:41--  https://caltech.box.com/public/static/fvttees53rp5hnjndjz9jt2d5i1lnmj4.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/fvttees53rp5hnjndjz9jt2d5i1lnmj4.gz [following]
# --2021-05-06 16:50:41--  https://caltech.app.box.com/public/static/fvttees53rp5hnjndjz9jt2d5i1lnmj4.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.26.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.26.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!V8f02kSSsab_B4u-QaY8e6VaUXtFxoxQjUQ-V2Awc-Fwljf98akU_JpOZsgVgf6eiYrLFq_b-8t86LcAPsLiaw3iCw6DyrGcwMG1vnOkIeYKuQCgHUxU2Zu4Ym3Nb47I4ViX34NfFvH46A2Vo09UmnYdbBtDTlRCO13mpIiyd5T_t7ZTZT0s3sEtcqQmx6_uyfEpgxkibY4QNLR1wVG6lVSlD2Z85CC7QTBdq6vZpF7ONS9ZjSIqsAciiBSCT4aui28rwZk-dNSwfrzlJ3q5FYHUp39_aoRYZiF1NlqUt7EHuvJEma8sCuO86yD8nFKTtlqUam1sj3nPKGRs6Z44rViC1BlqPoYJBvcKoa4P0Jc8gwfhA8pPHVYWe6HgOSoG8RGomQ9vt6iUFTkUlwU1IAmae8kurwQPxWi0D53z9-rb9GmF6Tb3IsJ178tGzKT3SgrRw_yjo-Glw7fP9FuKbhbLFsFzAooPGIGjmlSSeSCjg57oXT54BDvwfBLKb9s-4sulVu5deNmVQ9AlUySZEKzrvcmfJfwfN8LFbfJgCqxmDzwufNjiHX43uwBz44IvNoPvuwmVMf0_2j5KpZ4mWACROQ1zr7eN-YaxdL4F3_nAQugHXXEK_i9Jtc11FVu-jbCI98l66sBlr14wNvbWZkMZ5RWfM-xju5V-M0PYnZ0PrS_ywXx8ksH5cLTxZTPYpx_ZDHqYpv3t0iaegdrQ2V9BmYrLnrdZOVIVffH8EiZbL8tIojR51eQ5BcHAFo21-3gJQd0BEzWMedzs0TzqnVYJXN4r07PdBqQon2NoyxynDFPVIlOP_0wsJI9y1CWMAIqAIlcMReCYs9_6JnXBIQmDrcUcbKUSuPE1NNyBYcjijNlW9iuz3uyVxsqvQTxdQHOBvR5-Cm0riDtJyETqEaAnObDgQipdPwbAuw2N1UtJNRw7FWjxzl45y76zDejdjPJ9kfdU6HsE_8OjTJopfITyVepxpYGpp7Sp-gMLLNVhbO9fjgwhvTpcZNxtIHKRbAhilZaY9oUzlZbq8J36CJF2dHNvZ2QwDUF_h2oFxr-TlgHQui2LA_9Gx9PG545ONfmGru0RIWrHaz-pUievbEIX-yVidr_tg-wwDawwmuLP7gzdgnCYN4kX2JBhfyUwPJ9R4ak6qjwKS6lCATRM0iyfFzXeLxtKx140__gYEYYgvmASS2PcCuURzfdmqmiXlXUCMXisWS-Et3y6--VWJMJvh3ytTCngTU3dyn3pQfE6Qk3bdnp5Duu1xE8wyIzhtDTNbIv9oKTz5e3v0eWQ4jcdd2JgqmPOslP7VDki165cKy54CgSiTZPemqtQwiqgDaef-j2386JklcG7AouIk8Q1wCDMZbbpARNIC60uG2vsw959YX56LzAxUhu0kWfS03g./download [following]
# --2021-05-06 16:50:42--  https://public.boxcloud.com/d/1/b1!V8f02kSSsab_B4u-QaY8e6VaUXtFxoxQjUQ-V2Awc-Fwljf98akU_JpOZsgVgf6eiYrLFq_b-8t86LcAPsLiaw3iCw6DyrGcwMG1vnOkIeYKuQCgHUxU2Zu4Ym3Nb47I4ViX34NfFvH46A2Vo09UmnYdbBtDTlRCO13mpIiyd5T_t7ZTZT0s3sEtcqQmx6_uyfEpgxkibY4QNLR1wVG6lVSlD2Z85CC7QTBdq6vZpF7ONS9ZjSIqsAciiBSCT4aui28rwZk-dNSwfrzlJ3q5FYHUp39_aoRYZiF1NlqUt7EHuvJEma8sCuO86yD8nFKTtlqUam1sj3nPKGRs6Z44rViC1BlqPoYJBvcKoa4P0Jc8gwfhA8pPHVYWe6HgOSoG8RGomQ9vt6iUFTkUlwU1IAmae8kurwQPxWi0D53z9-rb9GmF6Tb3IsJ178tGzKT3SgrRw_yjo-Glw7fP9FuKbhbLFsFzAooPGIGjmlSSeSCjg57oXT54BDvwfBLKb9s-4sulVu5deNmVQ9AlUySZEKzrvcmfJfwfN8LFbfJgCqxmDzwufNjiHX43uwBz44IvNoPvuwmVMf0_2j5KpZ4mWACROQ1zr7eN-YaxdL4F3_nAQugHXXEK_i9Jtc11FVu-jbCI98l66sBlr14wNvbWZkMZ5RWfM-xju5V-M0PYnZ0PrS_ywXx8ksH5cLTxZTPYpx_ZDHqYpv3t0iaegdrQ2V9BmYrLnrdZOVIVffH8EiZbL8tIojR51eQ5BcHAFo21-3gJQd0BEzWMedzs0TzqnVYJXN4r07PdBqQon2NoyxynDFPVIlOP_0wsJI9y1CWMAIqAIlcMReCYs9_6JnXBIQmDrcUcbKUSuPE1NNyBYcjijNlW9iuz3uyVxsqvQTxdQHOBvR5-Cm0riDtJyETqEaAnObDgQipdPwbAuw2N1UtJNRw7FWjxzl45y76zDejdjPJ9kfdU6HsE_8OjTJopfITyVepxpYGpp7Sp-gMLLNVhbO9fjgwhvTpcZNxtIHKRbAhilZaY9oUzlZbq8J36CJF2dHNvZ2QwDUF_h2oFxr-TlgHQui2LA_9Gx9PG545ONfmGru0RIWrHaz-pUievbEIX-yVidr_tg-wwDawwmuLP7gzdgnCYN4kX2JBhfyUwPJ9R4ak6qjwKS6lCATRM0iyfFzXeLxtKx140__gYEYYgvmASS2PcCuURzfdmqmiXlXUCMXisWS-Et3y6--VWJMJvh3ytTCngTU3dyn3pQfE6Qk3bdnp5Duu1xE8wyIzhtDTNbIv9oKTz5e3v0eWQ4jcdd2JgqmPOslP7VDki165cKy54CgSiTZPemqtQwiqgDaef-j2386JklcG7AouIk8Q1wCDMZbbpARNIC60uG2vsw959YX56LzAxUhu0kWfS03g./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29251327 (28M) [application/octet-stream]
# Saving to: ‘adata.h5ad.gz’
#
# adata.h5ad.gz       100%[===================>]  27.90M  21.8MB/s    in 1.3s
#
# 2021-05-06 16:50:43 (21.8 MB/s) - ‘adata.h5ad.gz’ saved [29251327/29251327]

# %% [markdown]
# This dataset was too large to be processed in google colab. The gene count and TCC were generated using the following commands:
#
# ```
# SRA=SRR10668802
# GSM=GSM4213828
#
# cd /central/scratch/agalvezm/ace2/counts
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/prefetch 2.10.9 ${SRA} --max-size 2000000000
#
# cd ${SRA}
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/fasterq-dump --split-files --outdir fastq --include-technical ${SRA}.sra
#
# ~/anaconda3/bin/kb ref -d human -i index.idx -g t2g.txt -f1 transcriptome.fasta
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/output${GSM} --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/tccoutput${GSM} --tcc --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ```

# %%
no_samples = 1

fastqs_per_sample = [1] 

sample_id = "GSM4213828"

database_id = ["GSE134174"] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["trachea epithelial cells"] * no_samples

species = ["human"] * no_samples

technology = ["10xv3"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 5"] * no_samples

condition = ["light smoker"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 74kB/s
#      |████████████████████████████████| 10.3MB 40.4MB/s
#      |████████████████████████████████| 133kB 56.5MB/s
#      |████████████████████████████████| 13.2MB 34.9MB/s
#      |████████████████████████████████| 51kB 5.0MB/s
#      |████████████████████████████████| 81kB 6.7MB/s
#      |████████████████████████████████| 112kB 56.4MB/s
#      |████████████████████████████████| 1.2MB 37.5MB/s
#      |████████████████████████████████| 71kB 1.5MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %%
# Execute kb ref to get t2g.txt file
# !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2021-05-06 16:52:50,276]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:42<00:00, 23.2MB/s]
# [2021-05-06 16:54:35,162]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrices

# %%
# # Gunzip matrices
# !gunzip /content/adata.h5ad.gz
# !gunzip /content/adata_tcc.h5ad.gz

# Load matrices
adata = anndata.read_h5ad("/content/adata.h5ad")
adata_tcc = anndata.read_h5ad("/content/adata_tcc.h5ad")

# %%
adata.var
# Out:
#                      gene_name
# gene_id
# ENSG00000223972.5      DDX11L1
# ENSG00000227232.5       WASH7P
# ENSG00000278267.1    MIR6859-1
# ENSG00000243485.5  MIR1302-2HG
# ENSG00000284332.1    MIR1302-2
# ...                        ...
# ENSG00000271254.6   AC240274.1
# ENSG00000275405.1           U1
# ENSG00000275987.1           U1
# ENSG00000277475.1   AC213203.2
# ENSG00000268674.2   AC213203.1
#
# [60623 rows x 1 columns]

# %%
# Reformat and fill gene count matrix 

adata.var["gene_id"] = adata.var.index.values

t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
t2g.index = t2g.gene_id
t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

adata.var["gene_name"] = adata.var.gene_id.map(t2g["gene_name"])
adata.var.index = adata.var["gene_name"]
print("The unfiltered matrix " + sample_id + " contains {} cells by {} genes".format(len(adata.obs), len(adata.var)))

adata.obs["cell_counts"] = adata.X.sum(axis=1)
adata.var["gene_counts"] = nd(adata.X.sum(axis=0))

adata.obs["n_genes"] = nd((adata.X>0).sum(axis=1))
adata.var["n_cells"] = nd((adata.X>0).sum(axis=0))

mito_genes = adata.var_names.str.startswith("MT-" or "mt-") 
adata.obs["percent_mito"] = adata[:,mito_genes].X.sum(axis=1)/adata.X.sum(axis=1)*100

# Changing the name of the index is necessary to write the file (it won't work with duplicated names)
adata.var.index.name = "index"

# %% [markdown]
# ## Assign filters for gene count matrix

# %%
results = {}


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

# %%
expected_num_cells = 1500#@param {type:"integer"}
knee = np.sort(nd(adata.X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 12#@param {type:"integer"}
results["mito_criteria" + sample_id] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(adata.obs["cell_counts"][adata.obs["cell_counts"] > cell_threshold])
y = nd(adata.obs["percent_mito"][adata.obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 1500 with at least 5867.0 UMIs
# We select 12 % as the mitochondrial content threshold

# %% [markdown]
# # Filter gene count matrix

# %%
adata.obs["pass_count_filter"] = adata.obs["cell_counts"] > results["cell_threshold" + sample_id]
adata.obs["pass_mito_filter"] = adata.obs.percent_mito < results["mito_criteria" + sample_id]
adata.var["pass_gene_filter"] = adata.var["n_cells"] > gene_threshold

cell_mask = np.logical_and(adata.obs["pass_count_filter"].values, adata.obs["pass_mito_filter"].values)
gene_mask = adata.var["pass_gene_filter"].values

print("Current Shape: {:,} cells x {:,} genes".format(adata.shape[0], adata.shape[1]))
print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
results["data_" + sample_id] = adata[cell_mask, gene_mask]
# Out:
# Current Shape: 364,877 cells x 60,623 genes
#     New shape: 1,418 cells x 27,956 genes

# %% [markdown]
# # Anotate and write gene count matrix

# %%
adata.uns["database_id"] = database_id

adata.uns["tissue"] = tissue

adata.uns["cell_type"] = cell_type

adata.uns["sample_id"] = sample_id

adata.uns["condition"] = condition

adata.uns["species"] = species

adata.uns["technology"] = technology

adata.uns["paper"] = paper

adata.uns["figure"] = figure

# %cd /content

adata.write("result" + sample_id)
# Out:
# /content
# ... storing 'gene_name' as categorical

# %% [markdown]
# Filter TCC using gene count matrix's filter

# %%
adata_tcc = adata_tcc[adata.obs.index.values]
# transfer obs data
adata_tcc.obs = adata.obs
# transfer metadata
adata_tcc.uns = adata.uns
# write tcc matrix
adata_tcc.write("/content/tcc_" + sample_id)
#gzip tcc matrix
cmd = "gzip /content/tcc_" + sample_id
# !$cmd
