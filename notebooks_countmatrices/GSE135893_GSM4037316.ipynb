# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE135893_GSM4037316.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE135893_GSM4037316

# %%
# define the values for the analysis

# accession id for the data
id = "GSE135893"
samp_id = ["GSM4037316"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet

  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/015/SRR10368215/SRR10368215_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/015/SRR10368215/SRR10368215_2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["lung biopsy"] * no_samples

condition = ["healthy"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 c,d  Fig 4 e  ED Fig 11 a,c"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2021-03-01 18:49:34--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/015/SRR10368215/SRR10368215_1.fastq.gz
#            => ‘SRR10368215_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR103/015/SRR10368215 ... done.
# ==> SIZE SRR10368215_1.fastq.gz ... 23533056601
# ==> PASV ... done.    ==> RETR SRR10368215_1.fastq.gz ... done.
# Length: 23533056601 (22G) (unauthoritative)
#
# SRR10368215_1.fastq 100%[===================>]  21.92G  12.2MB/s    in 59m 56s
#
# 2021-03-01 19:49:33 (6.24 MB/s) - Control connection closed.
# Retrying.
#
# --2021-03-01 20:04:34--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/015/SRR10368215/SRR10368215_1.fastq.gz
#   (try: 2) => ‘SRR10368215_1.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR103/015/SRR10368215 ... done.
# ==> SIZE SRR10368215_1.fastq.gz ... 23533056601
# File has already been retrieved.
# 2021-03-01 20:04:37 (0.00 B/s) - ‘SRR10368215_1.fastq.gz’ saved [23533056601]
#
# --2021-03-01 20:04:37--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/015/SRR10368215/SRR10368215_2.fastq.gz
#            => ‘SRR10368215_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR103/015/SRR10368215 ... done.
# ==> SIZE SRR10368215_2.fastq.gz ... 26367855122
# ==> PASV ... done.    ==> RETR SRR10368215_2.fastq.gz ... done.
# Length: 26367855122 (25G) (unauthoritative)
#
# SRR10368215_2.fastq 100%[===================>]  24.56G  7.40MB/s    in 43m 24s
#
# 2021-03-01 20:48:04 (9.66 MB/s) - Control connection closed.
# Retrying.
#
# --2021-03-01 21:03:06--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/015/SRR10368215/SRR10368215_2.fastq.gz
#   (try: 2) => ‘SRR10368215_2.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR103/015/SRR10368215 ... done.
# ==> SIZE SRR10368215_2.fastq.gz ... 26367855122
# File has already been retrieved.
# 2021-03-01 21:03:08 (0.00 B/s) - ‘SRR10368215_2.fastq.gz’ saved [26367855122]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2021-03-01 21:03:11,929]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [02:40<00:00, 14.9MB/s]
# [2021-03-01 21:05:54,843]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['SRR10368215_1.fastq.gz', 'SRR10368215_2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['SRR10368215_1.fastq.gz', 'SRR10368215_2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2021-03-01 21:06:36,139]    INFO Using index index.idx to generate BUS file to outputGSM4037316 from
# [2021-03-01 21:06:36,139]    INFO         SRR10368215_1.fastq.gz
# [2021-03-01 21:06:36,139]    INFO         SRR10368215_2.fastq.gz
# [2021-03-01 22:36:05,602]    INFO Sorting BUS file outputGSM4037316/output.bus to outputGSM4037316/tmp/output.s.bus
# [2021-03-01 22:39:08,489]    INFO Whitelist not provided
# [2021-03-01 22:39:08,489]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM4037316
# [2021-03-01 22:39:08,626]    INFO Inspecting BUS file outputGSM4037316/tmp/output.s.bus
# [2021-03-01 22:39:30,242]    INFO Correcting BUS records in outputGSM4037316/tmp/output.s.bus to outputGSM4037316/tmp/output.s.c.bus with whitelist outputGSM4037316/10xv2_whitelist.txt
# [2021-03-01 22:39:46,341]    INFO Sorting BUS file outputGSM4037316/tmp/output.s.c.bus to outputGSM4037316/output.unfiltered.bus
# [2021-03-01 22:40:24,494]    INFO Generating count matrix outputGSM4037316/counts_unfiltered/cells_x_genes from BUS file outputGSM4037316/output.unfiltered.bus
# [2021-03-01 22:40:48,703]    INFO Reading matrix outputGSM4037316/counts_unfiltered/cells_x_genes.mtx
# [2021-03-01 22:41:01,201]    INFO Writing matrix to h5ad outputGSM4037316/counts_unfiltered/adata.h5ad
# [2021-03-01 22:41:02,071]    INFO Filtering with bustools
# [2021-03-01 22:41:02,071]    INFO Generating whitelist outputGSM4037316/filter_barcodes.txt from BUS file outputGSM4037316/output.unfiltered.bus
# [2021-03-01 22:41:02,518]    INFO Correcting BUS records in outputGSM4037316/output.unfiltered.bus to outputGSM4037316/tmp/output.unfiltered.c.bus with whitelist outputGSM4037316/filter_barcodes.txt
# [2021-03-01 22:41:14,232]    INFO Sorting BUS file outputGSM4037316/tmp/output.unfiltered.c.bus to outputGSM4037316/output.filtered.bus
# [2021-03-01 22:41:54,367]    INFO Generating count matrix outputGSM4037316/counts_filtered/cells_x_genes from BUS file outputGSM4037316/output.filtered.bus
# [2021-03-01 22:42:13,749]    INFO Reading matrix outputGSM4037316/counts_filtered/cells_x_genes.mtx
# [2021-03-01 22:42:22,095]    INFO Writing matrix to h5ad outputGSM4037316/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM4037316 contains 235587 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 4000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 30#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 4000 with at least 284.0 UMIs

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# We select 30 % as the mitochondrial content threshold
# Current Shape: 235,587 cells x 60,623 genes
#     New shape: 3,254 cells x 26,140 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical

# %%
'''
Create TCC matrix
'''
if not bam:
  # %cd /content/fastqs

if bam:
  # %cd /content/fastqs/$_filename

if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[0] + " "\
  + "--filter bustools -t 2 --tcc --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[i] + " \
    --filter bustools -t 2 --tcc --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]


tcc_results = {}

for sample in sample_id:
  output = "bus_raw_" + sample
  # !mkdir $output
  folder_tcc = "tccoutput" + sample
  folder_gc = "output" + sample

  # read tcc matrix
  tcc_results[sample] = anndata.read(folder_tcc + "/counts_unfiltered/adata.h5ad")
  # apply gene count matrix's filter
  tcc_results[sample] = tcc_results[sample][results["data_" + sample_id[i]].obs.index.values]
  # transfer obs data
  tcc_results[sample].obs = results["data_" + sample].obs
  # transfer metadata
  tcc_results[sample].uns = results["data_" + sample].uns
  # write tcc matrix
  tcc_results[sample].write("/content/tcc_" + sample)
  #gzip tcc matrix
  cmd = "gzip /content/tcc_" + sample
  # !$cmd
  #gzip filtered bus file
  cmd = "gzip " + folder_tcc + "/output.filtered.bus"
  # !$cmd
  # move and re-name bus file with sample id
  cmd = "mv " + folder_tcc + "/output.filtered.bus.gz " + output + "/" + sample +".filtered.bus.gz"
  # !$cmd
  # gzip all unfiltered counts
  cmd = "gzip " + folder_tcc + "/counts_unfiltered/*"
  # !$cmd
  cmd = "gzip " + folder_gc + "/counts_unfiltered/*"
  # !$cmd
  # move unfiltered counts for both
  cmd = "mv " + folder_tcc + "/counts_unfiltered " + output + "/tcc_unfiltered"
  # !$cmd
  cmd = "mv " + folder_gc + "/counts_unfiltered " + output + "/gc_unfiltered"
  # !$cmd

  # zip all files
  cmd = "zip -r /content" + output + ".zip " + output
  # !$cmd
# Out:
# /content/fastqs
# [2021-03-01 22:42:30,327]    INFO Using index index.idx to generate BUS file to tccoutputGSM4037316 from
# [2021-03-01 22:42:30,327]    INFO         SRR10368215_1.fastq.gz
# [2021-03-01 22:42:30,327]    INFO         SRR10368215_2.fastq.gz
# [2021-03-02 00:11:27,957]    INFO Sorting BUS file tccoutputGSM4037316/output.bus to tccoutputGSM4037316/tmp/output.s.bus
# [2021-03-02 00:14:30,850]    INFO Whitelist not provided
# [2021-03-02 00:14:30,850]    INFO Copying pre-packaged 10XV2 whitelist to tccoutputGSM4037316
# [2021-03-02 00:14:30,973]    INFO Inspecting BUS file tccoutputGSM4037316/tmp/output.s.bus
# [2021-03-02 00:14:52,324]    INFO Correcting BUS records in tccoutputGSM4037316/tmp/output.s.bus to tccoutputGSM4037316/tmp/output.s.c.bus with whitelist tccoutputGSM4037316/10xv2_whitelist.txt
# [2021-03-02 00:15:08,421]    INFO Sorting BUS file tccoutputGSM4037316/tmp/output.s.c.bus to tccoutputGSM4037316/output.unfiltered.bus
# [2021-03-02 00:15:57,761]    INFO Generating count matrix tccoutputGSM4037316/counts_unfiltered/cells_x_tcc from BUS file tccoutputGSM4037316/output.unfiltered.bus
# [2021-03-02 00:16:47,268]    INFO Reading matrix tccoutputGSM4037316/counts_unfiltered/cells_x_tcc.mtx
# [2021-03-02 00:17:25,843]    INFO Writing matrix to h5ad tccoutputGSM4037316/counts_unfiltered/adata.h5ad
# [2021-03-02 00:19:21,890]    INFO Filtering with bustools
# [2021-03-02 00:19:21,891]    INFO Generating whitelist tccoutputGSM4037316/filter_barcodes.txt from BUS file tccoutputGSM4037316/output.unfiltered.bus
# [2021-03-02 00:19:22,470]    INFO Correcting BUS records in tccoutputGSM4037316/output.unfiltered.bus to tccoutputGSM4037316/tmp/output.unfiltered.c.bus with whitelist tccoutputGSM4037316/filter_barcodes.txt
# [2021-03-02 00:19:35,003]    INFO Sorting BUS file tccoutputGSM4037316/tmp/output.unfiltered.c.bus to tccoutputGSM4037316/output.filtered.bus
# [2021-03-02 00:20:16,052]    INFO Generating count matrix tccoutputGSM4037316/counts_filtered/cells_x_tcc from BUS file tccoutputGSM4037316/output.filtered.bus
# [2021-03-02 00:20:58,882]    INFO Reading matrix tccoutputGSM4037316/counts_filtered/cells_x_tcc.mtx
# [2021-03-02 00:21:32,635]    INFO Writing matrix to h5ad tccoutputGSM4037316/counts_filtered/adata.h5ad
#   adding: bus_raw_GSM4037316/ (stored 0%)
#   adding: bus_raw_GSM4037316/tcc_unfiltered/ (stored 0%)
#   adding: bus_raw_GSM4037316/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 2%)
#   adding: bus_raw_GSM4037316/tcc_unfiltered/adata.h5ad.gz (deflated 7%)
#   adding: bus_raw_GSM4037316/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_GSM4037316/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: bus_raw_GSM4037316/GSM4037316.filtered.bus.gz (deflated 4%)
#   adding: bus_raw_GSM4037316/gc_unfiltered/ (stored 0%)
#   adding: bus_raw_GSM4037316/gc_unfiltered/cells_x_genes.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_GSM4037316/gc_unfiltered/cells_x_genes.genes.txt.gz (deflated 0%)
#   adding: bus_raw_GSM4037316/gc_unfiltered/adata.h5ad.gz (deflated 4%)
#   adding: bus_raw_GSM4037316/gc_unfiltered/cells_x_genes.mtx.gz (deflated 0%)

# %%
# !zip -r /content/fastqs/bus_raw_GSM4037316.zip /content/fastqs/bus_raw_GSM4037316
# Out:
#   adding: content/fastqs/bus_raw_GSM4037316/ (stored 0%)
#   adding: content/fastqs/bus_raw_GSM4037316/tcc_unfiltered/ (stored 0%)
#   adding: content/fastqs/bus_raw_GSM4037316/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 2%)
#   adding: content/fastqs/bus_raw_GSM4037316/tcc_unfiltered/adata.h5ad.gz (deflated 7%)
#   adding: content/fastqs/bus_raw_GSM4037316/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: content/fastqs/bus_raw_GSM4037316/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: content/fastqs/bus_raw_GSM4037316/GSM4037316.filtered.bus.gz (deflated 4%)
#   adding: content/fastqs/bus_raw_GSM4037316/gc_unfiltered/ (stored 0%)
#   adding: content/fastqs/bus_raw_GSM4037316/gc_unfiltered/cells_x_genes.barcodes.txt.gz (deflated 1%)
#   adding: content/fastqs/bus_raw_GSM4037316/gc_unfiltered/cells_x_genes.genes.txt.gz (deflated 0%)
#   adding: content/fastqs/bus_raw_GSM4037316/gc_unfiltered/adata.h5ad.gz (deflated 4%)
#   adding: content/fastqs/bus_raw_GSM4037316/gc_unfiltered/cells_x_genes.mtx.gz (deflated 0%)
