# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/PRJCA002413_CRX118016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRJCA002413_CRX118016

# %%
# define the values for the analysis

# accession id for the data
id = "PRJCA002413"
samp_id = ["CRX118016"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet
  links_raw = "ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

#sample specific metadata

no_samples = 1

condition = ["healthy control 5"] * no_samples

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["blood"] * no_samples

cell_type = ["PBMCs"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Wen et al 2020"] * no_samples

figure = ["Fig: all"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 101kB/s
#      |████████████████████████████████| 51kB 4.8MB/s
#      |████████████████████████████████| 13.2MB 40.2MB/s
#      |████████████████████████████████| 10.3MB 39.8MB/s
#      |████████████████████████████████| 133kB 47.1MB/s
#      |████████████████████████████████| 112kB 29.9MB/s
#      |████████████████████████████████| 81kB 6.5MB/s
#      |████████████████████████████████| 71kB 5.4MB/s
#      |████████████████████████████████| 1.2MB 40.2MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  while len(os.listdir()) != len(fastqs):
    for link in fastqs:
      # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2021-04-28 01:24:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_f1.fastq.gz ... 915311231
# ==> PASV ... done.    ==> RETR CRR144005_f1.fastq.gz ... done.
# Length: 915311231 (873M) (unauthoritative)
#
# CRR144005_f1.fastq. 100%[===================>] 872.91M  11.5MB/s    in 78s
#
# 2021-04-28 01:25:55 (11.3 MB/s) - ‘CRR144005_f1.fastq.gz’ saved [915311231]
#
# --2021-04-28 01:25:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_r2.fastq.gz ... 960618716
# ==> PASV ... done.    ==> RETR CRR144005_r2.fastq.gz ... done.
# Length: 960618716 (916M) (unauthoritative)
#
# CRR144005_r2.fastq. 100%[===================>] 916.12M  8.87MB/s    in 84s
#
# 2021-04-28 01:27:23 (10.9 MB/s) - ‘CRR144005_r2.fastq.gz’ saved [960618716]
#
# --2021-04-28 01:27:23--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_f1.fastq.gz ... 1074221772
# ==> PASV ... done.    ==> RETR CRR144006_f1.fastq.gz ... done.
# Length: 1074221772 (1.0G) (unauthoritative)
#
# CRR144006_f1.fastq. 100%[===================>]   1.00G  7.31MB/s    in 2m 38s
#
# 2021-04-28 01:30:04 (6.47 MB/s) - ‘CRR144006_f1.fastq.gz’ saved [1074221772]
#
# --2021-04-28 01:30:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_r2.fastq.gz ... 1115476709
# ==> PASV ... done.    ==> RETR CRR144006_r2.fastq.gz ... done.
# Length: 1115476709 (1.0G) (unauthoritative)
#
# CRR144006_r2.fastq. 100%[===================>]   1.04G  6.93MB/s    in 2m 48s
#
# 2021-04-28 01:32:56 (6.35 MB/s) - ‘CRR144006_r2.fastq.gz’ saved [1115476709]
#
# --2021-04-28 01:32:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 01:33:10--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 01:33:23--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 01:33:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz
#            => ‘CRR144008_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ... done.
# ==> SIZE CRR144008_r2.fastq.gz ... 830758949
# ==> PASV ... done.    ==> RETR CRR144008_r2.fastq.gz ... done.
# Length: 830758949 (792M) (unauthoritative)
#
# CRR144008_r2.fastq. 100%[===================>] 792.27M  5.13MB/s    in 1m 55s
#
# 2021-04-28 01:35:35 (6.91 MB/s) - ‘CRR144008_r2.fastq.gz’ saved [830758949]
#
# --2021-04-28 01:35:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz
#            => ‘CRR144009_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_f1.fastq.gz ... 2515705993
# ==> PASV ... done.    ==> RETR CRR144009_f1.fastq.gz ... done.
# Length: 2515705993 (2.3G) (unauthoritative)
#
# CRR144009_f1.fastq. 100%[===================>]   2.34G  7.90MB/s    in 5m 21s
#
# 2021-04-28 01:40:59 (7.47 MB/s) - ‘CRR144009_f1.fastq.gz’ saved [2515705993]
#
# --2021-04-28 01:40:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#            => ‘CRR144009_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_r2.fastq.gz ... 9389151594
# ==> PASV ... done.    ==> RETR CRR144009_r2.fastq.gz ... done.
# Length: 9389151594 (8.7G) (unauthoritative)
#
# CRR144009_r2.fastq. 100%[===================>]   8.74G  11.7MB/s    in 17m 20s
#
# 2021-04-28 01:58:23 (8.61 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 02:13:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#   (try: 2) => ‘CRR144009_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_r2.fastq.gz ... 9389151594
# File has already been retrieved.
# 2021-04-28 02:13:26 (0.00 B/s) - ‘CRR144009_r2.fastq.gz’ saved [9389151594]
#
# --2021-04-28 02:13:26--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz
#            => ‘CRR144010_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ...
# No such directory ‘gsa3/CRA002497/CRR144010’.
#
# --2021-04-28 02:13:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#            => ‘CRR144010_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ...
# No such directory ‘gsa3/CRA002497/CRR144010’.
#
# --2021-04-28 02:13:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz
#            => ‘CRR144011_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ...
# No such directory ‘gsa3/CRA002497/CRR144011’.
#
# --2021-04-28 02:14:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#            => ‘CRR144011_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_r2.fastq.gz ... 6275184398
# ==> PASV ... done.    ==> RETR CRR144011_r2.fastq.gz ... done.
# Length: 6275184398 (5.8G) (unauthoritative)
#
# CRR144011_r2.fastq. 100%[===================>]   5.84G  11.8MB/s    in 10m 22s
#
# 2021-04-28 02:24:29 (9.62 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 02:39:30--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#   (try: 2) => ‘CRR144011_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_r2.fastq.gz ... 6275184398
# File has already been retrieved.
# 2021-04-28 02:39:32 (0.00 B/s) - ‘CRR144011_r2.fastq.gz’ saved [6275184398]
#
# --2021-04-28 02:39:32--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz
#            => ‘CRR144012_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 02:39:45--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#            => ‘CRR144012_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 02:39:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz
#            => ‘CRR144013_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_f1.fastq.gz ... 1239579596
# ==> PASV ... done.    ==> RETR CRR144013_f1.fastq.gz ... done.
# Length: 1239579596 (1.2G) (unauthoritative)
#
# CRR144013_f1.fastq. 100%[===================>]   1.15G  10.8MB/s    in 1m 50s
#
# 2021-04-28 02:41:51 (10.7 MB/s) - ‘CRR144013_f1.fastq.gz’ saved [1239579596]
#
# --2021-04-28 02:41:51--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz
#            => ‘CRR144013_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_r2.fastq.gz ... 1250511974
# ==> PASV ... done.    ==> RETR CRR144013_r2.fastq.gz ... done.
# Length: 1250511974 (1.2G) (unauthoritative)
#
# CRR144013_r2.fastq. 100%[===================>]   1.16G  11.1MB/s    in 1m 48s
#
# 2021-04-28 02:43:43 (11.0 MB/s) - ‘CRR144013_r2.fastq.gz’ saved [1250511974]
#
# --2021-04-28 02:43:43--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz
#            => ‘CRR144014_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ...
# No such directory ‘gsa3/CRA002497/CRR144014’.
#
# --2021-04-28 02:43:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz
#            => ‘CRR144014_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_r2.fastq.gz ... 1748640248
# ==> PASV ... done.    ==> RETR CRR144014_r2.fastq.gz ... done.
# Length: 1748640248 (1.6G) (unauthoritative)
#
# CRR144014_r2.fastq. 100%[===================>]   1.63G  12.4MB/s    in 2m 30s
#
# 2021-04-28 02:46:28 (11.1 MB/s) - ‘CRR144014_r2.fastq.gz’ saved [1748640248]
#
# --2021-04-28 02:46:28--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_f1.fastq.gz ... 1223913717
# ==> PASV ... done.    ==> RETR CRR144015_f1.fastq.gz ... done.
# Length: 1223913717 (1.1G) (unauthoritative)
#
# CRR144015_f1.fastq. 100%[===================>]   1.14G  11.5MB/s    in 1m 43s
#
# 2021-04-28 02:48:14 (11.3 MB/s) - ‘CRR144015_f1.fastq.gz’ saved [1223913717]
#
# --2021-04-28 02:48:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_r2.fastq.gz ... 1248048314
# ==> PASV ... done.    ==> RETR CRR144015_r2.fastq.gz ... done.
# Length: 1248048314 (1.2G) (unauthoritative)
#
# CRR144015_r2.fastq. 100%[===================>]   1.16G  11.9MB/s    in 1m 45s
#
# 2021-04-28 02:50:02 (11.3 MB/s) - ‘CRR144015_r2.fastq.gz’ saved [1248048314]
#
# --2021-04-28 02:50:02--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.
#
# --2021-04-28 02:50:16--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_r2.fastq.gz ... 971216406
# ==> PASV ... done.    ==> RETR CRR144016_r2.fastq.gz ... done.
# Length: 971216406 (926M) (unauthoritative)
#
# CRR144016_r2.fastq. 100%[===================>] 926.22M  11.4MB/s    in 82s
#
# 2021-04-28 02:51:41 (11.3 MB/s) - ‘CRR144016_r2.fastq.gz’ saved [971216406]
#
# --2021-04-28 02:51:41--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_f1.fastq.gz ... 915311231
# File has already been retrieved.
# 2021-04-28 02:51:45 (0.00 B/s) - ‘CRR144005_f1.fastq.gz’ saved [915311231]
#
# --2021-04-28 02:51:45--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_r2.fastq.gz ... 960618716
# File has already been retrieved.
# 2021-04-28 02:51:47 (0.00 B/s) - ‘CRR144005_r2.fastq.gz’ saved [960618716]
#
# --2021-04-28 02:51:47--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 02:51:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_r2.fastq.gz ... 1115476709
# File has already been retrieved.
# 2021-04-28 02:52:01 (0.00 B/s) - ‘CRR144006_r2.fastq.gz’ saved [1115476709]
#
# --2021-04-28 02:52:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 02:52:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ... done.
# ==> SIZE CRR144007_r2.fastq.gz ... 532409556
# ==> PASV ... done.    ==> RETR CRR144007_r2.fastq.gz ... done.
# Length: 532409556 (508M) (unauthoritative)
#
# CRR144007_r2.fastq. 100%[===================>] 507.75M  3.58MB/s    in 90s
#
# 2021-04-28 02:53:47 (5.63 MB/s) - ‘CRR144007_r2.fastq.gz’ saved [532409556]
#
# --2021-04-28 02:53:47--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ... done.
# ==> SIZE CRR144008_f1.fastq.gz ... 800201797
# ==> PASV ... done.    ==> RETR CRR144008_f1.fastq.gz ... done.
# Length: 800201797 (763M) (unauthoritative)
#
# CRR144008_f1.fastq. 100%[===================>] 763.13M  12.2MB/s    in 68s
#
# 2021-04-28 02:54:58 (11.2 MB/s) - ‘CRR144008_f1.fastq.gz’ saved [800201797]
#
# --2021-04-28 02:54:58--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz
#            => ‘CRR144008_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 02:55:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz
#            => ‘CRR144009_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_f1.fastq.gz ... 2515705993
# File has already been retrieved.
# 2021-04-28 02:55:15 (0.00 B/s) - ‘CRR144009_f1.fastq.gz’ saved [2515705993]
#
# --2021-04-28 02:55:15--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#            => ‘CRR144009_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_r2.fastq.gz ... 9389151594
# File has already been retrieved.
# 2021-04-28 02:55:17 (0.00 B/s) - ‘CRR144009_r2.fastq.gz’ saved [9389151594]
#
# --2021-04-28 02:55:17--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz
#            => ‘CRR144010_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ...
# No such directory ‘gsa3/CRA002497/CRR144010’.
#
# --2021-04-28 02:55:29--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#            => ‘CRR144010_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# ==> PASV ... done.    ==> RETR CRR144010_r2.fastq.gz ... done.
# Length: 10351864191 (9.6G) (unauthoritative)
#
# CRR144010_r2.fastq. 100%[===================>]   9.64G  11.8MB/s    in 15m 24s
#
# 2021-04-28 03:10:56 (10.7 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 03:25:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#   (try: 2) => ‘CRR144010_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# File has already been retrieved.
# 2021-04-28 03:25:59 (0.00 B/s) - ‘CRR144010_r2.fastq.gz’ saved [10351864191]
#
# --2021-04-28 03:25:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz
#            => ‘CRR144011_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ...
# No such directory ‘gsa3/CRA002497/CRR144011’.
#
# --2021-04-28 03:26:12--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#            => ‘CRR144011_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_r2.fastq.gz ... 6275184398
# File has already been retrieved.
# 2021-04-28 03:26:14 (0.00 B/s) - ‘CRR144011_r2.fastq.gz’ saved [6275184398]
#
# --2021-04-28 03:26:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz
#            => ‘CRR144012_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 03:26:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#            => ‘CRR144012_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 03:26:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz
#            => ‘CRR144013_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_f1.fastq.gz ... 1239579596
# File has already been retrieved.
# 2021-04-28 03:26:42 (0.00 B/s) - ‘CRR144013_f1.fastq.gz’ saved [1239579596]
#
# --2021-04-28 03:26:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz
#            => ‘CRR144013_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_r2.fastq.gz ... 1250511974
# File has already been retrieved.
# 2021-04-28 03:26:44 (0.00 B/s) - ‘CRR144013_r2.fastq.gz’ saved [1250511974]
#
# --2021-04-28 03:26:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz
#            => ‘CRR144014_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ...
# No such directory ‘gsa3/CRA002497/CRR144014’.
#
# --2021-04-28 03:26:56--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz
#            => ‘CRR144014_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_r2.fastq.gz ... 1748640248
# File has already been retrieved.
# 2021-04-28 03:27:00 (0.00 B/s) - ‘CRR144014_r2.fastq.gz’ saved [1748640248]
#
# --2021-04-28 03:27:00--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ...
# No such directory ‘gsa3/CRA002497/CRR144015’.
#
# --2021-04-28 03:27:12--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ...
# No such directory ‘gsa3/CRA002497/CRR144015’.
#
# --2021-04-28 03:27:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_f1.fastq.gz ... 937554817
# ==> PASV ... done.    ==> RETR CRR144016_f1.fastq.gz ... done.
# Length: 937554817 (894M) (unauthoritative)
#
# CRR144016_f1.fastq. 100%[===================>] 894.12M  11.0MB/s    in 82s
#
# 2021-04-28 03:28:50 (10.8 MB/s) - ‘CRR144016_f1.fastq.gz’ saved [937554817]
#
# --2021-04-28 03:28:51--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_r2.fastq.gz ... 971216406
# File has already been retrieved.
# 2021-04-28 03:28:53 (0.00 B/s) - ‘CRR144016_r2.fastq.gz’ saved [971216406]
#
# --2021-04-28 03:28:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_f1.fastq.gz ... 915311231
# File has already been retrieved.
# 2021-04-28 03:28:55 (0.00 B/s) - ‘CRR144005_f1.fastq.gz’ saved [915311231]
#
# --2021-04-28 03:28:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_r2.fastq.gz ... 960618716
# File has already been retrieved.
# 2021-04-28 03:28:57 (0.00 B/s) - ‘CRR144005_r2.fastq.gz’ saved [960618716]
#
# --2021-04-28 03:28:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 03:29:10--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_r2.fastq.gz ... 1115476709
# File has already been retrieved.
# 2021-04-28 03:29:13 (0.00 B/s) - ‘CRR144006_r2.fastq.gz’ saved [1115476709]
#
# --2021-04-28 03:29:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 03:29:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ... done.
# ==> SIZE CRR144007_r2.fastq.gz ... 532409556
# File has already been retrieved.
# 2021-04-28 03:29:28 (0.00 B/s) - ‘CRR144007_r2.fastq.gz’ saved [532409556]
#
# --2021-04-28 03:29:28--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ... done.
# ==> SIZE CRR144008_f1.fastq.gz ... 800201797
# File has already been retrieved.
# 2021-04-28 03:29:30 (0.00 B/s) - ‘CRR144008_f1.fastq.gz’ saved [800201797]
#
# --2021-04-28 03:29:30--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz
#            => ‘CRR144008_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 03:29:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz
#            => ‘CRR144009_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ...
# No such directory ‘gsa3/CRA002497/CRR144009’.
#
# --2021-04-28 03:29:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#            => ‘CRR144009_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ...
# No such directory ‘gsa3/CRA002497/CRR144009’.
#
# --2021-04-28 03:30:08--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz
#            => ‘CRR144010_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_f1.fastq.gz ... 2750566018
# ==> PASV ... done.    ==> RETR CRR144010_f1.fastq.gz ... done.
# Length: 2750566018 (2.6G) (unauthoritative)
#
# CRR144010_f1.fastq. 100%[===================>]   2.56G  11.1MB/s    in 4m 8s
#
# 2021-04-28 03:34:20 (10.6 MB/s) - ‘CRR144010_f1.fastq.gz’ saved [2750566018]
#
# --2021-04-28 03:34:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#            => ‘CRR144010_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# File has already been retrieved.
# 2021-04-28 03:34:22 (0.00 B/s) - ‘CRR144010_r2.fastq.gz’ saved [10351864191]
#
# --2021-04-28 03:34:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz
#            => ‘CRR144011_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_f1.fastq.gz ... 1674825461
# ==> PASV ... done.    ==> RETR CRR144011_f1.fastq.gz ... done.
# Length: 1674825461 (1.6G) (unauthoritative)
#
# CRR144011_f1.fastq. 100%[===================>]   1.56G  11.8MB/s    in 3m 10s
#
# 2021-04-28 03:37:36 (8.40 MB/s) - ‘CRR144011_f1.fastq.gz’ saved [1674825461]
#
# --2021-04-28 03:37:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#            => ‘CRR144011_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ...
# No such directory ‘gsa3/CRA002497/CRR144011’.
#
# --2021-04-28 03:37:48--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz
#            => ‘CRR144012_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 03:38:00--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#            => ‘CRR144012_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 03:38:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz
#            => ‘CRR144013_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_f1.fastq.gz ... 1239579596
# File has already been retrieved.
# 2021-04-28 03:38:15 (0.00 B/s) - ‘CRR144013_f1.fastq.gz’ saved [1239579596]
#
# --2021-04-28 03:38:15--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz
#            => ‘CRR144013_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_r2.fastq.gz ... 1250511974
# File has already been retrieved.
# 2021-04-28 03:38:17 (0.00 B/s) - ‘CRR144013_r2.fastq.gz’ saved [1250511974]
#
# --2021-04-28 03:38:17--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz
#            => ‘CRR144014_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_f1.fastq.gz ... 1708491014
# ==> PASV ... done.    ==> RETR CRR144014_f1.fastq.gz ... done.
# Length: 1708491014 (1.6G) (unauthoritative)
#
# CRR144014_f1.fastq. 100%[===================>]   1.59G  11.6MB/s    in 2m 32s
#
# 2021-04-28 03:40:52 (10.7 MB/s) - ‘CRR144014_f1.fastq.gz’ saved [1708491014]
#
# --2021-04-28 03:40:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz
#            => ‘CRR144014_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_r2.fastq.gz ... 1748640248
# File has already been retrieved.
# 2021-04-28 03:40:55 (0.00 B/s) - ‘CRR144014_r2.fastq.gz’ saved [1748640248]
#
# --2021-04-28 03:40:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_f1.fastq.gz ... 1223913717
# File has already been retrieved.
# 2021-04-28 03:40:57 (0.00 B/s) - ‘CRR144015_f1.fastq.gz’ saved [1223913717]
#
# --2021-04-28 03:40:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_r2.fastq.gz ... 1248048314
# File has already been retrieved.
# 2021-04-28 03:40:59 (0.00 B/s) - ‘CRR144015_r2.fastq.gz’ saved [1248048314]
#
# --2021-04-28 03:40:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.
#
# --2021-04-28 03:41:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_r2.fastq.gz ... 971216406
# File has already been retrieved.
# 2021-04-28 03:41:13 (0.00 B/s) - ‘CRR144016_r2.fastq.gz’ saved [971216406]
#
# --2021-04-28 03:41:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ...
# No such directory ‘gsa3/CRA002497/CRR144005’.
#
# --2021-04-28 03:41:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_r2.fastq.gz ... 960618716
# File has already been retrieved.
# 2021-04-28 03:41:29 (0.00 B/s) - ‘CRR144005_r2.fastq.gz’ saved [960618716]
#
# --2021-04-28 03:41:29--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 03:41:41--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 03:41:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ... done.
# ==> SIZE CRR144007_f1.fastq.gz ... 524595845
# ==> PASV ... done.    ==> RETR CRR144007_f1.fastq.gz ... done.
# Length: 524595845 (500M) (unauthoritative)
#
# CRR144007_f1.fastq. 100%[===================>] 500.29M  10.3MB/s    in 56s
#
# 2021-04-28 03:42:52 (9.00 MB/s) - ‘CRR144007_f1.fastq.gz’ saved [524595845]
#
# --2021-04-28 03:42:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 03:43:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ...
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ...
# No such directory ‘gsa3/CRA002497/CRR144014’.
#
# --2021-04-28 03:44:43--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ...
# No such directory ‘gsa3/CRA002497/CRR144015’.
#
# --2021-04-28 03:44:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_r2.fastq.gz ... 1248048314
# File has already been retrieved.
# 2021-04-28 03:44:57 (0.00 B/s) - ‘CRR144015_r2.fastq.gz’ saved [1248048314]
#
# --2021-04-28 03:44:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.
#
# --2021-04-28 03:45:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_r2.fastq.gz ... 971216406
# File has already been retrieved.
# 2021-04-28 03:45:11 (0.00 B/s) - ‘CRR144016_r2.fastq.gz’ saved [971216406]
#
# --2021-04-28 03:45:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ...
# No such directory ‘gsa3/CRA002497/CRR144005’.
#
# --2021-04-28 03:45:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_r2.fastq.gz ... 960618716
# File has already been retrieved.
# 2021-04-28 03:45:27 (0.00 B/s) - ‘CRR144005_r2.fastq.gz’ saved [960618716]
#
# --2021-04-28 03:45:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 03:45:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 03:45:50--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ... done.
# ==> SIZE CRR144007_f1.fastq.gz ... 524595845
# File has already been retrieved.
# 2021-04-28 03:45:52 (0.00 B/s) - ‘CRR144007_f1.fastq.gz’ saved [524595845]
#
# --2021-04-28 03:45:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 03:46:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ... done.
# ==> SIZE CRR144008_f1.fastq.gz ... 800201797
# File has already been retrieved.
# 2021-04-28 03:46:06 (0.00 B/s) - ‘CRR144008_f1.fastq.gz’ saved [800201797]
#
# --2021-04-28 03:46:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz
#            => ‘CRR144008_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 03:46:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz
#            => ‘CRR144009_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_f1.fastq.gz ... 2515705993
# File has already been retrieved.
# 2021-04-28 03:46:20 (0.00 B/s) - ‘CRR144009_f1.fastq.gz’ saved [2515705993]
#
# --2021-04-28 03:46:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#            => ‘CRR144009_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_r2.fastq.gz ... 9389151594
# File has already been retrieved.
# 2021-04-28 03:46:23 (0.00 B/s) - ‘CRR144009_r2.fastq.gz’ saved [9389151594]
#
# --2021-04-28 03:46:23--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz
#            => ‘CRR144010_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ...
# No such directory ‘gsa3/CRA002497/CRR144010’.
#
# --2021-04-28 03:46:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#            => ‘CRR144010_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# File has already been retrieved.
# 2021-04-28 03:46:37 (0.00 B/s) - ‘CRR144010_r2.fastq.gz’ saved [10351864191]
#
# --2021-04-28 03:46:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz
#            => ‘CRR144011_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_f1.fastq.gz ... 1674825461
# File has already been retrieved.
# 2021-04-28 03:46:39 (0.00 B/s) - ‘CRR144011_f1.fastq.gz’ saved [1674825461]
#
# --2021-04-28 03:46:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#            => ‘CRR144011_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_r2.fastq.gz ... 6275184398
# File has already been retrieved.
# 2021-04-28 03:46:41 (0.00 B/s) - ‘CRR144011_r2.fastq.gz’ saved [6275184398]
#
# --2021-04-28 03:46:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz
#            => ‘CRR144012_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_f1.fastq.gz ... 3134151490
# ==> PASV ... done.    ==> RETR CRR144012_f1.fastq.gz ... done.
# Length: 3134151490 (2.9G) (unauthoritative)
#
# CRR144012_f1.fastq. 100%[===================>]   2.92G  11.3MB/s    in 4m 34s
#
# 2021-04-28 03:51:19 (10.9 MB/s) - ‘CRR144012_f1.fastq.gz’ saved [3134151490]
#
# --2021-04-28 03:51:19--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#            => ‘CRR144012_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_r2.fastq.gz ... 11933334512
# ==> PASV ... done.    ==> RETR CRR144012_r2.fastq.gz ... done.
# Length: 11933334512 (11G) (unauthoritative)
#
# CRR144012_r2.fastq. 100%[===================>]  11.11G  4.16MB/s    in 24m 2s
#
# 2021-04-28 04:15:24 (7.89 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 04:30:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#   (try: 2) => ‘CRR144012_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_r2.fastq.gz ... 11933334512
# File has already been retrieved.
# 2021-04-28 04:30:27 (0.00 B/s) - ‘CRR144012_r2.fastq.gz’ saved [11933334512]
#
# --2021-04-28 04:30:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz
#            => ‘CRR144013_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ...
# No such directory ‘gsa3/CRA002497/CRR144013’.
#
# --2021-04-28 04:30:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz
#            => ‘CRR144013_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ...
# No such directory ‘gsa3/CRA002497/CRR144013’.
#
# --2021-04-28 04:30:51--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz
#            => ‘CRR144014_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_f1.fastq.gz ... 1708491014
# File has already been retrieved.
# 2021-04-28 04:30:53 (0.00 B/s) - ‘CRR144014_f1.fastq.gz’ saved [1708491014]
#
# --2021-04-28 04:30:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz
#            => ‘CRR144014_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ...
# No such directory ‘gsa3/CRA002497/CRR144014’.
#
# --2021-04-28 04:31:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ...
# No such directory ‘gsa3/CRA002497/CRR144015’.
#
# --2021-04-28 04:31:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ...
# No such directory ‘gsa3/CRA002497/CRR144015’.
#
# --2021-04-28 04:31:30--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.
#
# --2021-04-28 04:31:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2021-04-28 04:31:57,185]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:56<00:00, 20.6MB/s]
# [2021-04-28 04:33:55,227]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['CRR144005_f1.fastq.gz', 'CRR144005_r2.fastq.gz', 'CRR144006_f1.fastq.gz', 'CRR144006_r2.fastq.gz', 'CRR144007_f1.fastq.gz', 'CRR144007_r2.fastq.gz', 'CRR144008_f1.fastq.gz', 'CRR144008_r2.fastq.gz', 'CRR144009_f1.fastq.gz', 'CRR144009_r2.fastq.gz', 'CRR144010_f1.fastq.gz', 'CRR144010_r2.fastq.gz', 'CRR144011_f1.fastq.gz', 'CRR144011_r2.fastq.gz', 'CRR144012_f1.fastq.gz', 'CRR144012_r2.fastq.gz', 'CRR144013_f1.fastq.gz', 'CRR144013_r2.fastq.gz', 'CRR144014_f1.fastq.gz', 'CRR144014_r2.fastq.gz', 'CRR144015_f1.fastq.gz', 'CRR144015_r2.fastq.gz', 'CRR144016_f1.fastq.gz', 'CRR144016_r2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['CRR144005_f1.fastq.gz',
#  'CRR144005_r2.fastq.gz',
#  'CRR144006_f1.fastq.gz',
#  'CRR144006_r2.fastq.gz',
#  'CRR144007_f1.fastq.gz',
#  'CRR144007_r2.fastq.gz',
#  'CRR144008_f1.fastq.gz',
#  'CRR144008_r2.fastq.gz',
#  'CRR144009_f1.fastq.gz',
#  'CRR144009_r2.fastq.gz',
#  'CRR144010_f1.fastq.gz',
#  'CRR144010_r2.fastq.gz',
#  'CRR144011_f1.fastq.gz',
#  'CRR144011_r2.fastq.gz',
#  'CRR144012_f1.fastq.gz',
#  'CRR144012_r2.fastq.gz',
#  'CRR144013_f1.fastq.gz',
#  'CRR144013_r2.fastq.gz',
#  'CRR144014_f1.fastq.gz',
#  'CRR144014_r2.fastq.gz',
#  'CRR144015_f1.fastq.gz',
#  'CRR144015_r2.fastq.gz',
#  'CRR144016_f1.fastq.gz',
#  'CRR144016_r2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2021-04-28 04:34:35,323]    INFO Using index index.idx to generate BUS file to outputCRX118016 from
# [2021-04-28 04:34:35,323]    INFO         CRR144005_f1.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144005_r2.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144006_f1.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144006_r2.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144007_f1.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144007_r2.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144008_f1.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144008_r2.fastq.gz
# [2021-04-28 04:34:35,323]    INFO         CRR144009_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144009_r2.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144010_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144010_r2.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144011_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144011_r2.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144012_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144012_r2.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144013_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144013_r2.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144014_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144014_r2.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144015_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144015_r2.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144016_f1.fastq.gz
# [2021-04-28 04:34:35,324]    INFO         CRR144016_r2.fastq.gz
# [2021-04-28 06:27:24,491]    INFO Sorting BUS file outputCRX118016/output.bus to outputCRX118016/tmp/output.s.bus
# [2021-04-28 06:33:21,554]    INFO Whitelist not provided
# [2021-04-28 06:33:21,555]    INFO Copying pre-packaged 10XV2 whitelist to outputCRX118016
# [2021-04-28 06:33:21,694]    INFO Inspecting BUS file outputCRX118016/tmp/output.s.bus
# [2021-04-28 06:34:13,019]    INFO Correcting BUS records in outputCRX118016/tmp/output.s.bus to outputCRX118016/tmp/output.s.c.bus with whitelist outputCRX118016/10xv2_whitelist.txt
# [2021-04-28 06:35:23,848]    INFO Sorting BUS file outputCRX118016/tmp/output.s.c.bus to outputCRX118016/output.unfiltered.bus
# [2021-04-28 06:37:45,640]    INFO Generating count matrix outputCRX118016/counts_unfiltered/cells_x_genes from BUS file outputCRX118016/output.unfiltered.bus
# [2021-04-28 06:39:19,560]    INFO Reading matrix outputCRX118016/counts_unfiltered/cells_x_genes.mtx
# [2021-04-28 06:40:12,854]    INFO Writing matrix to h5ad outputCRX118016/counts_unfiltered/adata.h5ad
# [2021-04-28 06:40:14,496]    INFO Filtering with bustools
# [2021-04-28 06:40:14,496]    INFO Generating whitelist outputCRX118016/filter_barcodes.txt from BUS file outputCRX118016/output.unfiltered.bus
# [2021-04-28 06:40:15,909]    INFO Correcting BUS records in outputCRX118016/output.unfiltered.bus to outputCRX118016/tmp/output.unfiltered.c.bus with whitelist outputCRX118016/filter_barcodes.txt
# [2021-04-28 06:41:15,978]    INFO Sorting BUS file outputCRX118016/tmp/output.unfiltered.c.bus to outputCRX118016/output.filtered.bus
# [2021-04-28 06:43:20,524]    INFO Generating count matrix outputCRX118016/counts_filtered/cells_x_genes from BUS file outputCRX118016/output.filtered.bus
# [2021-04-28 06:44:29,286]    INFO Reading matrix outputCRX118016/counts_filtered/cells_x_genes.mtx
# [2021-04-28 06:45:04,372]    INFO Writing matrix to h5ad outputCRX118016/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix CRX118016 contains 518228 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 10000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 22#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 10000 with at least 2773.0 UMIs
# We select 22 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 518,228 cells x 60,623 genes
#     New shape: 9,933 cells x 29,293 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[i]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[i]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[i]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[i]

  results["data_" + sample_id[i]].uns["condition"] = condition[i]

  results["data_" + sample_id[i]].uns["species"] = species[i]

  results["data_" + sample_id[i]].uns["technology"] = technology[i]

  results["data_" + sample_id[i]].uns["paper"] = paper[i]

  results["data_" + sample_id[i]].uns["figure"] = figure[i]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
