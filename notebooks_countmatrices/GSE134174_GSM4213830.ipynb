# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE134174_GSM4213830.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE134174_GSM4213830

# %%
# !wget -O adata_tcc.h5ad.gz https://caltech.box.com/shared/static/6pl4aj1wprp7vch0dtvvinnlr0tx55ux.gz
# !wget -O adata.h5ad.gz https://caltech.box.com/shared/static/n768i86nzb05r0panbw87sw9lk1cl083.gz
# Out:
# --2021-05-06 16:51:40--  https://caltech.box.com/shared/static/6pl4aj1wprp7vch0dtvvinnlr0tx55ux.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.24.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.24.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/6pl4aj1wprp7vch0dtvvinnlr0tx55ux.gz [following]
# --2021-05-06 16:51:40--  https://caltech.box.com/public/static/6pl4aj1wprp7vch0dtvvinnlr0tx55ux.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/6pl4aj1wprp7vch0dtvvinnlr0tx55ux.gz [following]
# --2021-05-06 16:51:40--  https://caltech.app.box.com/public/static/6pl4aj1wprp7vch0dtvvinnlr0tx55ux.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.25.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.25.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!etgAi-BAIE_afO3u4p8tTOnga7FpHiYbCbvvGWW40vQF-BBClqVgNtV7JDCIzcz1ZWicQnBP7l1NN5LCmIrqPRX0iH1221vpl52WSxZNbjrD1CliYfSzmxuQHLCI_jPBQJsGpSpfg5KugKiDR8jz2psZ6MokAO8EkeH6NUv5s2GXD7yBteoOONQXwY5wa5sUVTziLKWfHtwhpismSQGdtZouTXbl-GYRbZFkxJ7RpikQot2_ig15pvpn_vwGwDYrBnwTecKPeNdciHq0mB5phJbwggto5appx2q5diLXGneqxKz9paIzKEMm15vcKo3ih03PuCj4JU__Q4HqTGxHuXQBoPGljTnX68p_UnqqPQoe31VN4E2vRcasrcWiKPraX-t5YAlhWBK-5UQZ-ItrKzfu4zAAnRvz6bb-ujo0tgroqqevFSzBMD0INcjsYi0dQHmZQqOr9CIm1WVnhXJizBo822lIXu64DXhpAfr1eXuEYb0ga0uDrqYwE3jtsW8ce0WMkqJwis1rWIDEwBAp9wUaNKUCOgGt6l8mLD1ipQsecntMQhwXoBh4alCR3WqOidoR3itaCKg4gU6keFq7NHyJn0z5TZcg-Q81xX0MDKZ6Ov9WOk8EQg7QfQrG9pADGnf36SOn3e-PhVfgdiE4AeEzAny2_5-bGwMPl18cp_iRvu7LNHWtTLr-FRBnHSnvWvpu8vQ1yVRsvvwIR6xzc76kNLS4thsvr5MTeHvLin8jiG0ANGiRUN7uOgBxst2S8A3qZYjdMlAG8zjF6JVzjcuTQcPmo7Fib8OT2SdD3GtSfj3BndVUdHpHNfHS7XNH-aqrXx_YTgKmjuhvU2XbEIvOY9wROEdNNiTrmwoWjitoQ9BEbZOT7Gq8QSklLEVNlPiVctBQvl3tTXbnJ5Hk4sxV-QhWvgDqboVYC7hyrUZABH1wBbRLS7iQdCn00Nwj7NNkozOAWfKsE8vrRgC8WhAvBhDa8eTnnAqYupLQpVMcXs22CAwF37kyYrKVD6cSsMsUS3tCBnJ72q9dIQ3Bl-xf02LjlxLi4msl0VBq9waqvGlz3gvCgxhCbIJ-faYaer8-10ayWmqRDgQRMJbFiNAQBj1h7DnmY9BEBXEh4XGcJE9FhGOfg9-flNA9IxB6xEfogCrdMyYQg56YLXvBUgfA9g-IUHJwy6TLKQXmPjuR8NC-9IPfdf2O1XPa2z07r46yzq-XM81olO6Whyh8eR6zVW6sBd5QRjZeYE8WcqCJJvCoQx2o8bc3htigRcDvTD4pvWXyEs9iWxKzs32s1XNGjlaeCZes6dcKcR3YTB6-XEXzBV3hdULbdMKKK4n2caN2tGuTm5u0xKF-0C6KA9K37DQlEwdNXzIIBgu6ISILUwxq3VKq9bntEfU2lKdLFwYq9rT8qVQ./download [following]
# --2021-05-06 16:51:40--  https://public.boxcloud.com/d/1/b1!etgAi-BAIE_afO3u4p8tTOnga7FpHiYbCbvvGWW40vQF-BBClqVgNtV7JDCIzcz1ZWicQnBP7l1NN5LCmIrqPRX0iH1221vpl52WSxZNbjrD1CliYfSzmxuQHLCI_jPBQJsGpSpfg5KugKiDR8jz2psZ6MokAO8EkeH6NUv5s2GXD7yBteoOONQXwY5wa5sUVTziLKWfHtwhpismSQGdtZouTXbl-GYRbZFkxJ7RpikQot2_ig15pvpn_vwGwDYrBnwTecKPeNdciHq0mB5phJbwggto5appx2q5diLXGneqxKz9paIzKEMm15vcKo3ih03PuCj4JU__Q4HqTGxHuXQBoPGljTnX68p_UnqqPQoe31VN4E2vRcasrcWiKPraX-t5YAlhWBK-5UQZ-ItrKzfu4zAAnRvz6bb-ujo0tgroqqevFSzBMD0INcjsYi0dQHmZQqOr9CIm1WVnhXJizBo822lIXu64DXhpAfr1eXuEYb0ga0uDrqYwE3jtsW8ce0WMkqJwis1rWIDEwBAp9wUaNKUCOgGt6l8mLD1ipQsecntMQhwXoBh4alCR3WqOidoR3itaCKg4gU6keFq7NHyJn0z5TZcg-Q81xX0MDKZ6Ov9WOk8EQg7QfQrG9pADGnf36SOn3e-PhVfgdiE4AeEzAny2_5-bGwMPl18cp_iRvu7LNHWtTLr-FRBnHSnvWvpu8vQ1yVRsvvwIR6xzc76kNLS4thsvr5MTeHvLin8jiG0ANGiRUN7uOgBxst2S8A3qZYjdMlAG8zjF6JVzjcuTQcPmo7Fib8OT2SdD3GtSfj3BndVUdHpHNfHS7XNH-aqrXx_YTgKmjuhvU2XbEIvOY9wROEdNNiTrmwoWjitoQ9BEbZOT7Gq8QSklLEVNlPiVctBQvl3tTXbnJ5Hk4sxV-QhWvgDqboVYC7hyrUZABH1wBbRLS7iQdCn00Nwj7NNkozOAWfKsE8vrRgC8WhAvBhDa8eTnnAqYupLQpVMcXs22CAwF37kyYrKVD6cSsMsUS3tCBnJ72q9dIQ3Bl-xf02LjlxLi4msl0VBq9waqvGlz3gvCgxhCbIJ-faYaer8-10ayWmqRDgQRMJbFiNAQBj1h7DnmY9BEBXEh4XGcJE9FhGOfg9-flNA9IxB6xEfogCrdMyYQg56YLXvBUgfA9g-IUHJwy6TLKQXmPjuR8NC-9IPfdf2O1XPa2z07r46yzq-XM81olO6Whyh8eR6zVW6sBd5QRjZeYE8WcqCJJvCoQx2o8bc3htigRcDvTD4pvWXyEs9iWxKzs32s1XNGjlaeCZes6dcKcR3YTB6-XEXzBV3hdULbdMKKK4n2caN2tGuTm5u0xKF-0C6KA9K37DQlEwdNXzIIBgu6ISILUwxq3VKq9bntEfU2lKdLFwYq9rT8qVQ./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.25.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.25.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 152121441 (145M) [application/octet-stream]
# Saving to: ‘adata_tcc.h5ad.gz’
#
# adata_tcc.h5ad.gz   100%[===================>] 145.07M  22.7MB/s    in 8.8s
#
# 2021-05-06 16:51:49 (16.5 MB/s) - ‘adata_tcc.h5ad.gz’ saved [152121441/152121441]
#
# --2021-05-06 16:51:49--  https://caltech.box.com/shared/static/n768i86nzb05r0panbw87sw9lk1cl083.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.24.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.24.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/n768i86nzb05r0panbw87sw9lk1cl083.gz [following]
# --2021-05-06 16:51:50--  https://caltech.box.com/public/static/n768i86nzb05r0panbw87sw9lk1cl083.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/n768i86nzb05r0panbw87sw9lk1cl083.gz [following]
# --2021-05-06 16:51:50--  https://caltech.app.box.com/public/static/n768i86nzb05r0panbw87sw9lk1cl083.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.25.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.25.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!xtIkS5KYDlfYc7Zl4Tt7ONntuQjB00sfjbcuu-goXpR-Ogn9bcPLC50xi2hV8HxInZkNjZPmvoL1fAFn5pIS2ArwrQWaNiUXHCEHhG0okeWOfLLTAczXoJn7tBImO3KB7EamVdTinujktcrNz3G7t_Hxd6h_BGSo9laTpn3sApqPPmJV06gTjCRWlUu0P5h3Kj_zuJetxYgcSfkZACNdx3qj-l1H-rnhXLcEw2yAQBLnBEmKAcGHSGF4h-8-vukJYIf1E-X91wIxYcbBK3xMvfgMCT5gW_Uk4v7-gZ3MLXt_-EfX0ep7eLHu_QUq0h-UygrdY_PVAIo3JOae_OnUlZTlXu3BEUdUG6PDZk-toideqOEAoqwZr_c4FFvGSz_M5-olqUpCieOzpCdww7Kr4oCQQmliGErCpA5d1m-hwZmHAs5bUcmNZF-PRPmFz5wdqTIG4TZ8AtOceRBNNrVFROdCgQ_h3hhmJxY1sK7Hy1h0xkEtMCagUKZqPid7U6Rcivp4zMlk-L39cMuRJjc1q7_KFl06g8R9eBfNz9zds9l3wUXdcJsn2QTkFKiUJmd31iGt7v6EbjVbAiIKFoWqIjVe_-wOEUX5Rreazi_epSzsCPWbGzGXPtYIDpyQ5bctQG0CxHQ0dVGGtTKgh3uYq5vHAwV6ggvp9kjQUMsdF3z4JDQo-bBYX_8zw_9vszB5r0-OWtJUi-6aX7E--CK7svg5FVqaT7rQ5TLud313UKLxOMk4cAmiiIsve5X1cirSGQ_6CZwNt_g7ioG5AGThURqq419cBwN7ZOUFlcFrA3GFoo_yFeZMaE-Mv4FWFcxYQ3itT8-H4-5f3qcg-5F8h0pCiDFKrQCd0v3smcESbaUs7A6aeaS869oOJxesmhq_dw3c0_LEkrI5fgAn5CXAC99HNhzOKvUcpmcNqrVw4r8_mnAdPs--nGw8sJ57_p4WP8bnHfFST_ygo_94EVwibPxQjPV7rPJ-IVMKrY1reV2oMk6dDaxQEMNuD3lktO-EjuGPVkRHicYTVWklMY6O6KTvbCqmzhjy33bd_HeuVTaPc0ZFV1K3x2CiUpNYEwTjvbQ-J2kKp9TA_G4KGTIQYbuOz5vVhliacf6o1ZIkWyYz_PLBeuKbj_JrCy_6FPLmNkA7PYRYhgnlWlN5tkLiYWIyNNeFNlz507OHjPCtsRArZyAwHnvOOL2oWcs4-kWihcJEiYhfDduC1p3QX6jehWYOgx-rwtl-IEmJdNn9CLKvMuxnXKKAaw8m-MwduECVQws3G6N0AB9kjiDLjCoGLErrrLMBZCjqL11Spkd3i6QoHHVz_RELnDdI53Qc8_OsoRy7V9KHb-KS7BGjYX5Q82Oxqopf6VupSu0B6fpCi32akWy-18Tpc-A6kZWhRgsOynM4nvaEvir0P7Q9lOQAp0-t8cvpL90ikJ4RZJw./download [following]
# --2021-05-06 16:51:50--  https://public.boxcloud.com/d/1/b1!xtIkS5KYDlfYc7Zl4Tt7ONntuQjB00sfjbcuu-goXpR-Ogn9bcPLC50xi2hV8HxInZkNjZPmvoL1fAFn5pIS2ArwrQWaNiUXHCEHhG0okeWOfLLTAczXoJn7tBImO3KB7EamVdTinujktcrNz3G7t_Hxd6h_BGSo9laTpn3sApqPPmJV06gTjCRWlUu0P5h3Kj_zuJetxYgcSfkZACNdx3qj-l1H-rnhXLcEw2yAQBLnBEmKAcGHSGF4h-8-vukJYIf1E-X91wIxYcbBK3xMvfgMCT5gW_Uk4v7-gZ3MLXt_-EfX0ep7eLHu_QUq0h-UygrdY_PVAIo3JOae_OnUlZTlXu3BEUdUG6PDZk-toideqOEAoqwZr_c4FFvGSz_M5-olqUpCieOzpCdww7Kr4oCQQmliGErCpA5d1m-hwZmHAs5bUcmNZF-PRPmFz5wdqTIG4TZ8AtOceRBNNrVFROdCgQ_h3hhmJxY1sK7Hy1h0xkEtMCagUKZqPid7U6Rcivp4zMlk-L39cMuRJjc1q7_KFl06g8R9eBfNz9zds9l3wUXdcJsn2QTkFKiUJmd31iGt7v6EbjVbAiIKFoWqIjVe_-wOEUX5Rreazi_epSzsCPWbGzGXPtYIDpyQ5bctQG0CxHQ0dVGGtTKgh3uYq5vHAwV6ggvp9kjQUMsdF3z4JDQo-bBYX_8zw_9vszB5r0-OWtJUi-6aX7E--CK7svg5FVqaT7rQ5TLud313UKLxOMk4cAmiiIsve5X1cirSGQ_6CZwNt_g7ioG5AGThURqq419cBwN7ZOUFlcFrA3GFoo_yFeZMaE-Mv4FWFcxYQ3itT8-H4-5f3qcg-5F8h0pCiDFKrQCd0v3smcESbaUs7A6aeaS869oOJxesmhq_dw3c0_LEkrI5fgAn5CXAC99HNhzOKvUcpmcNqrVw4r8_mnAdPs--nGw8sJ57_p4WP8bnHfFST_ygo_94EVwibPxQjPV7rPJ-IVMKrY1reV2oMk6dDaxQEMNuD3lktO-EjuGPVkRHicYTVWklMY6O6KTvbCqmzhjy33bd_HeuVTaPc0ZFV1K3x2CiUpNYEwTjvbQ-J2kKp9TA_G4KGTIQYbuOz5vVhliacf6o1ZIkWyYz_PLBeuKbj_JrCy_6FPLmNkA7PYRYhgnlWlN5tkLiYWIyNNeFNlz507OHjPCtsRArZyAwHnvOOL2oWcs4-kWihcJEiYhfDduC1p3QX6jehWYOgx-rwtl-IEmJdNn9CLKvMuxnXKKAaw8m-MwduECVQws3G6N0AB9kjiDLjCoGLErrrLMBZCjqL11Spkd3i6QoHHVz_RELnDdI53Qc8_OsoRy7V9KHb-KS7BGjYX5Q82Oxqopf6VupSu0B6fpCi32akWy-18Tpc-A6kZWhRgsOynM4nvaEvir0P7Q9lOQAp0-t8cvpL90ikJ4RZJw./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26150697 (25M) [application/octet-stream]
# Saving to: ‘adata.h5ad.gz’
#
# adata.h5ad.gz       100%[===================>]  24.94M  30.7MB/s    in 0.8s
#
# 2021-05-06 16:51:51 (30.7 MB/s) - ‘adata.h5ad.gz’ saved [26150697/26150697]

# %% [markdown]
# This dataset was too large to be processed in google colab. The gene count and TCC were generated using the following commands:
#
# ```
# SRA=SRR10668804
# GSM=GSM4213830
#
# cd /central/scratch/agalvezm/ace2/counts
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/prefetch 2.10.9 ${SRA} --max-size 2000000000
#
# cd ${SRA}
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/fasterq-dump --split-files --outdir fastq --include-technical ${SRA}.sra
#
# ~/anaconda3/bin/kb ref -d human -i index.idx -g t2g.txt -f1 transcriptome.fasta
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/output${GSM} --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/tccoutput${GSM} --tcc --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ```

# %%
no_samples = 1

fastqs_per_sample = [1] 

sample_id = "GSM4213830"

database_id = ["GSE134174"] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["trachea epithelial cells"] * no_samples

species = ["human"] * no_samples

technology = ["10xv3"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 5"] * no_samples

condition = ["non smoker"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 73kB/s
#      |████████████████████████████████| 13.2MB 52.3MB/s
#      |████████████████████████████████| 51kB 6.2MB/s
#      |████████████████████████████████| 10.3MB 25.3MB/s
#      |████████████████████████████████| 133kB 47.8MB/s
#      |████████████████████████████████| 112kB 41.3MB/s
#      |████████████████████████████████| 81kB 9.2MB/s
#      |████████████████████████████████| 71kB 7.4MB/s
#      |████████████████████████████████| 1.2MB 39.3MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %%
# Execute kb ref to get t2g.txt file
# !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2021-05-06 16:53:16,492]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:50<00:00, 21.6MB/s]
# [2021-05-06 16:55:07,905]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrices

# %%
# # Gunzip matrices
# !gunzip /content/adata.h5ad.gz
# !gunzip /content/adata_tcc.h5ad.gz

# Load matrices
adata = anndata.read_h5ad("/content/adata.h5ad")
adata_tcc = anndata.read_h5ad("/content/adata_tcc.h5ad")

# %%
adata.var
# Out:
#                      gene_name
# gene_id
# ENSG00000223972.5      DDX11L1
# ENSG00000227232.5       WASH7P
# ENSG00000278267.1    MIR6859-1
# ENSG00000243485.5  MIR1302-2HG
# ENSG00000284332.1    MIR1302-2
# ...                        ...
# ENSG00000271254.6   AC240274.1
# ENSG00000275405.1           U1
# ENSG00000275987.1           U1
# ENSG00000277475.1   AC213203.2
# ENSG00000268674.2   AC213203.1
#
# [60623 rows x 1 columns]

# %%
# Reformat and fill gene count matrix 

adata.var["gene_id"] = adata.var.index.values

t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
t2g.index = t2g.gene_id
t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

adata.var["gene_name"] = adata.var.gene_id.map(t2g["gene_name"])
adata.var.index = adata.var["gene_name"]
print("The unfiltered matrix " + sample_id + " contains {} cells by {} genes".format(len(adata.obs), len(adata.var)))

adata.obs["cell_counts"] = adata.X.sum(axis=1)
adata.var["gene_counts"] = nd(adata.X.sum(axis=0))

adata.obs["n_genes"] = nd((adata.X>0).sum(axis=1))
adata.var["n_cells"] = nd((adata.X>0).sum(axis=0))

mito_genes = adata.var_names.str.startswith("MT-" or "mt-") 
adata.obs["percent_mito"] = adata[:,mito_genes].X.sum(axis=1)/adata.X.sum(axis=1)*100

# Changing the name of the index is necessary to write the file (it won't work with duplicated names)
adata.var.index.name = "index"
# Out:
# The unfiltered matrix GSM4213830 contains 341828 cells by 60623 genes

# %% [markdown]
# ## Assign filters for gene count matrix

# %%
results = {}


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

# %%
expected_num_cells = 1500#@param {type:"integer"}
knee = np.sort(nd(adata.X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 18#@param {type:"integer"}
results["mito_criteria" + sample_id] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(adata.obs["cell_counts"][adata.obs["cell_counts"] > cell_threshold])
y = nd(adata.obs["percent_mito"][adata.obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 1500 with at least 4114.0 UMIs
# We select 18 % as the mitochondrial content threshold

# %% [markdown]
# # Filter gene count matrix

# %%
adata.obs["pass_count_filter"] = adata.obs["cell_counts"] > results["cell_threshold" + sample_id]
adata.obs["pass_mito_filter"] = adata.obs.percent_mito < results["mito_criteria" + sample_id]
adata.var["pass_gene_filter"] = adata.var["n_cells"] > gene_threshold

cell_mask = np.logical_and(adata.obs["pass_count_filter"].values, adata.obs["pass_mito_filter"].values)
gene_mask = adata.var["pass_gene_filter"].values

print("Current Shape: {:,} cells x {:,} genes".format(adata.shape[0], adata.shape[1]))
print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
results["data_" + sample_id] = adata[cell_mask, gene_mask]
# Out:
# Current Shape: 341,828 cells x 60,623 genes
#     New shape: 1,395 cells x 27,128 genes

# %% [markdown]
# # Anotate and write gene count matrix

# %%
adata.uns["database_id"] = database_id

adata.uns["tissue"] = tissue

adata.uns["cell_type"] = cell_type

adata.uns["sample_id"] = sample_id

adata.uns["condition"] = condition

adata.uns["species"] = species

adata.uns["technology"] = technology

adata.uns["paper"] = paper

adata.uns["figure"] = figure

# %cd /content

adata.write("result" + sample_id)
# Out:
# /content
# ... storing 'gene_name' as categorical

# %% [markdown]
# Filter TCC using gene count matrix's filter

# %%
adata_tcc = adata_tcc[adata.obs.index.values]
# transfer obs data
adata_tcc.obs = adata.obs
# transfer metadata
adata_tcc.uns = adata.uns
# write tcc matrix
adata_tcc.write("/content/tcc_" + sample_id)
#gzip tcc matrix
cmd = "gzip /content/tcc_" + sample_id
# !$cmd
