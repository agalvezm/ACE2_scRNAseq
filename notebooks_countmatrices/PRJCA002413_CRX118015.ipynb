# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/PRJCA002413_CRX118015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRJCA002413_CRX118015

# %%
# define the values for the analysis

# accession id for the data
id = "PRJCA002413"
samp_id = ["CRX118015"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet
  links_raw = "ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_r2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

#sample specific metadata

no_samples = 1

condition = ["healthy control"] * no_samples

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["blood"] * no_samples

cell_type = ["PBMCs"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Wen et al 2020"] * no_samples

figure = ["Fig: all"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 106kB/s
#      |████████████████████████████████| 10.3MB 22.8MB/s
#      |████████████████████████████████| 13.2MB 219kB/s
#      |████████████████████████████████| 51kB 5.3MB/s
#      |████████████████████████████████| 133kB 43.7MB/s
#      |████████████████████████████████| 81kB 8.0MB/s
#      |████████████████████████████████| 112kB 47.3MB/s
#      |████████████████████████████████| 71kB 7.8MB/s
#      |████████████████████████████████| 1.2MB 41.0MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  while len(os.listdir()) != len(fastqs):
    for link in fastqs:
      # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2021-04-27 19:58:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_f1.fastq.gz
#            => ‘CRR143993_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ...
# No such directory ‘gsa3/CRA002497/CRR143993’.
#
# --2021-04-27 19:58:50--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_r2.fastq.gz
#            => ‘CRR143993_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ...
# No such directory ‘gsa3/CRA002497/CRR143993’.
#
# --2021-04-27 19:59:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_f1.fastq.gz
#            => ‘CRR143994_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 19:59:16--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_r2.fastq.gz
#            => ‘CRR143994_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ... done.
# ==> SIZE CRR143994_r2.fastq.gz ... 590166769
# ==> PASV ... done.    ==> RETR CRR143994_r2.fastq.gz ... done.
# Length: 590166769 (563M) (unauthoritative)
#
# CRR143994_r2.fastq. 100%[===================>] 562.83M  11.8MB/s    in 45s
#
# 2021-04-27 20:00:05 (12.5 MB/s) - ‘CRR143994_r2.fastq.gz’ saved [590166769]
#
# --2021-04-27 20:00:05--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_f1.fastq.gz
#            => ‘CRR143995_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ... done.
# ==> SIZE CRR143995_f1.fastq.gz ... 638437998
# ==> PASV ... done.    ==> RETR CRR143995_f1.fastq.gz ... done.
# Length: 638437998 (609M) (unauthoritative)
#
# CRR143995_f1.fastq. 100%[===================>] 608.86M  13.8MB/s    in 49s
#
# 2021-04-27 20:00:57 (12.4 MB/s) - ‘CRR143995_f1.fastq.gz’ saved [638437998]
#
# --2021-04-27 20:00:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_r2.fastq.gz
#            => ‘CRR143995_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ... done.
# ==> SIZE CRR143995_r2.fastq.gz ... 683410724
# ==> PASV ... done.    ==> RETR CRR143995_r2.fastq.gz ... done.
# Length: 683410724 (652M) (unauthoritative)
#
# CRR143995_r2.fastq. 100%[===================>] 651.75M  14.3MB/s    in 51s
#
# 2021-04-27 20:01:51 (12.8 MB/s) - ‘CRR143995_r2.fastq.gz’ saved [683410724]
#
# --2021-04-27 20:01:51--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_f1.fastq.gz
#            => ‘CRR143996_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ...
# No such directory ‘gsa3/CRA002497/CRR143996’.
#
# --2021-04-27 20:02:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_r2.fastq.gz
#            => ‘CRR143996_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ... done.
# ==> SIZE CRR143996_r2.fastq.gz ... 777409754
# ==> PASV ... done.    ==> RETR CRR143996_r2.fastq.gz ... done.
# Length: 777409754 (741M) (unauthoritative)
#
# CRR143996_r2.fastq. 100%[===================>] 741.40M  13.1MB/s    in 59s
#
# 2021-04-27 20:03:06 (12.6 MB/s) - ‘CRR143996_r2.fastq.gz’ saved [777409754]
#
# --2021-04-27 20:03:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_f1.fastq.gz
#            => ‘CRR143997_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ...
# No such directory ‘gsa3/CRA002497/CRR143997’.
#
# --2021-04-27 20:03:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_r2.fastq.gz
#            => ‘CRR143997_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ...
# No such directory ‘gsa3/CRA002497/CRR143997’.
#
# --2021-04-27 20:03:30--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_f1.fastq.gz
#            => ‘CRR143998_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ... done.
# ==> SIZE CRR143998_f1.fastq.gz ... 1145762172
# ==> PASV ... done.    ==> RETR CRR143998_f1.fastq.gz ... done.
# Length: 1145762172 (1.1G) (unauthoritative)
#
# CRR143998_f1.fastq. 100%[===================>]   1.07G  14.6MB/s    in 84s
#
# 2021-04-27 20:04:57 (12.9 MB/s) - ‘CRR143998_f1.fastq.gz’ saved [1145762172]
#
# --2021-04-27 20:04:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_r2.fastq.gz
#            => ‘CRR143998_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ...
# No such directory ‘gsa3/CRA002497/CRR143998’.
#
# --2021-04-27 20:05:08--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_f1.fastq.gz
#            => ‘CRR143999_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ... done.
# ==> SIZE CRR143999_f1.fastq.gz ... 1416474924
# ==> PASV ... done.    ==> RETR CRR143999_f1.fastq.gz ... done.
# Length: 1416474924 (1.3G) (unauthoritative)
#
# CRR143999_f1.fastq. 100%[===================>]   1.32G  11.7MB/s    in 1m 46s
#
# 2021-04-27 20:06:57 (12.8 MB/s) - ‘CRR143999_f1.fastq.gz’ saved [1416474924]
#
# --2021-04-27 20:06:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_r2.fastq.gz
#            => ‘CRR143999_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ...
# No such directory ‘gsa3/CRA002497/CRR143999’.
#
# --2021-04-27 20:07:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_f1.fastq.gz
#            => ‘CRR144000_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ...
# No such directory ‘gsa3/CRA002497/CRR144000’.
#
# --2021-04-27 20:07:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_r2.fastq.gz
#            => ‘CRR144000_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ...
# No such directory ‘gsa3/CRA002497/CRR144000’.
#
# --2021-04-27 20:07:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_f1.fastq.gz
#            => ‘CRR144001_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ... done.
# ==> SIZE CRR144001_f1.fastq.gz ... 2785716389
# ==> PASV ... done.    ==> RETR CRR144001_f1.fastq.gz ... done.
# Length: 2785716389 (2.6G) (unauthoritative)
#
# CRR144001_f1.fastq. 100%[===================>]   2.59G  12.9MB/s    in 3m 56s
#
# 2021-04-27 20:11:32 (11.3 MB/s) - ‘CRR144001_f1.fastq.gz’ saved [2785716389]
#
# --2021-04-27 20:11:32--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_r2.fastq.gz
#            => ‘CRR144001_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ...
# No such directory ‘gsa3/CRA002497/CRR144001’.
#
# --2021-04-27 20:11:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_f1.fastq.gz
#            => ‘CRR144002_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ... done.
# ==> SIZE CRR144002_f1.fastq.gz ... 2533293334
# ==> PASV ... done.    ==> RETR CRR144002_f1.fastq.gz ... done.
# Length: 2533293334 (2.4G) (unauthoritative)
#
# CRR144002_f1.fastq. 100%[===================>]   2.36G  14.6MB/s    in 3m 11s
#
# 2021-04-27 20:14:57 (12.7 MB/s) - ‘CRR144002_f1.fastq.gz’ saved [2533293334]
#
# --2021-04-27 20:14:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_r2.fastq.gz
#            => ‘CRR144002_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ...
# No such directory ‘gsa3/CRA002497/CRR144002’.
#
# --2021-04-27 20:15:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_f1.fastq.gz
#            => ‘CRR144003_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ...
# No such directory ‘gsa3/CRA002497/CRR144003’.
#
# --2021-04-27 20:15:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_r2.fastq.gz
#            => ‘CRR144003_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ... done.
# ==> SIZE CRR144003_r2.fastq.gz ... 6793807142
# ==> PASV ... done.    ==> RETR CRR144003_r2.fastq.gz ... done.
# Length: 6793807142 (6.3G) (unauthoritative)
#
# CRR144003_r2.fastq. 100%[===================>]   6.33G  13.9MB/s    in 9m 1s
#
# 2021-04-27 20:24:25 (12.0 MB/s) - ‘CRR144003_r2.fastq.gz’ saved [6793807142]
#
# --2021-04-27 20:24:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_f1.fastq.gz
#            => ‘CRR144004_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ...
# No such directory ‘gsa3/CRA002497/CRR144004’.
#
# --2021-04-27 20:24:38--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_r2.fastq.gz
#            => ‘CRR144004_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ...
# No such directory ‘gsa3/CRA002497/CRR144004’.
#
# --2021-04-27 20:24:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_f1.fastq.gz
#            => ‘CRR143993_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ... done.
# ==> SIZE CRR143993_f1.fastq.gz ... 756607588
# ==> PASV ... done.    ==> RETR CRR143993_f1.fastq.gz ... done.
# Length: 756607588 (722M) (unauthoritative)
#
# CRR143993_f1.fastq. 100%[===================>] 721.56M  13.1MB/s    in 57s
#
# 2021-04-27 20:25:52 (12.7 MB/s) - ‘CRR143993_f1.fastq.gz’ saved [756607588]
#
# --2021-04-27 20:25:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_r2.fastq.gz
#            => ‘CRR143993_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ...
# No such directory ‘gsa3/CRA002497/CRR143993’.
#
# --2021-04-27 20:26:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_f1.fastq.gz
#            => ‘CRR143994_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ... done.
# ==> SIZE CRR143994_f1.fastq.gz ... 566677747
# ==> PASV ... done.    ==> RETR CRR143994_f1.fastq.gz ... done.
# Length: 566677747 (540M) (unauthoritative)
#
# CRR143994_f1.fastq. 100%[===================>] 540.43M  12.4MB/s    in 43s
#
# 2021-04-27 20:26:50 (12.5 MB/s) - ‘CRR143994_f1.fastq.gz’ saved [566677747]
#
# --2021-04-27 20:26:50--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_r2.fastq.gz
#            => ‘CRR143994_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 20:27:02--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_f1.fastq.gz
#            => ‘CRR143995_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ... done.
# ==> SIZE CRR143995_f1.fastq.gz ... 638437998
# File has already been retrieved.
# 2021-04-27 20:27:04 (0.00 B/s) - ‘CRR143995_f1.fastq.gz’ saved [638437998]
#
# --2021-04-27 20:27:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_r2.fastq.gz
#            => ‘CRR143995_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ...
# No such directory ‘gsa3/CRA002497/CRR143995’.
#
# --2021-04-27 20:27:15--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_f1.fastq.gz
#            => ‘CRR143996_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ...
# No such directory ‘gsa3/CRA002497/CRR143996’.
#
# --2021-04-27 20:27:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_r2.fastq.gz
#            => ‘CRR143996_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ...
# No such directory ‘gsa3/CRA002497/CRR143996’.
#
# --2021-04-27 20:27:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_f1.fastq.gz
#            => ‘CRR143997_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ...
# No such directory ‘gsa3/CRA002497/CRR143997’.
#
# --2021-04-27 20:27:50--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_r2.fastq.gz
#            => ‘CRR143997_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ... done.
# ==> SIZE CRR143997_r2.fastq.gz ... 918270544
# ==> PASV ... done.    ==> RETR CRR143997_r2.fastq.gz ... done.
# Length: 918270544 (876M) (unauthoritative)
#
# CRR143997_r2.fastq. 100%[===================>] 875.73M  13.8MB/s    in 70s
#
# 2021-04-27 20:29:02 (12.5 MB/s) - ‘CRR143997_r2.fastq.gz’ saved [918270544]
#
# --2021-04-27 20:29:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_f1.fastq.gz
#            => ‘CRR143998_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ... done.
# ==> SIZE CRR143998_f1.fastq.gz ... 1145762172
# File has already been retrieved.
# 2021-04-27 20:29:04 (0.00 B/s) - ‘CRR143998_f1.fastq.gz’ saved [1145762172]
#
# --2021-04-27 20:29:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_r2.fastq.gz
#            => ‘CRR143998_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ...
# No such directory ‘gsa3/CRA002497/CRR143998’.
#
# --2021-04-27 20:29:16--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_f1.fastq.gz
#            => ‘CRR143999_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ... done.
# ==> SIZE CRR143999_f1.fastq.gz ... 1416474924
# File has already been retrieved.
# 2021-04-27 20:29:18 (0.00 B/s) - ‘CRR143999_f1.fastq.gz’ saved [1416474924]
#
# --2021-04-27 20:29:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_r2.fastq.gz
#            => ‘CRR143999_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ...
# No such directory ‘gsa3/CRA002497/CRR143999’.
#
# --2021-04-27 20:29:30--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_f1.fastq.gz
#            => ‘CRR144000_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ...
# No such directory ‘gsa3/CRA002497/CRR144000’.
#
# --2021-04-27 20:29:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_r2.fastq.gz
#            => ‘CRR144000_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ... done.
# ==> SIZE CRR144000_r2.fastq.gz ... 801490844
# ==> PASV ... done.    ==> RETR CRR144000_r2.fastq.gz ... done.
# Length: 801490844 (764M) (unauthoritative)
#
# CRR144000_r2.fastq. 100%[===================>] 764.36M  13.9MB/s    in 61s
#
# 2021-04-27 20:30:45 (12.4 MB/s) - ‘CRR144000_r2.fastq.gz’ saved [801490844]
#
# --2021-04-27 20:30:46--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_f1.fastq.gz
#            => ‘CRR144001_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ...
# No such directory ‘gsa3/CRA002497/CRR144001’.
#
# --2021-04-27 20:30:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_r2.fastq.gz
#            => ‘CRR144001_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ...
# No such directory ‘gsa3/CRA002497/CRR144001’.
#
# --2021-04-27 20:31:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_f1.fastq.gz
#            => ‘CRR144002_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ... done.
# ==> SIZE CRR144002_f1.fastq.gz ... 2533293334
# File has already been retrieved.
# 2021-04-27 20:31:11 (0.00 B/s) - ‘CRR144002_f1.fastq.gz’ saved [2533293334]
#
# --2021-04-27 20:31:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_r2.fastq.gz
#            => ‘CRR144002_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ...
# No such directory ‘gsa3/CRA002497/CRR144002’.
#
# --2021-04-27 20:31:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_f1.fastq.gz
#            => ‘CRR144003_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ...
# No such directory ‘gsa3/CRA002497/CRR144003’.
#
# --2021-04-27 20:31:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_r2.fastq.gz
#            => ‘CRR144003_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ... done.
# ==> SIZE CRR144003_r2.fastq.gz ... 6793807142
# File has already been retrieved.
# 2021-04-27 20:31:36 (0.00 B/s) - ‘CRR144003_r2.fastq.gz’ saved [6793807142]
#
# --2021-04-27 20:31:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_f1.fastq.gz
#            => ‘CRR144004_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ... done.
# ==> SIZE CRR144004_f1.fastq.gz ... 2099748147
# ==> PASV ... done.    ==> RETR CRR144004_f1.fastq.gz ... done.
# Length: 2099748147 (2.0G) (unauthoritative)
#
# CRR144004_f1.fastq. 100%[===================>]   1.96G  13.4MB/s    in 2m 34s
#
# 2021-04-27 20:34:13 (13.0 MB/s) - ‘CRR144004_f1.fastq.gz’ saved [2099748147]
#
# --2021-04-27 20:34:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_r2.fastq.gz
#            => ‘CRR144004_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ...
# No such directory ‘gsa3/CRA002497/CRR144004’.
#
# --2021-04-27 20:34:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_f1.fastq.gz
#            => ‘CRR143993_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ...
# No such directory ‘gsa3/CRA002497/CRR143993’.
#
# --2021-04-27 20:34:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_r2.fastq.gz
#            => ‘CRR143993_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ... done.
# ==> SIZE CRR143993_r2.fastq.gz ... 776294758
# ==> PASV ... done.    ==> RETR CRR143993_r2.fastq.gz ... done.
# Length: 776294758 (740M) (unauthoritative)
#
# CRR143993_r2.fastq. 100%[===================>] 740.33M  13.9MB/s    in 58s
#
# 2021-04-27 20:35:37 (12.8 MB/s) - ‘CRR143993_r2.fastq.gz’ saved [776294758]
#
# --2021-04-27 20:35:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_f1.fastq.gz
#            => ‘CRR143994_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 20:35:49--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_r2.fastq.gz
#            => ‘CRR143994_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 20:36:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_f1.fastq.gz
#            => ‘CRR143995_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ...
# No such directory ‘gsa3/CRA002497/CRR143995’.
#
# --2021-04-27 20:36:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_r2.fastq.gz
#            => ‘CRR143995_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ... done.
# ==> SIZE CRR143995_r2.fastq.gz ... 683410724
# File has already been retrieved.
# 2021-04-27 20:36:15 (0.00 B/s) - ‘CRR143995_r2.fastq.gz’ saved [683410724]
#
# --2021-04-27 20:36:15--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_f1.fastq.gz
#            => ‘CRR143996_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ... done.
# ==> SIZE CRR143996_f1.fastq.gz ... 753551099
# ==> PASV ... done.    ==> RETR CRR143996_f1.fastq.gz ... done.
# Length: 753551099 (719M) (unauthoritative)
#
# CRR143996_f1.fastq. 100%[===================>] 718.64M  12.1MB/s    in 57s
#
# 2021-04-27 20:37:14 (12.7 MB/s) - ‘CRR143996_f1.fastq.gz’ saved [753551099]
#
# --2021-04-27 20:37:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_r2.fastq.gz
#            => ‘CRR143996_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ... done.
# ==> SIZE CRR143996_r2.fastq.gz ... 777409754
# File has already been retrieved.
# 2021-04-27 20:37:16 (0.00 B/s) - ‘CRR143996_r2.fastq.gz’ saved [777409754]
#
# --2021-04-27 20:37:16--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_f1.fastq.gz
#            => ‘CRR143997_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ... done.
# ==> SIZE CRR143997_f1.fastq.gz ... 920229271
# ==> PASV ... done.    ==> RETR CRR143997_f1.fastq.gz ... done.
# Length: 920229271 (878M) (unauthoritative)
#
# CRR143997_f1.fastq. 100%[===================>] 877.60M  12.9MB/s    in 77s
#
# 2021-04-27 20:38:35 (11.4 MB/s) - ‘CRR143997_f1.fastq.gz’ saved [920229271]
#
# --2021-04-27 20:38:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_r2.fastq.gz
#            => ‘CRR143997_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ...
# No such directory ‘gsa3/CRA002497/CRR143997’.
#
# --2021-04-27 20:38:47--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_f1.fastq.gz
#            => ‘CRR143998_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ... done.
# ==> SIZE CRR143998_f1.fastq.gz ... 1145762172
# File has already been retrieved.
# 2021-04-27 20:38:48 (0.00 B/s) - ‘CRR143998_f1.fastq.gz’ saved [1145762172]
#
# --2021-04-27 20:38:48--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_r2.fastq.gz
#            => ‘CRR143998_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ...
# No such directory ‘gsa3/CRA002497/CRR143998’.
#
# --2021-04-27 20:39:00--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_f1.fastq.gz
#            => ‘CRR143999_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ... done.
# ==> SIZE CRR143999_f1.fastq.gz ... 1416474924
# File has already been retrieved.
# 2021-04-27 20:39:02 (0.00 B/s) - ‘CRR143999_f1.fastq.gz’ saved [1416474924]
#
# --2021-04-27 20:39:02--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_r2.fastq.gz
#            => ‘CRR143999_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ...
# No such directory ‘gsa3/CRA002497/CRR143999’.
#
# --2021-04-27 20:39:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_f1.fastq.gz
#            => ‘CRR144000_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ...
# No such directory ‘gsa3/CRA002497/CRR144000’.
#
# --2021-04-27 20:39:26--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_r2.fastq.gz
#            => ‘CRR144000_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ... done.
# ==> SIZE CRR144000_r2.fastq.gz ... 801490844
# File has already been retrieved.
# 2021-04-27 20:39:29 (0.00 B/s) - ‘CRR144000_r2.fastq.gz’ saved [801490844]
#
# --2021-04-27 20:39:29--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_f1.fastq.gz
#            => ‘CRR144001_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ...
# No such directory ‘gsa3/CRA002497/CRR144001’.
#
# --2021-04-27 20:39:41--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_r2.fastq.gz
#            => ‘CRR144001_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ...
# No such directory ‘gsa3/CRA002497/CRR144001’.
#
# --2021-04-27 20:39:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_f1.fastq.gz
#            => ‘CRR144002_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ...
# No such directory ‘gsa3/CRA002497/CRR144002’.
#
# --2021-04-27 20:40:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_r2.fastq.gz
#            => ‘CRR144002_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ...
# No such directory ‘gsa3/CRA002497/CRR144002’.
#
# --2021-04-27 20:40:17--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_f1.fastq.gz
#            => ‘CRR144003_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ... done.
# ==> SIZE CRR144003_f1.fastq.gz ... 1803026446
# ==> PASV ... done.    ==> RETR CRR144003_f1.fastq.gz ... done.
# Length: 1803026446 (1.7G) (unauthoritative)
#
# CRR144003_f1.fastq. 100%[===================>]   1.68G  12.5MB/s    in 2m 18s
#
# 2021-04-27 20:42:37 (12.5 MB/s) - ‘CRR144003_f1.fastq.gz’ saved [1803026446]
#
# --2021-04-27 20:42:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_r2.fastq.gz
#            => ‘CRR144003_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ... done.
# ==> SIZE CRR144003_r2.fastq.gz ... 6793807142
# File has already been retrieved.
# 2021-04-27 20:42:39 (0.00 B/s) - ‘CRR144003_r2.fastq.gz’ saved [6793807142]
#
# --2021-04-27 20:42:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_f1.fastq.gz
#            => ‘CRR144004_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ... done.
# ==> SIZE CRR144004_f1.fastq.gz ... 2099748147
# File has already been retrieved.
# 2021-04-27 20:42:41 (0.00 B/s) - ‘CRR144004_f1.fastq.gz’ saved [2099748147]
#
# --2021-04-27 20:42:41--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_r2.fastq.gz
#            => ‘CRR144004_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ...
# No such directory ‘gsa3/CRA002497/CRR144004’.
#
# --2021-04-27 20:42:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_f1.fastq.gz
#            => ‘CRR143993_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ... done.
# ==> SIZE CRR143993_f1.fastq.gz ... 756607588
# File has already been retrieved.
# 2021-04-27 20:42:54 (0.00 B/s) - ‘CRR143993_f1.fastq.gz’ saved [756607588]
#
# --2021-04-27 20:42:54--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_r2.fastq.gz
#            => ‘CRR143993_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ... done.
# ==> SIZE CRR143993_r2.fastq.gz ... 776294758
# File has already been retrieved.
# 2021-04-27 20:42:56 (0.00 B/s) - ‘CRR143993_r2.fastq.gz’ saved [776294758]
#
# --2021-04-27 20:42:56--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_f1.fastq.gz
#            => ‘CRR143994_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 20:43:08--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_r2.fastq.gz
#            => ‘CRR143994_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 20:43:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_f1.fastq.gz
#            => ‘CRR143995_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ...
# No such directory ‘gsa3/CRA002497/CRR143995’.
#
# --2021-04-27 20:43:31--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_r2.fastq.gz
#            => ‘CRR143995_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ...
# No such directory ‘gsa3/CRA002497/CRR143995’.
#
# --2021-04-27 20:43:43--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_f1.fastq.gz
#            => ‘CRR143996_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ... done.
# ==> SIZE CRR143996_f1.fastq.gz ... 753551099
# File has already been retrieved.
# 2021-04-27 20:43:44 (0.00 B/s) - ‘CRR143996_f1.fastq.gz’ saved [753551099]
#
# --2021-04-27 20:43:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_r2.fastq.gz
#            => ‘CRR143996_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ...
# No such directory ‘gsa3/CRA002497/CRR143996’.
#
# --2021-04-27 20:43:56--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_f1.fastq.gz
#            => ‘CRR143997_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ... done.
# ==> SIZE CRR143997_f1.fastq.gz ... 920229271
# File has already been retrieved.
# 2021-04-27 20:43:58 (0.00 B/s) - ‘CRR143997_f1.fastq.gz’ saved [920229271]
#
# --2021-04-27 20:43:58--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_r2.fastq.gz
#            => ‘CRR143997_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ...
# No such directory ‘gsa3/CRA002497/CRR143997’.
#
# --2021-04-27 20:44:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_f1.fastq.gz
#            => ‘CRR143998_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ...
# No such directory ‘gsa3/CRA002497/CRR143998’.
#
# --2021-04-27 20:44:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_r2.fastq.gz
#            => ‘CRR143998_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ...
# No such directory ‘gsa3/CRA002497/CRR143998’.
#
# --2021-04-27 20:44:32--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_f1.fastq.gz
#            => ‘CRR143999_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ... done.
# ==> SIZE CRR143999_f1.fastq.gz ... 1416474924
# File has already been retrieved.
# 2021-04-27 20:44:34 (0.00 B/s) - ‘CRR143999_f1.fastq.gz’ saved [1416474924]
#
# --2021-04-27 20:44:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_r2.fastq.gz
#            => ‘CRR143999_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ...
#
# --2021-04-27 21:52:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_r2.fastq.gz
#            => ‘CRR144003_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ...
# No such directory ‘gsa3/CRA002497/CRR144003’.
#
# --2021-04-27 21:52:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_f1.fastq.gz
#            => ‘CRR144004_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ... done.
# ==> SIZE CRR144004_f1.fastq.gz ... 2099748147
# File has already been retrieved.
# 2021-04-27 21:52:55 (0.00 B/s) - ‘CRR144004_f1.fastq.gz’ saved [2099748147]
#
# --2021-04-27 21:52:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_r2.fastq.gz
#            => ‘CRR144004_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ... done.
# ==> SIZE CRR144004_r2.fastq.gz ... 7721709854
# ==> PASV ... done.    ==> RETR CRR144004_r2.fastq.gz ... done.
# Length: 7721709854 (7.2G) (unauthoritative)
#
# CRR144004_r2.fastq. 100%[===================>]   7.19G  12.2MB/s    in 10m 41s
#
# 2021-04-27 22:03:39 (11.5 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-27 22:18:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_r2.fastq.gz
#   (try: 2) => ‘CRR144004_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ... done.
# ==> SIZE CRR144004_r2.fastq.gz ... 7721709854
# File has already been retrieved.
# 2021-04-27 22:18:42 (0.00 B/s) - ‘CRR144004_r2.fastq.gz’ saved [7721709854]
#
# --2021-04-27 22:18:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_f1.fastq.gz
#            => ‘CRR143993_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ... done.
# ==> SIZE CRR143993_f1.fastq.gz ... 756607588
# File has already been retrieved.
# 2021-04-27 22:18:44 (0.00 B/s) - ‘CRR143993_f1.fastq.gz’ saved [756607588]
#
# --2021-04-27 22:18:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143993/CRR143993_r2.fastq.gz
#            => ‘CRR143993_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143993 ... done.
# ==> SIZE CRR143993_r2.fastq.gz ... 776294758
# File has already been retrieved.
# 2021-04-27 22:18:46 (0.00 B/s) - ‘CRR143993_r2.fastq.gz’ saved [776294758]
#
# --2021-04-27 22:18:46--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_f1.fastq.gz
#            => ‘CRR143994_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 22:18:58--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143994/CRR143994_r2.fastq.gz
#            => ‘CRR143994_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143994 ...
# No such directory ‘gsa3/CRA002497/CRR143994’.
#
# --2021-04-27 22:19:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_f1.fastq.gz
#            => ‘CRR143995_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ...
# No such directory ‘gsa3/CRA002497/CRR143995’.
#
# --2021-04-27 22:19:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143995/CRR143995_r2.fastq.gz
#            => ‘CRR143995_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143995 ... done.
# ==> SIZE CRR143995_r2.fastq.gz ... 683410724
# File has already been retrieved.
# 2021-04-27 22:19:25 (0.00 B/s) - ‘CRR143995_r2.fastq.gz’ saved [683410724]
#
# --2021-04-27 22:19:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_f1.fastq.gz
#            => ‘CRR143996_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ... done.
# ==> SIZE CRR143996_f1.fastq.gz ... 753551099
# File has already been retrieved.
# 2021-04-27 22:19:28 (0.00 B/s) - ‘CRR143996_f1.fastq.gz’ saved [753551099]
#
# --2021-04-27 22:19:28--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143996/CRR143996_r2.fastq.gz
#            => ‘CRR143996_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143996 ...
# No such directory ‘gsa3/CRA002497/CRR143996’.
#
# --2021-04-27 22:19:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_f1.fastq.gz
#            => ‘CRR143997_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ... done.
# ==> SIZE CRR143997_f1.fastq.gz ... 920229271
# File has already been retrieved.
# 2021-04-27 22:19:42 (0.00 B/s) - ‘CRR143997_f1.fastq.gz’ saved [920229271]
#
# --2021-04-27 22:19:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143997/CRR143997_r2.fastq.gz
#            => ‘CRR143997_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143997 ... done.
# ==> SIZE CRR143997_r2.fastq.gz ... 918270544
# File has already been retrieved.
# 2021-04-27 22:19:43 (0.00 B/s) - ‘CRR143997_r2.fastq.gz’ saved [918270544]
#
# --2021-04-27 22:19:43--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_f1.fastq.gz
#            => ‘CRR143998_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ... done.
# ==> SIZE CRR143998_f1.fastq.gz ... 1145762172
# File has already been retrieved.
# 2021-04-27 22:19:45 (0.00 B/s) - ‘CRR143998_f1.fastq.gz’ saved [1145762172]
#
# --2021-04-27 22:19:45--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143998/CRR143998_r2.fastq.gz
#            => ‘CRR143998_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143998 ...
# No such directory ‘gsa3/CRA002497/CRR143998’.
#
# --2021-04-27 22:19:57--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_f1.fastq.gz
#            => ‘CRR143999_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ... done.
# ==> SIZE CRR143999_f1.fastq.gz ... 1416474924
# File has already been retrieved.
# 2021-04-27 22:19:58 (0.00 B/s) - ‘CRR143999_f1.fastq.gz’ saved [1416474924]
#
# --2021-04-27 22:19:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR143999/CRR143999_r2.fastq.gz
#            => ‘CRR143999_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR143999 ... done.
# ==> SIZE CRR143999_r2.fastq.gz ... 1402569628
# ==> PASV ... done.    ==> RETR CRR143999_r2.fastq.gz ... done.
# Length: 1402569628 (1.3G) (unauthoritative)
#
# CRR143999_r2.fastq. 100%[===================>]   1.31G  13.0MB/s    in 1m 49s
#
# 2021-04-27 22:21:50 (12.3 MB/s) - ‘CRR143999_r2.fastq.gz’ saved [1402569628]
#
# --2021-04-27 22:21:50--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_f1.fastq.gz
#            => ‘CRR144000_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ... done.
# ==> SIZE CRR144000_f1.fastq.gz ... 809157755
# File has already been retrieved.
# 2021-04-27 22:21:52 (0.00 B/s) - ‘CRR144000_f1.fastq.gz’ saved [809157755]
#
# --2021-04-27 22:21:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144000/CRR144000_r2.fastq.gz
#            => ‘CRR144000_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144000 ...
# No such directory ‘gsa3/CRA002497/CRR144000’.
#
# --2021-04-27 22:22:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_f1.fastq.gz
#            => ‘CRR144001_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ... done.
# ==> SIZE CRR144001_f1.fastq.gz ... 2785716389
# File has already been retrieved.
# 2021-04-27 22:22:05 (0.00 B/s) - ‘CRR144001_f1.fastq.gz’ saved [2785716389]
#
# --2021-04-27 22:22:05--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144001/CRR144001_r2.fastq.gz
#            => ‘CRR144001_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144001 ...
# No such directory ‘gsa3/CRA002497/CRR144001’.
#
# --2021-04-27 22:22:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_f1.fastq.gz
#            => ‘CRR144002_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ... done.
# ==> SIZE CRR144002_f1.fastq.gz ... 2533293334
# File has already been retrieved.
# 2021-04-27 22:22:19 (0.00 B/s) - ‘CRR144002_f1.fastq.gz’ saved [2533293334]
#
# --2021-04-27 22:22:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144002/CRR144002_r2.fastq.gz
#            => ‘CRR144002_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144002 ... done.
# ==> SIZE CRR144002_r2.fastq.gz ... 9616693844
# File has already been retrieved.
# 2021-04-27 22:22:22 (0.00 B/s) - ‘CRR144002_r2.fastq.gz’ saved [9616693844]
#
# --2021-04-27 22:22:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_f1.fastq.gz
#            => ‘CRR144003_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ... done.
# ==> SIZE CRR144003_f1.fastq.gz ... 1803026446
# File has already been retrieved.
# 2021-04-27 22:22:24 (0.00 B/s) - ‘CRR144003_f1.fastq.gz’ saved [1803026446]
#
# --2021-04-27 22:22:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144003/CRR144003_r2.fastq.gz
#            => ‘CRR144003_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144003 ... done.
# ==> SIZE CRR144003_r2.fastq.gz ... 6793807142
# File has already been retrieved.
# 2021-04-27 22:22:26 (0.00 B/s) - ‘CRR144003_r2.fastq.gz’ saved [6793807142]
#
# --2021-04-27 22:22:26--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_f1.fastq.gz
#            => ‘CRR144004_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ... done.
# ==> SIZE CRR144004_f1.fastq.gz ... 2099748147
# File has already been retrieved.
# 2021-04-27 22:22:28 (0.00 B/s) - ‘CRR144004_f1.fastq.gz’ saved [2099748147]
#
# --2021-04-27 22:22:28--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144004/CRR144004_r2.fastq.gz
#            => ‘CRR144004_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144004 ... done.
# ==> SIZE CRR144004_r2.fastq.gz ... 7721709854
# File has already been retrieved.
# 2021-04-27 22:22:29 (0.00 B/s) - ‘CRR144004_r2.fastq.gz’ saved [7721709854]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2021-04-27 22:22:32,771]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:43<00:00, 23.1MB/s]
# [2021-04-27 22:24:17,439]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['CRR143993_f1.fastq.gz', 'CRR143993_r2.fastq.gz', 'CRR143994_f1.fastq.gz', 'CRR143994_r2.fastq.gz', 'CRR143995_f1.fastq.gz', 'CRR143995_r2.fastq.gz', 'CRR143996_f1.fastq.gz', 'CRR143996_r2.fastq.gz', 'CRR143997_f1.fastq.gz', 'CRR143997_r2.fastq.gz', 'CRR143998_f1.fastq.gz', 'CRR143998_r2.fastq.gz', 'CRR143999_f1.fastq.gz', 'CRR143999_r2.fastq.gz', 'CRR144000_f1.fastq.gz', 'CRR144000_r2.fastq.gz', 'CRR144001_f1.fastq.gz', 'CRR144001_r2.fastq.gz', 'CRR144002_f1.fastq.gz', 'CRR144002_r2.fastq.gz', 'CRR144003_f1.fastq.gz', 'CRR144003_r2.fastq.gz', 'CRR144004_f1.fastq.gz', 'CRR144004_r2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['CRR143993_f1.fastq.gz',
#  'CRR143993_r2.fastq.gz',
#  'CRR143994_f1.fastq.gz',
#  'CRR143994_r2.fastq.gz',
#  'CRR143995_f1.fastq.gz',
#  'CRR143995_r2.fastq.gz',
#  'CRR143996_f1.fastq.gz',
#  'CRR143996_r2.fastq.gz',
#  'CRR143997_f1.fastq.gz',
#  'CRR143997_r2.fastq.gz',
#  'CRR143998_f1.fastq.gz',
#  'CRR143998_r2.fastq.gz',
#  'CRR143999_f1.fastq.gz',
#  'CRR143999_r2.fastq.gz',
#  'CRR144000_f1.fastq.gz',
#  'CRR144000_r2.fastq.gz',
#  'CRR144001_f1.fastq.gz',
#  'CRR144001_r2.fastq.gz',
#  'CRR144002_f1.fastq.gz',
#  'CRR144002_r2.fastq.gz',
#  'CRR144003_f1.fastq.gz',
#  'CRR144003_r2.fastq.gz',
#  'CRR144004_f1.fastq.gz',
#  'CRR144004_r2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2021-04-28 01:13:55,255]    INFO Using index index.idx to generate BUS file to outputCRX118015 from
# [2021-04-28 01:13:55,255]    INFO         CRR143993_f1.fastq.gz
# [2021-04-28 01:13:55,255]    INFO         CRR143993_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143994_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143994_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143995_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143995_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143996_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143996_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143997_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143997_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143998_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143998_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143999_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR143999_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144000_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144000_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144001_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144001_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144002_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144002_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144003_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144003_r2.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144004_f1.fastq.gz
# [2021-04-28 01:13:55,256]    INFO         CRR144004_r2.fastq.gz
# [2021-04-28 03:03:31,033]    INFO Sorting BUS file outputCRX118015/output.bus to outputCRX118015/tmp/output.s.bus
# [2021-04-28 03:08:29,946]    INFO Whitelist not provided
# [2021-04-28 03:08:29,946]    INFO Copying pre-packaged 10XV2 whitelist to outputCRX118015
# [2021-04-28 03:08:30,082]    INFO Inspecting BUS file outputCRX118015/tmp/output.s.bus
# [2021-04-28 03:09:05,504]    INFO Correcting BUS records in outputCRX118015/tmp/output.s.bus to outputCRX118015/tmp/output.s.c.bus with whitelist outputCRX118015/10xv2_whitelist.txt
# [2021-04-28 03:09:43,277]    INFO Sorting BUS file outputCRX118015/tmp/output.s.c.bus to outputCRX118015/output.unfiltered.bus
# [2021-04-28 03:11:34,484]    INFO Generating count matrix outputCRX118015/counts_unfiltered/cells_x_genes from BUS file outputCRX118015/output.unfiltered.bus
# [2021-04-28 03:12:26,029]    INFO Reading matrix outputCRX118015/counts_unfiltered/cells_x_genes.mtx
# [2021-04-28 03:12:53,840]    INFO Writing matrix to h5ad outputCRX118015/counts_unfiltered/adata.h5ad
# [2021-04-28 03:12:55,098]    INFO Filtering with bustools
# [2021-04-28 03:12:55,098]    INFO Generating whitelist outputCRX118015/filter_barcodes.txt from BUS file outputCRX118015/output.unfiltered.bus
# [2021-04-28 03:12:56,062]    INFO Correcting BUS records in outputCRX118015/output.unfiltered.bus to outputCRX118015/tmp/output.unfiltered.c.bus with whitelist outputCRX118015/filter_barcodes.txt
# [2021-04-28 03:13:23,656]    INFO Sorting BUS file outputCRX118015/tmp/output.unfiltered.c.bus to outputCRX118015/output.filtered.bus
# [2021-04-28 03:14:58,799]    INFO Generating count matrix outputCRX118015/counts_filtered/cells_x_genes from BUS file outputCRX118015/output.filtered.bus
# [2021-04-28 03:15:43,166]    INFO Reading matrix outputCRX118015/counts_filtered/cells_x_genes.mtx
# [2021-04-28 03:16:04,504]    INFO Writing matrix to h5ad outputCRX118015/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix CRX118015 contains 418875 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 7500#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 23#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 7500 with at least 1391.0 UMIs
# We select 23 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 418,875 cells x 60,623 genes
#     New shape: 7,452 cells x 25,473 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[i]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[i]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[i]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[i]

  results["data_" + sample_id[i]].uns["condition"] = condition[i]

  results["data_" + sample_id[i]].uns["species"] = species[i]

  results["data_" + sample_id[i]].uns["technology"] = technology[i]

  results["data_" + sample_id[i]].uns["paper"] = paper[i]

  results["data_" + sample_id[i]].uns["figure"] = figure[i]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
