# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE134174_GSM4213829.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE134174_GSM4213829

# %%
# !wget -O adata_tcc.h5ad.gz https://caltech.box.com/shared/static/xvg5bpxli4mj16buz6z925no52lz69zd.gz
# !wget -O adata.h5ad.gz https://caltech.box.com/shared/static/0gbowwdpwzsz4djxthsgut2x4p7h2jcx.gz
# Out:
# --2021-05-06 16:51:07--  https://caltech.box.com/shared/static/xvg5bpxli4mj16buz6z925no52lz69zd.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.26.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/xvg5bpxli4mj16buz6z925no52lz69zd.gz [following]
# --2021-05-06 16:51:07--  https://caltech.box.com/public/static/xvg5bpxli4mj16buz6z925no52lz69zd.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/xvg5bpxli4mj16buz6z925no52lz69zd.gz [following]
# --2021-05-06 16:51:07--  https://caltech.app.box.com/public/static/xvg5bpxli4mj16buz6z925no52lz69zd.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.26.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.26.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!xET1-1JEydBetLH6SivG41yP0-eF-hyJH6DZIf6laTVBPup5k0nhYrOf_rpEunHpBlJJZ0qFTAvfXVv6EjMhoseUTAXyvb-rhpnT0ekU9ObgBm79mZx6qmJa6JK2HtUwl9hmvk7xJw7Ivtlezm10_ifxN2gXNjxYapbc2KMA_BJJ5DJfbbUD_LIceqwZjloVYfsVASf9iIW7MZb_J89GcW7NyoUbaI_hiwdznS5U-87g1Ek3Uh46MXWEIuPNY6B4A7OSXGwyZigCS6SznEmh5SIrG39Y2KSioNCFRllFEpBqBGmeJnLRKyt8m9FIxrKQirhv9re8nMAi-09kP20Vm1qw__SdbyHgRa2LbZvzpI1F142uhgpAr83ApcMa8vKiKQmuxgvv6rresgmtMEGwD-Usg8ppUgga7DQ88mkKiPqaPXkZzSTb_yaMphbEBJ8mcKt-uyppIe1LVkW_aunvgSBNhKD22oUojv79CEmNnGHbSHYCsdtL3tfewJ_DJhEs3NyG7Gqs07GvQ9aa7DUh6F7TZ0WHeq-TiQK57qvzI_YqiM4-tPFJfK8kgmN04EKdpqFj3AtTjJNTqS2oRx7WapqpERmXwlzko_ry0ywZ10up_q4EoWx5JqEATkV-xSaWtbmPGu_E1d7Ncbymji7P2QGo0um10S9GnpuiQv1PSfY5dWb-MIgXuPUM6r5x8dQj3FCCbnYx1PxiQ4NAjST6A2Mq-9NSDNI_OeMx9VlrMA-O2Bwylrf7K84-m9t6ZUYAbdWws1I8JFTYIKYvq52CFTgpvkJY3b93Ey_hLkWQ--Cyg740wuheGYGNOYqDpQCU9X2Jh-80nXFJl6N8DymdAfPCoYlNJHHk44wVZilS3MUTmJdU87RRXHkF2NEVs5EDglyJUpvCCn_YDPD_1qqaUHxTjEieiCBLVUDsK2_-GpFSQVAwWm-Ft_ZI94MW9-ZvrD-mpjHzgjMa5kgT3igK2dOP-mITqZLr7cfzedulAwiXuMjai-_YkxzSbRFtFI65BlhFOTqs19xeszX3GR_0HhupfLTyzS9ktmtob8Igfe94CgtFaLf_vhRkYh3zgeX_fD3yxpCgEiSmxmHVyFeJIO_FC8GRXJxLS6vw4i77OwqtmpVqE0FDNlQi9TJiJ2MdE7wgA__BZJ9RLhqgHk4oXlEzNEXahkTcBLsrw4w5T830Xu_hZSPrFhhPGW-csmDJoPpaP6AAxhSBDIDixNAjtbaBMO60rxosz76Relm20ewQwctmOgwc0IzQ_p77w6ll3q1n3ws7OMIoIDteJIhF0e6Cup7wujXPHd2Gm1rkHP2_mW7lCVMy9va_8vdR1bjLqDzVVLBTvd3aqb6Z8Z1nrGfGgyxHi_Q1_IUJx7GsKtylk0W2FsFoFnOjcke0zx9hQKHnx5m-dA../download [following]
# --2021-05-06 16:51:08--  https://public.boxcloud.com/d/1/b1!xET1-1JEydBetLH6SivG41yP0-eF-hyJH6DZIf6laTVBPup5k0nhYrOf_rpEunHpBlJJZ0qFTAvfXVv6EjMhoseUTAXyvb-rhpnT0ekU9ObgBm79mZx6qmJa6JK2HtUwl9hmvk7xJw7Ivtlezm10_ifxN2gXNjxYapbc2KMA_BJJ5DJfbbUD_LIceqwZjloVYfsVASf9iIW7MZb_J89GcW7NyoUbaI_hiwdznS5U-87g1Ek3Uh46MXWEIuPNY6B4A7OSXGwyZigCS6SznEmh5SIrG39Y2KSioNCFRllFEpBqBGmeJnLRKyt8m9FIxrKQirhv9re8nMAi-09kP20Vm1qw__SdbyHgRa2LbZvzpI1F142uhgpAr83ApcMa8vKiKQmuxgvv6rresgmtMEGwD-Usg8ppUgga7DQ88mkKiPqaPXkZzSTb_yaMphbEBJ8mcKt-uyppIe1LVkW_aunvgSBNhKD22oUojv79CEmNnGHbSHYCsdtL3tfewJ_DJhEs3NyG7Gqs07GvQ9aa7DUh6F7TZ0WHeq-TiQK57qvzI_YqiM4-tPFJfK8kgmN04EKdpqFj3AtTjJNTqS2oRx7WapqpERmXwlzko_ry0ywZ10up_q4EoWx5JqEATkV-xSaWtbmPGu_E1d7Ncbymji7P2QGo0um10S9GnpuiQv1PSfY5dWb-MIgXuPUM6r5x8dQj3FCCbnYx1PxiQ4NAjST6A2Mq-9NSDNI_OeMx9VlrMA-O2Bwylrf7K84-m9t6ZUYAbdWws1I8JFTYIKYvq52CFTgpvkJY3b93Ey_hLkWQ--Cyg740wuheGYGNOYqDpQCU9X2Jh-80nXFJl6N8DymdAfPCoYlNJHHk44wVZilS3MUTmJdU87RRXHkF2NEVs5EDglyJUpvCCn_YDPD_1qqaUHxTjEieiCBLVUDsK2_-GpFSQVAwWm-Ft_ZI94MW9-ZvrD-mpjHzgjMa5kgT3igK2dOP-mITqZLr7cfzedulAwiXuMjai-_YkxzSbRFtFI65BlhFOTqs19xeszX3GR_0HhupfLTyzS9ktmtob8Igfe94CgtFaLf_vhRkYh3zgeX_fD3yxpCgEiSmxmHVyFeJIO_FC8GRXJxLS6vw4i77OwqtmpVqE0FDNlQi9TJiJ2MdE7wgA__BZJ9RLhqgHk4oXlEzNEXahkTcBLsrw4w5T830Xu_hZSPrFhhPGW-csmDJoPpaP6AAxhSBDIDixNAjtbaBMO60rxosz76Relm20ewQwctmOgwc0IzQ_p77w6ll3q1n3ws7OMIoIDteJIhF0e6Cup7wujXPHd2Gm1rkHP2_mW7lCVMy9va_8vdR1bjLqDzVVLBTvd3aqb6Z8Z1nrGfGgyxHi_Q1_IUJx7GsKtylk0W2FsFoFnOjcke0zx9hQKHnx5m-dA../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 222390082 (212M) [application/octet-stream]
# Saving to: ‘adata_tcc.h5ad.gz’
#
# adata_tcc.h5ad.gz   100%[===================>] 212.09M  19.5MB/s    in 12s
#
# 2021-05-06 16:51:20 (18.2 MB/s) - ‘adata_tcc.h5ad.gz’ saved [222390082/222390082]
#
# --2021-05-06 16:51:21--  https://caltech.box.com/shared/static/0gbowwdpwzsz4djxthsgut2x4p7h2jcx.gz
# Resolving caltech.box.com (caltech.box.com)... 107.152.26.197
# Connecting to caltech.box.com (caltech.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/0gbowwdpwzsz4djxthsgut2x4p7h2jcx.gz [following]
# --2021-05-06 16:51:21--  https://caltech.box.com/public/static/0gbowwdpwzsz4djxthsgut2x4p7h2jcx.gz
# Reusing existing connection to caltech.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://caltech.app.box.com/public/static/0gbowwdpwzsz4djxthsgut2x4p7h2jcx.gz [following]
# --2021-05-06 16:51:21--  https://caltech.app.box.com/public/static/0gbowwdpwzsz4djxthsgut2x4p7h2jcx.gz
# Resolving caltech.app.box.com (caltech.app.box.com)... 107.152.26.201
# Connecting to caltech.app.box.com (caltech.app.box.com)|107.152.26.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!5G5A-LDBH5sHzhzDqL3CuJyoNUIoh8YiqOHSINJJ5hKcNEAxbaZAukeuYhy9bjMsnB5Dq5YmaE74uJl2k2UuYas4hfreCZUQYymJzAHxCDdM5Yk8j--OGyCOmnUCVGQwjAmF6GLl1h4wKFjZow13_BNC_-kubskPpWR_hbqQGWOlS3dTcUZ3nw41ADezVShKQADFoDsFJfglmfQVxXAStYl6QCVDlN7TjOBI5vBq5C4e53a9KdX0f5N3s1iFuMxo3bCwvAMO0-bIiLtLCCAf9SliC-hzhDUlA7RB7h0dlGTOYubn6dkYW5VGSIkO9C9nQJK7MTiyHkx_PdY2UWHU43_Zln-kSLH77L315B6UOE1mPmYrpETbmcMgf4DNCPcpDBK9AlDhKcUfzbSCxtLo3btrWavSzVq3pzckXGmiRo45XXOexxbXJsqLNWpM6BXFE78cP0FwmmBHjMaj1Rp9IyZUkPzDRPyj-yO2kIN0Sq-NPxXCK3YPITE-1clFCtEmH_VaWLpUe9UdA4cXn-Hn2JSCJIVLC3zkjgrxbSP7PuomY8O6pt-72rPjaYlUYYOOb4dr7d0tF43hCE9P6ucFyMc-JlwWBpIE8y6T47Fe2bhZjriqebt51SS91VU61l9CMMakvVg9egQW3Y3FN3Any2yi1r5VVmAk2NDsOxXWzdb5DXuSjG_l0mQHc_RK9l_0QE653JTJnaHCLUuae7foKQpd7zQ-V93EoQXxCKKr2hKDLkBnya7Z9qseSYP-RUkmQeK9lSG5VWpo4hV2UpGT5lWr1_N47UmP7OYOpKx8-0YKRfHWP84CmHRwKsnptsXeNoXst5PJ1KJTJBY0n6Hso_6miT5LoI6T-IWvH1nvTOn8_o-9F6scfQzCdvAoBP96O_GAIyuIdPN_orPU1Wzd7-Hjri4bq-cDKSBmjkV2Ic_GWD9SqE-6ZuHcQe057A2Z32I1jVYQ3j1NbZ3JlSIrWxKmX5e4gLvyvzJ96WZEWrxbnaqgAvNyKHxna6zO1zuyCEmyVTjfzMRkSYfg3U3X_AJeP0vRjnuysEEVhAN7XAghV5lBWqUVi7wEIVCMidyp06Fx0Ti5F7qcKKAZHvJFRSTVbIvYv_58yo1hQq26I5PTk2a69y_7VjrFpPICgak-A2eBEzSX5NujFvDgITxVtDw-I4YzSJd2lPDgjWFMz8YjVPGIBfO8_qZYuuM3FAEeL3y1hvGSpM9wqlvcv3n9J5m7VFT-XqEGT2FaK2sDwFpbFWbKvFnT3Er3BhzdyGpprRNByUsdVTxnAr7iN6UyNPxoBMhZ3LSe0czMtpOk2TV6iknwEF_hyvj_7UGr63vuee3J1Wuyr0NFClFK1iZiGUIyGRqARRGdP7m_mm3h98MU5MCjOUxC9m8MC7sW2-7S45dsTpIeyaMwiy8KA-W2AuQYHOfZh3_NvefX8A../download [following]
# --2021-05-06 16:51:22--  https://public.boxcloud.com/d/1/b1!5G5A-LDBH5sHzhzDqL3CuJyoNUIoh8YiqOHSINJJ5hKcNEAxbaZAukeuYhy9bjMsnB5Dq5YmaE74uJl2k2UuYas4hfreCZUQYymJzAHxCDdM5Yk8j--OGyCOmnUCVGQwjAmF6GLl1h4wKFjZow13_BNC_-kubskPpWR_hbqQGWOlS3dTcUZ3nw41ADezVShKQADFoDsFJfglmfQVxXAStYl6QCVDlN7TjOBI5vBq5C4e53a9KdX0f5N3s1iFuMxo3bCwvAMO0-bIiLtLCCAf9SliC-hzhDUlA7RB7h0dlGTOYubn6dkYW5VGSIkO9C9nQJK7MTiyHkx_PdY2UWHU43_Zln-kSLH77L315B6UOE1mPmYrpETbmcMgf4DNCPcpDBK9AlDhKcUfzbSCxtLo3btrWavSzVq3pzckXGmiRo45XXOexxbXJsqLNWpM6BXFE78cP0FwmmBHjMaj1Rp9IyZUkPzDRPyj-yO2kIN0Sq-NPxXCK3YPITE-1clFCtEmH_VaWLpUe9UdA4cXn-Hn2JSCJIVLC3zkjgrxbSP7PuomY8O6pt-72rPjaYlUYYOOb4dr7d0tF43hCE9P6ucFyMc-JlwWBpIE8y6T47Fe2bhZjriqebt51SS91VU61l9CMMakvVg9egQW3Y3FN3Any2yi1r5VVmAk2NDsOxXWzdb5DXuSjG_l0mQHc_RK9l_0QE653JTJnaHCLUuae7foKQpd7zQ-V93EoQXxCKKr2hKDLkBnya7Z9qseSYP-RUkmQeK9lSG5VWpo4hV2UpGT5lWr1_N47UmP7OYOpKx8-0YKRfHWP84CmHRwKsnptsXeNoXst5PJ1KJTJBY0n6Hso_6miT5LoI6T-IWvH1nvTOn8_o-9F6scfQzCdvAoBP96O_GAIyuIdPN_orPU1Wzd7-Hjri4bq-cDKSBmjkV2Ic_GWD9SqE-6ZuHcQe057A2Z32I1jVYQ3j1NbZ3JlSIrWxKmX5e4gLvyvzJ96WZEWrxbnaqgAvNyKHxna6zO1zuyCEmyVTjfzMRkSYfg3U3X_AJeP0vRjnuysEEVhAN7XAghV5lBWqUVi7wEIVCMidyp06Fx0Ti5F7qcKKAZHvJFRSTVbIvYv_58yo1hQq26I5PTk2a69y_7VjrFpPICgak-A2eBEzSX5NujFvDgITxVtDw-I4YzSJd2lPDgjWFMz8YjVPGIBfO8_qZYuuM3FAEeL3y1hvGSpM9wqlvcv3n9J5m7VFT-XqEGT2FaK2sDwFpbFWbKvFnT3Er3BhzdyGpprRNByUsdVTxnAr7iN6UyNPxoBMhZ3LSe0czMtpOk2TV6iknwEF_hyvj_7UGr63vuee3J1Wuyr0NFClFK1iZiGUIyGRqARRGdP7m_mm3h98MU5MCjOUxC9m8MC7sW2-7S45dsTpIeyaMwiy8KA-W2AuQYHOfZh3_NvefX8A../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34209482 (33M) [application/octet-stream]
# Saving to: ‘adata.h5ad.gz’
#
# adata.h5ad.gz       100%[===================>]  32.62M  22.0MB/s    in 1.5s
#
# 2021-05-06 16:51:24 (22.0 MB/s) - ‘adata.h5ad.gz’ saved [34209482/34209482]

# %% [markdown]
# This dataset was too large to be processed in google colab. The gene count and TCC were generated using the following commands:
#
# ```
# SRA=SRR10668803
# GSM=GSM4213829
#
# cd /central/scratch/agalvezm/ace2/counts
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/prefetch 2.10.9 ${SRA} --max-size 2000000000
#
# cd ${SRA}
#
# /central/home/agalvezm/opt/sratoolkit.2.10.9-centos_linux64/bin/fasterq-dump --split-files --outdir fastq --include-technical ${SRA}.sra
#
# ~/anaconda3/bin/kb ref -d human -i index.idx -g t2g.txt -f1 transcriptome.fasta
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/output${GSM} --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ~/anaconda3/bin/kb count --h5ad -i index.idx -g t2g.txt -x 10xv2 -o ../results/tccoutput${GSM} --tcc --filter bustools -t 2 ${SRA}_1.fastq.gz ${SRA}_2.fastq.gz
#
# ```

# %%
no_samples = 1

fastqs_per_sample = [1] 

sample_id = "GSM4213829"

database_id = ["GSE134174"] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["trachea epithelial cells"] * no_samples

species = ["human"] * no_samples

technology = ["10xv3"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 5"] * no_samples

condition = ["non smoker"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 76kB/s
#      |████████████████████████████████| 133kB 55.7MB/s
#      |████████████████████████████████| 13.2MB 33.3MB/s
#      |████████████████████████████████| 51kB 4.8MB/s
#      |████████████████████████████████| 10.3MB 44.0MB/s
#      |████████████████████████████████| 112kB 40.0MB/s
#      |████████████████████████████████| 81kB 7.4MB/s
#      |████████████████████████████████| 71kB 5.7MB/s
#      |████████████████████████████████| 1.2MB 51.9MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %%
# Execute kb ref to get t2g.txt file
# !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2021-05-06 16:53:11,368]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [02:23<00:00, 16.6MB/s]
# [2021-05-06 16:55:37,239]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrices

# %%
# # Gunzip matrices
# !gunzip /content/adata.h5ad.gz
# !gunzip /content/adata_tcc.h5ad.gz

# Load matrices
adata = anndata.read_h5ad("/content/adata.h5ad")
adata_tcc = anndata.read_h5ad("/content/adata_tcc.h5ad")

# %%
adata.var
# Out:
#                      gene_name
# gene_id
# ENSG00000223972.5      DDX11L1
# ENSG00000227232.5       WASH7P
# ENSG00000278267.1    MIR6859-1
# ENSG00000243485.5  MIR1302-2HG
# ENSG00000284332.1    MIR1302-2
# ...                        ...
# ENSG00000271254.6   AC240274.1
# ENSG00000275405.1           U1
# ENSG00000275987.1           U1
# ENSG00000277475.1   AC213203.2
# ENSG00000268674.2   AC213203.1
#
# [60623 rows x 1 columns]

# %%
# Reformat and fill gene count matrix 

adata.var["gene_id"] = adata.var.index.values

t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
t2g.index = t2g.gene_id
t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

adata.var["gene_name"] = adata.var.gene_id.map(t2g["gene_name"])
adata.var.index = adata.var["gene_name"]
print("The unfiltered matrix " + sample_id + " contains {} cells by {} genes".format(len(adata.obs), len(adata.var)))

adata.obs["cell_counts"] = adata.X.sum(axis=1)
adata.var["gene_counts"] = nd(adata.X.sum(axis=0))

adata.obs["n_genes"] = nd((adata.X>0).sum(axis=1))
adata.var["n_cells"] = nd((adata.X>0).sum(axis=0))

mito_genes = adata.var_names.str.startswith("MT-" or "mt-") 
adata.obs["percent_mito"] = adata[:,mito_genes].X.sum(axis=1)/adata.X.sum(axis=1)*100

# Changing the name of the index is necessary to write the file (it won't work with duplicated names)
adata.var.index.name = "index"
# Out:
# The unfiltered matrix GSM4213829 contains 397070 cells by 60623 genes

# %% [markdown]
# ## Assign filters for gene count matrix

# %%
results = {}


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

# %%
expected_num_cells = 1800#@param {type:"integer"}
knee = np.sort(nd(adata.X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 15#@param {type:"integer"}
results["mito_criteria" + sample_id] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(adata.obs["cell_counts"][adata.obs["cell_counts"] > cell_threshold])
y = nd(adata.obs["percent_mito"][adata.obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 1800 with at least 6298.0 UMIs
# We select 15 % as the mitochondrial content threshold

# %% [markdown]
# # Filter gene count matrix

# %%
adata.obs["pass_count_filter"] = adata.obs["cell_counts"] > results["cell_threshold" + sample_id]
adata.obs["pass_mito_filter"] = adata.obs.percent_mito < results["mito_criteria" + sample_id]
adata.var["pass_gene_filter"] = adata.var["n_cells"] > gene_threshold

cell_mask = np.logical_and(adata.obs["pass_count_filter"].values, adata.obs["pass_mito_filter"].values)
gene_mask = adata.var["pass_gene_filter"].values

print("Current Shape: {:,} cells x {:,} genes".format(adata.shape[0], adata.shape[1]))
print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
results["data_" + sample_id] = adata[cell_mask, gene_mask]
# Out:
# Current Shape: 397,070 cells x 60,623 genes
#     New shape: 1,735 cells x 28,348 genes

# %% [markdown]
# # Anotate and write gene count matrix

# %%
adata.uns["database_id"] = database_id

adata.uns["tissue"] = tissue

adata.uns["cell_type"] = cell_type

adata.uns["sample_id"] = sample_id

adata.uns["condition"] = condition

adata.uns["species"] = species

adata.uns["technology"] = technology

adata.uns["paper"] = paper

adata.uns["figure"] = figure

# %cd /content

adata.write("result" + sample_id)
# Out:
# /content
# ... storing 'gene_name' as categorical

# %% [markdown]
# Filter TCC using gene count matrix's filter

# %%
adata_tcc = adata_tcc[adata.obs.index.values]
# transfer obs data
adata_tcc.obs = adata.obs
# transfer metadata
adata_tcc.uns = adata.uns
# write tcc matrix
adata_tcc.write("/content/tcc_" + sample_id)
#gzip tcc matrix
cmd = "gzip /content/tcc_" + sample_id
# !$cmd
