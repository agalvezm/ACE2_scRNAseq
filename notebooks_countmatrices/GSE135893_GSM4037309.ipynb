# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE135893_GSM4037309.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE135893_GSM4037309

# %%
# define the values for the analysis

# accession id for the data
id = "GSE135893"
samp_id = ["GSM4037309"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet

  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985358/SRR9985358_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985358/SRR9985358_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985361/SRR9985361_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985361/SRR9985361_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985362/SRR9985362_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985362/SRR9985362_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985363/SRR9985363_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985363/SRR9985363_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985360/SRR9985360_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985360/SRR9985360_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985359/SRR9985359_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985359/SRR9985359_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985356/SRR9985356_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985356/SRR9985356_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985357/SRR9985357_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985357/SRR9985357_2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["lung biopsy (multiple locations)"] * no_samples

condition = ["healthy"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 c,d Fig 4 e ED Fig 11 a,c"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 35.4MB 123kB/s
#      |████████████████████████████████| 51kB 6.3MB/s
#      |████████████████████████████████| 122kB 52.4MB/s
#      |████████████████████████████████| 112kB 52.1MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#      |████████████████████████████████| 7.7MB 8.2MB/s
#      |████████████████████████████████| 61kB 8.0MB/s
#      |████████████████████████████████| 51kB 7.4MB/s
#   Building wheel for sinfo (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2020-11-17 18:50:03--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985358/SRR9985358_1.fastq.gz
#            => ‘SRR9985358_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985358 ... done.
# ==> SIZE SRR9985358_1.fastq.gz ... 282688824
# ==> PASV ... done.    ==> RETR SRR9985358_1.fastq.gz ... done.
# Length: 282688824 (270M) (unauthoritative)
#
# SRR9985358_1.fastq. 100%[===================>] 269.59M  67.2MB/s    in 5.3s
#
# 2020-11-17 18:50:09 (50.7 MB/s) - ‘SRR9985358_1.fastq.gz’ saved [282688824]
#
# --2020-11-17 18:50:09--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985358/SRR9985358_2.fastq.gz
#            => ‘SRR9985358_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2020-11-17 18:50:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985358/SRR9985358_2.fastq.gz
#   (try: 2) => ‘SRR9985358_2.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985358 ... done.
# ==> SIZE SRR9985358_2.fastq.gz ... 300336081
# ==> PASV ... done.    ==> RETR SRR9985358_2.fastq.gz ... done.
# Length: 300336081 (286M) (unauthoritative)
#
# SRR9985358_2.fastq. 100%[===================>] 286.42M  5.35MB/s    in 60s
#
# 2020-11-17 18:51:12 (4.78 MB/s) - ‘SRR9985358_2.fastq.gz’ saved [300336081]
#
# --2020-11-17 18:51:12--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985361/SRR9985361_1.fastq.gz
#            => ‘SRR9985361_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985361 ... done.
# ==> SIZE SRR9985361_1.fastq.gz ... 385412969
# ==> PASV ... done.    ==> RETR SRR9985361_1.fastq.gz ... done.
# Length: 385412969 (368M) (unauthoritative)
#
# SRR9985361_1.fastq. 100%[===================>] 367.56M  58.3MB/s    in 17s
#
# 2020-11-17 18:51:30 (21.7 MB/s) - ‘SRR9985361_1.fastq.gz’ saved [385412969]
#
# --2020-11-17 18:51:30--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985361/SRR9985361_2.fastq.gz
#            => ‘SRR9985361_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985361 ... done.
# ==> SIZE SRR9985361_2.fastq.gz ... 466426955
# ==> PASV ... done.    ==> RETR SRR9985361_2.fastq.gz ... done.
# Length: 466426955 (445M) (unauthoritative)
#
# SRR9985361_2.fastq. 100%[===================>] 444.82M  85.3MB/s    in 13s
#
# 2020-11-17 18:51:43 (35.1 MB/s) - ‘SRR9985361_2.fastq.gz’ saved [466426955]
#
# --2020-11-17 18:51:43--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985362/SRR9985362_1.fastq.gz
#            => ‘SRR9985362_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985362 ... done.
# ==> SIZE SRR9985362_1.fastq.gz ... 388950409
# ==> PASV ... done.    ==> RETR SRR9985362_1.fastq.gz ... done.
# Length: 388950409 (371M) (unauthoritative)
#
# SRR9985362_1.fastq. 100%[===================>] 370.93M  34.2MB/s    in 11s
#
# 2020-11-17 18:51:55 (32.5 MB/s) - ‘SRR9985362_1.fastq.gz’ saved [388950409]
#
# --2020-11-17 18:51:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985362/SRR9985362_2.fastq.gz
#            => ‘SRR9985362_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985362 ... done.
# ==> SIZE SRR9985362_2.fastq.gz ... 412160173
# ==> PASV ... done.    ==> RETR SRR9985362_2.fastq.gz ... done.
# Length: 412160173 (393M) (unauthoritative)
#
# SRR9985362_2.fastq. 100%[===================>] 393.07M  48.1MB/s    in 13s
#
# 2020-11-17 18:52:09 (31.2 MB/s) - ‘SRR9985362_2.fastq.gz’ saved [412160173]
#
# --2020-11-17 18:52:09--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985363/SRR9985363_1.fastq.gz
#            => ‘SRR9985363_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985363 ... done.
# ==> SIZE SRR9985363_1.fastq.gz ... 472183915
# ==> PASV ... done.    ==> RETR SRR9985363_1.fastq.gz ... done.
# Length: 472183915 (450M) (unauthoritative)
#
# SRR9985363_1.fastq. 100%[===================>] 450.31M   127MB/s    in 6.5s
#
# 2020-11-17 18:52:17 (69.1 MB/s) - ‘SRR9985363_1.fastq.gz’ saved [472183915]
#
# --2020-11-17 18:52:17--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985363/SRR9985363_2.fastq.gz
#            => ‘SRR9985363_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2020-11-17 18:52:18--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985363/SRR9985363_2.fastq.gz
#   (try: 2) => ‘SRR9985363_2.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2020-11-17 18:52:20--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985363/SRR9985363_2.fastq.gz
#   (try: 3) => ‘SRR9985363_2.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985363 ... done.
# ==> SIZE SRR9985363_2.fastq.gz ... 562632150
# ==> PASV ... done.    ==> RETR SRR9985363_2.fastq.gz ... done.
# Length: 562632150 (537M) (unauthoritative)
#
# SRR9985363_2.fastq. 100%[===================>] 536.57M  73.6MB/s    in 15s
#
# 2020-11-17 18:52:36 (35.4 MB/s) - ‘SRR9985363_2.fastq.gz’ saved [562632150]
#
# --2020-11-17 18:52:36--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985360/SRR9985360_1.fastq.gz
#            => ‘SRR9985360_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2020-11-17 18:52:38--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985360/SRR9985360_1.fastq.gz
#   (try: 2) => ‘SRR9985360_1.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985360 ... done.
# ==> SIZE SRR9985360_1.fastq.gz ... 317910928
# ==> PASV ... done.    ==> RETR SRR9985360_1.fastq.gz ... done.
# Length: 317910928 (303M) (unauthoritative)
#
# SRR9985360_1.fastq. 100%[===================>] 303.18M  44.9MB/s    in 18s
#
# 2020-11-17 18:52:57 (17.0 MB/s) - ‘SRR9985360_1.fastq.gz’ saved [317910928]
#
# --2020-11-17 18:52:57--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985360/SRR9985360_2.fastq.gz
#            => ‘SRR9985360_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2020-11-17 18:52:58--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985360/SRR9985360_2.fastq.gz
#   (try: 2) => ‘SRR9985360_2.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2020-11-17 18:53:00--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985360/SRR9985360_2.fastq.gz
#   (try: 3) => ‘SRR9985360_2.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985360 ... done.
# ==> SIZE SRR9985360_2.fastq.gz ... 342445593
# ==> PASV ... done.    ==> RETR SRR9985360_2.fastq.gz ... done.
# Length: 342445593 (327M) (unauthoritative)
#
# SRR9985360_2.fastq. 100%[===================>] 326.58M  47.7MB/s    in 26s
#
# 2020-11-17 18:53:27 (12.4 MB/s) - ‘SRR9985360_2.fastq.gz’ saved [342445593]
#
# --2020-11-17 18:53:28--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985359/SRR9985359_1.fastq.gz
#            => ‘SRR9985359_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2020-11-17 18:53:29--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985359/SRR9985359_1.fastq.gz
#   (try: 2) => ‘SRR9985359_1.fastq.gz’
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985359 ... done.
# ==> SIZE SRR9985359_1.fastq.gz ... 343612130
# ==> PASV ... done.    ==> RETR SRR9985359_1.fastq.gz ... done.
# Length: 343612130 (328M) (unauthoritative)
#
# SRR9985359_1.fastq. 100%[===================>] 327.69M  41.3MB/s    in 12s
#
# 2020-11-17 18:53:41 (27.9 MB/s) - ‘SRR9985359_1.fastq.gz’ saved [343612130]
#
# --2020-11-17 18:53:41--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985359/SRR9985359_2.fastq.gz
#            => ‘SRR9985359_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985359 ... done.
# ==> SIZE SRR9985359_2.fastq.gz ... 410362366
# ==> PASV ... done.    ==> RETR SRR9985359_2.fastq.gz ... done.
# Length: 410362366 (391M) (unauthoritative)
#
# SRR9985359_2.fastq. 100%[===================>] 391.35M  98.2MB/s    in 13s
#
# 2020-11-17 18:53:55 (29.6 MB/s) - ‘SRR9985359_2.fastq.gz’ saved [410362366]
#
# --2020-11-17 18:53:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985356/SRR9985356_1.fastq.gz
#            => ‘SRR9985356_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985356 ... done.
# ==> SIZE SRR9985356_1.fastq.gz ... 411993429
# ==> PASV ... done.    ==> RETR SRR9985356_1.fastq.gz ... done.
# Length: 411993429 (393M) (unauthoritative)
#
# SRR9985356_1.fastq. 100%[===================>] 392.91M  83.4MB/s    in 11s
#
# 2020-11-17 18:54:07 (37.4 MB/s) - ‘SRR9985356_1.fastq.gz’ saved [411993429]
#
# --2020-11-17 18:54:07--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985356/SRR9985356_2.fastq.gz
#            => ‘SRR9985356_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985356 ... done.
# ==> SIZE SRR9985356_2.fastq.gz ... 442078703
# ==> PASV ... done.    ==> RETR SRR9985356_2.fastq.gz ... done.
# Length: 442078703 (422M) (unauthoritative)
#
# SRR9985356_2.fastq. 100%[===================>] 421.60M  16.7MB/s    in 44s
#
# 2020-11-17 18:54:52 (9.58 MB/s) - ‘SRR9985356_2.fastq.gz’ saved [442078703]
#
# --2020-11-17 18:54:52--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985357/SRR9985357_1.fastq.gz
#            => ‘SRR9985357_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985357 ... done.
# ==> SIZE SRR9985357_1.fastq.gz ... 500696745
# ==> PASV ... done.    ==> RETR SRR9985357_1.fastq.gz ... done.
# Length: 500696745 (478M) (unauthoritative)
#
# SRR9985357_1.fastq. 100%[===================>] 477.50M  66.7MB/s    in 11s
#
# 2020-11-17 18:55:04 (44.5 MB/s) - ‘SRR9985357_1.fastq.gz’ saved [500696745]
#
# --2020-11-17 18:55:04--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985357/SRR9985357_2.fastq.gz
#            => ‘SRR9985357_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985357 ... done.
# ==> SIZE SRR9985357_2.fastq.gz ... 603025356
# ==> PASV ... done.    ==> RETR SRR9985357_2.fastq.gz ... done.
# Length: 603025356 (575M) (unauthoritative)
#
# SRR9985357_2.fastq. 100%[===================>] 575.09M  62.8MB/s    in 14s
#
# 2020-11-17 18:55:18 (41.0 MB/s) - ‘SRR9985357_2.fastq.gz’ saved [603025356]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2020-11-17 18:55:20,028]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-11-17 18:58:43,695]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['SRR9985356_1.fastq.gz', 'SRR9985356_2.fastq.gz', 'SRR9985357_1.fastq.gz', 'SRR9985357_2.fastq.gz', 'SRR9985358_1.fastq.gz', 'SRR9985358_2.fastq.gz', 'SRR9985359_1.fastq.gz', 'SRR9985359_2.fastq.gz', 'SRR9985360_1.fastq.gz', 'SRR9985360_2.fastq.gz', 'SRR9985361_1.fastq.gz', 'SRR9985361_2.fastq.gz', 'SRR9985362_1.fastq.gz', 'SRR9985362_2.fastq.gz', 'SRR9985363_1.fastq.gz', 'SRR9985363_2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['SRR9985356_1.fastq.gz',
#  'SRR9985356_2.fastq.gz',
#  'SRR9985357_1.fastq.gz',
#  'SRR9985357_2.fastq.gz',
#  'SRR9985358_1.fastq.gz',
#  'SRR9985358_2.fastq.gz',
#  'SRR9985359_1.fastq.gz',
#  'SRR9985359_2.fastq.gz',
#  'SRR9985360_1.fastq.gz',
#  'SRR9985360_2.fastq.gz',
#  'SRR9985361_1.fastq.gz',
#  'SRR9985361_2.fastq.gz',
#  'SRR9985362_1.fastq.gz',
#  'SRR9985362_2.fastq.gz',
#  'SRR9985363_1.fastq.gz',
#  'SRR9985363_2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-11-17 18:59:22,891]    INFO Generating BUS file from
# [2020-11-17 18:59:22,892]    INFO         SRR9985356_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985356_2.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985357_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985357_2.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985358_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985358_2.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985359_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985359_2.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985360_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985360_2.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985361_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985361_2.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985362_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985362_2.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985363_1.fastq.gz
# [2020-11-17 18:59:22,892]    INFO         SRR9985363_2.fastq.gz
# [2020-11-17 19:07:58,781]    INFO Sorting BUS file outputGSM4037309/output.bus to tmp/output.s.bus
# [2020-11-17 19:08:32,951]    INFO Whitelist not provided
# [2020-11-17 19:08:32,951]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM4037309
# [2020-11-17 19:08:33,172]    INFO Inspecting BUS file tmp/output.s.bus
# [2020-11-17 19:08:39,474]    INFO Correcting BUS records in tmp/output.s.bus to tmp/output.s.c.bus with whitelist outputGSM4037309/10xv2_whitelist.txt
# [2020-11-17 19:08:58,786]    INFO Sorting BUS file tmp/output.s.c.bus to outputGSM4037309/output.unfiltered.bus
# [2020-11-17 19:09:07,377]    INFO Generating count matrix outputGSM4037309/counts_unfiltered/cells_x_genes from BUS file outputGSM4037309/output.unfiltered.bus
# [2020-11-17 19:09:14,209]    INFO Converting matrix outputGSM4037309/counts_unfiltered/cells_x_genes.mtx to h5ad outputGSM4037309/counts_unfiltered/adata.h5ad
# [2020-11-17 19:09:23,385]    INFO Filtering with bustools
# [2020-11-17 19:09:23,385]    INFO Generating whitelist outputGSM4037309/filter_barcodes.txt from BUS file outputGSM4037309/output.unfiltered.bus
# [2020-11-17 19:09:23,533]    INFO Capturing records from BUS file outputGSM4037309/output.unfiltered.bus to tmp/output.filtered.bus with capture list outputGSM4037309/filter_barcodes.txt
# [2020-11-17 19:09:24,629]    INFO Sorting BUS file tmp/output.filtered.bus to outputGSM4037309/output.filtered.bus
# [2020-11-17 19:09:29,278]    INFO Generating count matrix outputGSM4037309/counts_filtered/cells_x_genes from BUS file outputGSM4037309/output.filtered.bus
# [2020-11-17 19:09:33,653]    INFO Converting matrix outputGSM4037309/counts_filtered/cells_x_genes.mtx to h5ad outputGSM4037309/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM4037309 contains 172802 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 2000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 25#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 2000 with at least 210.0 UMIs
# We select 25 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 172,802 cells x 60,623 genes
#     New shape: 1,511 cells x 23,738 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
