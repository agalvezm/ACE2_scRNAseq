# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE109037_GSM2928377.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #GSE109037:GSM2928377

# %%
# define the values for the analysis

# accession id for the data
id = "GSE109037"

# If only bam available files, set bam = True, Fill link and filename
bam = True
if bam:
  # Assign link to python variable
  link_to_bam = "https://sra-pub-src-1.s3.amazonaws.com/SRR6459187/HumanSpermatogonia_17_1_possorted_genome_bam.bam.1"
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename="HumanSpermatogonia_17_1_possorted_genome_bam.bam.1"

if not bam:
  fastqs = ["ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR645/007/SRR6459187/SRR6459187.fastq.gz"]
# Out:
# env: BAM_LINK=https://sra-pub-src-1.s3.amazonaws.com/SRR6459187/HumanSpermatogonia_17_1_possorted_genome_bam.bam.1

# %%
no_samples = 1

database_id = [id] * no_samples

tissue = ["testis"] * no_samples

cell_type = ["spermatogonia"] * no_samples

sample_id = ["GSM2928377"] * no_samples

condition = ["17-1"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}
# Out:
# --2020-09-25 22:18:17--  http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
# Resolving cf.10xgenomics.com (cf.10xgenomics.com)... 104.18.0.173, 104.18.1.173, 2606:4700::6812:ad, ...
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.0.173|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cf.10xgenomics.com/misc/bamtofastq-1.2.0 [following]
# --2020-09-25 22:18:17--  https://cf.10xgenomics.com/misc/bamtofastq-1.2.0
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.0.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13288280 (13M) [binary/octet-stream]
# Saving to: ‘bamtofastq-1.2.0’
#
# bamtofastq-1.2.0    100%[===================>]  12.67M  64.0MB/s    in 0.2s
#
# 2020-09-25 22:18:18 (64.0 MB/s) - ‘bamtofastq-1.2.0’ saved [13288280/13288280]
#
# --2020-09-25 22:18:18--  http://continue/
# Resolving continue (continue)... failed: Name or service not known.
# wget: unable to resolve host address ‘continue’
# --2020-09-25 22:18:18--  https://sra-pub-src-1.s3.amazonaws.com/SRR6459187/HumanSpermatogonia_17_1_possorted_genome_bam.bam.1
# Resolving sra-pub-src-1.s3.amazonaws.com (sra-pub-src-1.s3.amazonaws.com)... 52.216.227.160
# Connecting to sra-pub-src-1.s3.amazonaws.com (sra-pub-src-1.s3.amazonaws.com)|52.216.227.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31255117906 (29G) [application/x-troff-man]
# Saving to: ‘HumanSpermatogonia_17_1_possorted_genome_bam.bam.1’
#
# HumanSpermatogonia_ 100%[===================>]  29.11G  43.0MB/s    in 13m 5s
#
# 2020-09-25 22:31:23 (38.0 MB/s) - ‘HumanSpermatogonia_17_1_possorted_genome_bam.bam.1’ saved [31255117906/31255117906]
#
# FINISHED --2020-09-25 22:31:23--
# Total wall clock time: 13m 5s
# Downloaded: 1 files, 29G in 13m 5s (38.0 MB/s)

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename
# Out:
# bamtofastq v1.2.0
# Args { arg_bam: "HumanSpermatogonia_17_1_possorted_genome_bam.bam.1", arg_output_path: "./fastqs", flag_nthreads: 4, flag_locus: None, flag_bx_list: None, flag_reads_per_fastq: 500000000, flag_gemcode: false, flag_lr20: false, flag_cr11: false }
# Writing finished.  Observed 311123552 read pairs. Wrote 311123552 read pairs

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      fastqs.remove(elem)

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)
# Out:
# /content/fastqs
# /content/fastqs/Human-SS022817-Sg2_Count_MissingLibrary_1_HJ3WTBBXX
#
#
# This is the complete list of fastqs:
#  -----------
# bamtofastq_S1_L008_R1_001.fastq.gz
# bamtofastq_S1_L008_R2_001.fastq.gz
# .ipynb_checkpoints
#
#
# This is the filtered list of fastqs:
#  -----------
# bamtofastq_S1_L008_R1_001.fastq.gz
# bamtofastq_S1_L008_R2_001.fastq.gz
# .ipynb_checkpoints

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2020-09-25 23:22:02,079]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-09-25 23:23:24,295]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
print(fastqs)
# Out:
# ['.ipynb_checkpoints', 'bamtofastq_S1_L008_R1_001.fastq.gz', 'bamtofastq_S1_L008_R2_001.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
#fastqs = fastqs[1:]
fastqs
# Out:
# ['bamtofastq_S1_L008_R1_001.fastq.gz', 'bamtofastq_S1_L008_R2_001.fastq.gz']

# %%
# Specify the sample number and whether they are paired end
number_of_samples = 1
paired_end = True 

# Initialize counter for fastq files
j = 0

# Loop over samples for analysis
for i in range(number_of_samples):
  # 0-based Index for fastqs:
  # Write the kb count command as a string
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
  --filter bustools -t 2 --overwrite " +\
  fastqs[j] + " " + fastqs[j+1] 
  # Execute it
  # !$cmd
  # Update j to get the two next fastqs
  if paired_end:
    j = j + 2
  else:
    j = j + 1
# Out:
# [2020-09-25 23:26:38,752]    INFO Generating BUS file from
# [2020-09-25 23:26:38,752]    INFO         bamtofastq_S1_L008_R1_001.fastq.gz
# [2020-09-25 23:26:38,753]    INFO         bamtofastq_S1_L008_R2_001.fastq.gz
# [2020-09-26 00:02:46,374]    INFO Sorting BUS file outputGSM2928377/output.bus to tmp/output.s.bus
# [2020-09-26 00:06:23,203]    INFO Whitelist not provided
# [2020-09-26 00:06:23,203]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM2928377
# [2020-09-26 00:06:23,323]    INFO Inspecting BUS file tmp/output.s.bus
# [2020-09-26 00:06:57,401]    INFO Correcting BUS records in tmp/output.s.bus to tmp/output.s.c.bus with whitelist outputGSM2928377/10xv2_whitelist.txt
# [2020-09-26 00:07:50,285]    INFO Sorting BUS file tmp/output.s.c.bus to outputGSM2928377/output.unfiltered.bus
# [2020-09-26 00:09:55,507]    INFO Generating count matrix outputGSM2928377/counts_unfiltered/cells_x_genes from BUS file outputGSM2928377/output.unfiltered.bus
# [2020-09-26 00:10:21,957]    INFO Converting matrix outputGSM2928377/counts_unfiltered/cells_x_genes.mtx to h5ad outputGSM2928377/counts_unfiltered/adata.h5ad
# [2020-09-26 00:10:57,737]    INFO Filtering with bustools
# [2020-09-26 00:10:57,738]    INFO Generating whitelist outputGSM2928377/filter_barcodes.txt from BUS file outputGSM2928377/output.unfiltered.bus
# [2020-09-26 00:10:58,742]    INFO Capturing records from BUS file outputGSM2928377/output.unfiltered.bus to tmp/output.filtered.bus with capture list outputGSM2928377/filter_barcodes.txt
# [2020-09-26 00:11:21,610]    INFO Sorting BUS file tmp/output.filtered.bus to outputGSM2928377/output.filtered.bus
# [2020-09-26 00:13:32,820]    INFO Generating count matrix outputGSM2928377/counts_filtered/cells_x_genes from BUS file outputGSM2928377/output.filtered.bus
# [2020-09-26 00:13:57,517]    INFO Converting matrix outputGSM2928377/counts_filtered/cells_x_genes.mtx to h5ad outputGSM2928377/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# !pwd
# Out:
# /content/fastqs/Human-SS022817-Sg2_Count_MissingLibrary_1_HJ3WTBBXX

# %%
# load the unfiltered matrix
for i in range(number_of_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM2928377 contains 334302 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 4500#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[i]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 21#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[i]].obs["cell_counts"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[i]].obs["percent_mito"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 4500 with at least 511.0 UMIs
# We select 21 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(number_of_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 334,302 cells x 60,623 genes
#     New shape: 4,426 cells x 38,076 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(number_of_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# %cd /content

for i in range(number_of_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# /content
# ... storing 'gene_name' as categorical
