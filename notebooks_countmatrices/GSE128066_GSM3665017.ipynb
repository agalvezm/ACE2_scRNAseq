# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE128066_GSM3665017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE124494_GSM3665017

# %%
# Install SRA-toolkit 
# !wget "http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz"

! tar -xzf sratoolkit.current-centos_linux64.tar.gz

# Add to path
import os
os.environ['PATH'] += ":/content/sratoolkit.2.10.8-centos_linux64/bin"

# Configure
# !vdb-config --interactive

# Import packages

import numpy as np
# Out:
# --2020-11-16 15:57:31--  http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz
# Resolving ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)... 130.14.250.10, 2607:f220:41e:250::7, 2607:f220:41e:250::10, ...
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz [following]
# --2020-11-16 15:57:31--  https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 97795576 (93M) [application/x-gzip]
# Saving to: ‘sratoolkit.current-centos_linux64.tar.gz’
#
# sratoolkit.current- 100%[===================>]  93.26M  35.7MB/s    in 2.6s
#
# 2020-11-16 15:57:34 (35.7 MB/s) - ‘sratoolkit.current-centos_linux64.tar.gz’ saved [97795576/97795576]
#
# 2020-11-16T15:57:37 vdb-config.2.10.8 fatal: SIGNAL - Segmentation fault

# %%
# List of SRAs to download and transform
SRAs = ["SRR8712346",	"SRR8712347", "SRR8712348",	"SRR8712349"]

# SRA to delete, usually the index file, which get downloaded because we include technical reads. 
# It varies so check in the SRA website
SRA_to_delete = "3"


SRAs_to_keep = np.setdiff1d(["1", "2", "3"], [SRA_to_delete])

# %%
for sra in SRAs:
  """
  Downloads SRAs and transforms to compressed fastq file. Remove index reads and original SRA
  """
  # Download SRA
  # !prefetch $sra

  # Convert to fastq. Biological reads are usually considered technicals in 10x so do not skip them.
  fastq_dump_cmd = "fastq-dump -F --gzip --readids --split-files " + sra + "/" + sra +".sra"
  # !$fastq_dump_cmd

  # Remove files
  rm_cmd_1 = "rm " + sra + "/" + sra + ".sra"
  rm_cmd_2 = "rm " + sra + "_" + SRA_to_delete + ".fastq.gz" 
  # !$rm_cmd_1
  # !$rm_cmd_2
# Out:
# 2020-11-16T17:11:20 prefetch.2.10.8: 1) Downloading 'SRR8712347'...
# 2020-11-16T17:11:20 prefetch.2.10.8:  Downloading via HTTPS...
# 2020-11-16T17:12:34 prefetch.2.10.8:  HTTPS download succeed
# 2020-11-16T17:12:42 prefetch.2.10.8:  'SRR8712347' is valid
# 2020-11-16T17:12:42 prefetch.2.10.8: 1) 'SRR8712347' was downloaded successfully
# 2020-11-16T17:12:42 prefetch.2.10.8: 'SRR8712347' has 0 unresolved dependencies
# Read 57030961 spots for SRR8712347/SRR8712347.sra
# Written 57030961 spots for SRR8712347/SRR8712347.sra
#
# 2020-11-16T18:10:56 prefetch.2.10.8: 1) Downloading 'SRR8712348'...
# 2020-11-16T18:10:56 prefetch.2.10.8:  Downloading via HTTPS...
# 2020-11-16T18:12:14 prefetch.2.10.8:  HTTPS download succeed
# 2020-11-16T18:12:23 prefetch.2.10.8:  'SRR8712348' is valid
# 2020-11-16T18:12:23 prefetch.2.10.8: 1) 'SRR8712348' was downloaded successfully
# 2020-11-16T18:12:23 prefetch.2.10.8: 'SRR8712348' has 0 unresolved dependencies
# Read 60052909 spots for SRR8712348/SRR8712348.sra
# Written 60052909 spots for SRR8712348/SRR8712348.sra
#
# 2020-11-16T19:13:09 prefetch.2.10.8: 1) Downloading 'SRR8712349'...
# 2020-11-16T19:13:09 prefetch.2.10.8:  Downloading via HTTPS...
# 2020-11-16T19:14:34 prefetch.2.10.8:  HTTPS download succeed
# 2020-11-16T19:14:43 prefetch.2.10.8:  'SRR8712349' is valid
# 2020-11-16T19:14:43 prefetch.2.10.8: 1) 'SRR8712349' was downloaded successfully
# 2020-11-16T19:14:43 prefetch.2.10.8: 'SRR8712349' has 0 unresolved dependencies
# Read 57856756 spots for SRR8712349/SRR8712349.sra
# Written 57856756 spots for SRR8712349/SRR8712349.sra

# %% [markdown]
# This is a test to compare with fasterq-dump. Once done, return SRA to original value.

# %%
# Define fastq list to feed kb

fastqs = []
for sra in SRAs:
  for read in SRAs_to_keep:
    fastqs.append(sra + "_" + read + ".fastq.gz")

# %% [markdown]
# ## Metadata

# %%
# define the values for the analysis

# accession id for the data
id = "GSE128066"

samp_id = ["GSM3665017"]

no_samples = 1

fastqs_per_sample = [8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["blood"] * no_samples

cell_type = ["PBMCs"] * no_samples

condition = ["healthy donor"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 35.4MB 1.3MB/s
#      |████████████████████████████████| 51kB 5.3MB/s
#      |████████████████████████████████| 122kB 42.8MB/s
#      |████████████████████████████████| 112kB 35.1MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#      |████████████████████████████████| 7.7MB 7.0MB/s
#      |████████████████████████████████| 51kB 4.4MB/s
#      |████████████████████████████████| 61kB 6.4MB/s
#   Building wheel for sinfo (setup.py) ... done

# %% [markdown]
# # Downloads: index

# %%
# Download the corresponding Kallisto index to fastq folder
# !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2020-11-16 20:17:44,325]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-11-16 20:19:03,340]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['SRR8712347_1.fastq.gz',
#  'SRR8712347_2.fastq.gz',
#  'SRR8712348_1.fastq.gz',
#  'SRR8712348_2.fastq.gz',
#  'SRR8712349_1.fastq.gz',
#  'SRR8712349_2.fastq.gz']

# %%
# Specify the sample number 


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-11-16 20:19:44,432]    INFO Generating BUS file from
# [2020-11-16 20:19:44,433]    INFO         SRR8712347_1.fastq.gz
# [2020-11-16 20:19:44,433]    INFO         SRR8712347_2.fastq.gz
# [2020-11-16 20:19:44,433]    INFO         SRR8712348_1.fastq.gz
# [2020-11-16 20:19:44,434]    INFO         SRR8712348_2.fastq.gz
# [2020-11-16 20:19:44,434]    INFO         SRR8712349_1.fastq.gz
# [2020-11-16 20:19:44,434]    INFO         SRR8712349_2.fastq.gz
# [2020-11-16 21:06:43,710]    INFO Sorting BUS file outputGSM3665017/output.bus to tmp/output.s.bus
# [2020-11-16 21:08:45,720]    INFO Whitelist not provided
# [2020-11-16 21:08:45,721]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM3665017
# [2020-11-16 21:08:47,245]    INFO Inspecting BUS file tmp/output.s.bus
# [2020-11-16 21:09:06,543]    INFO Correcting BUS records in tmp/output.s.bus to tmp/output.s.c.bus with whitelist outputGSM3665017/10xv2_whitelist.txt
# [2020-11-16 21:09:46,228]    INFO Sorting BUS file tmp/output.s.c.bus to outputGSM3665017/output.unfiltered.bus
# [2020-11-16 21:10:17,337]    INFO Generating count matrix outputGSM3665017/counts_unfiltered/cells_x_genes from BUS file outputGSM3665017/output.unfiltered.bus
# [2020-11-16 21:10:31,423]    INFO Converting matrix outputGSM3665017/counts_unfiltered/cells_x_genes.mtx to h5ad outputGSM3665017/counts_unfiltered/adata.h5ad
# [2020-11-16 21:10:48,849]    INFO Filtering with bustools
# [2020-11-16 21:10:48,849]    INFO Generating whitelist outputGSM3665017/filter_barcodes.txt from BUS file outputGSM3665017/output.unfiltered.bus
# [2020-11-16 21:10:49,506]    INFO Capturing records from BUS file outputGSM3665017/output.unfiltered.bus to tmp/output.filtered.bus with capture list outputGSM3665017/filter_barcodes.txt
# [2020-11-16 21:10:56,477]    INFO Sorting BUS file tmp/output.filtered.bus to outputGSM3665017/output.filtered.bus
# [2020-11-16 21:11:30,787]    INFO Generating count matrix outputGSM3665017/counts_filtered/cells_x_genes from BUS file outputGSM3665017/output.filtered.bus
# [2020-11-16 21:11:42,096]    INFO Converting matrix outputGSM3665017/counts_filtered/cells_x_genes.mtx to h5ad outputGSM3665017/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM3665017 contains 171673 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 2900#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 25#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 2900 with at least 59.0 UMIs
# We select 25 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 171,673 cells x 60,623 genes
#     New shape: 2,817 cells x 23,879 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
