# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE124263_GSM3526587.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE124263_GSM3526587

# %%
# define the values for the analysis

# accession id for the data
id = "GSE124263"
samp_id = ["GSM3526587"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = True


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet
  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363285/SRR8363285_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363285/SRR8363285_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363286/SRR8363286_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363286/SRR8363286_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363287/SRR8363287_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363287/SRR8363287_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363288/SRR8363288_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363288/SRR8363288_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363289/SRR8363289_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363289/SRR8363289_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363290/SRR8363290_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363290/SRR8363290_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363291/SRR8363291_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363291/SRR8363291_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363292/SRR8363292_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363292/SRR8363292_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363293/SRR8363293_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363293/SRR8363293_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363294/SRR8363294_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363294/SRR8363294_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363295/SRR8363295_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363295/SRR8363295_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363296/SRR8363296_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363296/SRR8363296_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363297/SRR8363297_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363297/SRR8363297_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363298/SRR8363298_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363298/SRR8363298_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363299/SRR8363299_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363299/SRR8363299_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363300/SRR8363300_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363300/SRR8363300_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363301/SRR8363301_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363301/SRR8363301_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363302/SRR8363302_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363302/SRR8363302_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363303/SRR8363303_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363303/SRR8363303_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363304/SRR8363304_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363304/SRR8363304_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363305/SRR8363305_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363305/SRR8363305_2.fastq.gz"
  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["testis"] * no_samples

cell_type = ["ITGA6 enriched"] * no_samples

condition = ["Adult 1 ITGA6 enriched"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 35.4MB 1.3MB/s
#      |████████████████████████████████| 51kB 6.8MB/s
#      |████████████████████████████████| 122kB 48.0MB/s
#      |████████████████████████████████| 112kB 37.4MB/s
# ...
#      |████████████████████████████████| 7.7MB 2.6MB/s
#      |████████████████████████████████| 51kB 6.5MB/s
#      |████████████████████████████████| 61kB 7.6MB/s
# ...

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content
# [2020-11-02 18:04:46,026]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-11-02 18:07:32,865]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363285/SRR8363285_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363285/SRR8363285_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363286/SRR8363286_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363286/SRR8363286_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363287/SRR8363287_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363287/SRR8363287_2.fastq.gz', 'ftp://ftp.sr
# ...

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363285/SRR8363285_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363285/SRR8363285_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363286/SRR8363286_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363286/SRR8363286_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363287/SRR8363287_1.fastq.gz',
# ...

# %%
# !pwd
# Out:
# /content

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-11-02 18:08:12,838]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_1.fastq.gz to tmp/SRR8363282_1.fastq.gz
# [2020-11-02 18:08:12,840]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363282/SRR8363282_2.fastq.gz to tmp/SRR8363282_2.fastq.gz
# [2020-11-02 18:08:12,841]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_1.fastq.gz to tmp/SRR8363283_1.fastq.gz
# [2020-11-02 18:08:12,841]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363283/SRR8363283_2.fastq.gz to tmp/SRR8363283_2.fastq.gz
# [2020-11-02 18:08:12,842]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_1.fastq.gz to tmp/SRR8363284_1.fastq.gz
# [2020-11-02 18:08:12,842]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363284/SRR8363284_2.fastq.gz to tmp/SRR8363284_2.fastq.gz
# ...

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM3526587 contains 190071 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 8000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 30#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 8000 with at least 50.0 UMIs
# We select 30 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 190,071 cells x 60,623 genes
#     New shape: 7,402 cells x 30,462 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
