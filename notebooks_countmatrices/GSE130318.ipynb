# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE130318.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE : GSM

# %%
# define the values for the analysis

# accession id for the data
id = "GSE130318"
samp_id = ["GSM3735993", "GSM3735994"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet

  links_raw = "https://sra-pub-src-2.s3.amazonaws.com/SRR8956099/Nonn_S2_L003_R1_001.fastq.gz	https://sra-pub-src-2.s3.amazonaws.com/SRR8956099/Nonn_S2_L003_R2_001.fastq.gz	https://sra-pub-src-2.s3.amazonaws.com/SRR8956098/Nonn_S2_L002_R1_001.fastq.gz	https://sra-pub-src-2.s3.amazonaws.com/SRR8956098/Nonn_S2_L002_R2_001.fastq.gz https://sra-pub-src-2.s3.amazonaws.com/SRR8956100/Org_S3_L002_R1_001.fastq.gz	https://sra-pub-src-2.s3.amazonaws.com/SRR8956100/Org_S3_L002_R2_001.fastq.gz	https://sra-pub-src-2.s3.amazonaws.com/SRR8956101/Org_S3_L003_R1_001.fastq.gz	https://sra-pub-src-2.s3.amazonaws.com/SRR8956101/Org_S3_L003_R2_001.fastq.gz"
  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
fastqs
# Out:
# ['https://sra-pub-src-2.s3.amazonaws.com/SRR8956099/Nonn_S2_L003_R1_001.fastq.gz',
#  'https://sra-pub-src-2.s3.amazonaws.com/SRR8956099/Nonn_S2_L003_R2_001.fastq.gz',
#  'https://sra-pub-src-2.s3.amazonaws.com/SRR8956098/Nonn_S2_L002_R1_001.fastq.gz',
#  'https://sra-pub-src-2.s3.amazonaws.com/SRR8956098/Nonn_S2_L002_R2_001.fastq.gz',
#  'https://sra-pub-src-2.s3.amazonaws.com/SRR8956100/Org_S3_L002_R1_001.fastq.gz',
#  'https://sra-pub-src-2.s3.amazonaws.com/SRR8956100/Org_S3_L002_R2_001.fastq.gz',
#  'https://sra-pub-src-2.s3.amazonaws.com/SRR8956101/Org_S3_L003_R1_001.fastq.gz',
#  'https://sra-pub-src-2.s3.amazonaws.com/SRR8956101/Org_S3_L003_R2_001.fastq.gz']

# %%
no_samples = 2

fastqs_per_sample = [4, 4] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["prostate"] * no_samples

cell_type = ["primary epithelial cells"] * no_samples

condition = ["Monolayer, Organoid"] 

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 35.4MB 119kB/s
#      |████████████████████████████████| 51kB 6.3MB/s
#      |████████████████████████████████| 122kB 49.8MB/s
#      |████████████████████████████████| 112kB 51.4MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#      |████████████████████████████████| 7.7MB 3.9MB/s
#      |████████████████████████████████| 51kB 6.1MB/s
#      |████████████████████████████████| 61kB 6.6MB/s
#   Building wheel for sinfo (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2020-11-11 15:37:29--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956099/Nonn_S2_L003_R1_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.217.17.228
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.217.17.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1759399707 (1.6G) [application/x-troff-man]
# Saving to: ‘Nonn_S2_L003_R1_001.fastq.gz’
#
# Nonn_S2_L003_R1_001 100%[===================>]   1.64G  35.5MB/s    in 47s
#
# 2020-11-11 15:38:16 (35.8 MB/s) - ‘Nonn_S2_L003_R1_001.fastq.gz’ saved [1759399707/1759399707]
#
# --2020-11-11 15:38:16--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956099/Nonn_S2_L003_R2_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.216.245.60
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.216.245.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6195050925 (5.8G) [application/x-troff-man]
# Saving to: ‘Nonn_S2_L003_R2_001.fastq.gz’
#
# Nonn_S2_L003_R2_001 100%[===================>]   5.77G  39.6MB/s    in 2m 50s
#
# 2020-11-11 15:41:07 (34.7 MB/s) - ‘Nonn_S2_L003_R2_001.fastq.gz’ saved [6195050925/6195050925]
#
# --2020-11-11 15:41:07--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956098/Nonn_S2_L002_R1_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.216.200.203
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.216.200.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1737657131 (1.6G) [application/x-troff-man]
# Saving to: ‘Nonn_S2_L002_R1_001.fastq.gz’
#
# Nonn_S2_L002_R1_001 100%[===================>]   1.62G  38.1MB/s    in 46s
#
# 2020-11-11 15:41:54 (35.9 MB/s) - ‘Nonn_S2_L002_R1_001.fastq.gz’ saved [1737657131/1737657131]
#
# --2020-11-11 15:41:54--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956098/Nonn_S2_L002_R2_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.216.84.211
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.216.84.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6093945713 (5.7G) [application/x-troff-man]
# Saving to: ‘Nonn_S2_L002_R2_001.fastq.gz’
#
# Nonn_S2_L002_R2_001 100%[===================>]   5.67G  37.1MB/s    in 2m 44s
#
# 2020-11-11 15:44:39 (35.4 MB/s) - ‘Nonn_S2_L002_R2_001.fastq.gz’ saved [6093945713/6093945713]
#
# --2020-11-11 15:44:39--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956100/Org_S3_L002_R1_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.216.186.43
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.216.186.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3179491151 (3.0G) [application/x-troff-man]
# Saving to: ‘Org_S3_L002_R1_001.fastq.gz’
#
# Org_S3_L002_R1_001. 100%[===================>]   2.96G  42.5MB/s    in 85s
#
# 2020-11-11 15:46:04 (35.8 MB/s) - ‘Org_S3_L002_R1_001.fastq.gz’ saved [3179491151/3179491151]
#
# --2020-11-11 15:46:04--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956100/Org_S3_L002_R2_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.216.144.147
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.216.144.147|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11311194906 (11G) [application/x-troff-man]
# Saving to: ‘Org_S3_L002_R2_001.fastq.gz’
#
# Org_S3_L002_R2_001. 100%[===================>]  10.53G  35.7MB/s    in 7m 18s
#
# 2020-11-11 15:53:22 (24.6 MB/s) - ‘Org_S3_L002_R2_001.fastq.gz’ saved [11311194906/11311194906]
#
# --2020-11-11 15:53:23--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956101/Org_S3_L003_R1_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.216.248.84
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.216.248.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3223529127 (3.0G) [application/x-troff-man]
# Saving to: ‘Org_S3_L003_R1_001.fastq.gz’
#
# Org_S3_L003_R1_001. 100%[===================>]   3.00G  37.7MB/s    in 84s
#
# 2020-11-11 15:54:47 (36.4 MB/s) - ‘Org_S3_L003_R1_001.fastq.gz’ saved [3223529127/3223529127]
#
# --2020-11-11 15:54:47--  https://sra-pub-src-2.s3.amazonaws.com/SRR8956101/Org_S3_L003_R2_001.fastq.gz
# Resolving sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)... 52.217.41.12
# Connecting to sra-pub-src-2.s3.amazonaws.com (sra-pub-src-2.s3.amazonaws.com)|52.217.41.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11516781182 (11G) [application/x-troff-man]
# Saving to: ‘Org_S3_L003_R2_001.fastq.gz’
#
# Org_S3_L003_R2_001. 100%[===================>]  10.73G  39.9MB/s    in 4m 54s
#
# 2020-11-11 15:59:42 (37.3 MB/s) - ‘Org_S3_L003_R2_001.fastq.gz’ saved [11516781182/11516781182]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2020-11-11 15:59:46,428]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-11-11 16:01:15,466]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['Nonn_S2_L002_R1_001.fastq.gz', 'Nonn_S2_L002_R2_001.fastq.gz', 'Nonn_S2_L003_R1_001.fastq.gz', 'Nonn_S2_L003_R2_001.fastq.gz', 'Org_S3_L002_R1_001.fastq.gz', 'Org_S3_L002_R2_001.fastq.gz', 'Org_S3_L003_R1_001.fastq.gz', 'Org_S3_L003_R2_001.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['Nonn_S2_L002_R1_001.fastq.gz',
#  'Nonn_S2_L002_R2_001.fastq.gz',
#  'Nonn_S2_L003_R1_001.fastq.gz',
#  'Nonn_S2_L003_R2_001.fastq.gz',
#  'Org_S3_L002_R1_001.fastq.gz',
#  'Org_S3_L002_R2_001.fastq.gz',
#  'Org_S3_L003_R1_001.fastq.gz',
#  'Org_S3_L003_R2_001.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-11-11 16:01:53,029]    INFO Generating BUS file from
# [2020-11-11 16:01:53,029]    INFO         Nonn_S2_L002_R1_001.fastq.gz
# [2020-11-11 16:01:53,029]    INFO         Nonn_S2_L002_R2_001.fastq.gz
# [2020-11-11 16:01:53,029]    INFO         Nonn_S2_L003_R1_001.fastq.gz
# [2020-11-11 16:01:53,029]    INFO         Nonn_S2_L003_R2_001.fastq.gz
# [2020-11-11 16:29:25,318]    INFO Sorting BUS file outputGSE130318/output.bus to tmp/output.s.bus
# [2020-11-11 16:33:07,817]    INFO Whitelist not provided
# [2020-11-11 16:33:07,822]    INFO Copying pre-packaged 10XV2 whitelist to outputGSE130318
# [2020-11-11 16:33:08,012]    INFO Inspecting BUS file tmp/output.s.bus
# [2020-11-11 16:33:46,456]    INFO Correcting BUS records in tmp/output.s.bus to tmp/output.s.c.bus with whitelist outputGSE130318/10xv2_whitelist.txt
# [2020-11-11 16:34:56,146]    INFO Sorting BUS file tmp/output.s.c.bus to outputGSE130318/output.unfiltered.bus
# [2020-11-11 16:38:15,633]    INFO Generating count matrix outputGSE130318/counts_unfiltered/cells_x_genes from BUS file outputGSE130318/output.unfiltered.bus
# [2020-11-11 16:39:01,849]    INFO Converting matrix outputGSE130318/counts_unfiltered/cells_x_genes.mtx to h5ad outputGSE130318/counts_unfiltered/adata.h5ad
# [2020-11-11 16:39:56,853]    INFO Filtering with bustools
# [2020-11-11 16:39:56,853]    INFO Generating whitelist outputGSE130318/filter_barcodes.txt from BUS file outputGSE130318/output.unfiltered.bus
# [2020-11-11 16:40:07,572]    INFO Capturing records from BUS file outputGSE130318/output.unfiltered.bus to tmp/output.filtered.bus with capture list outputGSE130318/filter_barcodes.txt
# [2020-11-11 16:40:34,476]    INFO Sorting BUS file tmp/output.filtered.bus to outputGSE130318/output.filtered.bus
# [2020-11-11 16:43:11,155]    INFO Generating count matrix outputGSE130318/counts_filtered/cells_x_genes from BUS file outputGSE130318/output.filtered.bus
# [2020-11-11 16:43:40,995]    INFO Converting matrix outputGSE130318/counts_filtered/cells_x_genes.mtx to h5ad outputGSE130318/counts_filtered/adata.h5ad
# [2020-11-11 16:44:13,485]    INFO Generating BUS file from
# [2020-11-11 16:44:13,485]    INFO         Org_S3_L002_R1_001.fastq.gz
# [2020-11-11 16:44:13,485]    INFO         Org_S3_L002_R2_001.fastq.gz
# [2020-11-11 16:44:13,485]    INFO         Org_S3_L003_R1_001.fastq.gz
# [2020-11-11 16:44:13,485]    INFO         Org_S3_L003_R2_001.fastq.gz
# [2020-11-11 17:34:54,843]    INFO Sorting BUS file outputGSE130319/output.bus to tmp/output.s.bus
# [2020-11-11 17:41:45,763]    INFO Whitelist not provided
# [2020-11-11 17:41:45,766]    INFO Copying pre-packaged 10XV2 whitelist to outputGSE130319
# [2020-11-11 17:41:45,916]    INFO Inspecting BUS file tmp/output.s.bus
# [2020-11-11 17:43:50,042]    INFO Correcting BUS records in tmp/output.s.bus to tmp/output.s.c.bus with whitelist outputGSE130319/10xv2_whitelist.txt
# [2020-11-11 17:46:16,027]    INFO Sorting BUS file tmp/output.s.c.bus to outputGSE130319/output.unfiltered.bus
# [2020-11-11 17:49:41,962]    INFO Generating count matrix outputGSE130319/counts_unfiltered/cells_x_genes from BUS file outputGSE130319/output.unfiltered.bus
# [2020-11-11 17:49:45,081]    INFO Converting matrix outputGSE130319/counts_unfiltered/cells_x_genes.mtx to h5ad outputGSE130319/counts_unfiltered/adata.h5ad
# [2020-11-11 17:49:45,305]    INFO Filtering with bustools
# [2020-11-11 17:49:45,305]    INFO Generating whitelist outputGSE130319/filter_barcodes.txt from BUS file outputGSE130319/output.unfiltered.bus
# [2020-11-11 17:49:45,316]    INFO Capturing records from BUS file outputGSE130319/output.unfiltered.bus to tmp/output.filtered.bus with capture list outputGSE130319/filter_barcodes.txt
# [2020-11-11 17:49:45,326]    INFO Sorting BUS file tmp/output.filtered.bus to outputGSE130319/output.filtered.bus
# [2020-11-11 17:49:48,186]    INFO Generating count matrix outputGSE130319/counts_filtered/cells_x_genes from BUS file outputGSE130319/output.filtered.bus
# [2020-11-11 17:49:51,209]    INFO Converting matrix outputGSE130319/counts_filtered/cells_x_genes.mtx to h5ad outputGSE130319/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSE130318 contains 536598 cells by 60623 genes
# The unfiltered matrix GSE130319 contains 11 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0

# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 12000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 15#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 12000 with at least 279.0 UMIs
# We select 15 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 536,598 cells x 60,623 genes
#     New shape: 10,867 cells x 29,874 genes
# Current Shape: 11 cells x 60,623 genes
#     New shape: 5 cells x 0 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[i]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[i]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[i]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[i]

  results["data_" + sample_id[i]].uns["condition"] = condition[i]

  results["data_" + sample_id[i]].uns["species"] = species[i]

  results["data_" + sample_id[i]].uns["technology"] = technology[i]

  results["data_" + sample_id[i]].uns["paper"] = paper[i]

  results["data_" + sample_id[i]].uns["figure"] = figure[i]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Trying to set attribute `.uns` of view, copying.
# /content
# ... storing 'gene_name' as categorical
