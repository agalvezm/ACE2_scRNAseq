# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE128066_GSM3667327.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE124494_GSM3667327

# %%
# Install SRA-toolkit 
# !wget "http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz"

! tar -xzf sratoolkit.current-centos_linux64.tar.gz

# Add to path
import os
os.environ['PATH'] += ":/content/sratoolkit.2.10.8-centos_linux64/bin"

# Configure
# !vdb-config --interactive

# Import packages

import numpy as np
# Out:
# --2020-11-16 15:58:25--  http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz
# Resolving ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)... 130.14.250.10, 2607:f220:41e:250::12, 2607:f220:41e:250::13, ...
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz [following]
# --2020-11-16 15:58:25--  https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-centos_linux64.tar.gz
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 97795576 (93M) [application/x-gzip]
# Saving to: ‘sratoolkit.current-centos_linux64.tar.gz’
#
# sratoolkit.current- 100%[===================>]  93.26M  34.4MB/s    in 2.7s
#
# 2020-11-16 15:58:28 (34.4 MB/s) - ‘sratoolkit.current-centos_linux64.tar.gz’ saved [97795576/97795576]
#
# 2020-11-16T15:58:31 vdb-config.2.10.8 fatal: SIGNAL - Segmentation fault

# %%
# List of SRAs to download and transform. Copy paste from excel as string
SRAs = "SRR8728153	SRR8728154	SRR8728155	SRR8728156"

SRAs = SRAs.split()

# SRA to delete, usually the index file, which get downloaded because we include technical reads. 
# It varies so check in the SRA website
SRA_to_delete = "3"


SRAs_to_keep = np.setdiff1d(["1", "2", "3"], [SRA_to_delete])

# %%
for sra in SRAs:
  """
  Downloads SRAs and transforms to compressed fastq file. Remove index reads and original SRA
  """
  # Download SRA
  # !prefetch $sra

  # Convert to fastq. Biological reads are usually considered technicals in 10x so do not skip them.
  fastq_dump_cmd = "fastq-dump -F --gzip --readids --split-files " + sra + "/" + sra +".sra"
  # !$fastq_dump_cmd

  # Remove files
  rm_cmd_1 = "rm " + sra + "/" + sra + ".sra"
  rm_cmd_2 = "rm " + sra + "_" + SRA_to_delete + ".fastq.gz" 
  # !$rm_cmd_1
  # !$rm_cmd_2
# Out:
# 2020-11-16T15:59:36 prefetch.2.10.8: 1) Downloading 'SRR8728153'...
# 2020-11-16T15:59:36 prefetch.2.10.8:  Downloading via HTTPS...
# 2020-11-16T16:00:15 prefetch.2.10.8:  HTTPS download succeed
# 2020-11-16T16:00:19 prefetch.2.10.8:  'SRR8728153' is valid
# 2020-11-16T16:00:19 prefetch.2.10.8: 1) 'SRR8728153' was downloaded successfully
# 2020-11-16T16:00:19 prefetch.2.10.8: 'SRR8728153' has 0 unresolved dependencies
# Read 27414091 spots for SRR8728153/SRR8728153.sra
# Written 27414091 spots for SRR8728153/SRR8728153.sra
#
# 2020-11-16T16:27:59 prefetch.2.10.8: 1) Downloading 'SRR8728154'...
# 2020-11-16T16:27:59 prefetch.2.10.8:  Downloading via HTTPS...
# 2020-11-16T16:28:31 prefetch.2.10.8:  HTTPS download succeed
# 2020-11-16T16:28:35 prefetch.2.10.8:  'SRR8728154' is valid
# 2020-11-16T16:28:35 prefetch.2.10.8: 1) 'SRR8728154' was downloaded successfully
# 2020-11-16T16:28:35 prefetch.2.10.8: 'SRR8728154' has 0 unresolved dependencies
# Read 26902013 spots for SRR8728154/SRR8728154.sra
# Written 26902013 spots for SRR8728154/SRR8728154.sra
#
# 2020-11-16T16:56:03 prefetch.2.10.8: 1) Downloading 'SRR8728155'...
# 2020-11-16T16:56:03 prefetch.2.10.8:  Downloading via HTTPS...
# 2020-11-16T16:56:36 prefetch.2.10.8:  HTTPS download succeed
# 2020-11-16T16:56:40 prefetch.2.10.8:  'SRR8728155' is valid
# 2020-11-16T16:56:40 prefetch.2.10.8: 1) 'SRR8728155' was downloaded successfully
# 2020-11-16T16:56:40 prefetch.2.10.8: 'SRR8728155' has 0 unresolved dependencies
# Read 27153044 spots for SRR8728155/SRR8728155.sra
# Written 27153044 spots for SRR8728155/SRR8728155.sra
#
# 2020-11-16T17:24:36 prefetch.2.10.8: 1) Downloading 'SRR8728156'...
# 2020-11-16T17:24:36 prefetch.2.10.8:  Downloading via HTTPS...
# 2020-11-16T17:25:14 prefetch.2.10.8:  HTTPS download succeed
# 2020-11-16T17:25:18 prefetch.2.10.8:  'SRR8728156' is valid
# 2020-11-16T17:25:18 prefetch.2.10.8: 1) 'SRR8728156' was downloaded successfully
# 2020-11-16T17:25:18 prefetch.2.10.8: 'SRR8728156' has 0 unresolved dependencies
# Read 26697640 spots for SRR8728156/SRR8728156.sra
# Written 26697640 spots for SRR8728156/SRR8728156.sra

# %%
# Define fastq list to feed kb

fastqs = []
for sra in SRAs:
  for read in SRAs_to_keep:
    fastqs.append(sra + "_" + read + ".fastq.gz")

# %% [markdown]
# ## Metadata

# %%
# define the values for the analysis

# accession id for the data
id = "GSE128066"

samp_id = ["GSM3667327"]

no_samples = 1

fastqs_per_sample = [8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["skin"] * no_samples

cell_type = ["skin cells"] * no_samples

condition = ["healthy donor"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Downloads: index

# %%
# Download the corresponding Kallisto index to fastq folder
# !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2020-11-16 18:22:14,122]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# [2020-11-16 18:23:31,741]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['SRR8728153_1.fastq.gz',
#  'SRR8728153_2.fastq.gz',
#  'SRR8728154_1.fastq.gz',
#  'SRR8728154_2.fastq.gz',
#  'SRR8728155_1.fastq.gz',
#  'SRR8728155_2.fastq.gz',
#  'SRR8728156_1.fastq.gz',
#  'SRR8728156_2.fastq.gz']

# %%
# Specify the sample number 


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-11-16 18:30:37,559]    INFO Generating BUS file from
# [2020-11-16 18:30:37,559]    INFO         SRR8728153_1.fastq.gz
# [2020-11-16 18:30:37,559]    INFO         SRR8728153_2.fastq.gz
# [2020-11-16 18:30:37,559]    INFO         SRR8728154_1.fastq.gz
# [2020-11-16 18:30:37,559]    INFO         SRR8728154_2.fastq.gz
# [2020-11-16 18:30:37,559]    INFO         SRR8728155_1.fastq.gz
# [2020-11-16 18:30:37,559]    INFO         SRR8728155_2.fastq.gz
# [2020-11-16 18:30:37,559]    INFO         SRR8728156_1.fastq.gz
# [2020-11-16 18:30:37,559]    INFO         SRR8728156_2.fastq.gz
# [2020-11-16 18:51:25,336]    INFO Sorting BUS file outputGSM3667327/output.bus to tmp/output.s.bus
# [2020-11-16 18:52:31,340]    INFO Whitelist not provided
# [2020-11-16 18:52:31,340]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM3667327
# [2020-11-16 18:52:36,229]    INFO Inspecting BUS file tmp/output.s.bus
# [2020-11-16 18:52:47,033]    INFO Correcting BUS records in tmp/output.s.bus to tmp/output.s.c.bus with whitelist outputGSM3667327/10xv2_whitelist.txt
# [2020-11-16 18:53:13,966]    INFO Sorting BUS file tmp/output.s.c.bus to outputGSM3667327/output.unfiltered.bus
# [2020-11-16 18:53:36,432]    INFO Generating count matrix outputGSM3667327/counts_unfiltered/cells_x_genes from BUS file outputGSM3667327/output.unfiltered.bus
# [2020-11-16 18:53:45,815]    INFO Converting matrix outputGSM3667327/counts_unfiltered/cells_x_genes.mtx to h5ad outputGSM3667327/counts_unfiltered/adata.h5ad
# [2020-11-16 18:53:55,907]    INFO Filtering with bustools
# [2020-11-16 18:53:55,908]    INFO Generating whitelist outputGSM3667327/filter_barcodes.txt from BUS file outputGSM3667327/output.unfiltered.bus
# [2020-11-16 18:53:56,196]    INFO Capturing records from BUS file outputGSM3667327/output.unfiltered.bus to tmp/output.filtered.bus with capture list outputGSM3667327/filter_barcodes.txt
# [2020-11-16 18:53:59,396]    INFO Sorting BUS file tmp/output.filtered.bus to outputGSM3667327/output.filtered.bus
# [2020-11-16 18:54:12,193]    INFO Generating count matrix outputGSM3667327/counts_filtered/cells_x_genes from BUS file outputGSM3667327/output.filtered.bus
# [2020-11-16 18:54:22,875]    INFO Converting matrix outputGSM3667327/counts_filtered/cells_x_genes.mtx to h5ad outputGSM3667327/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM3667327 contains 294657 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 2500#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 30#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 2500 with at least 409.0 UMIs
# We select 30 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 294,657 cells x 60,623 genes
#     New shape: 2,125 cells x 25,733 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical
