# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/tcc/PRJCA002413_CRX102286_from_gc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRJCA002413_CRX102286

# %% [markdown]
# This notebook uses the filtered count matrix resulting from the following google colab notebook. https://github.com/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/PRJCA002413_CRX102286.ipynb Please run the notebook above and upload the results file in /content

# %%
# define the values for the analysis

# accession id for the data
id = "PRJCA002413"
samp_id = ["CRX102286"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet
  links_raw = "ftp://download.big.ac.cn/gsa3/CRA002497/CRR126575/CRR126575_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126575/CRR126575_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126577/CRR126577_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126577/CRR126577_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126578/CRR126578_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126578/CRR126578_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126579/CRR126579_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126579/CRR126579_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126580/CRR126580_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126580/CRR126580_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126581/CRR126581_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126581/CRR126581_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126582/CRR126582_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126582/CRR126582_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126583/CRR126583_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126583/CRR126583_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126584/CRR126584_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126584/CRR126584_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126585/CRR126585_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126585/CRR126585_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126586/CRR126586_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR126586/CRR126586_r2.fastq.gz"
  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

#sample specific metadata

no_samples = 1

condition = ["covid infected, early recovery stage"] * no_samples

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["blood"] * no_samples

cell_type = ["PBMCs"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Wen et al 2020"] * no_samples

figure = ["Fig: all"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 127kB/s
#      |████████████████████████████████| 51kB 4.9MB/s
#      |████████████████████████████████| 10.3MB 32.2MB/s
#      |████████████████████████████████| 13.2MB 34.4MB/s
#      |████████████████████████████████| 133kB 56.8MB/s
#      |████████████████████████████████| 112kB 55.3MB/s
#      |████████████████████████████████| 81kB 7.3MB/s
#      |████████████████████████████████| 1.2MB 29.5MB/s
#      |████████████████████████████████| 71kB 7.9MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  while len(os.listdir()) != len(fastqs):
    for link in fastqs:
      # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2021-05-24 17:26:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126575/CRR126575_f1.fastq.gz
#            => ‘CRR126575_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126575 ... done.
# ==> SIZE CRR126575_f1.fastq.gz ... 1892258751
# ==> PASV ... done.    ==> RETR CRR126575_f1.fastq.gz ... done.
# Length: 1892258751 (1.8G) (unauthoritative)
#
# CRR126575_f1.fastq. 100%[===================>]   1.76G  5.40MB/s    in 4m 59s
#
# 2021-05-24 17:31:13 (6.04 MB/s) - ‘CRR126575_f1.fastq.gz’ saved [1892258751]
#
# --2021-05-24 17:31:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126575/CRR126575_r2.fastq.gz
#            => ‘CRR126575_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126575 ... done.
# ==> SIZE CRR126575_r2.fastq.gz ... 6846659768
# ==> PASV ... done.    ==> RETR CRR126575_r2.fastq.gz ... done.
# Length: 6846659768 (6.4G) (unauthoritative)
#
# CRR126575_r2.fastq. 100%[===================>]   6.38G  7.55MB/s    in 23m 14s
#
# 2021-05-24 17:54:31 (4.68 MB/s) - Control connection closed.
# Retrying.
#
# --2021-05-24 18:09:32--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126575/CRR126575_r2.fastq.gz
#   (try: 2) => ‘CRR126575_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126575 ... done.
# ==> SIZE CRR126575_r2.fastq.gz ... 6846659768
# File has already been retrieved.
# 2021-05-24 18:09:34 (0.00 B/s) - ‘CRR126575_r2.fastq.gz’ saved [6846659768]
#
# --2021-05-24 18:09:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_f1.fastq.gz
#            => ‘CRR126576_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126576 ... done.
# ==> SIZE CRR126576_f1.fastq.gz ... 3156812188
# ==> PASV ... done.    ==> RETR CRR126576_f1.fastq.gz ... done.
# Length: 3156812188 (2.9G) (unauthoritative)
#
# CRR126576_f1.fastq. 100%[===================>]   2.94G  3.90MB/s    in 12m 5s
#
# 2021-05-24 18:21:43 (4.15 MB/s) - Control connection closed.
# Retrying.
#
# --2021-05-24 18:36:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_f1.fastq.gz
#   (try: 2) => ‘CRR126576_f1.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126576 ... done.
# ==> SIZE CRR126576_f1.fastq.gz ... 3156812188
# File has already been retrieved.
# 2021-05-24 18:36:46 (0.00 B/s) - ‘CRR126576_f1.fastq.gz’ saved [3156812188]
#
# --2021-05-24 18:36:46--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_r2.fastq.gz
#            => ‘CRR126576_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... failed: Temporary failure in name resolution.
# wget: unable to resolve host address ‘download.big.ac.cn’
# --2021-05-24 18:36:56--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126577/CRR126577_f1.fastq.gz
#            => ‘CRR126577_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... failed: Temporary failure in name resolution.
# wget: unable to resolve host address ‘download.big.ac.cn’
# --2021-05-24 18:37:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126577/CRR126577_r2.fastq.gz
#            => ‘CRR126577_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126577 ... done.
# ==> SIZE CRR126577_r2.fastq.gz ... 10556936767
# ==> PASV ... done.    ==> RETR CRR126577_r2.fastq.gz ... done.
# Length: 10556936767 (9.8G) (unauthoritative)
#
# CRR126577_r2.fastq. 100%[===================>]   9.83G  4.01MB/s    in 36m 39s
#
# 2021-05-24 19:14:09 (4.58 MB/s) - Control connection closed.
# Retrying.
#
# --2021-05-24 19:29:10--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126577/CRR126577_r2.fastq.gz
#   (try: 2) => ‘CRR126577_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126577 ... done.
# ==> SIZE CRR126577_r2.fastq.gz ... 10556936767
# File has already been retrieved.
# 2021-05-24 19:29:12 (0.00 B/s) - ‘CRR126577_r2.fastq.gz’ saved [10556936767]
#
# --2021-05-24 19:29:12--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126578/CRR126578_f1.fastq.gz
#            => ‘CRR126578_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126578 ... done.
# ==> SIZE CRR126578_f1.fastq.gz ... 2823408924
# ==> PASV ... done.    ==> RETR CRR126578_f1.fastq.gz ... done.
# Length: 2823408924 (2.6G) (unauthoritative)
#
# CRR126578_f1.fastq. 100%[===================>]   2.63G  2.60MB/s    in 9m 18s
#
# 2021-05-24 19:38:33 (4.83 MB/s) - ‘CRR126578_f1.fastq.gz’ saved [2823408924]
#
# --2021-05-24 19:38:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126578/CRR126578_r2.fastq.gz
#            => ‘CRR126578_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126578 ... done.
# ==> SIZE CRR126578_r2.fastq.gz ... 10256622814
# ==> PASV ... done.    ==> RETR CRR126578_r2.fastq.gz ... done.
# Length: 10256622814 (9.6G) (unauthoritative)
#
# CRR126578_r2.fastq. 100%[===================>]   9.55G  8.51MB/s    in 31m 11s
#
# 2021-05-24 20:09:48 (5.23 MB/s) - Control connection closed.
# Retrying.
#
# --2021-05-24 20:24:49--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126578/CRR126578_r2.fastq.gz
#   (try: 2) => ‘CRR126578_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126578 ... done.
# ==> SIZE CRR126578_r2.fastq.gz ... 10256622814
# File has already been retrieved.
# 2021-05-24 20:24:51 (0.00 B/s) - ‘CRR126578_r2.fastq.gz’ saved [10256622814]
#
# --2021-05-24 20:24:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126579/CRR126579_f1.fastq.gz
#            => ‘CRR126579_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126579 ... done.
# ==> SIZE CRR126579_f1.fastq.gz ... 1246276998
# ==> PASV ... done.    ==> RETR CRR126579_f1.fastq.gz ... done.
# Length: 1246276998 (1.2G) (unauthoritative)
#
# CRR126579_f1.fastq. 100%[===================>]   1.16G  4.62MB/s    in 3m 31s
#
# 2021-05-24 20:28:26 (5.63 MB/s) - ‘CRR126579_f1.fastq.gz’ saved [1246276998]
#
# --2021-05-24 20:28:26--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126579/CRR126579_r2.fastq.gz
#            => ‘CRR126579_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126579 ... done.
# ==> SIZE CRR126579_r2.fastq.gz ... 1260238859
# ==> PASV ... done.    ==> RETR CRR126579_r2.fastq.gz ... done.
# Length: 1260238859 (1.2G) (unauthoritative)
#
# CRR126579_r2.fastq. 100%[===================>]   1.17G  6.56MB/s    in 3m 6s
#
# 2021-05-24 20:31:37 (6.47 MB/s) - ‘CRR126579_r2.fastq.gz’ saved [1260238859]
#
# --2021-05-24 20:31:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126580/CRR126580_f1.fastq.gz
#            => ‘CRR126580_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126580 ... done.
# ==> SIZE CRR126580_f1.fastq.gz ... 1171419953
# ==> PASV ... done.    ==> RETR CRR126580_f1.fastq.gz ... done.
# Length: 1171419953 (1.1G) (unauthoritative)
#
# CRR126580_f1.fastq. 100%[===================>]   1.09G  5.79MB/s    in 3m 21s
#
# 2021-05-24 20:35:01 (5.57 MB/s) - ‘CRR126580_f1.fastq.gz’ saved [1171419953]
#
# --2021-05-24 20:35:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126580/CRR126580_r2.fastq.gz
#            => ‘CRR126580_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126580 ... done.
# ==> SIZE CRR126580_r2.fastq.gz ... 1186116427
# ==> PASV ... done.    ==> RETR CRR126580_r2.fastq.gz ... done.
# Length: 1186116427 (1.1G) (unauthoritative)
#
# CRR126580_r2.fastq. 100%[===================>]   1.10G  3.07MB/s    in 3m 35s
#
# 2021-05-24 20:38:39 (5.27 MB/s) - ‘CRR126580_r2.fastq.gz’ saved [1186116427]
#
# --2021-05-24 20:38:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126581/CRR126581_f1.fastq.gz
#            => ‘CRR126581_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126581 ... done.
# ==> SIZE CRR126581_f1.fastq.gz ... 1979261724
# ==> PASV ... done.    ==> RETR CRR126581_f1.fastq.gz ... done.
# Length: 1979261724 (1.8G) (unauthoritative)
#
# CRR126581_f1.fastq. 100%[===================>]   1.84G  4.34MB/s    in 5m 48s
#
# 2021-05-24 20:44:31 (5.43 MB/s) - ‘CRR126581_f1.fastq.gz’ saved [1979261724]
#
# --2021-05-24 20:44:31--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126581/CRR126581_r2.fastq.gz
#            => ‘CRR126581_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126581 ... done.
# ==> SIZE CRR126581_r2.fastq.gz ... 1986633122
# ==> PASV ... done.    ==> RETR CRR126581_r2.fastq.gz ... done.
# Length: 1986633122 (1.8G) (unauthoritative)
#
# CRR126581_r2.fastq. 100%[===================>]   1.85G  5.82MB/s    in 5m 39s
#
# 2021-05-24 20:50:13 (5.59 MB/s) - ‘CRR126581_r2.fastq.gz’ saved [1986633122]
#
# --2021-05-24 20:50:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126582/CRR126582_f1.fastq.gz
#            => ‘CRR126582_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126582 ... done.
# ==> SIZE CRR126582_f1.fastq.gz ... 1727291379
# ==> PASV ... done.    ==> RETR CRR126582_f1.fastq.gz ... done.
# Length: 1727291379 (1.6G) (unauthoritative)
#
# CRR126582_f1.fastq. 100%[===================>]   1.61G  2.64MB/s    in 4m 54s
#
# 2021-05-24 20:55:11 (5.60 MB/s) - ‘CRR126582_f1.fastq.gz’ saved [1727291379]
#
# --2021-05-24 20:55:11--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126582/CRR126582_r2.fastq.gz
#            => ‘CRR126582_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126582 ... done.
# ==> SIZE CRR126582_r2.fastq.gz ... 1717260989
# ==> PASV ... done.    ==> RETR CRR126582_r2.fastq.gz ... done.
# Length: 1717260989 (1.6G) (unauthoritative)
#
# CRR126582_r2.fastq. 100%[===================>]   1.60G  5.36MB/s    in 6m 8s
#
# 2021-05-24 21:01:22 (4.46 MB/s) - ‘CRR126582_r2.fastq.gz’ saved [1717260989]
#
# --2021-05-24 21:01:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126583/CRR126583_f1.fastq.gz
#            => ‘CRR126583_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126583 ... done.
# ==> SIZE CRR126583_f1.fastq.gz ... 2253173116
# ==> PASV ... done.    ==> RETR CRR126583_f1.fastq.gz ... done.
# Length: 2253173116 (2.1G) (unauthoritative)
#
# CRR126583_f1.fastq. 100%[===================>]   2.10G  5.56MB/s    in 6m 18s
#
# 2021-05-24 21:07:44 (5.68 MB/s) - ‘CRR126583_f1.fastq.gz’ saved [2253173116]
#
# --2021-05-24 21:07:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126583/CRR126583_r2.fastq.gz
#            => ‘CRR126583_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126583 ... done.
# ==> SIZE CRR126583_r2.fastq.gz ... 2374983039
# ==> PASV ... done.    ==> RETR CRR126583_r2.fastq.gz ... done.
# Length: 2374983039 (2.2G) (unauthoritative)
#
# CRR126583_r2.fastq. 100%[===================>]   2.21G  7.14MB/s    in 7m 15s
#
# 2021-05-24 21:15:03 (5.20 MB/s) - ‘CRR126583_r2.fastq.gz’ saved [2374983039]
#
# --2021-05-24 21:15:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126584/CRR126584_f1.fastq.gz
#            => ‘CRR126584_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126584 ... done.
# ==> SIZE CRR126584_f1.fastq.gz ... 1337836797
# ==> PASV ... done.    ==> RETR CRR126584_f1.fastq.gz ... done.
# Length: 1337836797 (1.2G) (unauthoritative)
#
# CRR126584_f1.fastq. 100%[===================>]   1.25G  6.47MB/s    in 3m 40s
#
# 2021-05-24 21:18:46 (5.81 MB/s) - ‘CRR126584_f1.fastq.gz’ saved [1337836797]
#
# --2021-05-24 21:18:46--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126584/CRR126584_r2.fastq.gz
#            => ‘CRR126584_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126584 ... done.
# ==> SIZE CRR126584_r2.fastq.gz ... 1414814279
# ==> PASV ... done.    ==> RETR CRR126584_r2.fastq.gz ... done.
# Length: 1414814279 (1.3G) (unauthoritative)
#
# CRR126584_r2.fastq. 100%[===================>]   1.32G  5.91MB/s    in 4m 37s
#
# 2021-05-24 21:23:27 (4.87 MB/s) - ‘CRR126584_r2.fastq.gz’ saved [1414814279]
#
# --2021-05-24 21:23:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126585/CRR126585_f1.fastq.gz
#            => ‘CRR126585_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126585 ... done.
# ==> SIZE CRR126585_f1.fastq.gz ... 1461231177
# ==> PASV ... done.    ==> RETR CRR126585_f1.fastq.gz ... done.
# Length: 1461231177 (1.4G) (unauthoritative)
#
# CRR126585_f1.fastq. 100%[===================>]   1.36G  4.16MB/s    in 5m 33s
#
# 2021-05-24 21:29:05 (4.18 MB/s) - ‘CRR126585_f1.fastq.gz’ saved [1461231177]
#
# --2021-05-24 21:29:05--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126585/CRR126585_r2.fastq.gz
#            => ‘CRR126585_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126585 ... done.
# ==> SIZE CRR126585_r2.fastq.gz ... 1552759318
# ==> PASV ... done.    ==> RETR CRR126585_r2.fastq.gz ... done.
# Length: 1552759318 (1.4G) (unauthoritative)
#
# CRR126585_r2.fastq. 100%[===================>]   1.45G  4.68MB/s    in 5m 17s
#
# 2021-05-24 21:34:26 (4.67 MB/s) - ‘CRR126585_r2.fastq.gz’ saved [1552759318]
#
# --2021-05-24 21:34:26--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126586/CRR126586_f1.fastq.gz
#            => ‘CRR126586_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126586 ... done.
# ==> SIZE CRR126586_f1.fastq.gz ... 1345898626
# ==> PASV ... done.    ==> RETR CRR126586_f1.fastq.gz ... done.
# Length: 1345898626 (1.3G) (unauthoritative)
#
# CRR126586_f1.fastq. 100%[===================>]   1.25G  5.08MB/s    in 4m 14s
#
# 2021-05-24 21:38:43 (5.06 MB/s) - ‘CRR126586_f1.fastq.gz’ saved [1345898626]
#
# --2021-05-24 21:38:43--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126586/CRR126586_r2.fastq.gz
#            => ‘CRR126586_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126586 ... done.
# ==> SIZE CRR126586_r2.fastq.gz ... 1416677199
# ==> PASV ... done.    ==> RETR CRR126586_r2.fastq.gz ... done.
# Length: 1416677199 (1.3G) (unauthoritative)
#
# CRR126586_r2.fastq. 100%[===================>]   1.32G  2.95MB/s    in 5m 46s
#
# 2021-05-24 21:44:32 (3.91 MB/s) - ‘CRR126586_r2.fastq.gz’ saved [1416677199]
#
# --2021-05-24 21:44:32--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126575/CRR126575_f1.fastq.gz
#            => ‘CRR126575_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126575 ... done.
# ==> SIZE CRR126575_f1.fastq.gz ... 1892258751
# File has already been retrieved.
# 2021-05-24 21:44:35 (0.00 B/s) - ‘CRR126575_f1.fastq.gz’ saved [1892258751]
#
# --2021-05-24 21:44:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126575/CRR126575_r2.fastq.gz
#            => ‘CRR126575_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126575 ... done.
# ==> SIZE CRR126575_r2.fastq.gz ... 6846659768
# File has already been retrieved.
# 2021-05-24 21:44:37 (0.00 B/s) - ‘CRR126575_r2.fastq.gz’ saved [6846659768]
#
# --2021-05-24 21:44:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_f1.fastq.gz
#            => ‘CRR126576_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126576 ... done.
# ==> SIZE CRR126576_f1.fastq.gz ... 3156812188
# File has already been retrieved.
# 2021-05-24 21:44:39 (0.00 B/s) - ‘CRR126576_f1.fastq.gz’ saved [3156812188]
#
# --2021-05-24 21:44:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_r2.fastq.gz
#            => ‘CRR126576_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126576 ... done.
# ==> SIZE CRR126576_r2.fastq.gz ... 11470801231
# ==> PASV ... done.    ==> RETR CRR126576_r2.fastq.gz ... done.
# Length: 11470801231 (11G) (unauthoritative)
#
# CRR126576_r2.fastq. 100%[===================>]  10.68G  2.35MB/s    in 41m 49s
#
# 2021-05-24 22:26:32 (4.36 MB/s) - Control connection closed.
# Retrying.
#
# --2021-05-24 22:41:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126576/CRR126576_r2.fastq.gz
#   (try: 2) => ‘CRR126576_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126576 ... done.
# ==> SIZE CRR126576_r2.fastq.gz ... 11470801231
# File has already been retrieved.
# 2021-05-24 22:41:35 (0.00 B/s) - ‘CRR126576_r2.fastq.gz’ saved [11470801231]
#
# --2021-05-24 22:41:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126577/CRR126577_f1.fastq.gz
#            => ‘CRR126577_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126577 ... done.
# ==> SIZE CRR126577_f1.fastq.gz ... 2845593147
# ==> PASV ... done.    ==> RETR CRR126577_f1.fastq.gz ... done.
# Length: 2845593147 (2.6G) (unauthoritative)
#
# CRR126577_f1.fastq. 100%[===================>]   2.65G  6.60MB/s    in 8m 16s
#
# 2021-05-24 22:49:56 (5.47 MB/s) - ‘CRR126577_f1.fastq.gz’ saved [2845593147]
#
# --2021-05-24 22:49:56--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126577/CRR126577_r2.fastq.gz
#            => ‘CRR126577_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126577 ... done.
# ==> SIZE CRR126577_r2.fastq.gz ... 10556936767
# File has already been retrieved.
# 2021-05-24 22:49:58 (0.00 B/s) - ‘CRR126577_r2.fastq.gz’ saved [10556936767]
#
# --2021-05-24 22:49:59--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126578/CRR126578_f1.fastq.gz
#            => ‘CRR126578_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126578 ... done.
# ==> SIZE CRR126578_f1.fastq.gz ... 2823408924
# File has already been retrieved.
# 2021-05-24 22:50:01 (0.00 B/s) - ‘CRR126578_f1.fastq.gz’ saved [2823408924]
#
# --2021-05-24 22:50:01--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126578/CRR126578_r2.fastq.gz
#            => ‘CRR126578_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126578 ... done.
# ==> SIZE CRR126578_r2.fastq.gz ... 10256622814
# File has already been retrieved.
# 2021-05-24 22:50:03 (0.00 B/s) - ‘CRR126578_r2.fastq.gz’ saved [10256622814]
#
# --2021-05-24 22:50:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126579/CRR126579_f1.fastq.gz
#            => ‘CRR126579_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126579 ... done.
# ==> SIZE CRR126579_f1.fastq.gz ... 1246276998
# File has already been retrieved.
# 2021-05-24 22:50:06 (0.00 B/s) - ‘CRR126579_f1.fastq.gz’ saved [1246276998]
#
# --2021-05-24 22:50:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126579/CRR126579_r2.fastq.gz
#            => ‘CRR126579_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126579 ... done.
# ==> SIZE CRR126579_r2.fastq.gz ... 1260238859
# File has already been retrieved.
# 2021-05-24 22:50:08 (0.00 B/s) - ‘CRR126579_r2.fastq.gz’ saved [1260238859]
#
# --2021-05-24 22:50:08--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126580/CRR126580_f1.fastq.gz
#            => ‘CRR126580_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126580 ... done.
# ==> SIZE CRR126580_f1.fastq.gz ... 1171419953
# File has already been retrieved.
# 2021-05-24 22:50:10 (0.00 B/s) - ‘CRR126580_f1.fastq.gz’ saved [1171419953]
#
# --2021-05-24 22:50:10--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126580/CRR126580_r2.fastq.gz
#            => ‘CRR126580_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126580 ... done.
# ==> SIZE CRR126580_r2.fastq.gz ... 1186116427
# File has already been retrieved.
# 2021-05-24 22:50:13 (0.00 B/s) - ‘CRR126580_r2.fastq.gz’ saved [1186116427]
#
# --2021-05-24 22:50:13--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126581/CRR126581_f1.fastq.gz
#            => ‘CRR126581_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126581 ... done.
# ==> SIZE CRR126581_f1.fastq.gz ... 1979261724
# File has already been retrieved.
# 2021-05-24 22:50:15 (0.00 B/s) - ‘CRR126581_f1.fastq.gz’ saved [1979261724]
#
# --2021-05-24 22:50:15--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126581/CRR126581_r2.fastq.gz
#            => ‘CRR126581_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126581 ... done.
# ==> SIZE CRR126581_r2.fastq.gz ... 1986633122
# File has already been retrieved.
# 2021-05-24 22:50:18 (0.00 B/s) - ‘CRR126581_r2.fastq.gz’ saved [1986633122]
#
# --2021-05-24 22:50:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126582/CRR126582_f1.fastq.gz
#            => ‘CRR126582_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126582 ... done.
# ==> SIZE CRR126582_f1.fastq.gz ... 1727291379
# File has already been retrieved.
# 2021-05-24 22:50:20 (0.00 B/s) - ‘CRR126582_f1.fastq.gz’ saved [1727291379]
#
# --2021-05-24 22:50:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126582/CRR126582_r2.fastq.gz
#            => ‘CRR126582_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126582 ... done.
# ==> SIZE CRR126582_r2.fastq.gz ... 1717260989
# File has already been retrieved.
# 2021-05-24 22:50:22 (0.00 B/s) - ‘CRR126582_r2.fastq.gz’ saved [1717260989]
#
# --2021-05-24 22:50:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126583/CRR126583_f1.fastq.gz
#            => ‘CRR126583_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126583 ... done.
# ==> SIZE CRR126583_f1.fastq.gz ... 2253173116
# File has already been retrieved.
# 2021-05-24 22:50:24 (0.00 B/s) - ‘CRR126583_f1.fastq.gz’ saved [2253173116]
#
# --2021-05-24 22:50:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126583/CRR126583_r2.fastq.gz
#            => ‘CRR126583_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126583 ... done.
# ==> SIZE CRR126583_r2.fastq.gz ... 2374983039
# File has already been retrieved.
# 2021-05-24 22:50:27 (0.00 B/s) - ‘CRR126583_r2.fastq.gz’ saved [2374983039]
#
# --2021-05-24 22:50:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126584/CRR126584_f1.fastq.gz
#            => ‘CRR126584_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126584 ... done.
# ==> SIZE CRR126584_f1.fastq.gz ... 1337836797
# File has already been retrieved.
# 2021-05-24 22:50:30 (0.00 B/s) - ‘CRR126584_f1.fastq.gz’ saved [1337836797]
#
# --2021-05-24 22:50:30--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126584/CRR126584_r2.fastq.gz
#            => ‘CRR126584_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126584 ... done.
# ==> SIZE CRR126584_r2.fastq.gz ... 1414814279
# File has already been retrieved.
# 2021-05-24 22:50:33 (0.00 B/s) - ‘CRR126584_r2.fastq.gz’ saved [1414814279]
#
# --2021-05-24 22:50:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126585/CRR126585_f1.fastq.gz
#            => ‘CRR126585_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126585 ... done.
# ==> SIZE CRR126585_f1.fastq.gz ... 1461231177
# File has already been retrieved.
# 2021-05-24 22:50:35 (0.00 B/s) - ‘CRR126585_f1.fastq.gz’ saved [1461231177]
#
# --2021-05-24 22:50:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126585/CRR126585_r2.fastq.gz
#            => ‘CRR126585_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126585 ... done.
# ==> SIZE CRR126585_r2.fastq.gz ... 1552759318
# File has already been retrieved.
# 2021-05-24 22:50:37 (0.00 B/s) - ‘CRR126585_r2.fastq.gz’ saved [1552759318]
#
# --2021-05-24 22:50:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126586/CRR126586_f1.fastq.gz
#            => ‘CRR126586_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126586 ... done.
# ==> SIZE CRR126586_f1.fastq.gz ... 1345898626
# File has already been retrieved.
# 2021-05-24 22:50:40 (0.00 B/s) - ‘CRR126586_f1.fastq.gz’ saved [1345898626]
#
# --2021-05-24 22:50:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR126586/CRR126586_r2.fastq.gz
#            => ‘CRR126586_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR126586 ... done.
# ==> SIZE CRR126586_r2.fastq.gz ... 1416677199
# File has already been retrieved.
# 2021-05-24 22:50:42 (0.00 B/s) - ‘CRR126586_r2.fastq.gz’ saved [1416677199]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2021-05-24 22:50:45,708]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:34<00:00, 25.4MB/s]
# [2021-05-24 22:52:21,932]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['CRR126575_f1.fastq.gz', 'CRR126575_r2.fastq.gz', 'CRR126576_f1.fastq.gz', 'CRR126576_r2.fastq.gz', 'CRR126577_f1.fastq.gz', 'CRR126577_r2.fastq.gz', 'CRR126578_f1.fastq.gz', 'CRR126578_r2.fastq.gz', 'CRR126579_f1.fastq.gz', 'CRR126579_r2.fastq.gz', 'CRR126580_f1.fastq.gz', 'CRR126580_r2.fastq.gz', 'CRR126581_f1.fastq.gz', 'CRR126581_r2.fastq.gz', 'CRR126582_f1.fastq.gz', 'CRR126582_r2.fastq.gz', 'CRR126583_f1.fastq.gz', 'CRR126583_r2.fastq.gz', 'CRR126584_f1.fastq.gz', 'CRR126584_r2.fastq.gz', 'CRR126585_f1.fastq.gz', 'CRR126585_r2.fastq.gz', 'CRR126586_f1.fastq.gz', 'CRR126586_r2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['CRR126575_f1.fastq.gz',
#  'CRR126575_r2.fastq.gz',
#  'CRR126576_f1.fastq.gz',
#  'CRR126576_r2.fastq.gz',
#  'CRR126577_f1.fastq.gz',
#  'CRR126577_r2.fastq.gz',
#  'CRR126578_f1.fastq.gz',
#  'CRR126578_r2.fastq.gz',
#  'CRR126579_f1.fastq.gz',
#  'CRR126579_r2.fastq.gz',
#  'CRR126580_f1.fastq.gz',
#  'CRR126580_r2.fastq.gz',
#  'CRR126581_f1.fastq.gz',
#  'CRR126581_r2.fastq.gz',
#  'CRR126582_f1.fastq.gz',
#  'CRR126582_r2.fastq.gz',
#  'CRR126583_f1.fastq.gz',
#  'CRR126583_r2.fastq.gz',
#  'CRR126584_f1.fastq.gz',
#  'CRR126584_r2.fastq.gz',
#  'CRR126585_f1.fastq.gz',
#  'CRR126585_r2.fastq.gz',
#  'CRR126586_f1.fastq.gz',
#  'CRR126586_r2.fastq.gz']

# %%
if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[0] + " "\
  + "--filter bustools --tcc -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[i] + " \
    --filter bustools --tcc -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]






results = {}
tcc_results = {}
for sample in sample_id:
  # Read the filtered gene count matrix
  results["data_" + sample] = anndata.read("/content/result" + sample)


for sample in sample_id:
  output = "bus_raw_" + sample + "_from_gc"
  # !mkdir $output
  folder_tcc = "tccoutput" + sample

  # read tcc matrix
  tcc_results[sample] = anndata.read(folder_tcc + "/counts_unfiltered/adata.h5ad")
  # apply gene count matrix's filter
  tcc_results[sample] = tcc_results[sample][results["data_" + sample].obs.index.values]
  # transfer obs data
  tcc_results[sample].obs = results["data_" + sample].obs
  # transfer metadata
  tcc_results[sample].uns = results["data_" + sample].uns
  # write tcc matrix
  tcc_results[sample].write("/content/tcc_" + sample)
  #gzip tcc matrix
  cmd = "gzip /content/tcc_" + sample
  # !$cmd
  #gzip unfiltered bus file
  cmd = "gzip " + folder_tcc + "/output.unfiltered.bus"
  # !$cmd
  # move and re-name bus file with sample id
  cmd = "mv " + folder_tcc + "/output.unfiltered.bus.gz " + output + "/" + sample +".unfiltered.bus.gz"
  # !$cmd
  # gzip all unfiltered counts
  cmd = "gzip " + folder_tcc + "/counts_unfiltered/*"
  # !$cmd

  # move unfiltered counts for both
  cmd = "mv " + folder_tcc + "/counts_unfiltered " + output + "/tcc_unfiltered"
  # !$cmd

  cmd = "mv " + folder_tcc + "/*.json " + output 
  # !$cmd
  # zip all files
  cmd = "zip -r "+ output + ".zip " + output
  # !$cmd


import time
time.sleep(60000000)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   adding: bus_raw_CRX102286_from_gc/ (stored 0%)
#   adding: bus_raw_CRX102286_from_gc/tcc_unfiltered/ (stored 0%)
#   adding: bus_raw_CRX102286_from_gc/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_CRX102286_from_gc/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 2%)
#   adding: bus_raw_CRX102286_from_gc/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: bus_raw_CRX102286_from_gc/tcc_unfiltered/adata.h5ad.gz (deflated 6%)
#   adding: bus_raw_CRX102286_from_gc/CRX102286.unfiltered.bus.gz (deflated 4%)
#   adding: bus_raw_CRX102286_from_gc/kb_info.json (deflated 79%)
#   adding: bus_raw_CRX102286_from_gc/inspect.json (deflated 57%)
#   adding: bus_raw_CRX102286_from_gc/run_info.json (deflated 64%)
