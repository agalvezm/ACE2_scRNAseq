# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/tcc/GSE124263_GSM3526583.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE124263_GSM3526583

# %%
# define the values for the analysis

# accession id for the data
id = "GSE124263"
samp_id = ["GSM3526583"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = True


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet

  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363196/SRR8363196_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363196/SRR8363196_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363197/SRR8363197_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363197/SRR8363197_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363198/SRR8363198_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363198/SRR8363198_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363199/SRR8363199_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363199/SRR8363199_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363200/SRR8363200_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363200/SRR8363200_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363201/SRR8363201_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363201/SRR8363201_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363202/SRR8363202_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363202/SRR8363202_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363203/SRR8363203_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363203/SRR8363203_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363204/SRR8363204_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363204/SRR8363204_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363205/SRR8363205_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363205/SRR8363205_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363206/SRR8363206_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363206/SRR8363206_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363207/SRR8363207_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363207/SRR8363207_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363208/SRR8363208_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363208/SRR8363208_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363209/SRR8363209_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363209/SRR8363209_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363210/SRR8363210_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363210/SRR8363210_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363211/SRR8363211_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363211/SRR8363211_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363212/SRR8363212_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363212/SRR8363212_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363213/SRR8363213_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363213/SRR8363213_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363214/SRR8363214_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363214/SRR8363214_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363215/SRR8363215_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363215/SRR8363215_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363216/SRR8363216_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363216/SRR8363216_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363217/SRR8363217_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363217/SRR8363217_2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["testis"] * no_samples

cell_type = ["ITGA6 positive"] * no_samples

condition = ["neonatal day 2 ITGA6 enriched"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 77kB/s
#      |████████████████████████████████| 51kB 6.4MB/s
#      |████████████████████████████████| 13.2MB 46.0MB/s
#      |████████████████████████████████| 10.3MB 38.6MB/s
#      |████████████████████████████████| 122kB 53.5MB/s
#      |████████████████████████████████| 112kB 42.5MB/s
#      |████████████████████████████████| 71kB 8.7MB/s
#      |████████████████████████████████| 51kB 7.0MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content
# [2021-03-01 18:24:08,356]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:42<00:00, 23.3MB/s]
# [2021-03-01 18:25:52,059]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363196/SRR8363196_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363196/SRR8363196_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363197/SRR8363197_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363197/SRR8363197_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363198/SRR8363198_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363198/SRR8363198_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363199/SRR8363199_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363199/SRR8363199_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363200/SRR8363200_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363200/SRR8363200_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363201/SRR8363201_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363201/SRR8363201_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363202/SRR8363202_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363202/SRR8363202_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363203/SRR8363203_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363203/SRR8363203_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363204/SRR8363204_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363204/SRR8363204_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363205/SRR8363205_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363205/SRR8363205_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363206/SRR8363206_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363206/SRR8363206_2.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363207/SRR8363207_1.fastq.gz', 'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836
ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363207/SRR8363207_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363208/SRR8363208_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/008/SRR8363208/SRR8363208_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363209/SRR8363209_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/009/SRR8363209/SRR8363209_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363210/SRR8363210_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/000/SRR8363210/SRR8363210_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363211/SRR8363211_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/001/SRR8363211/SRR8363211_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363212/SRR8363212_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/002/SRR8363212/SRR8363212_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363213/SRR8363213_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/003/SRR8363213/SRR8363213_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363214/SRR8363214_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363214/SRR8363214_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363215/SRR8363215_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363215/SRR8363215_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363216/SRR8363216_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363216/SRR8363216_2.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363217/SRR8363217_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/007/SRR8363217/SRR8363217_2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2021-03-01 18:26:30,633]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_1.fastq.gz to outputGSM3526583/tmp/SRR8363194_1.fastq.gz
# [2021-03-01 18:26:30,634]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_2.fastq.gz to outputGSM3526583/tmp/SRR8363194_2.fastq.gz
# [2021-03-01 18:26:30,635]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_1.fastq.gz to outputGSM3526583/tmp/SRR8363195_1.fastq.gz
# [2021-03-01 18:26:30,635]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_2.fastq.gz to outputGSM3526583/tmp/SRR8363195_2.fastq.gz
# [2021-03-01 18:26:30,636]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363196/SRR8363196_1.fastq.gz to outputGSM3526583/tmp/SRR8363196_1.fastq.gz
# [2021-03-01 18:26:30,636]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/006/SRR8363196/SRR8363196_2.fastq.gz to outputGSM3526583/tmp/SRR8363196_2.fastq.gz
# [2021-03-01 18:26:30,637]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363208_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363208_2.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363209_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363209_2.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363210_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363210_2.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363211_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363211_2.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363212_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363212_2.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363213_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363213_2.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363214_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363214_2.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363215_1.fastq.gz
# [2021-03-01 18:26:30,661]    INFO         outputGSM3526583/tmp/SRR8363215_2.fastq.gz
# [2021-03-01 18:26:30,662]    INFO         outputGSM3526583/tmp/SRR8363216_1.fastq.gz
# [2021-03-01 18:26:30,662]    INFO         outputGSM3526583/tmp/SRR8363216_2.fastq.gz
# [2021-03-01 18:26:30,662]    INFO         outputGSM3526583/tmp/SRR8363217_1.fastq.gz
# [2021-03-01 18:26:30,662]    INFO         outputGSM3526583/tmp/SRR8363217_2.fastq.gz
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 395680 out of 29860455 bytes>
#
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 648704 out of 184050516 bytes>
#
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 712416 out of 171637785 bytes>
#
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 648704 out of 504976753 bytes>
#
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-29:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 648704 out of 629095227 bytes>
#
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-37:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 680560 out of 142442978 bytes>
#
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 680560 out of 186631185 bytes>
#
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-46:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-48:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# [2021-03-01 18:33:32,646]    INFO Sorting BUS file outputGSM3526583/output.bus to outputGSM3526583/tmp/output.s.bus
# [2021-03-01 18:33:39,171]    INFO Whitelist not provided
# [2021-03-01 18:33:39,171]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM3526583
# [2021-03-01 18:33:39,288]    INFO Inspecting BUS file outputGSM3526583/tmp/output.s.bus
# [2021-03-01 18:33:43,990]    INFO Correcting BUS records in outputGSM3526583/tmp/output.s.bus to outputGSM3526583/tmp/output.s.c.bus with whitelist outputGSM3526583/10xv2_whitelist.txt
# [2021-03-01 18:33:47,128]    INFO Sorting BUS file outputGSM3526583/tmp/output.s.c.bus to outputGSM3526583/output.unfiltered.bus
# [2021-03-01 18:33:52,971]    INFO Generating count matrix outputGSM3526583/counts_unfiltered/cells_x_genes from BUS file outputGSM3526583/output.unfiltered.bus
# [2021-03-01 18:34:05,328]    INFO Reading matrix outputGSM3526583/counts_unfiltered/cells_x_genes.mtx
# [2021-03-01 18:34:12,410]    INFO Writing matrix to h5ad outputGSM3526583/counts_unfiltered/adata.h5ad
# [2021-03-01 18:34:13,119]    INFO Filtering with bustools
# [2021-03-01 18:34:13,119]    INFO Generating whitelist outputGSM3526583/filter_barcodes.txt from BUS file outputGSM3526583/output.unfiltered.bus
# [2021-03-01 18:34:13,180]    INFO Correcting BUS records in outputGSM3526583/output.unfiltered.bus to outputGSM3526583/tmp/output.unfiltered.c.bus with whitelist outputGSM3526583/filter_barcodes.txt
# [2021-03-01 18:34:15,461]    INFO Sorting BUS file outputGSM3526583/tmp/output.unfiltered.c.bus to outputGSM3526583/output.filtered.bus
# [2021-03-01 18:34:19,647]    INFO Generating count matrix outputGSM3526583/counts_filtered/cells_x_genes from BUS file outputGSM3526583/output.filtered.bus
# [2021-03-01 18:34:27,182]    INFO Reading matrix outputGSM3526583/counts_filtered/cells_x_genes.mtx
# [2021-03-01 18:34:30,748]    INFO Writing matrix to h5ad outputGSM3526583/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM3526583 contains 150526 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 7000#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 25#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 7000 with at least 160.0 UMIs
# We select 25 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# Current Shape: 150,526 cells x 60,623 genes
#     New shape: 3,698 cells x 23,698 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /content
# ... storing 'gene_name' as categorical

# %%
'''
Create TCC matrix
'''
if not bam:
  # %cd /content/fastqs

if bam:
  # %cd /content/fastqs/$_filename

if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[0] + " "\
  + "--filter bustools -t 2 --tcc --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[i] + " \
    --filter bustools -t 2 --tcc --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]


tcc_results = {}

for sample in sample_id:
  output = "bus_raw_" + sample
  # !mkdir $output
  folder_tcc = "tccoutput" + sample
  folder_gc = "output" + sample

  # read tcc matrix
  tcc_results[sample] = anndata.read(folder_tcc + "/counts_unfiltered/adata.h5ad")
  # apply gene count matrix's filter
  tcc_results[sample] = tcc_results[sample][results["data_" + sample_id[i]].obs.index.values]
  # transfer obs data
  tcc_results[sample].obs = results["data_" + sample].obs
  # transfer metadata
  tcc_results[sample].uns = results["data_" + sample].uns
  # write tcc matrix
  tcc_results[sample].write("/content/tcc_" + sample)
  #gzip tcc matrix
  cmd = "gzip /content/tcc_" + sample
  # !$cmd
  #gzip filtered bus file
  cmd = "gzip " + folder_tcc + "/output.filtered.bus"
  # !$cmd
  # move and re-name bus file with sample id
  cmd = "mv " + folder_tcc + "/output.filtered.bus.gz " + output + "/" + sample +".filtered.bus.gz"
  # !$cmd
  # gzip all unfiltered counts
  cmd = "gzip " + folder_tcc + "/counts_unfiltered/*"
  # !$cmd
  cmd = "gzip " + folder_gc + "/counts_unfiltered/*"
  # !$cmd
  # move unfiltered counts for both
  cmd = "mv " + folder_tcc + "/counts_unfiltered " + output + "/tcc_unfiltered"
  # !$cmd
  cmd = "mv " + folder_gc + "/counts_unfiltered " + output + "/gc_unfiltered"
  # !$cmd

  # zip all files
  cmd = "zip -r /content" + output + ".zip " + output
  # !$cmd
# Out:
# [Errno 2] No such file or directory: '/content/fastqs'
# /content
# [2021-03-01 18:34:35,454]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_1.fastq.gz to tccoutputGSM3526583/tmp/SRR8363194_1.fastq.gz
# [2021-03-01 18:34:35,456]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/004/SRR8363194/SRR8363194_2.fastq.gz to tccoutputGSM3526583/tmp/SRR8363194_2.fastq.gz
# [2021-03-01 18:34:35,457]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_1.fastq.gz to tccoutputGSM3526583/tmp/SRR8363195_1.fastq.gz
# [2021-03-01 18:34:35,458]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836/005/SRR8363195/SRR8363195_2.fastq.gz to tccoutputGSM3526583/tmp/SRR8363195_2.fastq.gz
# [2021-03-01 18:34:35,459]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR836
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363204_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363205_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363205_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363206_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363206_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363207_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363207_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363208_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363208_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363209_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363209_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363210_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363210_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363211_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363211_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363212_1.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363212_2.fastq.gz
# [2021-03-01 18:34:35,492]    INFO         tccoutputGSM3526583/tmp/SRR8363213_1.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363213_2.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363214_1.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363214_2.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363215_1.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363215_2.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363216_1.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363216_2.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363217_1.fastq.gz
# [2021-03-01 18:34:35,493]    INFO         tccoutputGSM3526583/tmp/SRR8363217_2.fastq.gz
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 616848 out of 29860455 bytes>
#
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 680560 out of 179785079 bytes>
#
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-18:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 288, in urlretrieve
#     % (read, size), result)
# urllib.error.ContentTooShortError: <urlopen error retrieval incomplete: got only 616848 out of 179960607 bytes>
#
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-37:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 280, in urlretrieve
#     tfp.write(block)
# BrokenPipeError: [Errno 32] Broken pipe
#
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-46:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-48:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/tempfile.py", line 620, in func_wrapper
#     return func(*args, **kwargs)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# [2021-03-01 18:42:12,542]    INFO Sorting BUS file tccoutputGSM3526583/output.bus to tccoutputGSM3526583/tmp/output.s.bus
# [2021-03-01 18:42:21,647]    INFO Whitelist not provided
# [2021-03-01 18:42:21,647]    INFO Copying pre-packaged 10XV2 whitelist to tccoutputGSM3526583
# [2021-03-01 18:42:21,758]    INFO Inspecting BUS file tccoutputGSM3526583/tmp/output.s.bus
# [2021-03-01 18:42:27,704]    INFO Correcting BUS records in tccoutputGSM3526583/tmp/output.s.bus to tccoutputGSM3526583/tmp/output.s.c.bus with whitelist tccoutputGSM3526583/10xv2_whitelist.txt
# [2021-03-01 18:42:31,850]    INFO Sorting BUS file tccoutputGSM3526583/tmp/output.s.c.bus to tccoutputGSM3526583/output.unfiltered.bus
# [2021-03-01 18:42:39,611]    INFO Generating count matrix tccoutputGSM3526583/counts_unfiltered/cells_x_tcc from BUS file tccoutputGSM3526583/output.unfiltered.bus
# [2021-03-01 18:42:58,927]    INFO Reading matrix tccoutputGSM3526583/counts_unfiltered/cells_x_tcc.mtx
# [2021-03-01 18:43:19,597]    INFO Writing matrix to h5ad tccoutputGSM3526583/counts_unfiltered/adata.h5ad
# [2021-03-01 18:44:18,929]    INFO Filtering with bustools
# [2021-03-01 18:44:18,929]    INFO Generating whitelist tccoutputGSM3526583/filter_barcodes.txt from BUS file tccoutputGSM3526583/output.unfiltered.bus
# [2021-03-01 18:44:19,045]    INFO Correcting BUS records in tccoutputGSM3526583/output.unfiltered.bus to tccoutputGSM3526583/tmp/output.unfiltered.c.bus with whitelist tccoutputGSM3526583/filter_barcodes.txt
# [2021-03-01 18:44:22,563]    INFO Sorting BUS file tccoutputGSM3526583/tmp/output.unfiltered.c.bus to tccoutputGSM3526583/output.filtered.bus
# [2021-03-01 18:44:28,427]    INFO Generating count matrix tccoutputGSM3526583/counts_filtered/cells_x_tcc from BUS file tccoutputGSM3526583/output.filtered.bus
# [2021-03-01 18:44:40,933]    INFO Reading matrix tccoutputGSM3526583/counts_filtered/cells_x_tcc.mtx
# [2021-03-01 18:44:57,200]    INFO Writing matrix to h5ad tccoutputGSM3526583/counts_filtered/adata.h5ad
#   adding: bus_raw_GSM3526583/ (stored 0%)
#   adding: bus_raw_GSM3526583/tcc_unfiltered/ (stored 0%)
#   adding: bus_raw_GSM3526583/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 4%)
#   adding: bus_raw_GSM3526583/tcc_unfiltered/adata.h5ad.gz (deflated 9%)
#   adding: bus_raw_GSM3526583/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_GSM3526583/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: bus_raw_GSM3526583/GSM3526583.filtered.bus.gz (deflated 3%)
#   adding: bus_raw_GSM3526583/gc_unfiltered/ (stored 0%)
#   adding: bus_raw_GSM3526583/gc_unfiltered/cells_x_genes.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_GSM3526583/gc_unfiltered/cells_x_genes.genes.txt.gz (deflated 0%)
#   adding: bus_raw_GSM3526583/gc_unfiltered/adata.h5ad.gz (deflated 4%)
#   adding: bus_raw_GSM3526583/gc_unfiltered/cells_x_genes.mtx.gz (deflated 0%)

# %%
# !zip -r /content/bus_raw_GSM3526583.zip /content/bus_raw_GSM3526583
# Out:
#   adding: content/bus_raw_GSM3526583/ (stored 0%)
#   adding: content/bus_raw_GSM3526583/tcc_unfiltered/ (stored 0%)
#   adding: content/bus_raw_GSM3526583/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 4%)
#   adding: content/bus_raw_GSM3526583/tcc_unfiltered/adata.h5ad.gz (deflated 9%)
#   adding: content/bus_raw_GSM3526583/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: content/bus_raw_GSM3526583/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: content/bus_raw_GSM3526583/GSM3526583.filtered.bus.gz (deflated 3%)
#   adding: content/bus_raw_GSM3526583/gc_unfiltered/ (stored 0%)
#   adding: content/bus_raw_GSM3526583/gc_unfiltered/cells_x_genes.barcodes.txt.gz (deflated 1%)
#   adding: content/bus_raw_GSM3526583/gc_unfiltered/cells_x_genes.genes.txt.gz (deflated 0%)
#   adding: content/bus_raw_GSM3526583/gc_unfiltered/adata.h5ad.gz (deflated 4%)
#   adding: content/bus_raw_GSM3526583/gc_unfiltered/cells_x_genes.mtx.gz (deflated 0%)
