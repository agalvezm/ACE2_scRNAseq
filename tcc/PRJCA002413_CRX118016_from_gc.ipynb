# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/tcc/PRJCA002413_CRX118016_from_gc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRJCA002413_CRX118016

# %% [markdown]
# This notebook uses the result filtered count matrix from the following google colab notebook.
# https://github.com/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/PRJCA002413_CRX118016.ipynb Please run it and upload the file in /content

# %%
# define the values for the analysis

# accession id for the data
id = "PRJCA002413"
samp_id = ["CRX118016"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet
  links_raw = "ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz	ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

#sample specific metadata

no_samples = 1

condition = ["healthy control 5"] * no_samples

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["blood"] * no_samples

cell_type = ["PBMCs"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Wen et al 2020"] * no_samples

figure = ["Fig: all"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 123kB/s
#      |████████████████████████████████| 133kB 55.8MB/s
#      |████████████████████████████████| 51kB 5.8MB/s
#      |████████████████████████████████| 13.2MB 36.7MB/s
#      |████████████████████████████████| 10.3MB 34.0MB/s
#      |████████████████████████████████| 112kB 56.9MB/s
#      |████████████████████████████████| 81kB 8.2MB/s
#      |████████████████████████████████| 71kB 8.0MB/s
#      |████████████████████████████████| 1.2MB 36.4MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  while len(os.listdir()) != len(fastqs):
    for link in fastqs:
      # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2021-04-28 16:53:12--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ...
# No such directory ‘gsa3/CRA002497/CRR144005’.
#
# --2021-04-28 16:53:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ...
# No such directory ‘gsa3/CRA002497/CRR144005’.
#
# --2021-04-28 16:53:36--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_f1.fastq.gz ... 1074221772
# ==> PASV ... done.    ==> RETR CRR144006_f1.fastq.gz ... done.
# Length: 1074221772 (1.0G) (unauthoritative)
#
# CRR144006_f1.fastq. 100%[===================>]   1.00G  11.3MB/s    in 87s
#
# 2021-04-28 16:55:06 (11.7 MB/s) - ‘CRR144006_f1.fastq.gz’ saved [1074221772]
#
# --2021-04-28 16:55:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_r2.fastq.gz ... 1115476709
# ==> PASV ... done.    ==> RETR CRR144006_r2.fastq.gz ... done.
# Length: 1115476709 (1.0G) (unauthoritative)
#
# CRR144006_r2.fastq. 100%[===================>]   1.04G  12.3MB/s    in 89s
#
# 2021-04-28 16:56:39 (11.9 MB/s) - ‘CRR144006_r2.fastq.gz’ saved [1115476709]
#
# --2021-04-28 16:56:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ... done.
# ==> SIZE CRR144007_f1.fastq.gz ... 524595845
# ==> PASV ... done.    ==> RETR CRR144007_f1.fastq.gz ... done.
# Length: 524595845 (500M) (unauthoritative)
#
# CRR144007_f1.fastq. 100%[===================>] 500.29M  9.17MB/s    in 54s
#
# 2021-04-28 16:57:35 (9.34 MB/s) - ‘CRR144007_f1.fastq.gz’ saved [524595845]
#
# --2021-04-28 16:57:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ... done.
# ==> SIZE CRR144007_r2.fastq.gz ... 532409556
# ==> PASV ... done.    ==> RETR CRR144007_r2.fastq.gz ... done.
# Length: 532409556 (508M) (unauthoritative)
#
# CRR144007_r2.fastq. 100%[===================>] 507.75M  11.1MB/s    in 56s
#
# 2021-04-28 16:58:34 (9.12 MB/s) - ‘CRR144007_r2.fastq.gz’ saved [532409556]
#
# --2021-04-28 16:58:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ... done.
# ==> SIZE CRR144008_f1.fastq.gz ... 800201797
# ==> PASV ... done.    ==> RETR CRR144008_f1.fastq.gz ... done.
# Length: 800201797 (763M) (unauthoritative)
#
# CRR144008_f1.fastq. 100%[===================>] 763.13M  8.51MB/s    in 1m 49s
#
# 2021-04-28 17:00:27 (6.98 MB/s) - ‘CRR144008_f1.fastq.gz’ saved [800201797]
#
# --2021-04-28 17:00:27--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz
#            => ‘CRR144008_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ... done.
# ==> SIZE CRR144008_r2.fastq.gz ... 830758949
# ==> PASV ... done.    ==> RETR CRR144008_r2.fastq.gz ... done.
# Length: 830758949 (792M) (unauthoritative)
#
# CRR144008_r2.fastq. 100%[===================>] 792.27M  11.7MB/s    in 82s
#
# 2021-04-28 17:01:52 (9.70 MB/s) - ‘CRR144008_r2.fastq.gz’ saved [830758949]
#
# --2021-04-28 17:01:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz
#            => ‘CRR144009_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_f1.fastq.gz ... 2515705993
# ==> PASV ... done.    ==> RETR CRR144009_f1.fastq.gz ... done.
# Length: 2515705993 (2.3G) (unauthoritative)
#
# CRR144009_f1.fastq. 100%[===================>]   2.34G  9.35MB/s    in 3m 47s
#
# 2021-04-28 17:05:42 (10.6 MB/s) - ‘CRR144009_f1.fastq.gz’ saved [2515705993]
#
# --2021-04-28 17:05:42--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#            => ‘CRR144009_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ...
# No such directory ‘gsa3/CRA002497/CRR144009’.
#
# --2021-04-28 17:05:55--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz
#            => ‘CRR144010_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_f1.fastq.gz ... 2750566018
# ==> PASV ... done.    ==> RETR CRR144010_f1.fastq.gz ... done.
# Length: 2750566018 (2.6G) (unauthoritative)
#
# CRR144010_f1.fastq. 100%[===================>]   2.56G  8.14MB/s    in 4m 23s
#
# 2021-04-28 17:10:21 (9.99 MB/s) - ‘CRR144010_f1.fastq.gz’ saved [2750566018]
#
# --2021-04-28 17:10:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#            => ‘CRR144010_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# ==> PASV ... done.    ==> RETR CRR144010_r2.fastq.gz ... done.
# Length: 10351864191 (9.6G) (unauthoritative)
#
# CRR144010_r2.fastq. 100%[===================>]   9.64G  12.3MB/s    in 14m 12s
#
# 2021-04-28 17:24:36 (11.6 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 17:39:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#   (try: 2) => ‘CRR144010_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# File has already been retrieved.
# 2021-04-28 17:39:38 (0.00 B/s) - ‘CRR144010_r2.fastq.gz’ saved [10351864191]
#
# --2021-04-28 17:39:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz
#            => ‘CRR144011_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_f1.fastq.gz ... 1674825461
# ==> PASV ... done.    ==> RETR CRR144011_f1.fastq.gz ... done.
# Length: 1674825461 (1.6G) (unauthoritative)
#
# CRR144011_f1.fastq. 100%[===================>]   1.56G  12.2MB/s    in 2m 21s
#
# 2021-04-28 17:42:03 (11.3 MB/s) - ‘CRR144011_f1.fastq.gz’ saved [1674825461]
#
# --2021-04-28 17:42:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#            => ‘CRR144011_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ...
# No such directory ‘gsa3/CRA002497/CRR144011’.
#
# --2021-04-28 17:42:16--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz
#            => ‘CRR144012_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_f1.fastq.gz ... 3134151490
# ==> PASV ... done.    ==> RETR CRR144012_f1.fastq.gz ... done.
# Length: 3134151490 (2.9G) (unauthoritative)
#
# CRR144012_f1.fastq. 100%[===================>]   2.92G  12.2MB/s    in 4m 20s
#
# 2021-04-28 17:46:40 (11.5 MB/s) - ‘CRR144012_f1.fastq.gz’ saved [3134151490]
#
# --2021-04-28 17:46:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#            => ‘CRR144012_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 17:46:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz
#            => ‘CRR144013_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ...
# No such directory ‘gsa3/CRA002497/CRR144013’.
#
# --2021-04-28 17:47:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz
#            => ‘CRR144013_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_r2.fastq.gz ... 1250511974
# ==> PASV ... done.    ==> RETR CRR144013_r2.fastq.gz ... done.
# Length: 1250511974 (1.2G) (unauthoritative)
#
# CRR144013_r2.fastq. 100%[===================>]   1.16G  10.8MB/s    in 1m 41s
#
# 2021-04-28 17:48:49 (11.8 MB/s) - ‘CRR144013_r2.fastq.gz’ saved [1250511974]
#
# --2021-04-28 17:48:49--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz
#            => ‘CRR144014_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_f1.fastq.gz ... 1708491014
# ==> PASV ... done.    ==> RETR CRR144014_f1.fastq.gz ... done.
# Length: 1708491014 (1.6G) (unauthoritative)
#
# CRR144014_f1.fastq. 100%[===================>]   1.59G  12.2MB/s    in 2m 15s
#
# 2021-04-28 17:51:07 (12.1 MB/s) - ‘CRR144014_f1.fastq.gz’ saved [1708491014]
#
# --2021-04-28 17:51:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz
#            => ‘CRR144014_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_r2.fastq.gz ... 1748640248
# ==> PASV ... done.    ==> RETR CRR144014_r2.fastq.gz ... done.
# Length: 1748640248 (1.6G) (unauthoritative)
#
# CRR144014_r2.fastq. 100%[===================>]   1.63G  13.1MB/s    in 2m 21s
#
# 2021-04-28 17:53:31 (11.8 MB/s) - ‘CRR144014_r2.fastq.gz’ saved [1748640248]
#
# --2021-04-28 17:53:31--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_f1.fastq.gz ... 1223913717
# ==> PASV ... done.    ==> RETR CRR144015_f1.fastq.gz ... done.
# Length: 1223913717 (1.1G) (unauthoritative)
#
# CRR144015_f1.fastq. 100%[===================>]   1.14G  10.2MB/s    in 99s
#
# 2021-04-28 17:55:14 (11.8 MB/s) - ‘CRR144015_f1.fastq.gz’ saved [1223913717]
#
# --2021-04-28 17:55:14--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_r2.fastq.gz ... 1248048314
# ==> PASV ... done.    ==> RETR CRR144015_r2.fastq.gz ... done.
# Length: 1248048314 (1.2G) (unauthoritative)
#
# CRR144015_r2.fastq. 100%[===================>]   1.16G  12.6MB/s    in 2m 5s
#
# 2021-04-28 17:57:22 (9.55 MB/s) - ‘CRR144015_r2.fastq.gz’ saved [1248048314]
#
# --2021-04-28 17:57:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_f1.fastq.gz ... 937554817
# ==> PASV ... done.    ==> RETR CRR144016_f1.fastq.gz ... done.
# Length: 937554817 (894M) (unauthoritative)
#
# CRR144016_f1.fastq. 100%[===================>] 894.12M  12.5MB/s    in 79s
#
# 2021-04-28 17:58:44 (11.4 MB/s) - ‘CRR144016_f1.fastq.gz’ saved [937554817]
#
# --2021-04-28 17:58:44--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_r2.fastq.gz ... 971216406
# ==> PASV ... done.    ==> RETR CRR144016_r2.fastq.gz ... done.
# Length: 971216406 (926M) (unauthoritative)
#
# CRR144016_r2.fastq. 100%[===================>] 926.22M  3.74MB/s    in 1m 44s
#
# 2021-04-28 18:00:33 (8.88 MB/s) - ‘CRR144016_r2.fastq.gz’ saved [971216406]
#
# --2021-04-28 18:00:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_f1.fastq.gz ... 915311231
# ==> PASV ... done.    ==> RETR CRR144005_f1.fastq.gz ... done.
# Length: 915311231 (873M) (unauthoritative)
#
# CRR144005_f1.fastq. 100%[===================>] 872.91M  9.06MB/s    in 2m 17s
#
# 2021-04-28 18:02:53 (6.39 MB/s) - ‘CRR144005_f1.fastq.gz’ saved [915311231]
#
# --2021-04-28 18:02:53--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_r2.fastq.gz ... 960618716
# ==> PASV ... done.    ==> RETR CRR144005_r2.fastq.gz ... done.
# Length: 960618716 (916M) (unauthoritative)
#
# CRR144005_r2.fastq. 100%[===================>] 916.12M  12.2MB/s    in 90s
#
# 2021-04-28 18:04:26 (10.2 MB/s) - ‘CRR144005_r2.fastq.gz’ saved [960618716]
#
# --2021-04-28 18:04:26--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 18:04:38--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_r2.fastq.gz ... 1115476709
# File has already been retrieved.
# 2021-04-28 18:04:40 (0.00 B/s) - ‘CRR144006_r2.fastq.gz’ saved [1115476709]
#
# --2021-04-28 18:04:40--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 18:04:52--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ... done.
# ==> SIZE CRR144007_r2.fastq.gz ... 532409556
# File has already been retrieved.
# 2021-04-28 18:04:54 (0.00 B/s) - ‘CRR144007_r2.fastq.gz’ saved [532409556]
#
# --2021-04-28 18:04:54--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 18:05:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz
#            => ‘CRR144008_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 18:05:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz
#            => ‘CRR144009_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_f1.fastq.gz ... 2515705993
# File has already been retrieved.
# 2021-04-28 18:05:21 (0.00 B/s) - ‘CRR144009_f1.fastq.gz’ saved [2515705993]
#
# --2021-04-28 18:05:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#            => ‘CRR144009_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ...
# No such directory ‘gsa3/CRA002497/CRR144009’.
#
# --2021-04-28 18:05:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz
#            => ‘CRR144010_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ...
# No such directory ‘gsa3/CRA002497/CRR144010’.
#
# --2021-04-28 18:05:45--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#            => ‘CRR144010_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# File has already been retrieved.
# 2021-04-28 18:05:47 (0.00 B/s) - ‘CRR144010_r2.fastq.gz’ saved [10351864191]
#
# --2021-04-28 18:05:47--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz
#            => ‘CRR144011_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_f1.fastq.gz ... 1674825461
# File has already been retrieved.
# 2021-04-28 18:05:49 (0.00 B/s) - ‘CRR144011_f1.fastq.gz’ saved [1674825461]
#
# --2021-04-28 18:05:49--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#            => ‘CRR144011_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_r2.fastq.gz ... 6275184398
# ==> PASV ... done.    ==> RETR CRR144011_r2.fastq.gz ... done.
# Length: 6275184398 (5.8G) (unauthoritative)
#
# CRR144011_r2.fastq. 100%[===================>]   5.84G  8.51MB/s    in 12m 28s
#
# 2021-04-28 18:18:19 (8.00 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 18:33:20--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#   (try: 2) => ‘CRR144011_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_r2.fastq.gz ... 6275184398
# File has already been retrieved.
# 2021-04-28 18:33:22 (0.00 B/s) - ‘CRR144011_r2.fastq.gz’ saved [6275184398]
#
# --2021-04-28 18:33:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz
#            => ‘CRR144012_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_f1.fastq.gz ... 3134151490
# File has already been retrieved.
# 2021-04-28 18:33:25 (0.00 B/s) - ‘CRR144012_f1.fastq.gz’ saved [3134151490]
#
# --2021-04-28 18:33:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#            => ‘CRR144012_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_r2.fastq.gz ... 11933334512
# ==> PASV ... done.    ==> RETR CRR144012_r2.fastq.gz ... done.
# Length: 11933334512 (11G) (unauthoritative)
#
# CRR144012_r2.fastq. 100%[===================>]  11.11G  12.1MB/s    in 20m 54s
#
# 2021-04-28 18:54:21 (9.08 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 19:09:22--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#   (try: 2) => ‘CRR144012_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_r2.fastq.gz ... 11933334512
# File has already been retrieved.
# 2021-04-28 19:09:24 (0.00 B/s) - ‘CRR144012_r2.fastq.gz’ saved [11933334512]
#
# --2021-04-28 19:09:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz
#            => ‘CRR144013_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ... done.
# ==> SIZE CRR144013_f1.fastq.gz ... 1239579596
# ==> PASV ... done.    ==> RETR CRR144013_f1.fastq.gz ... done.
# Length: 1239579596 (1.2G) (unauthoritative)
#
# CRR144013_f1.fastq. 100%[===================>]   1.15G  13.5MB/s    in 1m 42s
#
# 2021-04-28 19:11:09 (11.6 MB/s) - ‘CRR144013_f1.fastq.gz’ saved [1239579596]
#
# --2021-04-28 19:11:09--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz
#            => ‘CRR144013_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ...
# No such directory ‘gsa3/CRA002497/CRR144013’.
#
# --2021-04-28 19:11:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz
#            => ‘CRR144014_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_f1.fastq.gz ... 1708491014
# File has already been retrieved.
# 2021-04-28 19:11:24 (0.00 B/s) - ‘CRR144014_f1.fastq.gz’ saved [1708491014]
#
# --2021-04-28 19:11:24--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz
#            => ‘CRR144014_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ...
# No such directory ‘gsa3/CRA002497/CRR144014’.
#
# --2021-04-28 19:11:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_f1.fastq.gz ... 1223913717
# File has already been retrieved.
# 2021-04-28 19:11:37 (0.00 B/s) - ‘CRR144015_f1.fastq.gz’ saved [1223913717]
#
# --2021-04-28 19:11:38--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_r2.fastq.gz ... 1248048314
# File has already been retrieved.
# 2021-04-28 19:11:39 (0.00 B/s) - ‘CRR144015_r2.fastq.gz’ saved [1248048314]
#
# --2021-04-28 19:11:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.
#
# --2021-04-28 19:11:51--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.
#
# --2021-04-28 19:12:04--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_f1.fastq.gz
#            => ‘CRR144005_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ... done.
# ==> SIZE CRR144005_f1.fastq.gz ... 915311231
# File has already been retrieved.
# 2021-04-28 19:12:07 (0.00 B/s) - ‘CRR144005_f1.fastq.gz’ saved [915311231]
#
# --2021-04-28 19:12:07--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144005/CRR144005_r2.fastq.gz
#            => ‘CRR144005_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144005 ...
# No such directory ‘gsa3/CRA002497/CRR144005’.
#
# --2021-04-28 19:12:19--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_f1.fastq.gz
#            => ‘CRR144006_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ... done.
# ==> SIZE CRR144006_f1.fastq.gz ... 1074221772
# File has already been retrieved.
# 2021-04-28 19:12:21 (0.00 B/s) - ‘CRR144006_f1.fastq.gz’ saved [1074221772]
#
# --2021-04-28 19:12:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144006/CRR144006_r2.fastq.gz
#            => ‘CRR144006_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144006 ...
# No such directory ‘gsa3/CRA002497/CRR144006’.
#
# --2021-04-28 19:12:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_f1.fastq.gz
#            => ‘CRR144007_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 19:12:46--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144007/CRR144007_r2.fastq.gz
#            => ‘CRR144007_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144007 ...
# No such directory ‘gsa3/CRA002497/CRR144007’.
#
# --2021-04-28 19:12:58--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_f1.fastq.gz
#            => ‘CRR144008_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 19:13:10--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144008/CRR144008_r2.fastq.gz
#            => ‘CRR144008_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144008 ...
# No such directory ‘gsa3/CRA002497/CRR144008’.
#
# --2021-04-28 19:13:23--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_f1.fastq.gz
#            => ‘CRR144009_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ...
# No such directory ‘gsa3/CRA002497/CRR144009’.
#
# --2021-04-28 19:13:34--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#            => ‘CRR144009_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ... done.
# ==> SIZE CRR144009_r2.fastq.gz ... 9389151594
# ==> PASV ... done.    ==> RETR CRR144009_r2.fastq.gz ... done.
# Length: 9389151594 (8.7G) (unauthoritative)
#
# CRR144009_r2.fastq. 100%[===================>]   8.74G  12.5MB/s    in 12m 27s
#
# 2021-04-28 19:26:05 (12.0 MB/s) - Control connection closed.
# Retrying.
#
# --2021-04-28 19:41:06--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144009/CRR144009_r2.fastq.gz
#   (try: 2) => ‘CRR144009_r2.fastq.gz’
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144009 ...
# No such directory ‘gsa3/CRA002497/CRR144009’.
#
# --2021-04-28 19:41:18--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_f1.fastq.gz
#            => ‘CRR144010_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_f1.fastq.gz ... 2750566018
# File has already been retrieved.
# 2021-04-28 19:41:21 (0.00 B/s) - ‘CRR144010_f1.fastq.gz’ saved [2750566018]
#
# --2021-04-28 19:41:21--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144010/CRR144010_r2.fastq.gz
#            => ‘CRR144010_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144010 ... done.
# ==> SIZE CRR144010_r2.fastq.gz ... 10351864191
# File has already been retrieved.
# 2021-04-28 19:41:23 (0.00 B/s) - ‘CRR144010_r2.fastq.gz’ saved [10351864191]
#
# --2021-04-28 19:41:23--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_f1.fastq.gz
#            => ‘CRR144011_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ... done.
# ==> SIZE CRR144011_f1.fastq.gz ... 1674825461
# File has already been retrieved.
# 2021-04-28 19:41:25 (0.00 B/s) - ‘CRR144011_f1.fastq.gz’ saved [1674825461]
#
# --2021-04-28 19:41:25--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144011/CRR144011_r2.fastq.gz
#            => ‘CRR144011_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144011 ...
# No such directory ‘gsa3/CRA002497/CRR144011’.
#
# --2021-04-28 19:41:37--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_f1.fastq.gz
#            => ‘CRR144012_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ... done.
# ==> SIZE CRR144012_f1.fastq.gz ... 3134151490
# File has already been retrieved.
# 2021-04-28 19:41:39 (0.00 B/s) - ‘CRR144012_f1.fastq.gz’ saved [3134151490]
#
# --2021-04-28 19:41:39--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144012/CRR144012_r2.fastq.gz
#            => ‘CRR144012_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144012 ...
# No such directory ‘gsa3/CRA002497/CRR144012’.
#
# --2021-04-28 19:41:51--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_f1.fastq.gz
#            => ‘CRR144013_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ...
# No such directory ‘gsa3/CRA002497/CRR144013’.
#
# --2021-04-28 19:42:03--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144013/CRR144013_r2.fastq.gz
#            => ‘CRR144013_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144013 ...
# No such directory ‘gsa3/CRA002497/CRR144013’.
#
# --2021-04-28 19:42:15--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_f1.fastq.gz
#            => ‘CRR144014_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ... done.
# ==> SIZE CRR144014_f1.fastq.gz ... 1708491014
# File has already been retrieved.
# 2021-04-28 19:42:17 (0.00 B/s) - ‘CRR144014_f1.fastq.gz’ saved [1708491014]
#
# --2021-04-28 19:42:17--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144014/CRR144014_r2.fastq.gz
#            => ‘CRR144014_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144014 ...
# No such directory ‘gsa3/CRA002497/CRR144014’.
#
# --2021-04-28 19:42:29--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_f1.fastq.gz
#            => ‘CRR144015_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_f1.fastq.gz ... 1223913717
# File has already been retrieved.
# 2021-04-28 19:42:31 (0.00 B/s) - ‘CRR144015_f1.fastq.gz’ saved [1223913717]
#
# --2021-04-28 19:42:31--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144015/CRR144015_r2.fastq.gz
#            => ‘CRR144015_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144015 ... done.
# ==> SIZE CRR144015_r2.fastq.gz ... 1248048314
# File has already been retrieved.
# 2021-04-28 19:42:33 (0.00 B/s) - ‘CRR144015_r2.fastq.gz’ saved [1248048314]
#
# --2021-04-28 19:42:33--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_f1.fastq.gz
#            => ‘CRR144016_f1.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ... done.
# ==> SIZE CRR144016_f1.fastq.gz ... 937554817
# File has already been retrieved.
# 2021-04-28 19:42:35 (0.00 B/s) - ‘CRR144016_f1.fastq.gz’ saved [937554817]
#
# --2021-04-28 19:42:35--  ftp://download.big.ac.cn/gsa3/CRA002497/CRR144016/CRR144016_r2.fastq.gz
#            => ‘CRR144016_r2.fastq.gz’
# Resolving download.big.ac.cn (download.big.ac.cn)... 124.16.164.229
# Connecting to download.big.ac.cn (download.big.ac.cn)|124.16.164.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gsa3/CRA002497/CRR144016 ...
# No such directory ‘gsa3/CRA002497/CRR144016’.

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2021-04-28 19:42:51,519]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:33<00:00, 25.7MB/s]
# [2021-04-28 19:44:25,850]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['CRR144005_f1.fastq.gz', 'CRR144005_r2.fastq.gz', 'CRR144006_f1.fastq.gz', 'CRR144006_r2.fastq.gz', 'CRR144007_f1.fastq.gz', 'CRR144007_r2.fastq.gz', 'CRR144008_f1.fastq.gz', 'CRR144008_r2.fastq.gz', 'CRR144009_f1.fastq.gz', 'CRR144009_r2.fastq.gz', 'CRR144010_f1.fastq.gz', 'CRR144010_r2.fastq.gz', 'CRR144011_f1.fastq.gz', 'CRR144011_r2.fastq.gz', 'CRR144012_f1.fastq.gz', 'CRR144012_r2.fastq.gz', 'CRR144013_f1.fastq.gz', 'CRR144013_r2.fastq.gz', 'CRR144014_f1.fastq.gz', 'CRR144014_r2.fastq.gz', 'CRR144015_f1.fastq.gz', 'CRR144015_r2.fastq.gz', 'CRR144016_f1.fastq.gz', 'CRR144016_r2.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['CRR144005_f1.fastq.gz',
#  'CRR144005_r2.fastq.gz',
#  'CRR144006_f1.fastq.gz',
#  'CRR144006_r2.fastq.gz',
#  'CRR144007_f1.fastq.gz',
#  'CRR144007_r2.fastq.gz',
#  'CRR144008_f1.fastq.gz',
#  'CRR144008_r2.fastq.gz',
#  'CRR144009_f1.fastq.gz',
#  'CRR144009_r2.fastq.gz',
#  'CRR144010_f1.fastq.gz',
#  'CRR144010_r2.fastq.gz',
#  'CRR144011_f1.fastq.gz',
#  'CRR144011_r2.fastq.gz',
#  'CRR144012_f1.fastq.gz',
#  'CRR144012_r2.fastq.gz',
#  'CRR144013_f1.fastq.gz',
#  'CRR144013_r2.fastq.gz',
#  'CRR144014_f1.fastq.gz',
#  'CRR144014_r2.fastq.gz',
#  'CRR144015_f1.fastq.gz',
#  'CRR144015_r2.fastq.gz',
#  'CRR144016_f1.fastq.gz',
#  'CRR144016_r2.fastq.gz']

# %%
if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[0] + " "\
  + "--filter bustools --tcc -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[i] + " \
    --filter bustools --tcc -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]






results = {}
tcc_results = {}
for sample in sample_id:
  # Read the filtered gene count matrix
  results["data_" + sample] = anndata.read("/content/result" + sample)


for sample in sample_id:
  output = "bus_raw_" + sample + "_from_gc"
  # !mkdir $output
  folder_tcc = "tccoutput" + sample

  # read tcc matrix
  tcc_results[sample] = anndata.read(folder_tcc + "/counts_unfiltered/adata.h5ad")
  # apply gene count matrix's filter
  tcc_results[sample] = tcc_results[sample][results["data_" + sample].obs.index.values]
  # transfer obs data
  tcc_results[sample].obs = results["data_" + sample].obs
  # transfer metadata
  tcc_results[sample].uns = results["data_" + sample].uns
  # write tcc matrix
  tcc_results[sample].write("/content/tcc_" + sample)
  #gzip tcc matrix
  cmd = "gzip /content/tcc_" + sample
  # !$cmd
  #gzip unfiltered bus file
  cmd = "gzip " + folder_tcc + "/output.unfiltered.bus"
  # !$cmd
  # move and re-name bus file with sample id
  cmd = "mv " + folder_tcc + "/output.unfiltered.bus.gz " + output + "/" + sample +".unfiltered.bus.gz"
  # !$cmd
  # gzip all unfiltered counts
  cmd = "gzip " + folder_tcc + "/counts_unfiltered/*"
  # !$cmd

  # move unfiltered counts for both
  cmd = "mv " + folder_tcc + "/counts_unfiltered " + output + "/tcc_unfiltered"
  # !$cmd

  cmd = "mv " + folder_tcc + "/*.json " + output 
  # !$cmd
  # zip all files
  cmd = "zip -r "+ output + ".zip " + output
  # !$cmd


import time
time.sleep(60000000)
# Out:
# [2021-04-28 19:45:07,634]    INFO Using index index.idx to generate BUS file to tccoutputCRX118016 from
# [2021-04-28 19:45:07,635]    INFO         CRR144005_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144005_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144006_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144006_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144007_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144007_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144008_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144008_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144009_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144009_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144010_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144010_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144011_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144011_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144012_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144012_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144013_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144013_r2.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144014_f1.fastq.gz
# [2021-04-28 19:45:07,635]    INFO         CRR144014_r2.fastq.gz
# [2021-04-28 19:45:07,636]    INFO         CRR144015_f1.fastq.gz
# [2021-04-28 19:45:07,636]    INFO         CRR144015_r2.fastq.gz
# [2021-04-28 19:45:07,636]    INFO         CRR144016_f1.fastq.gz
# [2021-04-28 19:45:07,636]    INFO         CRR144016_r2.fastq.gz
# [2021-04-28 21:52:34,378]    INFO Sorting BUS file tccoutputCRX118016/output.bus to tccoutputCRX118016/tmp/output.s.bus
# [2021-04-28 21:58:37,628]    INFO Whitelist not provided
# [2021-04-28 21:58:37,632]    INFO Copying pre-packaged 10XV2 whitelist to tccoutputCRX118016
# [2021-04-28 21:58:37,772]    INFO Inspecting BUS file tccoutputCRX118016/tmp/output.s.bus
# [2021-04-28 21:59:40,713]    INFO Correcting BUS records in tccoutputCRX118016/tmp/output.s.bus to tccoutputCRX118016/tmp/output.s.c.bus with whitelist tccoutputCRX118016/10xv2_whitelist.txt
# [2021-04-28 22:00:51,392]    INFO Sorting BUS file tccoutputCRX118016/tmp/output.s.c.bus to tccoutputCRX118016/output.unfiltered.bus
# [2021-04-28 22:03:14,451]    INFO Generating count matrix tccoutputCRX118016/counts_unfiltered/cells_x_tcc from BUS file tccoutputCRX118016/output.unfiltered.bus
# [2021-04-28 22:06:14,302]    INFO Reading matrix tccoutputCRX118016/counts_unfiltered/cells_x_tcc.mtx
# [2021-04-28 22:07:55,208]    INFO Writing matrix to h5ad tccoutputCRX118016/counts_unfiltered/adata.h5ad
# [2021-04-28 22:08:08,049]    INFO Filtering with bustools
# [2021-04-28 22:08:08,050]    INFO Generating whitelist tccoutputCRX118016/filter_barcodes.txt from BUS file tccoutputCRX118016/output.unfiltered.bus
# [2021-04-28 22:08:11,809]    INFO Correcting BUS records in tccoutputCRX118016/output.unfiltered.bus to tccoutputCRX118016/tmp/output.unfiltered.c.bus with whitelist tccoutputCRX118016/filter_barcodes.txt
# [2021-04-28 22:09:12,230]    INFO Sorting BUS file tccoutputCRX118016/tmp/output.unfiltered.c.bus to tccoutputCRX118016/output.filtered.bus
# [2021-04-28 22:11:38,870]    INFO Generating count matrix tccoutputCRX118016/counts_filtered/cells_x_tcc from BUS file tccoutputCRX118016/output.filtered.bus
# [2021-04-28 22:13:49,226]    INFO Reading matrix tccoutputCRX118016/counts_filtered/cells_x_tcc.mtx
# [2021-04-28 22:15:07,682]    INFO Writing matrix to h5ad tccoutputCRX118016/counts_filtered/adata.h5ad
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   adding: bus_raw_CRX118016_from_gc/ (stored 0%)
#   adding: bus_raw_CRX118016_from_gc/kb_info.json (deflated 79%)
#   adding: bus_raw_CRX118016_from_gc/run_info.json (deflated 64%)
#   adding: bus_raw_CRX118016_from_gc/tcc_unfiltered/ (stored 0%)
#   adding: bus_raw_CRX118016_from_gc/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: bus_raw_CRX118016_from_gc/tcc_unfiltered/adata.h5ad.gz (deflated 5%)
#   adding: bus_raw_CRX118016_from_gc/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 2%)
#   adding: bus_raw_CRX118016_from_gc/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_CRX118016_from_gc/inspect.json (deflated 56%)
#   adding: bus_raw_CRX118016_from_gc/CRX118016.unfiltered.bus.gz (deflated 4%)
