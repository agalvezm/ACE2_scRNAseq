# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/tcc/GSE135893_GSM4037325_from_gc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE135893_GSM4037325

# %% [markdown]
# This notebook uses the filtered count matrix resulting from the following google colab notebook. https://github.com/agalvezm/ACE2_scRNAseq/blob/master/notebooks_countmatrices/GSE135893_GSM4037325.ipynb Please run the notebook above and upload the results file in /content

# %%
# define the values for the analysis

# accession id for the data
id = "GSE135893"
samp_id = ["GSM4037325"]

# If only bam available files, set bam = True, Fill link and filename
bam = False

# If fastq links available but are not ffq links
fastq_ffqlinks = False


if bam:
  # Assign link to python variable
  link_to_bam = ""
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename=""


if not bam:

  # Copy and paste the links from the ACE2 scRNAseq datasets google  spreadsheet

  links_raw = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985495/SRR9985495_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985497/SRR9985497_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985496/SRR9985496_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_2.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_2.fastq.gz"

  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [4, 8, 8] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["lung"] * no_samples

cell_type = ["None"] * no_samples

condition = ["healthy"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 c,d  Fig 4 e  ED Fig 11 a,c"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 115kB/s
#      |████████████████████████████████| 51kB 4.9MB/s
#      |████████████████████████████████| 122kB 41.7MB/s
#      |████████████████████████████████| 13.2MB 36.9MB/s
#      |████████████████████████████████| 10.3MB 14.4MB/s
#      |████████████████████████████████| 112kB 41.4MB/s
#      |████████████████████████████████| 81kB 6.9MB/s
#      |████████████████████████████████| 51kB 4.5MB/s
#      |████████████████████████████████| 1.2MB 26.6MB/s
#      |████████████████████████████████| 71kB 6.4MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# /content/fastqs
# --2021-04-06 21:57:06--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_1.fastq.gz
#            => ‘SRR9985509_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985509 ... done.
# ==> SIZE SRR9985509_1.fastq.gz ... 665494275
# ==> PASV ... done.    ==> RETR SRR9985509_1.fastq.gz ... done.
# Length: 665494275 (635M) (unauthoritative)
#
# SRR9985509_1.fastq. 100%[===================>] 634.66M  36.0MB/s    in 19s
#
# 2021-04-06 21:57:26 (33.9 MB/s) - ‘SRR9985509_1.fastq.gz’ saved [665494275]
#
# --2021-04-06 21:57:26--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985509/SRR9985509_2.fastq.gz
#            => ‘SRR9985509_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985509 ... done.
# ==> SIZE SRR9985509_2.fastq.gz ... 674042245
# ==> PASV ... done.    ==> RETR SRR9985509_2.fastq.gz ... done.
# Length: 674042245 (643M) (unauthoritative)
#
# SRR9985509_2.fastq. 100%[===================>] 642.82M  35.6MB/s    in 19s
#
# 2021-04-06 21:57:46 (34.5 MB/s) - ‘SRR9985509_2.fastq.gz’ saved [674042245]
#
# --2021-04-06 21:57:46--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_1.fastq.gz
#            => ‘SRR9985505_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985505 ... done.
# ==> SIZE SRR9985505_1.fastq.gz ... 866824827
# ==> PASV ... done.    ==> RETR SRR9985505_1.fastq.gz ... done.
# Length: 866824827 (827M) (unauthoritative)
#
# SRR9985505_1.fastq. 100%[===================>] 826.67M  36.9MB/s    in 26s
#
# 2021-04-06 21:58:14 (31.7 MB/s) - ‘SRR9985505_1.fastq.gz’ saved [866824827]
#
# --2021-04-06 21:58:14--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985505/SRR9985505_2.fastq.gz
#            => ‘SRR9985505_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985505 ... done.
# ==> SIZE SRR9985505_2.fastq.gz ... 874347943
# ==> PASV ... done.    ==> RETR SRR9985505_2.fastq.gz ... done.
# Length: 874347943 (834M) (unauthoritative)
#
# SRR9985505_2.fastq. 100%[===================>] 833.84M  10.9MB/s    in 48s
#
# 2021-04-06 21:59:03 (17.4 MB/s) - ‘SRR9985505_2.fastq.gz’ saved [874347943]
#
# --2021-04-06 21:59:03--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_1.fastq.gz
#            => ‘SRR9985503_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985503 ... done.
# ==> SIZE SRR9985503_1.fastq.gz ... 618220272
# ==> PASV ... done.    ==> RETR SRR9985503_1.fastq.gz ... done.
# Length: 618220272 (590M) (unauthoritative)
#
# SRR9985503_1.fastq. 100%[===================>] 589.58M  8.75MB/s    in 45s
#
# 2021-04-06 21:59:50 (13.0 MB/s) - ‘SRR9985503_1.fastq.gz’ saved [618220272]
#
# --2021-04-06 21:59:50--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985503/SRR9985503_2.fastq.gz
#            => ‘SRR9985503_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985503 ... done.
# ==> SIZE SRR9985503_2.fastq.gz ... 622433191
# ==> PASV ... done.    ==> RETR SRR9985503_2.fastq.gz ... done.
# Length: 622433191 (594M) (unauthoritative)
#
# SRR9985503_2.fastq. 100%[===================>] 593.60M  35.1MB/s    in 18s
#
# 2021-04-06 22:00:09 (33.4 MB/s) - ‘SRR9985503_2.fastq.gz’ saved [622433191]
#
# --2021-04-06 22:00:09--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_1.fastq.gz
#            => ‘SRR9985506_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985506 ... done.
# ==> SIZE SRR9985506_1.fastq.gz ... 248159151
# ==> PASV ... done.    ==> RETR SRR9985506_1.fastq.gz ... done.
# Length: 248159151 (237M) (unauthoritative)
#
# SRR9985506_1.fastq. 100%[===================>] 236.66M  35.7MB/s    in 11s
#
# 2021-04-06 22:00:21 (21.3 MB/s) - ‘SRR9985506_1.fastq.gz’ saved [248159151]
#
# --2021-04-06 22:00:21--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985506/SRR9985506_2.fastq.gz
#            => ‘SRR9985506_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985506 ... done.
# ==> SIZE SRR9985506_2.fastq.gz ... 255142545
# ==> PASV ... done.    ==> RETR SRR9985506_2.fastq.gz ... done.
# Length: 255142545 (243M) (unauthoritative)
#
# SRR9985506_2.fastq. 100%[===================>] 243.32M  36.1MB/s    in 8.3s
#
# 2021-04-06 22:00:31 (29.3 MB/s) - ‘SRR9985506_2.fastq.gz’ saved [255142545]
#
# --2021-04-06 22:00:31--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_1.fastq.gz
#            => ‘SRR9985507_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985507 ... done.
# ==> SIZE SRR9985507_1.fastq.gz ... 861753540
# ==> PASV ... done.    ==> RETR SRR9985507_1.fastq.gz ... done.
# Length: 861753540 (822M) (unauthoritative)
#
# SRR9985507_1.fastq. 100%[===================>] 821.83M  36.0MB/s    in 28s
#
# 2021-04-06 22:01:00 (29.6 MB/s) - ‘SRR9985507_1.fastq.gz’ saved [861753540]
#
# --2021-04-06 22:01:00--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985507/SRR9985507_2.fastq.gz
#            => ‘SRR9985507_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985507 ... done.
# ==> SIZE SRR9985507_2.fastq.gz ... 865817815
# ==> PASV ... done.    ==> RETR SRR9985507_2.fastq.gz ... done.
# Length: 865817815 (826M) (unauthoritative)
#
# SRR9985507_2.fastq. 100%[===================>] 825.71M  6.74MB/s    in 1m 43s
#
# 2021-04-06 22:02:45 (8.00 MB/s) - ‘SRR9985507_2.fastq.gz’ saved [865817815]
#
# --2021-04-06 22:02:45--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_1.fastq.gz
#            => ‘SRR9985504_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985504 ... done.
# ==> SIZE SRR9985504_1.fastq.gz ... 615538795
# ==> PASV ... done.    ==> RETR SRR9985504_1.fastq.gz ... done.
# Length: 615538795 (587M) (unauthoritative)
#
# SRR9985504_1.fastq. 100%[===================>] 587.02M  36.8MB/s    in 19s
#
# 2021-04-06 22:03:06 (30.4 MB/s) - ‘SRR9985504_1.fastq.gz’ saved [615538795]
#
# --2021-04-06 22:03:06--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985504/SRR9985504_2.fastq.gz
#            => ‘SRR9985504_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985504 ... done.
# ==> SIZE SRR9985504_2.fastq.gz ... 617583143
# ==> PASV ... done.    ==> RETR SRR9985504_2.fastq.gz ... done.
# Length: 617583143 (589M) (unauthoritative)
#
# SRR9985504_2.fastq. 100%[===================>] 588.97M  11.6MB/s    in 34s
#
# 2021-04-06 22:03:41 (17.3 MB/s) - ‘SRR9985504_2.fastq.gz’ saved [617583143]
#
# --2021-04-06 22:03:41--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_1.fastq.gz
#            => ‘SRR9985502_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985502 ... done.
# ==> SIZE SRR9985502_1.fastq.gz ... 619148817
# ==> PASV ... done.    ==> RETR SRR9985502_1.fastq.gz ... done.
# Length: 619148817 (590M) (unauthoritative)
#
# SRR9985502_1.fastq. 100%[===================>] 590.47M  35.4MB/s    in 19s
#
# 2021-04-06 22:04:01 (31.1 MB/s) - ‘SRR9985502_1.fastq.gz’ saved [619148817]
#
# --2021-04-06 22:04:02--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985502/SRR9985502_2.fastq.gz
#            => ‘SRR9985502_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985502 ... done.
# ==> SIZE SRR9985502_2.fastq.gz ... 612217436
# ==> PASV ... done.    ==> RETR SRR9985502_2.fastq.gz ... done.
# Length: 612217436 (584M) (unauthoritative)
#
# SRR9985502_2.fastq. 100%[===================>] 583.86M  35.7MB/s    in 18s
#
# 2021-04-06 22:04:20 (32.7 MB/s) - ‘SRR9985502_2.fastq.gz’ saved [612217436]
#
# --2021-04-06 22:04:21--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_1.fastq.gz
#            => ‘SRR9985500_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985500 ... done.
# ==> SIZE SRR9985500_1.fastq.gz ... 588894835
# ==> PASV ... done.    ==> RETR SRR9985500_1.fastq.gz ... done.
# Length: 588894835 (562M) (unauthoritative)
#
# SRR9985500_1.fastq. 100%[===================>] 561.61M  35.2MB/s    in 17s
#
# 2021-04-06 22:04:39 (32.9 MB/s) - ‘SRR9985500_1.fastq.gz’ saved [588894835]
#
# --2021-04-06 22:04:39--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985500/SRR9985500_2.fastq.gz
#            => ‘SRR9985500_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985500 ... done.
# ==> SIZE SRR9985500_2.fastq.gz ... 588149966
# ==> PASV ... done.    ==> RETR SRR9985500_2.fastq.gz ... done.
# Length: 588149966 (561M) (unauthoritative)
#
# SRR9985500_2.fastq. 100%[===================>] 560.90M  37.0MB/s    in 17s
#
# 2021-04-06 22:04:57 (32.4 MB/s) - ‘SRR9985500_2.fastq.gz’ saved [588149966]
#
# --2021-04-06 22:04:58--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_1.fastq.gz
#            => ‘SRR9985499_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985499 ... done.
# ==> SIZE SRR9985499_1.fastq.gz ... 592578996
# ==> PASV ... done.    ==> RETR SRR9985499_1.fastq.gz ... done.
# Length: 592578996 (565M) (unauthoritative)
#
# SRR9985499_1.fastq. 100%[===================>] 565.13M  36.9MB/s    in 18s
#
# 2021-04-06 22:05:17 (31.1 MB/s) - ‘SRR9985499_1.fastq.gz’ saved [592578996]
#
# --2021-04-06 22:05:17--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/009/SRR9985499/SRR9985499_2.fastq.gz
#            => ‘SRR9985499_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/009/SRR9985499 ... done.
# ==> SIZE SRR9985499_2.fastq.gz ... 593876466
# ==> PASV ... done.    ==> RETR SRR9985499_2.fastq.gz ... done.
# Length: 593876466 (566M) (unauthoritative)
#
# SRR9985499_2.fastq. 100%[===================>] 566.36M  37.2MB/s    in 20s
#
# 2021-04-06 22:05:38 (28.9 MB/s) - ‘SRR9985499_2.fastq.gz’ saved [593876466]
#
# --2021-04-06 22:05:38--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_1.fastq.gz
#            => ‘SRR9985501_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985501 ... done.
# ==> SIZE SRR9985501_1.fastq.gz ... 622446193
# ==> PASV ... done.    ==> RETR SRR9985501_1.fastq.gz ... done.
# Length: 622446193 (594M) (unauthoritative)
#
# SRR9985501_1.fastq. 100%[===================>] 593.61M  35.7MB/s    in 17s
#
# 2021-04-06 22:05:56 (34.0 MB/s) - ‘SRR9985501_1.fastq.gz’ saved [622446193]
#
# --2021-04-06 22:05:57--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985501/SRR9985501_2.fastq.gz
#            => ‘SRR9985501_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985501 ... done.
# ==> SIZE SRR9985501_2.fastq.gz ... 618131589
# ==> PASV ... done.    ==> RETR SRR9985501_2.fastq.gz ... done.
# Length: 618131589 (589M) (unauthoritative)
#
# SRR9985501_2.fastq. 100%[===================>] 589.50M  37.5MB/s    in 33s
#
# 2021-04-06 22:06:30 (18.1 MB/s) - ‘SRR9985501_2.fastq.gz’ saved [618131589]
#
# --2021-04-06 22:06:30--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_1.fastq.gz
#            => ‘SRR9985498_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985498 ... done.
# ==> SIZE SRR9985498_1.fastq.gz ... 848592429
# ==> PASV ... done.    ==> RETR SRR9985498_1.fastq.gz ... done.
# Length: 848592429 (809M) (unauthoritative)
#
# SRR9985498_1.fastq. 100%[===================>] 809.28M  35.8MB/s    in 2m 44s
#
# 2021-04-06 22:09:16 (4.94 MB/s) - ‘SRR9985498_1.fastq.gz’ saved [848592429]
#
# --2021-04-06 22:09:16--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985498/SRR9985498_2.fastq.gz
#            => ‘SRR9985498_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985498 ... done.
# ==> SIZE SRR9985498_2.fastq.gz ... 854567084
# ==> PASV ... done.    ==> RETR SRR9985498_2.fastq.gz ... done.
# Length: 854567084 (815M) (unauthoritative)
#
# SRR9985498_2.fastq. 100%[===================>] 814.98M  14.7MB/s    in 71s
#
# 2021-04-06 22:10:28 (11.5 MB/s) - ‘SRR9985498_2.fastq.gz’ saved [854567084]
#
# --2021-04-06 22:10:28--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998
  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_1.fastq.gz
#            => ‘SRR9985516_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985516 ... done.
# ==> SIZE SRR9985516_1.fastq.gz ... 301189179
# ==> PASV ... done.    ==> RETR SRR9985516_1.fastq.gz ... done.
# Length: 301189179 (287M) (unauthoritative)
#
# SRR9985516_1.fastq. 100%[===================>] 287.24M  5.19MB/s    in 38s
#
# 2021-04-06 22:16:21 (7.47 MB/s) - ‘SRR9985516_1.fastq.gz’ saved [301189179]
#
# --2021-04-06 22:16:21--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/006/SRR9985516/SRR9985516_2.fastq.gz
#            => ‘SRR9985516_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/006/SRR9985516 ... done.
# ==> SIZE SRR9985516_2.fastq.gz ... 308733725
# ==> PASV ... done.    ==> RETR SRR9985516_2.fastq.gz ... done.
# Length: 308733725 (294M) (unauthoritative)
#
# SRR9985516_2.fastq. 100%[===================>] 294.43M  30.0MB/s    in 12s
#
# 2021-04-06 22:16:34 (23.6 MB/s) - ‘SRR9985516_2.fastq.gz’ saved [308733725]
#
# --2021-04-06 22:16:34--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_1.fastq.gz
#            => ‘SRR9985517_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985517 ... done.
# ==> SIZE SRR9985517_1.fastq.gz ... 300067368
# ==> PASV ... done.    ==> RETR SRR9985517_1.fastq.gz ... done.
# Length: 300067368 (286M) (unauthoritative)
#
# SRR9985517_1.fastq. 100%[===================>] 286.17M  35.6MB/s    in 9.2s
#
# 2021-04-06 22:16:45 (31.2 MB/s) - ‘SRR9985517_1.fastq.gz’ saved [300067368]
#
# --2021-04-06 22:16:45--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/007/SRR9985517/SRR9985517_2.fastq.gz
#            => ‘SRR9985517_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/007/SRR9985517 ... done.
# ==> SIZE SRR9985517_2.fastq.gz ... 306479429
# ==> PASV ... done.    ==> RETR SRR9985517_2.fastq.gz ... done.
# Length: 306479429 (292M) (unauthoritative)
#
# SRR9985517_2.fastq. 100%[===================>] 292.28M  17.1MB/s    in 15s
#
# 2021-04-06 22:17:02 (19.1 MB/s) - ‘SRR9985517_2.fastq.gz’ saved [306479429]
#
# --2021-04-06 22:17:02--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_1.fastq.gz
#            => ‘SRR9985518_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985518 ... done.
# ==> SIZE SRR9985518_1.fastq.gz ... 738541328
# ==> PASV ... done.    ==> RETR SRR9985518_1.fastq.gz ... done.
# Length: 738541328 (704M) (unauthoritative)
#
# SRR9985518_1.fastq. 100%[===================>] 704.33M  19.9MB/s    in 23s
#
# 2021-04-06 22:17:26 (30.2 MB/s) - ‘SRR9985518_1.fastq.gz’ saved [738541328]
#
# --2021-04-06 22:17:26--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985518/SRR9985518_2.fastq.gz
#            => ‘SRR9985518_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985518 ... done.
# ==> SIZE SRR9985518_2.fastq.gz ... 753461882
# ==> PASV ... done.    ==> RETR SRR9985518_2.fastq.gz ... done.
# Length: 753461882 (719M) (unauthoritative)
#
# SRR9985518_2.fastq. 100%[===================>] 718.56M  36.6MB/s    in 40s
#
# 2021-04-06 22:18:07 (18.1 MB/s) - ‘SRR9985518_2.fastq.gz’ saved [753461882]
#
# --2021-04-06 22:18:07--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_1.fastq.gz
#            => ‘SRR9985511_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985511 ... done.
# ==> SIZE SRR9985511_1.fastq.gz ... 734798658
# ==> PASV ... done.    ==> RETR SRR9985511_1.fastq.gz ... done.
# Length: 734798658 (701M) (unauthoritative)
#
# SRR9985511_1.fastq. 100%[===================>] 700.76M  36.6MB/s    in 21s
#
# 2021-04-06 22:18:30 (33.1 MB/s) - ‘SRR9985511_1.fastq.gz’ saved [734798658]
#
# --2021-04-06 22:18:30--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/001/SRR9985511/SRR9985511_2.fastq.gz
#            => ‘SRR9985511_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/001/SRR9985511 ... done.
# ==> SIZE SRR9985511_2.fastq.gz ... 740300733
# ==> PASV ... done.    ==> RETR SRR9985511_2.fastq.gz ... done.
# Length: 740300733 (706M) (unauthoritative)
#
# SRR9985511_2.fastq. 100%[===================>] 706.00M  36.2MB/s    in 84s
#
# 2021-04-06 22:19:55 (8.40 MB/s) - ‘SRR9985511_2.fastq.gz’ saved [740300733]
#
# --2021-04-06 22:19:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_1.fastq.gz
#            => ‘SRR9985515_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985515 ... done.
# ==> SIZE SRR9985515_1.fastq.gz ... 326544779
# ==> PASV ... done.    ==> RETR SRR9985515_1.fastq.gz ... done.
# Length: 326544779 (311M) (unauthoritative)
#
# SRR9985515_1.fastq. 100%[===================>] 311.42M  35.7MB/s    in 10s
#
# 2021-04-06 22:20:07 (30.1 MB/s) - ‘SRR9985515_1.fastq.gz’ saved [326544779]
#
# --2021-04-06 22:20:07--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/005/SRR9985515/SRR9985515_2.fastq.gz
#            => ‘SRR9985515_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/005/SRR9985515 ... done.
# ==> SIZE SRR9985515_2.fastq.gz ... 325966360
# ==> PASV ... done.    ==> RETR SRR9985515_2.fastq.gz ... done.
# Length: 325966360 (311M) (unauthoritative)
#
# SRR9985515_2.fastq. 100%[===================>] 310.87M  22.1MB/s    in 12s
#
# 2021-04-06 22:20:20 (25.4 MB/s) - ‘SRR9985515_2.fastq.gz’ saved [325966360]
#
# --2021-04-06 22:20:20--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_1.fastq.gz
#            => ‘SRR9985514_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985514 ... done.
# ==> SIZE SRR9985514_1.fastq.gz ... 327004580
# ==> PASV ... done.    ==> RETR SRR9985514_1.fastq.gz ... done.
# Length: 327004580 (312M) (unauthoritative)
#
# SRR9985514_1.fastq. 100%[===================>] 311.86M  36.9MB/s    in 9.7s
#
# 2021-04-06 22:20:32 (32.2 MB/s) - ‘SRR9985514_1.fastq.gz’ saved [327004580]
#
# --2021-04-06 22:20:32--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/004/SRR9985514/SRR9985514_2.fastq.gz
#            => ‘SRR9985514_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/004/SRR9985514 ... done.
# ==> SIZE SRR9985514_2.fastq.gz ... 327681334
# ==> PASV ... done.    ==> RETR SRR9985514_2.fastq.gz ... done.
# Length: 327681334 (313M) (unauthoritative)
#
# SRR9985514_2.fastq. 100%[===================>] 312.50M  37.1MB/s    in 15s
#
# 2021-04-06 22:20:47 (21.2 MB/s) - ‘SRR9985514_2.fastq.gz’ saved [327681334]
#
# --2021-04-06 22:20:48--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_1.fastq.gz
#            => ‘SRR9985512_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985512 ... done.
# ==> SIZE SRR9985512_1.fastq.gz ... 310550951
# ==> PASV ... done.    ==> RETR SRR9985512_1.fastq.gz ... done.
# Length: 310550951 (296M) (unauthoritative)
#
# SRR9985512_1.fastq. 100%[===================>] 296.16M  33.1MB/s    in 10s
#
# 2021-04-06 22:20:59 (28.5 MB/s) - ‘SRR9985512_1.fastq.gz’ saved [310550951]
#
# --2021-04-06 22:20:59--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/002/SRR9985512/SRR9985512_2.fastq.gz
#            => ‘SRR9985512_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/002/SRR9985512 ... done.
# ==> SIZE SRR9985512_2.fastq.gz ... 317079656
# ==> PASV ... done.    ==> RETR SRR9985512_2.fastq.gz ... done.
# Length: 317079656 (302M) (unauthoritative)
#
# SRR9985512_2.fastq. 100%[===================>] 302.39M  32.8MB/s    in 10s
#
# 2021-04-06 22:21:10 (30.2 MB/s) - ‘SRR9985512_2.fastq.gz’ saved [317079656]
#
# --2021-04-06 22:21:10--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_1.fastq.gz
#            => ‘SRR9985510_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985510 ... done.
# ==> SIZE SRR9985510_1.fastq.gz ... 735054841
# ==> PASV ... done.    ==> RETR SRR9985510_1.fastq.gz ... done.
# Length: 735054841 (701M) (unauthoritative)
#
# SRR9985510_1.fastq. 100%[===================>] 701.00M  35.4MB/s    in 28s
#
# 2021-04-06 22:21:40 (24.7 MB/s) - ‘SRR9985510_1.fastq.gz’ saved [735054841]
#
# --2021-04-06 22:21:40--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/000/SRR9985510/SRR9985510_2.fastq.gz
#            => ‘SRR9985510_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/000/SRR9985510 ... done.
# ==> SIZE SRR9985510_2.fastq.gz ... 743516384
# ==> PASV ... done.    ==> RETR SRR9985510_2.fastq.gz ... done.
# Length: 743516384 (709M) (unauthoritative)
#
# SRR9985510_2.fastq. 100%[===================>] 709.07M  37.2MB/s    in 21s
#
# 2021-04-06 22:22:02 (33.5 MB/s) - ‘SRR9985510_2.fastq.gz’ saved [743516384]
#
# --2021-04-06 22:22:02--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_1.fastq.gz
#            => ‘SRR9985508_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985508 ... done.
# ==> SIZE SRR9985508_1.fastq.gz ... 668694771
# ==> PASV ... done.    ==> RETR SRR9985508_1.fastq.gz ... done.
# Length: 668694771 (638M) (unauthoritative)
#
# SRR9985508_1.fastq. 100%[===================>] 637.72M  37.5MB/s    in 24s
#
# 2021-04-06 22:22:28 (26.4 MB/s) - ‘SRR9985508_1.fastq.gz’ saved [668694771]
#
# --2021-04-06 22:22:28--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/008/SRR9985508/SRR9985508_2.fastq.gz
#            => ‘SRR9985508_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/008/SRR9985508 ... done.
# ==> SIZE SRR9985508_2.fastq.gz ... 679453991
# ==> PASV ... done.    ==> RETR SRR9985508_2.fastq.gz ... done.
# Length: 679453991 (648M) (unauthoritative)
#
# SRR9985508_2.fastq. 100%[===================>] 647.98M  36.3MB/s    in 20s
#
# 2021-04-06 22:22:49 (32.6 MB/s) - ‘SRR9985508_2.fastq.gz’ saved [679453991]
#
# --2021-04-06 22:22:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_1.fastq.gz
#            => ‘SRR9985513_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985513 ... done.
# ==> SIZE SRR9985513_1.fastq.gz ... 309178433
# ==> PASV ... done.    ==> RETR SRR9985513_1.fastq.gz ... done.
# Length: 309178433 (295M) (unauthoritative)
#
# SRR9985513_1.fastq. 100%[===================>] 294.86M  36.6MB/s    in 10s
#
# 2021-04-06 22:23:00 (28.9 MB/s) - ‘SRR9985513_1.fastq.gz’ saved [309178433]
#
# --2021-04-06 22:23:00--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR998/003/SRR9985513/SRR9985513_2.fastq.gz
#            => ‘SRR9985513_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR998/003/SRR9985513 ... done.
# ==> SIZE SRR9985513_2.fastq.gz ... 314534778
# ==> PASV ... done.    ==> RETR SRR9985513_2.fastq.gz ... done.
# Length: 314534778 (300M) (unauthoritative)
#
# SRR9985513_2.fastq. 100%[===================>] 299.96M  37.3MB/s    in 14s
#
# 2021-04-06 22:23:15 (21.9 MB/s) - ‘SRR9985513_2.fastq.gz’ saved [314534778]

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# /content/fastqs
# [2021-04-06 22:23:18,937]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:24<00:00, 28.4MB/s]
# [2021-04-06 22:24:44,614]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)
# Out:
# ['SRR9985495_1.fastq.gz', 'SRR9985495_2.fastq.gz', 'SRR9985496_1.fastq.gz', 'SRR9985496_2.fastq.gz', 'SRR9985497_1.fastq.gz', 'SRR9985497_2.fastq.gz', 'SRR9985498_1.fastq.gz', 'SRR9985498_2.fastq.gz', 'SRR9985499_1.fastq.gz', 'SRR9985499_2.fastq.gz', 'SRR9985500_1.fastq.gz', 'SRR9985500_2.fastq.gz', 'SRR9985501_1.fastq.gz', 'SRR9985501_2
#  'SRR9985517_1.fastq.gz',
#  'SRR9985517_2.fastq.gz',
#  'SRR9985518_1.fastq.gz',
#  'SRR9985518_2.fastq.gz']

# %%
if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[0] + " "\
  + "--filter bustools --tcc -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[i] + " \
    --filter bustools --tcc -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]






results = {}
tcc_results = {}
for sample in sample_id:
  # Read the filtered gene count matrix
  results["data_" + sample] = anndata.read("/content/result" + sample)


for sample in sample_id:
  output = "bus_raw_" + sample + "_from_gc"
  # !mkdir $output
  folder_tcc = "tccoutput" + sample

  # read tcc matrix
  tcc_results[sample] = anndata.read(folder_tcc + "/counts_unfiltered/adata.h5ad")
  # apply gene count matrix's filter
  tcc_results[sample] = tcc_results[sample][results["data_" + sample].obs.index.values]
  # transfer obs data
  tcc_results[sample].obs = results["data_" + sample].obs
  # transfer metadata
  tcc_results[sample].uns = results["data_" + sample].uns
  # write tcc matrix
  tcc_results[sample].write("/content/tcc_" + sample)
  #gzip tcc matrix
  cmd = "gzip /content/tcc_" + sample
  # !$cmd
  #gzip unfiltered bus file
  cmd = "gzip " + folder_tcc + "/output.unfiltered.bus"
  # !$cmd
  # move and re-name bus file with sample id
  cmd = "mv " + folder_tcc + "/output.unfiltered.bus.gz " + output + "/" + sample +".unfiltered.bus.gz"
  # !$cmd
  # gzip all unfiltered counts
  cmd = "gzip " + folder_tcc + "/counts_unfiltered/*"
  # !$cmd

  # move unfiltered counts for both
  cmd = "mv " + folder_tcc + "/counts_unfiltered " + output + "/tcc_unfiltered"
  # !$cmd

  cmd = "mv " + folder_tcc + "/*.json " + output 
  # !$cmd
  # zip all files
  cmd = "zip -r "+ output + ".zip " + output
  # !$cmd
# Out:
# [2021-04-06 22:25:26,312]    INFO Using index index.idx to generate BUS file to tccoutputGSM4037325 from
# [2021-04-06 22:25:26,313]    INFO         SRR9985495_1.fastq.gz
# [2021-04-06 22:25:26,313]    INFO         SRR9985495_2.fastq.gz
# [2021-04-06 22:25:26,313]    INFO         SRR9985496_1.fastq.gz
# [2021-04-06 22:25:26,313]    INFO         SRR9985496_2.fastq.gz
# [2021-04-06 22:25:26,313]    INFO         SRR9985497_1.fastq.gz
# [2021-04-06 22:25:26,313]    INFO         SRR9985497_2.fastq.gz
# [2021-04-06 22:25:26,313]    INFO         SRR9985498_1.fastq.gz
# [2021-04-06 23:15:12,134]    INFO Sorting BUS file tccoutputGSM4037325/output.bus to tccoutputGSM4037325/tmp/output.s.bus
# [2021-04-06 23:17:55,681]    INFO Whitelist not provided
# [2021-04-06 23:17:55,684]    INFO Copying pre-packaged 10XV2 whitelist to tccoutputGSM4037325
# [2021-04-06 23:17:55,859]    INFO Inspecting BUS file tccoutputGSM4037325/tmp/output.s.bus
# [2021-04-06 23:18:44,844]    INFO Correcting BUS records in tccoutputGSM4037325/tmp/output.s.bus to tccoutputGSM4037325/tmp/output.s.c.bus with whitelist tccoutputGSM4037325/10xv2_whitelist.txt
# [2021-04-06 23:19:21,096]    INFO Sorting BUS file tccoutputGSM4037325/tmp/output.s.c.bus to tccoutputGSM4037325/output.unfiltered.bus
# [2021-04-06 23:20:53,649]    INFO Generating count matrix tccoutputGSM4037325/counts_unfiltered/cells_x_tcc from BUS file tccoutputGSM4037325/output.unfiltered.bus
# [2021-04-06 23:22:52,937]    INFO Reading matrix tccoutputGSM4037325/counts_unfiltered/cells_x_tcc.mtx
# [2021-04-06 23:24:14,666]    INFO Writing matrix to h5ad tccoutputGSM4037325/counts_unfiltered/adata.h5ad
# [2021-04-06 23:25:59,519]    INFO Filtering with bustools
# [2021-04-06 23:25:59,519]    INFO Generating whitelist tccoutputGSM4037325/filter_barcodes.txt from BUS file tccoutputGSM4037325/output.unfiltered.bus
# [2021-04-06 23:26:00,633]    INFO Correcting BUS records in tccoutputGSM4037325/output.unfiltered.bus to tccoutputGSM4037325/tmp/output.unfiltered.c.bus with whitelist tccoutputGSM4037325/filter_barcodes.txt
# [2021-04-06 23:26:31,930]    INFO Sorting BUS file tccoutputGSM4037325/tmp/output.unfiltered.c.bus to tccoutputGSM4037325/output.filtered.bus
# [2021-04-06 23:27:15,116]    INFO Generating count matrix tccoutputGSM4037325/counts_filtered/cells_x_tcc from BUS file tccoutputGSM4037325/output.filtered.bus
# [2021-04-06 23:28:09,207]    INFO Reading matrix tccoutputGSM4037325/counts_filtered/cells_x_tcc.mtx
# [2021-04-06 23:28:50,333]    INFO Writing matrix to h5ad tccoutputGSM4037325/counts_filtered/adata.h5ad
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   adding: bus_raw_GSM4037325_from_gc/ (stored 0%)
#   adding: bus_raw_GSM4037325_from_gc/run_info.json (deflated 73%)
#   adding: bus_raw_GSM4037325_from_gc/inspect.json (deflated 57%)
#   adding: bus_raw_GSM4037325_from_gc/GSM4037325.unfiltered.bus.gz (deflated 3%)
#   adding: bus_raw_GSM4037325_from_gc/kb_info.json (deflated 83%)
#   adding: bus_raw_GSM4037325_from_gc/tcc_unfiltered/ (stored 0%)
#   adding: bus_raw_GSM4037325_from_gc/tcc_unfiltered/adata.h5ad.gz (deflated 5%)
#   adding: bus_raw_GSM4037325_from_gc/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: bus_raw_GSM4037325_from_gc/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_GSM4037325_from_gc/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 3%)
