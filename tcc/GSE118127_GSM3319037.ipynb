# %% [markdown]
# <a href="https://colab.research.google.com/github/agalvezm/ACE2_scRNAseq/blob/master/tcc/GSE118127_GSM3319037.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GSE118127_GSM3319037

# %%
# define the values for the analysis

# accession id for the data
id = "GSE118127"
samp_id = "GSM3319037"

# If only bam available files, set bam = True, Fill link and filename
bam = True

if bam:
  # Assign link to python variable
  link_to_bam = "https://sra-pub-src-1.s3.amazonaws.com/SRR7644623/sample_1_6.bam.1"
  
  # Assigns the link to the bash variable BAM_LINK. To be used by wget
  # %env BAM_LINK=$link_to_bam

  # Assign filename to python variable. Used to convert to fastq and remove bam file to fastq after conversion

  bam_filename="sample_1_6.bam.1"

if not bam:
  fastqs = ["",
            "",
            ]
# Out:
# env: BAM_LINK=https://sra-pub-src-1.s3.amazonaws.com/SRR7644623/sample_1_6.bam.1

# %%
no_samples = 1

sample_id = [samp_id] * no_samples

database_id = [id] * no_samples

tissue = ["ovary"] * no_samples

cell_type = ["stroma"] * no_samples

condition = ["sample 1-6"] * no_samples

species = ["human"] * no_samples

technology = ["10xv2"] * no_samples

paper = ["Muus et al 2020"] * no_samples

figure = ["Fig 1 a,b  ED Fig 1 a,b,c,d  ED Fig 2 a,b,c,d,e"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'
# Out:
#      |████████████████████████████████| 59.1MB 77kB/s
#      |████████████████████████████████| 51kB 6.5MB/s
#      |████████████████████████████████| 10.3MB 43.8MB/s
#      |████████████████████████████████| 13.2MB 51.8MB/s
#      |████████████████████████████████| 122kB 44.3MB/s
#      |████████████████████████████████| 112kB 26.3MB/s
#      |████████████████████████████████| 71kB 8.2MB/s
#      |████████████████████████████████| 51kB 6.4MB/s
#   Building wheel for loompy (setup.py) ... done
#   Building wheel for numpy-groupies (setup.py) ... done
#   Building wheel for sinfo (setup.py) ... done

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}
# Out:
# --2021-03-01 04:26:43--  http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
# Resolving cf.10xgenomics.com (cf.10xgenomics.com)... 104.18.1.173, 104.18.0.173, 2606:4700::6812:1ad, ...
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cf.10xgenomics.com/misc/bamtofastq-1.2.0 [following]
# --2021-03-01 04:26:43--  https://cf.10xgenomics.com/misc/bamtofastq-1.2.0
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13288280 (13M) [binary/octet-stream]
# Saving to: ‘bamtofastq-1.2.0’
#
# bamtofastq-1.2.0    100%[===================>]  12.67M  23.7MB/s    in 0.5s
#
# 2021-03-01 04:26:43 (23.7 MB/s) - ‘bamtofastq-1.2.0’ saved [13288280/13288280]
#
# --2021-03-01 04:26:44--  http://continue/
# Resolving continue (continue)... failed: Name or service not known.
# wget: unable to resolve host address ‘continue’
# --2021-03-01 04:26:44--  https://sra-pub-src-1.s3.amazonaws.com/SRR7644623/sample_1_6.bam.1
# Resolving sra-pub-src-1.s3.amazonaws.com (sra-pub-src-1.s3.amazonaws.com)... 52.217.108.164
# Connecting to sra-pub-src-1.s3.amazonaws.com (sra-pub-src-1.s3.amazonaws.com)|52.217.108.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4875905130 (4.5G) [application/x-troff-man]
# Saving to: ‘sample_1_6.bam.1’
#
# sample_1_6.bam.1    100%[===================>]   4.54G  41.0MB/s    in 2m 3s
#
# 2021-03-01 04:28:47 (37.9 MB/s) - ‘sample_1_6.bam.1’ saved [4875905130/4875905130]
#
# FINISHED --2021-03-01 04:28:47--
# Total wall clock time: 2m 3s
# Downloaded: 1 files, 4.5G in 2m 3s (37.9 MB/s)

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename
# Out:
# bamtofastq v1.2.0
# Args { arg_bam: "sample_1_6.bam.1", arg_output_path: "./fastqs", flag_nthreads: 4, flag_locus: None, flag_bx_list: None, flag_reads_per_fastq: 500000000, flag_gemcode: false, flag_lr20: false, flag_cr11: false }
# Writing finished.  Observed 38635729 read pairs. Wrote 38635729 read pairs

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)
# Out:
# /content/fastqs
# /content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX
#
#
# This is the complete list of fastqs:
#  -----------
# bamtofastq_S1_L007_R2_001.fastq.gz
# bamtofastq_S1_L007_R1_001.fastq.gz
# bamtofastq_S1_L007_I1_001.fastq.gz
#
#
# This is the filtered list of fastqs:
#  -----------
# bamtofastq_S1_L007_R2_001.fastq.gz
# bamtofastq_S1_L007_R1_001.fastq.gz

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta
# Out:
# [2021-03-01 04:36:07,999]    INFO Downloading files for human from https://caltech.box.com/shared/static/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz to tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz
# 100% 2.23G/2.23G [01:30<00:00, 26.3MB/s]
# [2021-03-01 04:37:40,125]    INFO Extracting files from tmp/v1nm7lpnqz5syh8dyzdk2zs8bglncfib.gz

# %%
print(fastqs)
# Out:
# ['bamtofastq_S1_L007_R1_001.fastq.gz', 'bamtofastq_S1_L007_R2_001.fastq.gz']

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['bamtofastq_S1_L007_R1_001.fastq.gz', 'bamtofastq_S1_L007_R2_001.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended
number_of_samples = 1
fastqs_per_sample = 2

if number_of_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(number_of_samples):

    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " +\
    fastqs[j] + " " + fastqs[j+1]

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample
# Out:
# [2021-03-01 04:38:23,664]    INFO Using index index.idx to generate BUS file to outputGSM3319037 from
# [2021-03-01 04:38:23,664]    INFO         bamtofastq_S1_L007_R1_001.fastq.gz
# [2021-03-01 04:38:23,664]    INFO         bamtofastq_S1_L007_R2_001.fastq.gz
# [2021-03-01 04:46:18,483]    INFO Sorting BUS file outputGSM3319037/output.bus to outputGSM3319037/tmp/output.s.bus
# [2021-03-01 04:46:32,362]    INFO Whitelist not provided
# [2021-03-01 04:46:32,362]    INFO Copying pre-packaged 10XV2 whitelist to outputGSM3319037
# [2021-03-01 04:46:32,635]    INFO Inspecting BUS file outputGSM3319037/tmp/output.s.bus
# [2021-03-01 04:46:39,281]    INFO Correcting BUS records in outputGSM3319037/tmp/output.s.bus to outputGSM3319037/tmp/output.s.c.bus with whitelist outputGSM3319037/10xv2_whitelist.txt
# [2021-03-01 04:46:44,032]    INFO Sorting BUS file outputGSM3319037/tmp/output.s.c.bus to outputGSM3319037/output.unfiltered.bus
# [2021-03-01 04:46:55,260]    INFO Generating count matrix outputGSM3319037/counts_unfiltered/cells_x_genes from BUS file outputGSM3319037/output.unfiltered.bus
# [2021-03-01 04:47:08,019]    INFO Reading matrix outputGSM3319037/counts_unfiltered/cells_x_genes.mtx
# [2021-03-01 04:47:14,965]    INFO Writing matrix to h5ad outputGSM3319037/counts_unfiltered/adata.h5ad
# [2021-03-01 04:47:15,761]    INFO Filtering with bustools
# [2021-03-01 04:47:15,761]    INFO Generating whitelist outputGSM3319037/filter_barcodes.txt from BUS file outputGSM3319037/output.unfiltered.bus
# [2021-03-01 04:47:15,874]    INFO Correcting BUS records in outputGSM3319037/output.unfiltered.bus to outputGSM3319037/tmp/output.unfiltered.c.bus with whitelist outputGSM3319037/filter_barcodes.txt
# [2021-03-01 04:47:19,459]    INFO Sorting BUS file outputGSM3319037/tmp/output.unfiltered.c.bus to outputGSM3319037/output.filtered.bus
# [2021-03-01 04:47:28,184]    INFO Generating count matrix outputGSM3319037/counts_filtered/cells_x_genes from BUS file outputGSM3319037/output.filtered.bus
# [2021-03-01 04:47:39,214]    INFO Reading matrix outputGSM3319037/counts_filtered/cells_x_genes.mtx
# [2021-03-01 04:47:44,306]    INFO Writing matrix to h5ad outputGSM3319037/counts_filtered/adata.h5ad

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(number_of_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix GSM3319037 contains 219820 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 2700#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[i]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 30#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[i]].obs["cell_counts"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[i]].obs["percent_mito"][results[sample_id[i]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 2700 with at least 88.0 UMIs

# %% [markdown]
# # Filter matrix

# %%
for i in range(number_of_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]
# Out:
# We select 30 % as the mitochondrial content threshold
# Current Shape: 219,820 cells x 60,623 genes
#     New shape: 2,460 cells x 23,080 genes

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(number_of_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[samp_n]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[samp_n]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[samp_n]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[samp_n]

  results["data_" + sample_id[i]].uns["condition"] = condition[samp_n]

  results["data_" + sample_id[i]].uns["species"] = species[samp_n]

  results["data_" + sample_id[i]].uns["technology"] = technology[samp_n]

  results["data_" + sample_id[i]].uns["paper"] = paper[samp_n]

  results["data_" + sample_id[i]].uns["figure"] = figure[samp_n]
# Out:
# Trying to set attribute `.uns` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# %cd /content

for i in range(number_of_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
# Out:
# /content
# ... storing 'gene_name' as categorical

# %%
'''
Create TCC matrix
'''
if not bam:
  # %cd /content/fastqs

if bam:
  # %cd /content/fastqs/$_filename

if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[0] + " "\
  + "--filter bustools -t 2 --tcc --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o tccoutput" + sample_id[i] + " \
    --filter bustools -t 2 --tcc --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]


tcc_results = {}

for sample in sample_id:
  output = "bus_raw_" + sample
  # !mkdir $output
  folder_tcc = "tccoutput" + sample
  folder_gc = "output" + sample

  # read tcc matrix
  tcc_results[sample] = anndata.read(folder_tcc + "/counts_unfiltered/adata.h5ad")
  # apply gene count matrix's filter
  tcc_results[sample] = tcc_results[sample][results["data_" + sample_id[i]].obs.index.values]
  # transfer obs data
  tcc_results[sample].obs = results["data_" + sample].obs
  # transfer metadata
  tcc_results[sample].uns = results["data_" + sample].uns
  # write tcc matrix
  tcc_results[sample].write("/content/tcc_" + sample)
  #gzip tcc matrix
  cmd = "gzip /content/tcc_" + sample
  # !$cmd
  #gzip filtered bus file
  cmd = "gzip " + folder_tcc + "/output.filtered.bus"
  # !$cmd
  # move and re-name bus file with sample id
  cmd = "mv " + folder_tcc + "/output.filtered.bus.gz " + output + "/" + sample +".filtered.bus.gz"
  # !$cmd
  # gzip all unfiltered counts
  cmd = "gzip " + folder_tcc + "/counts_unfiltered/*"
  # !$cmd
  cmd = "gzip " + folder_gc + "/counts_unfiltered/*"
  # !$cmd
  # move unfiltered counts for both
  cmd = "mv " + folder_tcc + "/counts_unfiltered " + output + "/tcc_unfiltered"
  # !$cmd
  cmd = "mv " + folder_gc + "/counts_unfiltered " + output + "/gc_unfiltered"
  # !$cmd

  # zip all files
  cmd = "zip -r /content" + output + ".zip " + output
  # !$cmd
# Out:
# /content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX
# [2021-03-01 04:52:26,566]    INFO Using index index.idx to generate BUS file to tccoutputGSM3319037 from
# [2021-03-01 04:52:26,566]    INFO         bamtofastq_S1_L007_R1_001.fastq.gz
# [2021-03-01 04:52:26,566]    INFO         bamtofastq_S1_L007_R2_001.fastq.gz
# [2021-03-01 05:00:35,463]    INFO Sorting BUS file tccoutputGSM3319037/output.bus to tccoutputGSM3319037/tmp/output.s.bus
# [2021-03-01 05:00:48,810]    INFO Whitelist not provided
# [2021-03-01 05:00:48,810]    INFO Copying pre-packaged 10XV2 whitelist to tccoutputGSM3319037
# [2021-03-01 05:00:48,994]    INFO Inspecting BUS file tccoutputGSM3319037/tmp/output.s.bus
# [2021-03-01 05:00:55,622]    INFO Correcting BUS records in tccoutputGSM3319037/tmp/output.s.bus to tccoutputGSM3319037/tmp/output.s.c.bus with whitelist tccoutputGSM3319037/10xv2_whitelist.txt
# [2021-03-01 05:01:00,475]    INFO Sorting BUS file tccoutputGSM3319037/tmp/output.s.c.bus to tccoutputGSM3319037/output.unfiltered.bus
# [2021-03-01 05:01:10,343]    INFO Generating count matrix tccoutputGSM3319037/counts_unfiltered/cells_x_tcc from BUS file tccoutputGSM3319037/output.unfiltered.bus
# [2021-03-01 05:01:29,118]    INFO Reading matrix tccoutputGSM3319037/counts_unfiltered/cells_x_tcc.mtx
# [2021-03-01 05:01:49,024]    INFO Writing matrix to h5ad tccoutputGSM3319037/counts_unfiltered/adata.h5ad
# [2021-03-01 05:02:52,448]    INFO Filtering with bustools
# [2021-03-01 05:02:52,448]    INFO Generating whitelist tccoutputGSM3319037/filter_barcodes.txt from BUS file tccoutputGSM3319037/output.unfiltered.bus
# [2021-03-01 05:02:52,617]    INFO Correcting BUS records in tccoutputGSM3319037/output.unfiltered.bus to tccoutputGSM3319037/tmp/output.unfiltered.c.bus with whitelist tccoutputGSM3319037/filter_barcodes.txt
# [2021-03-01 05:02:56,176]    INFO Sorting BUS file tccoutputGSM3319037/tmp/output.unfiltered.c.bus to tccoutputGSM3319037/output.filtered.bus
# [2021-03-01 05:03:04,970]    INFO Generating count matrix tccoutputGSM3319037/counts_filtered/cells_x_tcc from BUS file tccoutputGSM3319037/output.filtered.bus
# [2021-03-01 05:03:21,612]    INFO Reading matrix tccoutputGSM3319037/counts_filtered/cells_x_tcc.mtx
# [2021-03-01 05:03:39,938]    INFO Writing matrix to h5ad tccoutputGSM3319037/counts_filtered/adata.h5ad
#   adding: bus_raw_GSM3319037/ (stored 0%)
#   adding: bus_raw_GSM3319037/gc_unfiltered/ (stored 0%)
#   adding: bus_raw_GSM3319037/gc_unfiltered/cells_x_genes.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_GSM3319037/gc_unfiltered/cells_x_genes.genes.txt.gz (deflated 0%)
#   adding: bus_raw_GSM3319037/gc_unfiltered/cells_x_genes.mtx.gz (deflated 0%)
#   adding: bus_raw_GSM3319037/gc_unfiltered/adata.h5ad.gz (deflated 6%)
#   adding: bus_raw_GSM3319037/tcc_unfiltered/ (stored 0%)
#   adding: bus_raw_GSM3319037/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 4%)
#   adding: bus_raw_GSM3319037/tcc_unfiltered/adata.h5ad.gz (deflated 10%)
#   adding: bus_raw_GSM3319037/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: bus_raw_GSM3319037/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: bus_raw_GSM3319037/GSM3319037.filtered.bus.gz (deflated 4%)

# %%
# !zip -r /content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037.zip /content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037
# Out:
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/ (stored 0%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/gc_unfiltered/ (stored 0%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/gc_unfiltered/cells_x_genes.barcodes.txt.gz (deflated 1%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/gc_unfiltered/cells_x_genes.genes.txt.gz (deflated 0%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/gc_unfiltered/cells_x_genes.mtx.gz (deflated 0%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/gc_unfiltered/adata.h5ad.gz (deflated 6%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/tcc_unfiltered/ (stored 0%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/tcc_unfiltered/cells_x_tcc.ec.txt.gz (deflated 4%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/tcc_unfiltered/adata.h5ad.gz (deflated 10%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/tcc_unfiltered/cells_x_tcc.mtx.gz (deflated 0%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/tcc_unfiltered/cells_x_tcc.barcodes.txt.gz (deflated 1%)
#   adding: content/fastqs/sample_1-6_MissingLibrary_1_HW2NMBBXX/bus_raw_GSM3319037/GSM3319037.filtered.bus.gz (deflated 4%)
