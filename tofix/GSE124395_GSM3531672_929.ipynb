1.fastq.gz	ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/006/SRR8371466/SRR8371466_2.fastq.gz"
  # Convert it to a list where each link is an element
  
  fastqs = links_raw.split()

# %%
no_samples = 1

fastqs_per_sample = [200] 

sample_id = samp_id

database_id = [id] * no_samples

tissue = ["liver"] * no_samples

cell_type = ["normal liver resection specimen"] * no_samples

condition = ["Colorectal cancer metastasis"] * no_samples

species = ["human"] * no_samples

technology = ["CELSeq2"] * no_samples

paper = ["Zhu et al. Preprint (2020)"] * no_samples

figure = ["Fig 2 a,b"] * no_samples


# Set string variables for kb functions

species_kb = species[0]

technology_kb = technology[0]

# %% [markdown]
# # Imports and installs

# %%
# install and import necessary software

# Install kb and scanpy
# !pip -q install kb-python 
# !pip -q install scanpy

import re
import os

# Setup

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import scanpy as sc
from scipy import stats

from collections import OrderedDict
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from matplotlib import cm
from matplotlib.lines import Line2D

def nd(arr):
    return np.asarray(arr).reshape(-1)
def yex(ax):
    lims = [np.min([ax.get_xlim(), ax.get_ylim()]),
            np.max([ax.get_xlim(), ax.get_ylim()])]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

def trim_axs(axs, N):
    """little helper to massage the axs list to have correct length..."""
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

import warnings
warnings.filterwarnings('ignore')

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Downloads: (bam (if bam) and index

# %%
if bam:

  # Install bamtofastq from 10x website (only bam files available)
  # !wget http://cf.10xgenomics.com/misc/bamtofastq-1.2.0
  # !chmod +x bamtofastq-1.2.0
  # Download the bam file
  # !wget -- continue ${BAM_LINK}

# %%
if bam:
  # Convert to fastq
  # !./bamtofastq-1.2.0 --reads-per-fastq=500000000 $bam_filename ./fastqs\

  # Remove original bam file to save space
  # !rm $bam_filename

# %%
# Store fastq names on a list

if bam:
  # cd into fastqs folder
  # %cd /content/fastqs

  #store the name of the folder generated by bamtofastq
  _filename = os.listdir()[0]

  # cd into that folder
  # %cd $_filename

  # store fastq names in a list
  fastqs = os.listdir()


  # Remove I1 and R3 reads not relevant for our analysis

  # Initialize list containing elements to remove
  remov_elem = []

  print ("\n\nThis is the complete list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

  # Search index (I1 or R3) fastqs and remove them from list
  for elem in fastqs:
    if re.search("_R3_", elem) or re.search("_I1_", elem):
      remov_elem = remov_elem +[elem]

  fastqs = [elem for elem in fastqs if elem not in remov_elem] 

  print ("\n\nThis is the filtered list of fastqs:\n -----------")
  for elem in fastqs:
    print (elem)

# %%
# Remove fastqs that wont be analyzed to save space
if bam:
  for elem in remov_elem:
    # !rm $elem

# %%
if bam:
  # sort fastqs alphabetically to get R1 and R2 in order
  fastqs = sorted(fastqs)

# %%
# wget fastqs from non ffq links in fastqs folder
if not bam and not fastq_ffqlinks:
  # !mkdir fastqs
  # %cd fastqs
  for link in fastqs:
    # !wget $link --continue

  # update fastqs variable with name of files
  fastqs = sorted(os.listdir())
# Out:
# Streaming output truncated to the last 5000 lines.
# ==> SIZE SRR8371268_2.fastq.gz ... 1112630995
# ==> PASV ... done.    ==> RETR SRR8371268_2.fastq.gz ... done.
# Length: 1112630995 (1.0G) (unauthoritative)
#
# SRR8371268_2.fastq. 100%[===================>]   1.04G  32.5MB/s    in 68s
#
# 2020-12-02 22:45:40 (15.6 MB/s) - ‘SRR8371268_2.fastq.gz’ saved [1112630995]
#
# --2020-12-02 22:45:40--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371269/SRR8371269_1.fastq.gz
#            => ‘SRR8371269_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371269 ... done.
# ==> SIZE SRR8371269_1.fastq.gz ... 355552779
# ==> PASV ... done.    ==> RETR SRR8371269_1.fastq.gz ... done.
# Length: 355552779 (339M) (unauthoritative)
#
# SRR8371269_1.fastq. 100%[===================>] 339.08M  31.9MB/s    in 19s
#
# 2020-12-02 22:46:01 (18.0 MB/s) - ‘SRR8371269_1.fastq.gz’ saved [355552779]
#
# --2020-12-02 22:46:01--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371269/SRR8371269_2.fastq.gz
#            => ‘SRR8371269_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371269 ... done.
# ==> SIZE SRR8371269_2.fastq.gz ... 968053036
# ==> PASV ... done.    ==> RETR SRR8371269_2.fastq.gz ... done.
# Length: 968053036 (923M) (unauthoritative)
#
# SRR8371269_2.fastq. 100%[===================>] 923.21M  32.2MB/s    in 33s
#
# 2020-12-02 22:46:35 (28.1 MB/s) - ‘SRR8371269_2.fastq.gz’ saved [968053036]
#
# --2020-12-02 22:46:35--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371270/SRR8371270_1.fastq.gz
#            => ‘SRR8371270_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371270 ... done.
# ==> SIZE SRR8371270_1.fastq.gz ... 289949983
# ==> PASV ... done.    ==> RETR SRR8371270_1.fastq.gz ... done.
# Length: 289949983 (277M) (unauthoritative)
#
# SRR8371270_1.fastq. 100%[===================>] 276.52M  8.23MB/s    in 80s
#
# 2020-12-02 22:47:57 (3.45 MB/s) - ‘SRR8371270_1.fastq.gz’ saved [289949983]
#
# --2020-12-02 22:47:57--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371270/SRR8371270_2.fastq.gz
#            => ‘SRR8371270_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371270 ... done.
# ==> SIZE SRR8371270_2.fastq.gz ... 748922810
# ==> PASV ... done.    ==> RETR SRR8371270_2.fastq.gz ... done.
# Length: 748922810 (714M) (unauthoritative)
#
# SRR8371270_2.fastq. 100%[===================>] 714.23M  33.0MB/s    in 24s
#
# 2020-12-02 22:48:22 (30.4 MB/s) - ‘SRR8371270_2.fastq.gz’ saved [748922810]
#
# --2020-12-02 22:48:22--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371271/SRR8371271_1.fastq.gz
#            => ‘SRR8371271_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371271 ... done.
# ==> SIZE SRR8371271_1.fastq.gz ... 366390648
# ==> PASV ... done.    ==> RETR SRR8371271_1.fastq.gz ... done.
# Length: 366390648 (349M) (unauthoritative)
#
# SRR8371271_1.fastq. 100%[===================>] 349.42M  32.1MB/s    in 20s
#
# 2020-12-02 22:48:43 (17.3 MB/s) - ‘SRR8371271_1.fastq.gz’ saved [366390648]
#
# --2020-12-02 22:48:43--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371271/SRR8371271_2.fastq.gz
#            => ‘SRR8371271_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371271 ... done.
# ==> SIZE SRR8371271_2.fastq.gz ... 1000600799
# ==> PASV ... done.    ==> RETR SRR8371271_2.fastq.gz ... done.
# Length: 1000600799 (954M) (unauthoritative)
#
# SRR8371271_2.fastq. 100%[===================>] 954.25M  33.1MB/s    in 32s
#
# 2020-12-02 22:49:17 (29.9 MB/s) - ‘SRR8371271_2.fastq.gz’ saved [1000600799]
#
# --2020-12-02 22:49:17--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371272/SRR8371272_1.fastq.gz
#            => ‘SRR8371272_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371272 ... done.
# ==> SIZE SRR8371272_1.fastq.gz ... 200485313
# ==> PASV ... done.    ==> RETR SRR8371272_1.fastq.gz ... done.
# Length: 200485313 (191M) (unauthoritative)
#
# SRR8371272_1.fastq. 100%[===================>] 191.20M  23.9MB/s    in 9.2s
#
# 2020-12-02 22:49:27 (20.8 MB/s) - ‘SRR8371272_1.fastq.gz’ saved [200485313]
#
# --2020-12-02 22:49:27--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371272/SRR8371272_2.fastq.gz
#            => ‘SRR8371272_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371272 ... done.
# ==> SIZE SRR8371272_2.fastq.gz ... 516598355
# ==> PASV ... done.    ==> RETR SRR8371272_2.fastq.gz ... done.
# Length: 516598355 (493M) (unauthoritative)
#
# SRR8371272_2.fastq. 100%[===================>] 492.67M  9.80MB/s    in 32s
#
# 2020-12-02 22:50:01 (15.3 MB/s) - ‘SRR8371272_2.fastq.gz’ saved [516598355]
#
# --2020-12-02 22:50:01--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371273/SRR8371273_1.fastq.gz
#            => ‘SRR8371273_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371273 ... done.
# ==> SIZE SRR8371273_1.fastq.gz ... 178074692
# ==> PASV ... done.    ==> RETR SRR8371273_1.fastq.gz ... done.
# Length: 178074692 (170M) (unauthoritative)
#
# SRR8371273_1.fastq. 100%[===================>] 169.83M  33.0MB/s    in 9.1s
#
# 2020-12-02 22:50:12 (18.6 MB/s) - ‘SRR8371273_1.fastq.gz’ saved [178074692]
#
# --2020-12-02 22:50:12--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371273/SRR8371273_2.fastq.gz
#            => ‘SRR8371273_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371273 ... done.
# ==> SIZE SRR8371273_2.fastq.gz ... 439431538
# ==> PASV ... done.    ==> RETR SRR8371273_2.fastq.gz ... done.
# Length: 439431538 (419M) (unauthoritative)
#
# SRR8371273_2.fastq. 100%[===================>] 419.07M  25.4MB/s    in 20s
#
# 2020-12-02 22:50:33 (20.8 MB/s) - ‘SRR8371273_2.fastq.gz’ saved [439431538]
#
# --2020-12-02 22:50:33--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371274/SRR8371274_1.fastq.gz
#            => ‘SRR8371274_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371274 ... done.
# ==> SIZE SRR8371274_1.fastq.gz ... 163453287
# ==> PASV ... done.    ==> RETR SRR8371274_1.fastq.gz ... done.
# Length: 163453287 (156M) (unauthoritative)
#
# SRR8371274_1.fastq. 100%[===================>] 155.88M  30.7MB/s    in 7.1s
#
# 2020-12-02 22:50:42 (21.9 MB/s) - ‘SRR8371274_1.fastq.gz’ saved [163453287]
#
# --2020-12-02 22:50:42--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371274/SRR8371274_2.fastq.gz
#            => ‘SRR8371274_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371274 ... done.
# ==> SIZE SRR8371274_2.fastq.gz ... 364374511
# ==> PASV ... done.    ==> RETR SRR8371274_2.fastq.gz ... done.
# Length: 364374511 (347M) (unauthoritative)
#
# SRR8371274_2.fastq. 100%[===================>] 347.49M  32.5MB/s    in 49s
#
# 2020-12-02 22:51:33 (7.03 MB/s) - ‘SRR8371274_2.fastq.gz’ saved [364374511]
#
# --2020-12-02 22:51:33--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371275/SRR8371275_1.fastq.gz
#            => ‘SRR8371275_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/005/SRR8371275 ... done.
# ==> SIZE SRR8371275_1.fastq.gz ... 267529871
# ==> PASV ... done.    ==> RETR SRR8371275_1.fastq.gz ... done.
# Length: 267529871 (255M) (unauthoritative)
#
# SRR8371275_1.fastq. 100%[===================>] 255.14M  33.1MB/s    in 9.6s
#
# 2020-12-02 22:51:44 (26.5 MB/s) - ‘SRR8371275_1.fastq.gz’ saved [267529871]
#
# --2020-12-02 22:51:44--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371275/SRR8371275_2.fastq.gz
#            => ‘SRR8371275_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/005/SRR8371275 ... done.
# ==> SIZE SRR8371275_2.fastq.gz ... 691452299
# ==> PASV ... done.    ==> RETR SRR8371275_2.fastq.gz ... done.
# Length: 691452299 (659M) (unauthoritative)
#
# SRR8371275_2.fastq. 100%[===================>] 659.42M  28.6MB/s    in 23s
#
# 2020-12-02 22:52:08 (28.5 MB/s) - ‘SRR8371275_2.fastq.gz’ saved [691452299]
#
# --2020-12-02 22:52:08--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/006/SRR8371276/SRR8371276_1.fastq.gz
#            => ‘SRR8371276_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/006/SRR8371276 ... done.
# ==> SIZE SRR8371276_1.fastq.gz ... 284746278
# ==> PASV ... done.    ==> RETR SRR8371276_1.fastq.gz ... done.
# Length: 284746278 (272M) (unauthoritative)
#
# SRR8371276_1.fastq. 100%[===================>] 271.55M  27.5MB/s    in 12s
#
# 2020-12-02 22:52:25 (23.1 MB/s) - ‘SRR8371276_1.fastq.gz’ saved [284746278]
#
# --2020-12-02 22:52:25--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/006/SRR8371276/SRR8371276_2.fastq.gz
#            => ‘SRR8371276_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/006/SRR8371276 ... done.
# ==> SIZE SRR8371276_2.fastq.gz ... 715770196
# ==> PASV ... done.    ==> RETR SRR8371276_2.fastq.gz ... done.
# Length: 715770196 (683M) (unauthoritative)
#
# SRR8371276_2.fastq. 100%[===================>] 682.61M  33.0MB/s    in 23s
#
# 2020-12-02 22:52:49 (30.3 MB/s) - ‘SRR8371276_2.fastq.gz’ saved [715770196]
#
# --2020-12-02 22:52:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/007/SRR8371277/SRR8371277_1.fastq.gz
#            => ‘SRR8371277_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/007/SRR8371277 ... done.
# ==> SIZE SRR8371277_1.fastq.gz ... 283206042
# ==> PASV ... done.    ==> RETR SRR8371277_1.fastq.gz ... done.
# Length: 283206042 (270M) (unauthoritative)
#
# SRR8371277_1.fastq. 100%[===================>] 270.09M  28.7MB/s    in 13s
#
# 2020-12-02 22:53:03 (21.6 MB/s) - ‘SRR8371277_1.fastq.gz’ saved [283206042]
#
# --2020-12-02 22:53:03--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/007/SRR8371277/SRR8371277_2.fastq.gz
#            => ‘SRR8371277_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/007/SRR8371277 ... done.
# ==> SIZE SRR8371277_2.fastq.gz ... 729236829
# ==> PASV ... done.    ==> RETR SRR8371277_2.fastq.gz ... done.
# Length: 729236829 (695M) (unauthoritative)
#
# SRR8371277_2.fastq. 100%[===================>] 695.45M  33.0MB/s    in 27s
#
# 2020-12-02 22:53:31 (26.0 MB/s) - ‘SRR8371277_2.fastq.gz’ saved [729236829]
#
# --2020-12-02 22:53:31--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371278/SRR8371278_1.fastq.gz
#            => ‘SRR8371278_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371278 ... done.
# ==> SIZE SRR8371278_1.fastq.gz ... 283894803
# ==> PASV ... done.    ==> RETR SRR8371278_1.fastq.gz ... done.
# Length: 283894803 (271M) (unauthoritative)
#
# SRR8371278_1.fastq. 100%[===================>] 270.74M  33.3MB/s    in 9.8s
#
# 2020-12-02 22:53:42 (27.6 MB/s) - ‘SRR8371278_1.fastq.gz’ saved [283894803]
#
# --2020-12-02 22:53:42--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371278/SRR8371278_2.fastq.gz
#            => ‘SRR8371278_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371278 ... done.
# ==> SIZE SRR8371278_2.fastq.gz ... 669119531
# ==> PASV ... done.    ==> RETR SRR8371278_2.fastq.gz ... done.
# Length: 669119531 (638M) (unauthoritative)
#
# SRR8371278_2.fastq. 100%[===================>] 638.12M  27.7MB/s    in 27s
#
# 2020-12-02 22:54:11 (23.6 MB/s) - ‘SRR8371278_2.fastq.gz’ saved [669119531]
#
# --2020-12-02 22:54:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371279/SRR8371279_1.fastq.gz
#            => ‘SRR8371279_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371279 ... done.
# ==> SIZE SRR8371279_1.fastq.gz ... 210418957
# ==> PASV ... done.    ==> RETR SRR8371279_1.fastq.gz ... done.
# Length: 210418957 (201M) (unauthoritative)
#
# SRR8371279_1.fastq. 100%[===================>] 200.67M  32.7MB/s    in 8.0s
#
# 2020-12-02 22:54:20 (25.2 MB/s) - ‘SRR8371279_1.fastq.gz’ saved [210418957]
#
# --2020-12-02 22:54:20--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371279/SRR8371279_2.fastq.gz
#            => ‘SRR8371279_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371279 ... done.
# ==> SIZE SRR8371279_2.fastq.gz ... 545730124
# ==> PASV ... done.    ==> RETR SRR8371279_2.fastq.gz ... done.
# Length: 545730124 (520M) (unauthoritative)
#
# SRR8371279_2.fastq. 100%[===================>] 520.45M  27.5MB/s    in 23s
#
# 2020-12-02 22:54:45 (22.3 MB/s) - ‘SRR8371279_2.fastq.gz’ saved [545730124]
#
# --2020-12-02 22:54:45--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371280/SRR8371280_1.fastq.gz
#            => ‘SRR8371280_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371280 ... done.
# ==> SIZE SRR8371280_1.fastq.gz ... 503797577
# ==> PASV ... done.    ==> RETR SRR8371280_1.fastq.gz ... done.
# Length: 503797577 (480M) (unauthoritative)
#
# SRR8371280_1.fastq. 100%[===================>] 480.46M  27.3MB/s    in 2m 22s
#
# 2020-12-02 22:57:08 (3.39 MB/s) - ‘SRR8371280_1.fastq.gz’ saved [503797577]
#
# --2020-12-02 22:57:08--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371280/SRR8371280_2.fastq.gz
#            => ‘SRR8371280_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371280 ... done.
# ==> SIZE SRR8371280_2.fastq.gz ... 1264022350
# ==> PASV ... done.    ==> RETR SRR8371280_2.fastq.gz ... done.
# Length: 1264022350 (1.2G) (unauthoritative)
#
# SRR8371280_2.fastq. 100%[===================>]   1.18G  16.3MB/s    in 66s
#
# 2020-12-02 22:58:15 (18.3 MB/s) - ‘SRR8371280_2.fastq.gz’ saved [1264022350]
#
# --2020-12-02 22:58:15--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371281/SRR8371281_1.fastq.gz
#            => ‘SRR8371281_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371281 ... done.
# ==> SIZE SRR8371281_1.fastq.gz ... 697786574
# ==> PASV ... done.    ==> RETR SRR8371281_1.fastq.gz ... done.
# Length: 697786574 (665M) (unauthoritative)
#
# SRR8371281_1.fastq. 100%[===================>] 665.46M  18.2MB/s    in 46s
#
# 2020-12-02 22:59:03 (14.6 MB/s) - ‘SRR8371281_1.fastq.gz’ saved [697786574]
#
# --2020-12-02 22:59:03--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371281/SRR8371281_2.fastq.gz
#            => ‘SRR8371281_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371281 ... done.
# ==> SIZE SRR8371281_2.fastq.gz ... 1824658527
# ==> PASV ... done.    ==> RETR SRR8371281_2.fastq.gz ... done.
# Length: 1824658527 (1.7G) (unauthoritative)
#
# SRR8371281_2.fastq. 100%[===================>]   1.70G  32.3MB/s    in 58s
#
# 2020-12-02 23:00:02 (29.9 MB/s) - ‘SRR8371281_2.fastq.gz’ saved [1824658527]
#
# --2020-12-02 23:00:02--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371282/SRR8371282_1.fastq.gz
#            => ‘SRR8371282_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371282 ... done.
# ==> SIZE SRR8371282_1.fastq.gz ... 915463015
# ==> PASV ... done.    ==> RETR SRR8371282_1.fastq.gz ... done.
# Length: 915463015 (873M) (unauthoritative)
#
# SRR8371282_1.fastq. 100%[===================>] 873.05M  32.9MB/s    in 34s
#
# 2020-12-02 23:00:38 (25.7 MB/s) - ‘SRR8371282_1.fastq.gz’ saved [915463015]
#
# --2020-12-02 23:00:38--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371282/SRR8371282_2.fastq.gz
#            => ‘SRR8371282_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371282 ... done.
# ==> SIZE SRR8371282_2.fastq.gz ... 2269853194
# ==> PASV ... done.    ==> RETR SRR8371282_2.fastq.gz ... done.
# Length: 2269853194 (2.1G) (unauthoritative)
#
# SRR8371282_2.fastq. 100%[===================>]   2.11G  33.1MB/s    in 92s
#
# 2020-12-02 23:02:11 (23.6 MB/s) - ‘SRR8371282_2.fastq.gz’ saved [2269853194]
#
# --2020-12-02 23:02:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371283/SRR8371283_1.fastq.gz
#            => ‘SRR8371283_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371283 ... done.
# ==> SIZE SRR8371283_1.fastq.gz ... 680094574
# ==> PASV ... done.    ==> RETR SRR8371283_1.fastq.gz ... done.
# Length: 680094574 (649M) (unauthoritative)
#
# SRR8371283_1.fastq. 100%[===================>] 648.59M  18.2MB/s    in 42s
#
# 2020-12-02 23:02:55 (15.3 MB/s) - ‘SRR8371283_1.fastq.gz’ saved [680094574]
#
# --2020-12-02 23:02:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371283/SRR8371283_2.fastq.gz
#            => ‘SRR8371283_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371283 ... done.
# ==> SIZE SRR8371283_2.fastq.gz ... 1660533492
# ==> PASV ... done.    ==> RETR SRR8371283_2.fastq.gz ... done.
# Length: 1660533492 (1.5G) (unauthoritative)
#
# SRR8371283_2.fastq. 100%[===================>]   1.55G  20.3MB/s    in 97s
#
# 2020-12-02 23:04:34 (16.3 MB/s) - ‘SRR8371283_2.fastq.gz’ saved [1660533492]
#
# --2020-12-02 23:04:34--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371284/SRR8371284_1.fastq.gz
#            => ‘SRR8371284_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371284 ... done.
# ==> SIZE SRR8371284_1.fastq.gz ... 315040950
# ==> PASV ... done.    ==> RETR SRR8371284_1.fastq.gz ... done.
# Length: 315040950 (300M) (unauthoritative)
#
# SRR8371284_1.fastq. 100%[===================>] 300.45M  30.0MB/s    in 16s
#
# 2020-12-02 23:04:51 (19.4 MB/s) - ‘SRR8371284_1.fastq.gz’ saved [315040950]
#
# --2020-12-02 23:04:51--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371284/SRR8371284_2.fastq.gz
#            => ‘SRR8371284_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371284 ... done.
# ==> SIZE SRR8371284_2.fastq.gz ... 726614813
# ==> PASV ... done.    ==> RETR SRR8371284_2.fastq.gz ... done.
# Length: 726614813 (693M) (unauthoritative)
#
# SRR8371284_2.fastq. 100%[===================>] 692.95M  33.3MB/s    in 23s
#
# 2020-12-02 23:05:15 (30.0 MB/s) - ‘SRR8371284_2.fastq.gz’ saved [726614813]
#
# --2020-12-02 23:05:15--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371285/SRR8371285_1.fastq.gz
#            => ‘SRR8371285_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837
  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371288/SRR8371288_1.fastq.gz
#            => ‘SRR8371288_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371288 ... done.
# ==> SIZE SRR8371288_1.fastq.gz ... 125763828
# ==> PASV ... done.    ==> RETR SRR8371288_1.fastq.gz ... done.
# Length: 125763828 (120M) (unauthoritative)
#
# SRR8371288_1.fastq. 100%[===================>] 119.94M  30.9MB/s    in 5.2s
#
# 2020-12-02 23:07:16 (22.9 MB/s) - ‘SRR8371288_1.fastq.gz’ saved [125763828]
#
# --2020-12-02 23:07:16--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371288/SRR8371288_2.fastq.gz
#            => ‘SRR8371288_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371288 ... done.
# ==> SIZE SRR8371288_2.fastq.gz ... 292207144
# ==> PASV ... done.    ==> RETR SRR8371288_2.fastq.gz ... done.
# Length: 292207144 (279M) (unauthoritative)
#
# SRR8371288_2.fastq. 100%[===================>] 278.67M  20.3MB/s    in 19s
#
# 2020-12-02 23:07:36 (14.6 MB/s) - ‘SRR8371288_2.fastq.gz’ saved [292207144]
#
# --2020-12-02 23:07:37--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371289/SRR8371289_1.fastq.gz
#            => ‘SRR8371289_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371289 ... done.
# ==> SIZE SRR8371289_1.fastq.gz ... 778838320
# ==> PASV ... done.    ==> RETR SRR8371289_1.fastq.gz ... done.
# Length: 778838320 (743M) (unauthoritative)
#
# SRR8371289_1.fastq. 100%[===================>] 742.76M  32.2MB/s    in 30s
#
# 2020-12-02 23:08:08 (24.7 MB/s) - ‘SRR8371289_1.fastq.gz’ saved [778838320]
#
# --2020-12-02 23:08:08--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371289/SRR8371289_2.fastq.gz
#            => ‘SRR8371289_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371289 ... done.
# ==> SIZE SRR8371289_2.fastq.gz ... 1982746504
# ==> PASV ... done.    ==> RETR SRR8371289_2.fastq.gz ... done.
# Length: 1982746504 (1.8G) (unauthoritative)
#
# SRR8371289_2.fastq. 100%[===================>]   1.85G  32.8MB/s    in 77s
#
# 2020-12-02 23:09:27 (24.5 MB/s) - ‘SRR8371289_2.fastq.gz’ saved [1982746504]
#
# --2020-12-02 23:09:27--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371290/SRR8371290_1.fastq.gz
#            => ‘SRR8371290_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371290 ... done.
# ==> SIZE SRR8371290_1.fastq.gz ... 246273206
# ==> PASV ... done.    ==> RETR SRR8371290_1.fastq.gz ... done.
# Length: 246273206 (235M) (unauthoritative)
#
# SRR8371290_1.fastq. 100%[===================>] 234.86M  33.2MB/s    in 8.6s
#
# 2020-12-02 23:09:36 (27.4 MB/s) - ‘SRR8371290_1.fastq.gz’ saved [246273206]
#
# --2020-12-02 23:09:36--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371290/SRR8371290_2.fastq.gz
#            => ‘SRR8371290_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371290 ... done.
# ==> SIZE SRR8371290_2.fastq.gz ... 639829642
# ==> PASV ... done.    ==> RETR SRR8371290_2.fastq.gz ... done.
# Length: 639829642 (610M) (unauthoritative)
#
# SRR8371290_2.fastq. 100%[===================>] 610.19M  10.8MB/s    in 62s
#
# 2020-12-02 23:10:40 (9.85 MB/s) - ‘SRR8371290_2.fastq.gz’ saved [639829642]
#
# --2020-12-02 23:10:40--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371291/SRR8371291_1.fastq.gz
#            => ‘SRR8371291_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371291 ... done.
# ==> SIZE SRR8371291_1.fastq.gz ... 33332003
# ==> PASV ... done.    ==> RETR SRR8371291_1.fastq.gz ... done.
# Length: 33332003 (32M) (unauthoritative)
#
# SRR8371291_1.fastq. 100%[===================>]  31.79M  8.47MB/s    in 3.8s
#
# 2020-12-02 23:10:45 (8.47 MB/s) - ‘SRR8371291_1.fastq.gz’ saved [33332003]
#
# --2020-12-02 23:10:45--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371291/SRR8371291_2.fastq.gz
#            => ‘SRR8371291_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371291 ... done.
# ==> SIZE SRR8371291_2.fastq.gz ... 38500259
# ==> PASV ... done.    ==> RETR SRR8371291_2.fastq.gz ... done.
# Length: 38500259 (37M) (unauthoritative)
#
# SRR8371291_2.fastq. 100%[===================>]  36.72M  10.9MB/s    in 3.4s
#
# 2020-12-02 23:10:50 (10.9 MB/s) - ‘SRR8371291_2.fastq.gz’ saved [38500259]
#
# --2020-12-02 23:10:50--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371292/SRR8371292_1.fastq.gz
#            => ‘SRR8371292_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371292 ... done.
# ==> SIZE SRR8371292_1.fastq.gz ... 29165794
# ==> PASV ... done.    ==> RETR SRR8371292_1.fastq.gz ... done.
# Length: 29165794 (28M) (unauthoritative)
#
# SRR8371292_1.fastq. 100%[===================>]  27.81M  10.1MB/s    in 2.8s
#
# 2020-12-02 23:10:54 (10.1 MB/s) - ‘SRR8371292_1.fastq.gz’ saved [29165794]
#
# --2020-12-02 23:10:54--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371292/SRR8371292_2.fastq.gz
#            => ‘SRR8371292_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371292 ... done.
# ==> SIZE SRR8371292_2.fastq.gz ... 33323552
# ==> PASV ... done.    ==> RETR SRR8371292_2.fastq.gz ... done.
# Length: 33323552 (32M) (unauthoritative)
#
# SRR8371292_2.fastq. 100%[===================>]  31.78M  17.2MB/s    in 1.8s
#
# 2020-12-02 23:10:57 (17.2 MB/s) - ‘SRR8371292_2.fastq.gz’ saved [33323552]
#
# --2020-12-02 23:10:57--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371293/SRR8371293_1.fastq.gz
#            => ‘SRR8371293_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371293 ... done.
# ==> SIZE SRR8371293_1.fastq.gz ... 192261099
# ==> PASV ... done.    ==> RETR SRR8371293_1.fastq.gz ... done.
# Length: 192261099 (183M) (unauthoritative)
#
# SRR8371293_1.fastq. 100%[===================>] 183.35M  19.9MB/s    in 14s
#
# 2020-12-02 23:11:12 (13.4 MB/s) - ‘SRR8371293_1.fastq.gz’ saved [192261099]
#
# --2020-12-02 23:11:13--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371293/SRR8371293_2.fastq.gz
#            => ‘SRR8371293_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371293 ... done.
# ==> SIZE SRR8371293_2.fastq.gz ... 219371658
# ==> PASV ... done.    ==> RETR SRR8371293_2.fastq.gz ... done.
# Length: 219371658 (209M) (unauthoritative)
#
# SRR8371293_2.fastq. 100%[===================>] 209.21M  33.2MB/s    in 7.6s
#
# 2020-12-02 23:11:21 (27.6 MB/s) - ‘SRR8371293_2.fastq.gz’ saved [219371658]
#
# --2020-12-02 23:11:22--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371294/SRR8371294_1.fastq.gz
#            => ‘SRR8371294_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371294 ... done.
# ==> SIZE SRR8371294_1.fastq.gz ... 210643123
# ==> PASV ... done.    ==> RETR SRR8371294_1.fastq.gz ... done.
# Length: 210643123 (201M) (unauthoritative)
#
# SRR8371294_1.fastq. 100%[===================>] 200.88M  32.5MB/s    in 16s
#
# 2020-12-02 23:11:39 (12.2 MB/s) - ‘SRR8371294_1.fastq.gz’ saved [210643123]
#
# --2020-12-02 23:11:39--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371294/SRR8371294_2.fastq.gz
#            => ‘SRR8371294_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371294 ... done.
# ==> SIZE SRR8371294_2.fastq.gz ... 234538312
# ==> PASV ... done.    ==> RETR SRR8371294_2.fastq.gz ... done.
# Length: 234538312 (224M) (unauthoritative)
#
# SRR8371294_2.fastq. 100%[===================>] 223.67M  33.2MB/s    in 18s
#
# 2020-12-02 23:11:59 (12.3 MB/s) - ‘SRR8371294_2.fastq.gz’ saved [234538312]
#
# --2020-12-02 23:11:59--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371295/SRR8371295_1.fastq.gz
#            => ‘SRR8371295_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/005/SRR8371295 ... done.
# ==> SIZE SRR8371295_1.fastq.gz ... 253493505
# ==> PASV ... done.    ==> RETR SRR8371295_1.fastq.gz ... done.
# Length: 253493505 (242M) (unauthoritative)
#
# SRR8371295_1.fastq. 100%[===================>] 241.75M  6.47MB/s    in 55s
#
# 2020-12-02 23:12:55 (4.39 MB/s) - ‘SRR8371295_1.fastq.gz’ saved [253493505]
#
# --2020-12-02 23:12:56--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371295/SRR8371295_2.fastq.gz
#            => ‘SRR8371295_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/005/SRR8371295 ... done.
# ==> SIZE SRR8371295_2.fastq.gz ... 711724422
# ==> PASV ... done.    ==> RETR SRR8371295_2.fastq.gz ... done.
# Length: 711724422 (679M) (unauthoritative)
#
# SRR8371295_2.fastq. 100%[===================>] 678.75M  32.8MB/s    in 24s
#
# 2020-12-02 23:13:21 (27.7 MB/s) - ‘SRR8371295_2.fastq.gz’ saved [711724422]
#
# --2020-12-02 23:13:21--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/006/SRR8371296/SRR8371296_1.fastq.gz
#            => ‘SRR8371296_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/006/SRR8371296 ... done.
# ==> SIZE SRR8371296_1.fastq.gz ... 219198283
# ==> PASV ... done.    ==> RETR SRR8371296_1.fastq.gz ... done.
# Length: 219198283 (209M) (unauthoritative)
#
# SRR8371296_1.fastq. 100%[===================>] 209.04M  33.3MB/s    in 9.9s
#
# 2020-12-02 23:13:33 (21.1 MB/s) - ‘SRR8371296_1.fastq.gz’ saved [219198283]
#
# --2020-12-02 23:13:33--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/006/SRR8371296/SRR8371296_2.fastq.gz
#            => ‘SRR8371296_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/006/SRR8371296 ... done.
# ==> SIZE SRR8371296_2.fastq.gz ... 578353370
# ==> PASV ... done.    ==> RETR SRR8371296_2.fastq.gz ... done.
# Length: 578353370 (552M) (unauthoritative)
#
# SRR8371296_2.fastq. 100%[===================>] 551.56M  32.8MB/s    in 25s
#
# 2020-12-02 23:13:59 (22.2 MB/s) - ‘SRR8371296_2.fastq.gz’ saved [578353370]
#
# --2020-12-02 23:13:59--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/007/SRR8371297/SRR8371297_1.fastq.gz
#            => ‘SRR8371297_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/007/SRR8371297 ... done.
# ==> SIZE SRR8371297_1.fastq.gz ... 227119956
# ==> PASV ... done.    ==> RETR SRR8371297_1.fastq.gz ... done.
# Length: 227119956 (217M) (unauthoritative)
#
# SRR8371297_1.fastq. 100%[===================>] 216.60M  33.3MB/s    in 11s
#
# 2020-12-02 23:14:11 (20.3 MB/s) - ‘SRR8371297_1.fastq.gz’ saved [227119956]
#
# --2020-12-02 23:14:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/007/SRR8371297/SRR8371297_2.fastq.gz
#            => ‘SRR8371297_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/007/SRR8371297 ... done.
# ==> SIZE SRR8371297_2.fastq.gz ... 628489488
# ==> PASV ... done.    ==> RETR SRR8371297_2.fastq.gz ... done.
# Length: 628489488 (599M) (unauthoritative)
#
# SRR8371297_2.fastq. 100%[===================>] 599.37M  32.9MB/s    in 21s
#
# 2020-12-02 23:14:34 (28.5 MB/s) - ‘SRR8371297_2.fastq.gz’ saved [628489488]
#
# --2020-12-02 23:14:34--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371298/SRR8371298_1.fastq.gz
#            => ‘SRR8371298_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371298 ... done.
# ==> SIZE SRR8371298_1.fastq.gz ... 225039472
# ==> PASV ... done.    ==> RETR SRR8371298_1.fastq.gz ... done.
# Length: 225039472 (215M) (unauthoritative)
#
# SRR8371298_1.fastq. 100%[===================>] 214.61M  33.0MB/s    in 14s
#
# 2020-12-02 23:14:49 (15.5 MB/s) - ‘SRR8371298_1.fastq.gz’ saved [225039472]
#
# --2020-12-02 23:14:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371298/SRR8371298_2.fastq.gz
#            => ‘SRR8371298_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371298 ... done.
# ==> SIZE SRR8371298_2.fastq.gz ... 590212108
# ==> PASV ... done.    ==> RETR SRR8371298_2.fastq.gz ... done.
# Length: 590212108 (563M) (unauthoritative)
#
# SRR8371298_2.fastq. 100%[===================>] 562.87M  32.6MB/s    in 20s
#
# 2020-12-02 23:15:10 (27.7 MB/s) - ‘SRR8371298_2.fastq.gz’ saved [590212108]
#
# --2020-12-02 23:15:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371299/SRR8371299_1.fastq.gz
#            => ‘SRR8371299_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371299 ... done.
# ==> SIZE SRR8371299_1.fastq.gz ... 169939369
# ==> PASV ... done.    ==> RETR SRR8371299_1.fastq.gz ... done.
# Length: 169939369 (162M) (unauthoritative)
#
# SRR8371299_1.fastq. 100%[===================>] 162.07M  32.3MB/s    in 7.1s
#
# 2020-12-02 23:15:19 (22.9 MB/s) - ‘SRR8371299_1.fastq.gz’ saved [169939369]
#
# --2020-12-02 23:15:19--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371299/SRR8371299_2.fastq.gz
#            => ‘SRR8371299_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371299 ... done.
# ==> SIZE SRR8371299_2.fastq.gz ... 448366791
# ==> PASV ... done.    ==> RETR SRR8371299_2.fastq.gz ... done.
# Length: 448366791 (428M) (unauthoritative)
#
# SRR8371299_2.fastq. 100%[===================>] 427.60M  32.3MB/s    in 17s
#
# 2020-12-02 23:15:38 (24.8 MB/s) - ‘SRR8371299_2.fastq.gz’ saved [448366791]
#
# --2020-12-02 23:15:38--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371300/SRR8371300_1.fastq.gz
#            => ‘SRR8371300_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371300 ... done.
# ==> SIZE SRR8371300_1.fastq.gz ... 145579785
# ==> PASV ... done.    ==> RETR SRR8371300_1.fastq.gz ... done.
# Length: 145579785 (139M) (unauthoritative)
#
# ...
#
# 2020-12-03 01:44:11 (21.4 MB/s) - ‘SRR8371426_2.fastq.gz’ saved [881869204]
#
# --2020-12-03 01:44:11--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/007/SRR8371427/SRR8371427_1.fastq.gz
#            => ‘SRR8371427_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/007/SRR8371427 ... done.
# ==> SIZE SRR8371427_1.fastq.gz ... 881861583
# ==> PASV ... done.    ==> RETR SRR8371427_1.fastq.gz ... done.
# Length: 881861583 (841M) (unauthoritative)
#
# SRR8371427_1.fastq. 100%[===================>] 841.01M  33.1MB/s    in 36s
#
# 2020-12-03 01:44:48 (23.4 MB/s) - ‘SRR8371427_1.fastq.gz’ saved [881861583]
#
# --2020-12-03 01:44:48--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/007/SRR8371427/SRR8371427_2.fastq.gz
#            => ‘SRR8371427_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/007/SRR8371427 ... done.
# ==> SIZE SRR8371427_2.fastq.gz ... 972402808
# ==> PASV ... done.    ==> RETR SRR8371427_2.fastq.gz ... done.
# Length: 972402808 (927M) (unauthoritative)
#
# SRR8371427_2.fastq. 100%[===================>] 927.36M  33.0MB/s    in 38s
#
# 2020-12-03 01:45:27 (24.5 MB/s) - ‘SRR8371427_2.fastq.gz’ saved [972402808]
#
# --2020-12-03 01:45:28--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371428/SRR8371428_1.fastq.gz
#            => ‘SRR8371428_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371428 ... done.
# ==> SIZE SRR8371428_1.fastq.gz ... 1078517708
# ==> PASV ... done.    ==> RETR SRR8371428_1.fastq.gz ... done.
# Length: 1078517708 (1.0G) (unauthoritative)
#
# SRR8371428_1.fastq. 100%[===================>]   1.00G  32.2MB/s    in 42s
#
# 2020-12-03 01:46:12 (24.2 MB/s) - ‘SRR8371428_1.fastq.gz’ saved [1078517708]
#
# --2020-12-03 01:46:12--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/008/SRR8371428/SRR8371428_2.fastq.gz
#            => ‘SRR8371428_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/008/SRR8371428 ... done.
# ==> SIZE SRR8371428_2.fastq.gz ... 1169561941
# ==> PASV ... done.    ==> RETR SRR8371428_2.fastq.gz ... done.
# Length: 1169561941 (1.1G) (unauthoritative)
#
# SRR8371428_2.fastq. 100%[===================>]   1.09G  6.84MB/s    in 2m 33s
#
# 2020-12-03 01:48:46 (7.27 MB/s) - ‘SRR8371428_2.fastq.gz’ saved [1169561941]
#
# --2020-12-03 01:48:47--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371429/SRR8371429_1.fastq.gz
#            => ‘SRR8371429_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371429 ... done.
# ==> SIZE SRR8371429_1.fastq.gz ... 968211303
# ==> PASV ... done.    ==> RETR SRR8371429_1.fastq.gz ... done.
# Length: 968211303 (923M) (unauthoritative)
#
# SRR8371429_1.fastq. 100%[===================>] 923.36M  33.1MB/s    in 34s
#
# 2020-12-03 01:49:22 (27.2 MB/s) - ‘SRR8371429_1.fastq.gz’ saved [968211303]
#
# --2020-12-03 01:49:22--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/009/SRR8371429/SRR8371429_2.fastq.gz
#            => ‘SRR8371429_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/009/SRR8371429 ... done.
# ==> SIZE SRR8371429_2.fastq.gz ... 1036704863
# ==> PASV ... done.    ==> RETR SRR8371429_2.fastq.gz ... done.
# Length: 1036704863 (989M) (unauthoritative)
#
# SRR8371429_2.fastq. 100%[===================>] 988.68M  30.2MB/s    in 39s
#
# 2020-12-03 01:50:02 (25.6 MB/s) - ‘SRR8371429_2.fastq.gz’ saved [1036704863]
#
# --2020-12-03 01:50:02--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371430/SRR8371430_1.fastq.gz
#            => ‘SRR8371430_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371430 ... done.
# ==> SIZE SRR8371430_1.fastq.gz ... 855841761
# ==> PASV ... done.    ==> RETR SRR8371430_1.fastq.gz ... done.
# Length: 855841761 (816M) (unauthoritative)
#
# SRR8371430_1.fastq. 100%[===================>] 816.19M  30.8MB/s    in 1m 58s
#
# 2020-12-03 01:52:01 (6.92 MB/s) - ‘SRR8371430_1.fastq.gz’ saved [855841761]
#
# --2020-12-03 01:52:01--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/000/SRR8371430/SRR8371430_2.fastq.gz
#            => ‘SRR8371430_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/000/SRR8371430 ... done.
# ==> SIZE SRR8371430_2.fastq.gz ... 907566569
# ==> PASV ... done.    ==> RETR SRR8371430_2.fastq.gz ... done.
# Length: 907566569 (866M) (unauthoritative)
#
# SRR8371430_2.fastq. 100%[===================>] 865.52M  32.6MB/s    in 35s
#
# 2020-12-03 01:52:38 (24.9 MB/s) - ‘SRR8371430_2.fastq.gz’ saved [907566569]
#
# --2020-12-03 01:52:38--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371431/SRR8371431_1.fastq.gz
#            => ‘SRR8371431_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371431 ... done.
# ==> SIZE SRR8371431_1.fastq.gz ... 870654222
# ==> PASV ... done.    ==> RETR SRR8371431_1.fastq.gz ... done.
# Length: 870654222 (830M) (unauthoritative)
#
# SRR8371431_1.fastq. 100%[===================>] 830.32M  31.7MB/s    in 37s
#
# 2020-12-03 01:53:16 (22.7 MB/s) - ‘SRR8371431_1.fastq.gz’ saved [870654222]
#
# --2020-12-03 01:53:16--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/001/SRR8371431/SRR8371431_2.fastq.gz
#            => ‘SRR8371431_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/001/SRR8371431 ... done.
# ==> SIZE SRR8371431_2.fastq.gz ... 910972542
# ==> PASV ... done.    ==> RETR SRR8371431_2.fastq.gz ... done.
# Length: 910972542 (869M) (unauthoritative)
#
# SRR8371431_2.fastq. 100%[===================>] 868.77M  32.9MB/s    in 32s
#
# 2020-12-03 01:53:49 (27.5 MB/s) - ‘SRR8371431_2.fastq.gz’ saved [910972542]
#
# --2020-12-03 01:53:49--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371432/SRR8371432_1.fastq.gz
#            => ‘SRR8371432_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371432 ... done.
# ==> SIZE SRR8371432_1.fastq.gz ... 767058769
# ==> PASV ... done.    ==> RETR SRR8371432_1.fastq.gz ... done.
# Length: 767058769 (732M) (unauthoritative)
#
# SRR8371432_1.fastq. 100%[===================>] 731.52M  32.9MB/s    in 43s
#
# 2020-12-03 01:54:33 (16.9 MB/s) - ‘SRR8371432_1.fastq.gz’ saved [767058769]
#
# --2020-12-03 01:54:33--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/002/SRR8371432/SRR8371432_2.fastq.gz
#            => ‘SRR8371432_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/002/SRR8371432 ... done.
# ==> SIZE SRR8371432_2.fastq.gz ... 819760011
# ==> PASV ... done.    ==> RETR SRR8371432_2.fastq.gz ... done.
# Length: 819760011 (782M) (unauthoritative)
#
# SRR8371432_2.fastq. 100%[===================>] 781.78M  32.1MB/s    in 33s
#
# 2020-12-03 01:55:08 (23.8 MB/s) - ‘SRR8371432_2.fastq.gz’ saved [819760011]
#
# --2020-12-03 01:55:08--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371433/SRR8371433_1.fastq.gz
#            => ‘SRR8371433_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371433 ... done.
# ==> SIZE SRR8371433_1.fastq.gz ... 952722691
# ==> PASV ... done.    ==> RETR SRR8371433_1.fastq.gz ... done.
# Length: 952722691 (909M) (unauthoritative)
#
# SRR8371433_1.fastq. 100%[===================>] 908.59M  32.9MB/s    in 35s
#
# 2020-12-03 01:55:44 (26.2 MB/s) - ‘SRR8371433_1.fastq.gz’ saved [952722691]
#
# --2020-12-03 01:55:44--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/003/SRR8371433/SRR8371433_2.fastq.gz
#            => ‘SRR8371433_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/003/SRR8371433 ... done.
# ==> SIZE SRR8371433_2.fastq.gz ... 996085519
# ==> PASV ... done.    ==> RETR SRR8371433_2.fastq.gz ... done.
# Length: 996085519 (950M) (unauthoritative)
#
# SRR8371433_2.fastq. 100%[===================>] 949.94M  32.0MB/s    in 2m 57s
#
# 2020-12-03 01:58:42 (5.36 MB/s) - ‘SRR8371433_2.fastq.gz’ saved [996085519]
#
# --2020-12-03 01:58:43--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371434/SRR8371434_1.fastq.gz
#            => ‘SRR8371434_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371434 ... done.
# ==> SIZE SRR8371434_1.fastq.gz ... 527934474
# ==> PASV ... done.    ==> RETR SRR8371434_1.fastq.gz ... done.
# Length: 527934474 (503M) (unauthoritative)
#
# SRR8371434_1.fastq. 100%[===================>] 503.48M  32.1MB/s    in 26s
#
# 2020-12-03 01:59:10 (19.6 MB/s) - ‘SRR8371434_1.fastq.gz’ saved [527934474]
#
# --2020-12-03 01:59:10--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/004/SRR8371434/SRR8371434_2.fastq.gz
#            => ‘SRR8371434_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/004/SRR8371434 ... done.
# ==> SIZE SRR8371434_2.fastq.gz ... 609927913
# ==> PASV ... done.    ==> RETR SRR8371434_2.fastq.gz ... done.
# Length: 609927913 (582M) (unauthoritative)
#
# SRR8371434_2.fastq. 100%[===================>] 581.67M  33.3MB/s    in 22s
#
# 2020-12-03 01:59:33 (26.3 MB/s) - ‘SRR8371434_2.fastq.gz’ saved [609927913]
#
# --2020-12-03 01:59:33--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371435/SRR8371435_1.fastq.gz
#            => ‘SRR8371435_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/005/SRR8371435 ... done.
# ==> SIZE SRR8371435_1.fastq.gz ... 471262483
# ==> PASV ... done.    ==> RETR SRR8371435_1.fastq.gz ... done.
# Length: 471262483 (449M) (unauthoritative)
#
# SRR8371435_1.fastq. 100%[===================>] 449.43M  33.1MB/s    in 20s
#
# 2020-12-03 01:59:54 (22.4 MB/s) - ‘SRR8371435_1.fastq.gz’ saved [471262483]
#
# --2020-12-03 01:59:55--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371435/SRR8371435_2.fastq.gz
#            => ‘SRR8371435_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/005/SRR8371435 ... done.
# ==> SIZE SRR8371435_2.fastq.gz ... 517892985
# ==> PASV ... done.    ==> RETR SRR8371435_2.fastq.gz ... done.
# Length: 517892985 (494M) (unauthoritative)
#
# SRR8371435_2.fastq. 100%[===================>] 493.90M  32.8MB/s    in 23s
#
# 2020-12-03 02:00:19 (21.7 MB/s) - ‘SRR8371435_2.fastq.gz’ saved [517892985]
#
# --2020-12-03 02:00:19--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/006/SRR8371436/SRR8371436_1.fastq.gz
#            => ‘SRR8371436_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/006/SRR8371436 ... done.
# ==> SIZE SRR8371436_1.fastq.gz ... 504096935
# ==> PASV ... done.    ==> RETR SRR8371436_1.fastq.gz ... done.
# Length: 504096935 (481M) (unauthoritative)
#
# SRR8371436_1.fastq. 100%[===================>] 480.74M  32.6MB/s    in 17s
#
# 2020-12-03 02:00:37 (27.5 MB/s) - ‘SRR8371436_1.fastq.gz’ saved [504096935]
#
# --2020-12-03 02:00:38--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/006/SRR8371436/SRR8371436_2.fastq.gz
#            => ‘SRR8371436_2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/006/SRR8371436 ... done.
# ==> SIZE SRR8371436_2.fastq.gz ... 587677765
# ==> PASV ... done.    ==> RETR SRR8371436_2.fastq.gz ... done.
# Length: 587677765 (560M) (unauthoritative)
#
# SRR8371436_2.fastq. 100%[===================>] 560.45M  33.0MB/s    in 23s
#
# 2020-12-03 02:01:02 (24.2 MB/s) - ‘SRR8371436_2.fastq.gz’ saved [587677765]
#
# --2020-12-03 02:01:02--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/007/SRR8371437/SRR8371437_1.fastq.gz
#            => ‘SRR8371437_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.197.74
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.197.74|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR837/007/SRR8371437 ... done.
# ==> SIZE SRR8371437_1.fastq.gz ... 574656560
# ==> PASV ... done.    ==> RETR SRR8371437_1.fastq.gz ... done.
# Length: 574656560 (548M) (unauthoritative)
#
# SRR8371437_1.fastq.   8%[>                   ]  46.00M  6.56MB/s    eta 89s

# %%
if bam:
  # Download the corresponding Kallisto index to folder containing fastqs
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and fastq_ffqlinks:
  # %cd /content

  # Download the corresponding Kallisto index to content folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

if not bam and not fastq_ffqlinks:
  # %cd /content/fastqs

  # Download the corresponding Kallisto index to fastq folder
  # !kb ref -d $species_kb -i index.idx -g t2g.txt -f1 transcriptome.fasta

# %%
# Check to make sure the metadata is in the right order after sorting
print(fastqs)

# %% [markdown]
# # Process fastq files (modify kb command according to fastqs list)

# %%
fastqs
# Out:
# ['ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371265/SRR8371265_1.fastq.gz',
#  'ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371265/SRR8371265_2.fastq.gz']

# %%
# Specify the sample number and whether they are paired-ended


if no_samples == 1:

  # Write the kb count command as a string with all fastqs of the list as an input
  cmd = "kb count --h5ad -i index.idx -g t2g.txt -x " + technology_kb + " -o output" + sample_id[0] + " "\
  + "--filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs) + "'"
  
  # Execute it
  # !$cmd

# If more than one sample, iterate through fastqs accordingly
else:

  # Initializa counter for fastq files
  j = 0

  # Loop over samples for analysis
  for i in range(no_samples):

    fastqs_to_analyze = fastqs[j:j + fastqs_per_sample[i]]
    # Write the kb count command as a string
    cmd = "kb count --h5ad -i ../index.idx -g ../t2g.txt -x " + technology_kb + " -o output" + sample_id[i] + " \
    --filter bustools -t 2 --overwrite " + "'" +  "' '".join(fastqs_to_analyze) + "'"

    # Execute it
    # !$cmd

    # Update j to move to the next set of fastq
    j = j + fastqs_per_sample[i]
# Out:
# [2020-12-02 22:35:03,147]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371265/SRR8371265_1.fastq.gz to outputG/tmp/SRR8371265_1.fastq.gz
# [2020-12-02 22:35:03,149]    INFO Piping ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/005/SRR8371265/SRR8371265_2.fastq.gz to outputG/tmp/SRR8371265_2.fastq.gz
# [2020-12-02 22:35:03,149]    INFO Using index index.idx to generate BUS file to outputG from
# [2020-12-02 22:35:03,149]    INFO         outputG/tmp/SRR8371265_1.fastq.gz
# [2020-12-02 22:35:03,149]    INFO         outputG/tmp/SRR8371265_2.fastq.gz
# [2020-12-02 22:38:26,485]    INFO Sorting BUS file outputG/output.bus to outputG/tmp/output.s.bus
# [2020-12-02 22:38:32,015]    INFO Whitelist not provided
# [2020-12-02 22:38:32,016]    INFO Generating whitelist outputG/whitelist.txt from BUS file outputG/tmp/output.s.bus
# [2020-12-02 22:38:32,036]    INFO Inspecting BUS file outputG/tmp/output.s.bus
# [2020-12-02 22:38:33,463]    INFO Correcting BUS records in outputG/tmp/output.s.bus to outputG/tmp/output.s.c.bus with whitelist outputG/whitelist.txt
# [2020-12-02 22:38:33,654]    INFO Sorting BUS file outputG/tmp/output.s.c.bus to outputG/output.unfiltered.bus
# [2020-12-02 22:38:36,550]    INFO Generating count matrix outputG/counts_unfiltered/cells_x_genes from BUS file outputG/output.unfiltered.bus
# [2020-12-02 22:38:39,440]    INFO Reading matrix outputG/counts_unfiltered/cells_x_genes.mtx
# [2020-12-02 22:38:39,815]    INFO Writing matrix to h5ad outputG/counts_unfiltered/adata.h5ad
# ... storing 'gene_name' as categorical
# [2020-12-02 22:38:40,412]    INFO Filtering with bustools
# [2020-12-02 22:38:40,412]    INFO Generating whitelist outputG/filter_barcodes.txt from BUS file outputG/output.unfiltered.bus
# [2020-12-02 22:38:40,433]    INFO Correcting BUS records in outputG/output.unfiltered.bus to outputG/tmp/output.unfiltered.c.bus with whitelist outputG/filter_barcodes.txt
# [2020-12-02 22:38:40,595]    INFO Sorting BUS file outputG/tmp/output.unfiltered.c.bus to outputG/output.filtered.bus
# [2020-12-02 22:38:43,452]    INFO Generating count matrix outputG/counts_filtered/cells_x_genes from BUS file outputG/output.filtered.bus
# [2020-12-02 22:38:46,283]    INFO Reading matrix outputG/counts_filtered/cells_x_genes.mtx
# [2020-12-02 22:38:46,584]    INFO Writing matrix to h5ad outputG/counts_filtered/adata.h5ad
# ... storing 'gene_name' as categorical

# %% [markdown]
# # Load unfiltered matrix and assign filters to each matrix individually

# %% [markdown]
# ## Load the unfiltered matrix (check dimensions)

# %%
# Define dict to store data
results = {}

# %%
# load the unfiltered matrix
for i in range(no_samples):
  results[sample_id[i]] = anndata.read_h5ad("output" + sample_id[i] + "/counts_unfiltered/adata.h5ad")
  results[sample_id[i]].var["gene_id"] = results[sample_id[i]].var.index.values

  t2g = pd.read_csv("t2g.txt", header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
  t2g.index = t2g.gene_id
  t2g = t2g.loc[~t2g.index.duplicated(keep='first')]

  results[sample_id[i]].var["gene_name"] = results[sample_id[i]].var.gene_id.map(t2g["gene_name"])
  results[sample_id[i]].var.index = results[sample_id[i]].var["gene_name"]
  print("The unfiltered matrix " + sample_id[i] + " contains {} cells by {} genes".format(len(results[sample_id[i]].obs), len(results[sample_id[i]].var)))

  results[sample_id[i]].obs["cell_counts"] = results[sample_id[i]].X.sum(axis=1)
  results[sample_id[i]].var["gene_counts"] = nd(results[sample_id[i]].X.sum(axis=0))

  results[sample_id[i]].obs["n_genes"] = nd((results[sample_id[i]].X>0).sum(axis=1))
  results[sample_id[i]].var["n_cells"] = nd((results[sample_id[i]].X>0).sum(axis=0))

  mito_genes = results[sample_id[i]].var_names.str.startswith("MT-" or "mt-") 
  results[sample_id[i]].obs["percent_mito"] = results[sample_id[i]][:,mito_genes].X.sum(axis=1)/results[sample_id[i]].X.sum(axis=1)*100

  # Changing the name of the index is necessary to write the file (it won't work with duplicated names)
  results[sample_id[i]].var.index.name = "index"
# Out:
# The unfiltered matrix G contains 95 cells by 60623 genes

# %% [markdown]
# ## Assign filters for each matrix individually

# %%
# Modify this manually to change sample after having assigned the "expected_num_cells" and "mito_criteria" parameters
samp_n = 0


# Filtering criteria
cell_threshold = 100
gene_threshold = 3

mito_criteria = 30

# %%
expected_num_cells = 50#@param {type:"integer"}
knee = np.sort(nd(results[sample_id[samp_n]].X.sum(axis=1)))[::-1]

fig, ax = plt.subplots(figsize=(5, 5))

x = knee
y = range(len(knee))

ax.loglog(x, y, linewidth=5, color="g")

ax.axvline(x=knee[expected_num_cells], linewidth=3, color="k")
ax.axhline(y=expected_num_cells, linewidth=3, color="k")

ax.set_xlabel("UMI Counts")
ax.set_ylabel("Set of Barcodes")

plt.show()

cell_threshold = knee[expected_num_cells]

results["cell_threshold" + sample_id[samp_n]] = knee[expected_num_cells]

print ("Cells were filtered down to " + str(expected_num_cells) + " with at least " + str(cell_threshold) + " UMIs")


mito_criteria = 18#@param {type:"integer"}
results["mito_criteria" + sample_id[samp_n]] = mito_criteria

fig, ax = plt.subplots(figsize=(5,5))


x = nd(results[sample_id[samp_n]].obs["cell_counts"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])
y = nd(results[sample_id[samp_n]].obs["percent_mito"][results[sample_id[samp_n]].obs["cell_counts"] > cell_threshold])

ax.scatter(x, y, color="green", alpha=0.1)

ax.axhline(y=mito_criteria, linestyle="--", color="k")


ax.set_xlabel("UMI Counts")
ax.set_ylabel("Percent mito")


plt.show()

print("We select " + str(mito_criteria) + " % as the mitochondrial content threshold")
# Out:
# Cells were filtered down to 50 with at least 637.0 UMIs
# We select 18 % as the mitochondrial content threshold

# %% [markdown]
# # Filter matrix

# %%
for i in range(no_samples):
  results[sample_id[i]].obs["pass_count_filter"] = results[sample_id[i]].obs["cell_counts"] > results["cell_threshold" + sample_id[i]]
  results[sample_id[i]].obs["pass_mito_filter"] = results[sample_id[i]].obs.percent_mito < results["mito_criteria" + sample_id[i]]
  results[sample_id[i]].var["pass_gene_filter"] = results[sample_id[i]].var["n_cells"] > gene_threshold

  cell_mask = np.logical_and(results[sample_id[i]].obs["pass_count_filter"].values, results[sample_id[i]].obs["pass_mito_filter"].values)
  gene_mask = results[sample_id[i]].var["pass_gene_filter"].values

  print("Current Shape: {:,} cells x {:,} genes".format(results[sample_id[i]].shape[0], results[sample_id[i]].shape[1]))
  print("    New shape: {:,} cells x {:,} genes".format(cell_mask.sum(), gene_mask.sum()))
  results["data_" + sample_id[i]] = results[sample_id[i]][cell_mask, gene_mask]

# %% [markdown]
# # Anotate and write the Anndata object

# %%
for i in range(no_samples):


  results["data_" + sample_id[i]].uns["database_id"] = database_id[i]

  results["data_" + sample_id[i]].uns["tissue"] = tissue[i]

  results["data_" + sample_id[i]].uns["cell_type"] = cell_type[i]

  results["data_" + sample_id[i]].uns["sample_id"] = sample_id[i]

  results["data_" + sample_id[i]].uns["condition"] = condition[i]

  results["data_" + sample_id[i]].uns["species"] = species[i]

  results["data_" + sample_id[i]].uns["technology"] = technology[i]

  results["data_" + sample_id[i]].uns["paper"] = paper[i]

  results["data_" + sample_id[i]].uns["figure"] = figure[i]


# %cd /content

for i in range(no_samples):

  results["data_" + sample_id[i]].write("result" + sample_id[i])
